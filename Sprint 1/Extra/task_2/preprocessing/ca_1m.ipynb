# %% [markdown]
# # California 1m - Chunk 1

# %%
from pathlib import Path

ca_1m_dir = Path("../datasets/california_tiffs/ca_1m/chunk_1")
ca_1m_dir
# Out:
# WindowsPath('../datasets/california_tiffs/ca_1m/chunk_1')

# %%
import os

check_fp = os.listdir()
len(check_fp)
# Out:
# 3

# %%
# !pip install tiffile

# %%
import tiffile
import numpy as np

images = tiffile.imread("Landsat_Composite_1984_1984_26-02-19-16-51-11.tif")
if (images != -32768).sum() > 0:
    print(1)

# %%
images
# Out:
# array([[[-32768, -32768, -32768, -32768, -32768, -32768],
#         [-32768, -32768, -32768, -32768, -32768, -32768],
#         [-32768, -32768, -32768, -32768, -32768, -32768],
#         ...,
#         [-32768, -32768, -32768, -32768, -32768, -32768],
#         [-32768, -32768, -32768, -32768, -32768, -32768],
#         [-32768, -32768, -32768, -32768, -32768, -32768]],
#
#        [[-32768, -32768, -32768, -32768, -32768, -32768],
#         [-32768, -32768, -32768, -32768, -32768, -32768],
#         [-32768, -32768, -32768, -32768, -32768, -32768],
#         ...,
#         [-32768, -32768, -32768, -32768, -32768, -32768],
#         [-32768, -32768, -32768, -32768, -32768, -32768],
#         [-32768, -32768, -32768, -32768, -32768, -32768]],
#
#        [[-32768, -32768, -32768, -32768, -32768, -32768],
#         [-32768, -32768, -32768, -32768, -32768, -32768],
#         [-32768, -32768, -32768, -32768, -32768, -32768],
#         ...,
# ...
