# %% [markdown]
# # Setup

# %%
import sys
from pathlib import Path

repo_root = Path.cwd()
while not ((repo_root / "Final").exists() and (repo_root / "Sprint 3").exists()):
    if repo_root.parent == repo_root:
        raise RuntimeError("Could not locate repo root.")
    repo_root = repo_root.parent

if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

import json
from dataclasses import dataclass, field, asdict
from enum import Enum
from typing import Any

import pandas as pd

from Final.config import default_config
from Final.paths import FINAL_ROOT
from Final.shared_utils import setup_logging, get_logger

# %%
cfg = default_config()

logger = setup_logging(
    name="shrub",
    log_dir=cfg.output.logs_root,
    log_filename="main_pipeline.log",
    force=True,
)

logger.info("Initialized main pipeline notebook.")
logger.info("FINAL_ROOT = %s", FINAL_ROOT)

MAIN_OUTPUT_ROOT = cfg.output.root / "main"
MAIN_OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

MAIN_MANIFEST_DIR = MAIN_OUTPUT_ROOT / "manifests"
MAIN_MANIFEST_DIR.mkdir(parents=True, exist_ok=True)
# Out:
# 2026-04-10 04:38:21 | INFO     | shrub | Initialized main pipeline notebook.
# 2026-04-10 04:38:21 | INFO     | shrub | FINAL_ROOT = /home/jovyan/work/Dry-shRub/shrub/Final

# %% [markdown]
# # Framework

# %%
class PipelineDomain(str, Enum):
    LABELING = "label_engineering"
    FEATURES = "feature_engineering"
    MODELING = "modeling"
    POSTPROCESSING = "postprocessing"
    SHARED = "shared"


class RepresentationTarget(str, Enum):
    RASTER = "raster"
    OBJECT = "object"
    BOTH = "both"


class SpatialScope(str, Enum):
    PIXEL = "pixel-level"
    OBJECT = "object-level"
    PATCH = "patch-level"
    SITE = "site-level"


class ResolutionScope(str, Enum):
    NATIVE = "native_only"
    MULTI = "multi_resolution"
    COARSE = "coarse_only_prior"


class AvailabilityTier(str, Enum):
    UNIVERSAL = "universal"
    MOST = "most_sites"
    PARTIAL = "partial_site_conditional"


class RuntimeTier(str, Enum):
    CHEAP = "cheap"
    MODERATE = "moderate"
    EXPENSIVE = "expensive"


class ModuleStatus(str, Enum):
    CANDIDATE = "candidate"
    EXPERIMENTAL = "experimental"
    PROMOTED = "promoted"
    REJECTED = "rejected"

# %%
@dataclass
class ModuleCard:
    name: str
    domain: PipelineDomain
    representation_target: RepresentationTarget
    spatial_scope: SpatialScope
    resolution_scope: ResolutionScope
    availability_tier: AvailabilityTier
    runtime_tier: RuntimeTier

    description: str
    inputs_required: list[str] = field(default_factory=list)
    outputs_produced: list[str] = field(default_factory=list)

    strengths: list[str] = field(default_factory=list)
    weaknesses: list[str] = field(default_factory=list)
    notes: list[str] = field(default_factory=list)

    status: ModuleStatus = ModuleStatus.CANDIDATE

    gate_coverage: str | None = None
    gate_alignment: str | None = None
    gate_information: str | None = None
    gate_resource: str | None = None
    gate_robustness: str | None = None

    coverage_score: float | None = None
    alignment_score: float | None = None
    information_score: float | None = None
    resource_score: float | None = None
    robustness_score: float | None = None

    evidence: dict[str, Any] = field(default_factory=dict)

# %%
@dataclass
class ExperimentState:
    experiment_name: str
    active_modules: list[str]
    notes: str = ""

    # these get filled in as sections run
    raster_outputs: dict[str, Any] = field(default_factory=dict)
    object_outputs: dict[str, Any] = field(default_factory=dict)
    qa_outputs: dict[str, Any] = field(default_factory=dict)

    section_status: dict[str, str] = field(default_factory=dict)

# %%
MODULE_REGISTRY: dict[str, ModuleCard] = {
    "labeling.base_sprint3_revised": ModuleCard(
        name="labeling.base_sprint3_revised",
        domain=PipelineDomain.LABELING,
        representation_target=RepresentationTarget.OBJECT,
        spatial_scope=SpatialScope.OBJECT,
        resolution_scope=ResolutionScope.NATIVE,
        availability_tier=AvailabilityTier.UNIVERSAL,
        runtime_tier=RuntimeTier.MODERATE,
        description="Base Sprint 3 revised shrub-object extraction from TLS.",
        inputs_required=["PTX", "R scripts"],
        outputs_produced=["shrub object table", "metrics", "fuels raster"],
        strengths=["Produces shrub-object supervision", "Site-agnostic execution"],
        weaknesses=["Heuristic", "May vary across sites"],
    ),
    "labeling.base_sprint4_transfer": ModuleCard(
        name="labeling.base_sprint4_transfer",
        domain=PipelineDomain.LABELING,
        representation_target=RepresentationTarget.BOTH,
        spatial_scope=SpatialScope.OBJECT,
        resolution_scope=ResolutionScope.MULTI,
        availability_tier=AvailabilityTier.MOST,
        runtime_tier=RuntimeTier.MODERATE,
        description="Base Sprint 4 transfer from TLS shrub objects into NAIP-aligned masks.",
        inputs_required=["Sprint 3 objects", "ALS metadata", "transform files", "NAIP"],
        outputs_produced=["mask rasters", "confidence rasters", "object tables", "QA overlays"],
        strengths=["Creates scalable raster labels", "Supports multires export"],
        weaknesses=["Transform-sensitive", "Current footprint geometry is crude"],
    ),
    "features.naip_raw": ModuleCard(
        name="features.naip_raw",
        domain=PipelineDomain.FEATURES,
        representation_target=RepresentationTarget.RASTER,
        spatial_scope=SpatialScope.PIXEL,
        resolution_scope=ResolutionScope.NATIVE,
        availability_tier=AvailabilityTier.UNIVERSAL,
        runtime_tier=RuntimeTier.CHEAP,
        description="Raw NAIP bands as appearance features.",
        inputs_required=["NAIP"],
        outputs_produced=["raster stack"],
        strengths=["Universal", "Direct image signal"],
        weaknesses=["No explicit structure"],
    ),
    "features.als_structure": ModuleCard(
        name="features.als_structure",
        domain=PipelineDomain.FEATURES,
        representation_target=RepresentationTarget.RASTER,
        spatial_scope=SpatialScope.PIXEL,
        resolution_scope=ResolutionScope.MULTI,
        availability_tier=AvailabilityTier.MOST,
        runtime_tier=RuntimeTier.MODERATE,
        description="ALS-derived structure/height features.",
        inputs_required=["ALS"],
        outputs_produced=["height/roughness rasters"],
        strengths=["Adds structure", "Helpful for shrub-vs-tree distinction"],
        weaknesses=["Extra processing", "Site coverage may vary"],
    ),
}

# %%
state = ExperimentState(
    experiment_name="main_scaffold_v1",
    active_modules=[
        "labeling.base_sprint3_revised",
        "labeling.base_sprint4_transfer",
        # features not yet executed, but can still be registered
        "features.naip_raw",
        "features.als_structure",
    ],
    notes="Generic scalability framework scaffold before full multi-section integration.",
)

state
# Out:
# ExperimentState(experiment_name='main_scaffold_v1', active_modules=['labeling.base_sprint3_revised', 'labeling.base_sprint4_transfer', 'features.naip_raw', 'features.als_structure'], notes='Generic scalability framework scaffold before full multi-section integration.', raster_outputs={}, object_outputs={}, qa_outputs={}, section_status={})

# %%
def initialize_canonical_outputs(state: ExperimentState) -> ExperimentState:
    state.raster_outputs = {
        "labels": None,
        "features": None,
        "predictions": None,
        "qa_overlays": None,
    }
    state.object_outputs = {
        "objects": None,
        "predicted_objects": None,
        "source_provenance": None,
        "quality_flags": None,
    }
    state.qa_outputs = {}
    return state


state = initialize_canonical_outputs(state)
state
# Out:
# ExperimentState(experiment_name='main_scaffold_v1', active_modules=['labeling.base_sprint3_revised', 'labeling.base_sprint4_transfer', 'features.naip_raw', 'features.als_structure'], notes='Generic scalability framework scaffold before full multi-section integration.', raster_outputs={'labels': None, 'features': None, 'predictions': None, 'qa_overlays': None}, object_outputs={'objects': None, 'predicted_objects': None, 'source_provenance': None, 'quality_flags': None}, qa_outputs={}, section_status={})

# %%
def evaluate_coverage_gate(module: ModuleCard) -> tuple[str, float]:
    mapping = {
        AvailabilityTier.UNIVERSAL: ("pass", 1.0),
        AvailabilityTier.MOST: ("conditional_pass", 0.75),
        AvailabilityTier.PARTIAL: ("warning", 0.4),
    }
    return mapping[module.availability_tier]


def evaluate_resource_gate(module: ModuleCard) -> tuple[str, float]:
    mapping = {
        RuntimeTier.CHEAP: ("pass", 1.0),
        RuntimeTier.MODERATE: ("conditional_pass", 0.7),
        RuntimeTier.EXPENSIVE: ("warning", 0.35),
    }
    return mapping[module.runtime_tier]


def evaluate_alignment_gate(module: ModuleCard) -> tuple[str, float]:
    # scaffold placeholder; later this should consume actual outputs
    if module.representation_target in {RepresentationTarget.RASTER, RepresentationTarget.BOTH}:
        return "pass", 0.8
    return "conditional_pass", 0.7


def evaluate_information_gate(module: ModuleCard) -> tuple[str, float]:
    # scaffold placeholder; later this should use actual ablations / QA
    if "structure" in module.name or "transfer" in module.name:
        return "conditional_pass", 0.75
    return "pass", 0.8


def evaluate_robustness_gate(module: ModuleCard) -> tuple[str, float]:
    # scaffold placeholder; later this should use cross-site evidence
    if module.availability_tier == AvailabilityTier.PARTIAL:
        return "warning", 0.45
    return "conditional_pass", 0.7

def evaluate_module_card(module: ModuleCard) -> ModuleCard:
    module.gate_coverage, module.coverage_score = evaluate_coverage_gate(module)
    module.gate_alignment, module.alignment_score = evaluate_alignment_gate(module)
    module.gate_information, module.information_score = evaluate_information_gate(module)
    module.gate_resource, module.resource_score = evaluate_resource_gate(module)
    module.gate_robustness, module.robustness_score = evaluate_robustness_gate(module)
    return module


evaluated_modules = {}
for name in state.active_modules:
    evaluated_modules[name] = evaluate_module_card(MODULE_REGISTRY[name])

evaluated_modules
# Out:
# {'labeling.base_sprint3_revised': ModuleCard(name='labeling.base_sprint3_revised', domain=<PipelineDomain.LABELING: 'label_engineering'>, representation_target=<RepresentationTarget.OBJECT: 'object'>, spatial_scope=<SpatialScope.OBJECT: 'object-level'>, resolution_scope=<ResolutionScope.NATIVE: 'native_only'>, availability_tier=<AvailabilityTier.UNIVERSAL: 'universal'>, runtime_tier=<RuntimeTier.MODERATE: 'moderate'>, description='Base Sprint 3 revised shrub-object extraction from TLS.', inputs_required=['PTX', 'R scripts'], outputs_produced=['shrub object table', 'metrics', 'fuels raster'], strengths=['Produces shrub-object supervision', 'Site-agnostic execution'], weaknesses=['Heuristic', 'May vary across sites'], notes=[], status=<ModuleStatus.CANDIDATE: 'candidate'>, gate_coverage='pass', gate_alignment='conditional_pass', gate_information='pass', gate_resource='conditional_pass', gate_robustness='conditional_pass', coverage_score=1.0, alignment_score=0.7, information_score=0.8, 
# ...

# %%
def decide_module_status(module: ModuleCard) -> ModuleStatus:
    scores = [
        module.coverage_score or 0.0,
        module.alignment_score or 0.0,
        module.information_score or 0.0,
        module.resource_score or 0.0,
        module.robustness_score or 0.0,
    ]
    avg_score = sum(scores) / len(scores)

    if avg_score >= 0.85:
        return ModuleStatus.PROMOTED
    if avg_score >= 0.65:
        return ModuleStatus.EXPERIMENTAL
    if avg_score >= 0.45:
        return ModuleStatus.CANDIDATE
    return ModuleStatus.REJECTED


for module in evaluated_modules.values():
    module.status = decide_module_status(module)

# %%
summary_rows = []
for module in evaluated_modules.values():
    summary_rows.append(
        {
            "name": module.name,
            "domain": module.domain.value,
            "representation_target": module.representation_target.value,
            "availability_tier": module.availability_tier.value,
            "runtime_tier": module.runtime_tier.value,
            "gate_coverage": module.gate_coverage,
            "gate_alignment": module.gate_alignment,
            "gate_information": module.gate_information,
            "gate_resource": module.gate_resource,
            "gate_robustness": module.gate_robustness,
            "coverage_score": module.coverage_score,
            "alignment_score": module.alignment_score,
            "information_score": module.information_score,
            "resource_score": module.resource_score,
            "robustness_score": module.robustness_score,
            "status": module.status.value,
        }
    )

module_summary_df = pd.DataFrame(summary_rows).sort_values(["domain", "name"])
display(module_summary_df)
# Out:
#                              name               domain representation_target  \
# 3          features.als_structure  feature_engineering                raster
# 2               features.naip_raw  feature_engineering                raster
# 0   labeling.base_sprint3_revised    label_engineering                object
# 1  labeling.base_sprint4_transfer    label_engineering                  both
#
#   availability_tier runtime_tier     gate_coverage    gate_alignment  \
# 3        most_sites     moderate  conditional_pass              pass
# 2         universal        cheap              pass              pass
# 0         universal     moderate              pass  conditional_pass
# 1        most_sites     moderate  conditional_pass              pass
#
#    gate_information     gate_resource   gate_robustness  coverage_score  \
# 3  conditional_pass  conditional_pass  conditional_pass            0.75
# 2              pass              pass  conditional_pass            1.00
# ...

# %%
registry_json = MAIN_MANIFEST_DIR / f"{state.experiment_name}_module_registry.json"
summary_csv = MAIN_MANIFEST_DIR / f"{state.experiment_name}_module_summary.csv"
state_json = MAIN_MANIFEST_DIR / f"{state.experiment_name}_state.json"

registry_payload = {name: asdict(card) for name, card in evaluated_modules.items()}
registry_json.write_text(json.dumps(registry_payload, indent=2, default=str), encoding="utf-8")
module_summary_df.to_csv(summary_csv, index=False)
state_json.write_text(json.dumps(asdict(state), indent=2, default=str), encoding="utf-8")

print("Saved:")
print(registry_json)
print(summary_csv)
print(state_json)
# Out:
# Saved:
# /home/jovyan/work/Dry-shRub/shrub/Final/artifacts/main/manifests/main_scaffold_v1_module_registry.json
# /home/jovyan/work/Dry-shRub/shrub/Final/artifacts/main/manifests/main_scaffold_v1_module_summary.csv
# /home/jovyan/work/Dry-shRub/shrub/Final/artifacts/main/manifests/main_scaffold_v1_state.json

# %% [markdown]
# ## Labeling

# %% [markdown]
# ## Features
