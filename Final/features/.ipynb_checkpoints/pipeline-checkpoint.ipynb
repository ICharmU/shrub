# %% [markdown]
# ## Architectural principles
#
# The FE pipeline should follow these rules:
#
# 1. **One canonical raster space**
#    - source-aligned features
#    - modeling-ready raster stack
#    - patch export / chunk manifests
#
# 2. **One canonical object space**
#    - shrub objects from labeling
#    - aggregated feature summaries
#    - provenance / confidence / QA fields
#
# 3. **Chunk is the primary compute unit**
#    - not whole-site full-raster computation by default
#
# 4. **Manifest-first resume**
#    - stages and families write manifests
#    - large artifacts may be pushed remotely and pruned locally
#
# 5. **Source-agnostic processing**
#    - each source follows the same ingest → align → family → finalize contract
#
# 6. **Notebook functions should migrate cleanly to pipeline.py**

# %% [markdown]
# # Setup

# %%
# Must run on new server launch
#!pip install -r requirements.txt
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import sys
from pathlib import Path

repo_root = Path.cwd()
while not ((repo_root / "Final").exists() and (repo_root / "Sprint 3").exists()):
    if repo_root.parent == repo_root:
        raise RuntimeError("Could not locate repo root.")
    repo_root = repo_root.parent

if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))


from __future__ import annotations

import json
import math
import os
import logging
import shutil
import tempfile
import time
import warnings
from collections import defaultdict
from contextlib import contextmanager
from dataclasses import dataclass, field, asdict
from pathlib import Path
from typing import Any, Iterable

from pyproj import Transformer
import ee
import geemap
import folium
import numpy as np
import pandas as pd
import rasterio
from rasterio.enums import Resampling
from rasterio.transform import Affine
from rasterio.windows import Window
from rasterio.warp import reproject
from rasterio.crs import CRS
from rasterio.warp import transform_bounds
from rasterio.merge import merge as rio_merge
from rasterio.transform import from_origin

import laspy
print(laspy.__version__)
print(laspy.LazBackend.detect_available())

import pdal
import open3d as o3d
from scipy.spatial import cKDTree
from scipy.stats import binned_statistic_2d
from scipy.ndimage import distance_transform_edt, minimum_filter
import plotly.graph_objects as go

pd.set_option("display.max_columns", 200)
pd.set_option("display.max_rows", 200)
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=UserWarning)

from Final.config import default_config
from Final.models import (
    PipelineDomain,
    RepresentationTarget,
    SpatialScope,
    ResolutionScope,
    AvailabilityTier,
    RuntimeTier,
    ModuleCard,
    PipelineSpec,
    StageSpec,
    ModuleSpec,
    SearchAxis,
    CachePolicy,
    CacheRetentionMode,
    ArtifactSpec,
    StorageTier,
    CanonicalRasterOutputs,
    CanonicalObjectOutputs,
)
from Final.pipeline_caching import (
    hash_payload,
    write_stage_cache_manifest,
    read_stage_cache_manifest,
    is_valid_stage_cache,
)
from Final.artifact_store import (
    LocalArtifactStore,
    DriveRegistryArtifactStore,
    HybridArtifactStore,
)

from Final.labeling.io import download_file, extract_als_metadata
from Final.labeling.manifests import list_files_with_suffix, site_to_remote_base, site_to_tif_name

from Final.features.fe_2d import (
    get_color_diff,
    get_entropy_feature,
    get_fast_lbp_texture,
    get_fractal_dimension_map,
    get_granulometry_features,
    get_ldp_feature,
    get_uniform_blur,
    get_wavelet_features,
    fast_cpu_gabor,
)
from scipy.ndimage import grey_opening, grey_closing

from Final.features.fe_3dep import (
    get_slope_and_aspect,
    get_northness_eastness,
    get_curvature,
    get_ruggedness,
    get_tpi,
    get_exposure_proxies,
)

from Final.features.fe_rap import (
    get_surrounding_shrub_fraction,
    get_broad_vegetation_composition,
    extract_coarse_vegetation_prior,
)

from Final.features.fe_als import (
    calculate_distance_to_tall_canopy,
    calculate_height_above_ground,
    calculate_knn_node_metrics,
    calculate_local_relief,
    calculate_roughness_knn,
    calculate_surface_angle,
    classify_vegetation_rules,
    create_height_rasters
)

cfg = default_config()
cfg.ensure_dirs()


LOGGER = logging.getLogger("features.notebook")
if not LOGGER.handlers:
    logging.basicConfig(
        level=logging.INFO,
        format="%(asctime)s | %(levelname)-8s | %(name)s | %(message)s",
    )

cfg.output.features_root.mkdir(parents=True, exist_ok=True)
cfg.output.logs_root.mkdir(parents=True, exist_ok=True)

print("Sites:", cfg.sites)
print("Project root:", cfg.data.project_root)
print("Features root:", cfg.output.features_root)
print("Canonical grid source:", cfg.features.canonical_grid_source)
print("Object table enabled:", cfg.features.object_table_enabled)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 2.7.0
# (<LazBackend.LazrsParallel: 0>, <LazBackend.Lazrs: 1>)
# Sites: ['calaveras-big-trees', 'dl-bliss', 'independence-lake', 'pacific-union-college', 'sedgwick', 'shaver-lake']
# Project root: /home/jovyan/work/Dry-shRub/shrub
# Features root: /home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features
# Canonical grid source: naip
# Object table enabled: True

# %% [markdown]
# # Run Context

# %%
NOTEBOOK_VERSION = "fe_notebook"

DEFAULT_SOURCE_ORDER = ("naip", "als", "3dep", "rap")

DEFAULT_FAMILY_ORDER = {
    "naip": (
        "raw",
        "veg_idx",
        "texture",
        "multiscale",
        "color_diff",
        "granulometry",
        "fractal",
        "wavelet",
        "gabor",
        "ldp",
        "morphology",
    ),
    "als": ("height_structure"),
    "3dep": ("terrain"),
    "rap": ("prior",),
}

@dataclass
class TimingConfig:
    enabled: bool = True
    log_start_end: bool = True
    warn_if_seconds_over: float = 30.0
    enable_rate_tracking: bool = True
    extrapolation_unit: str = "megapixels"


@dataclass
class ChunkingConfig:
    enabled: bool = True
    chunk_size_px: int = 1024
    halo_px_default: int = 32
    allow_full_raster_fallback: bool = True
    materialize_full_rasters_by_default: bool = False


@dataclass
class StorageConfig:
    enable_local_store: bool = True
    enable_drive_store: bool = False
    use_hybrid_store: bool = False

    local_storage_root: Path = cfg.output.features_root / "artifact_store_local"
    drive_registry_path: Path = cfg.data.project_root / "Final" / "artifact_registry.yaml"
    drive_config_path: Path = cfg.data.project_root / "drive_config.yaml"
    client_secrets_path: Path = cfg.data.project_root / "client_secrets.json"
    credentials_path: Path = cfg.data.project_root / "pydrive_credentials.json"

    fail_if_drive_missing: bool = False


@dataclass
class PersistenceConfig:
    persist_manifests: bool = True
    persist_chunk_outputs: bool = True
    persist_family_outputs: bool = True
    persist_stack_registry: bool = True
    persist_object_tables: bool = True
    write_runtime_csv: bool = True
    write_summary_csvs: bool = True

    push_large_artifacts_to_remote: bool = False
    prune_local_after_remote_push: bool = False
    verify_remote_before_prune: bool = True


@dataclass
class ObjectAggregationConfig:
    enabled: bool = True
    include_centroid_sample: bool = True
    centroid_only: bool = False
    square_window_radius_px: int = 3
    use_radius_scaled_window: bool = True
    min_radius_px: int = 2
    max_radius_px: int = 12
    stats: tuple[str, ...] = ("mean", "std", "min", "max")


@dataclass
class NAIPFamilyConfig:
    enabled_families: tuple[str, ...] = ("raw", "veg_idx", "texture", "multiscale")
    heavy_families_enabled: tuple[str, ...] = ()

    texture_entropy_window: int = 9
    texture_lbp_radius: int = 2
    texture_blur_sizes: tuple[int, ...] = (5, 11)

    multiscale_sizes: tuple[int, ...] = (3, 7, 15)

    granulometry_scales: tuple[int, ...] = (3, 5, 7, 11)
    fractal_scales: tuple[int, ...] = (3, 5, 7, 9)
    wavelet_type: str = "db2"
    wavelet_level: int = 2
    gabor_frequencies: tuple[float, ...] = (0.1, 0.2)
    gabor_thetas: tuple[float, ...] = (0.0, math.pi / 4, math.pi / 2, 3 * math.pi / 4)
    ldp_k: int = 3
    morphology_window_sizes: tuple[int, ...] = (3, 7, 11)

    quantize_for_texture: bool = True
    quantize_levels: int = 256
    base_band_preference: tuple[str, ...] = ("nir", "green", "red", "blue")


@dataclass
class ALSFamilyConfig:
    enabled_families: tuple[str, ...] = ("height_structure",)
    heavy_families_enabled: tuple[str, ...] = ()

    structural_raster_resolution_m: float = 1.0
    tall_canopy_threshold_m: float = 5.0
    local_relief_window_px: int = 5
    knn_k: int = 30


@dataclass
class TerrainFamilyConfig:
    enabled_families: tuple[str, ...] = ("terrain",)
    heavy_families_enabled: tuple[str, ...] = ()
    ruggedness_kernel_radius: int = 3
    tpi_radius_meters: int = 150
    hillshade_azimuth: int = 270
    hillshade_zenith: int = 45


@dataclass
class RAPFamilyConfig:
    enabled_families: tuple[str, ...] = ("prior",)
    context_radius_meters: int = 500


@dataclass
class NotebookFEConfig:
    sites: list[str] = field(default_factory=lambda: list(cfg.sites))
    enabled_sources: dict[str, bool] = field(
        default_factory=lambda: {k: True for k in DEFAULT_SOURCE_ORDER}
    )
    source_order: tuple[str, ...] = DEFAULT_SOURCE_ORDER

    canonical_grid_source: str = cfg.features.canonical_grid_source
    object_table_enabled: bool = cfg.features.object_table_enabled

    force_refresh_assets: bool = False
    force_refresh_features: bool = False
    force_refresh_objects: bool = False
    force_rebuild_chunk_manifest: bool = False

    timing: TimingConfig = field(default_factory=TimingConfig)
    chunking: ChunkingConfig = field(default_factory=ChunkingConfig)
    storage: StorageConfig = field(default_factory=StorageConfig)
    persistence: PersistenceConfig = field(default_factory=PersistenceConfig)
    object_agg: ObjectAggregationConfig = field(default_factory=ObjectAggregationConfig)

    naip: NAIPFamilyConfig = field(default_factory=NAIPFamilyConfig)
    als: ALSFamilyConfig = field(default_factory=ALSFamilyConfig)
    terrain: TerrainFamilyConfig = field(default_factory=TerrainFamilyConfig)
    rap: RAPFamilyConfig = field(default_factory=RAPFamilyConfig)

    cache_root: Path = cfg.output.features_root / "notebook_cache"
    summary_root: Path = cfg.output.features_root / "notebook_summaries"
    qa_root: Path = cfg.output.features_root / "notebook_qa"

    version: str = NOTEBOOK_VERSION

    def resolve(self) -> "NotebookFEConfig":
        self.cache_root = Path(self.cache_root).resolve()
        self.summary_root = Path(self.summary_root).resolve()
        self.qa_root = Path(self.qa_root).resolve()
        self.storage.local_storage_root = Path(self.storage.local_storage_root).resolve()

        for root in [
            self.cache_root,
            self.summary_root,
            self.qa_root,
            self.storage.local_storage_root,
        ]:
            root.mkdir(parents=True, exist_ok=True)

        return self


fe_cfg = NotebookFEConfig().resolve()
LOGGER.info("Resolved notebook FE config")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 2026-04-17 10:55:36,121 | INFO     | features.notebook | Resolved notebook FE config

# %%
RUNTIME_LOGS: list[dict[str, Any]] = []
RUNTIME_ACCUM = defaultdict(list)


def log_info(msg: str, *args):
    LOGGER.info(msg, *args)


def stable_json(payload: dict[str, Any]) -> str:
    return json.dumps(payload, sort_keys=True, default=str)


def config_signature(payload: dict[str, Any]) -> str:
    return hash_payload(payload)


def fe_config_signature() -> str:
    return config_signature(asdict(fe_cfg))


def runtime_frame() -> pd.DataFrame:
    return pd.DataFrame(RUNTIME_LOGS) if RUNTIME_LOGS else pd.DataFrame()


def array_megapixels(arr: np.ndarray) -> float:
    return float(arr.shape[0] * arr.shape[1]) / 1_000_000.0


def estimate_remaining_time(stage_name: str, remaining_units: float) -> float | None:
    rows = RUNTIME_ACCUM.get(stage_name, [])
    rates = [
        r["sec_per_unit"]
        for r in rows
        if np.isfinite(r.get("sec_per_unit", np.nan))
    ]
    if not rates:
        return None
    return float(np.mean(rates) * remaining_units)


@contextmanager
def timed_stage(
    stage_name: str,
    *,
    site_id: str | None = None,
    source_name: str | None = None,
    family_name: str | None = None,
    unit_amount: float | None = None,
    extra: dict[str, Any] | None = None,
):
    start = time.perf_counter()

    if fe_cfg.timing.log_start_end:
        log_info(
            "START | stage=%s | site=%s | source=%s | family=%s",
            stage_name, site_id, source_name, family_name
        )

    try:
        yield
    finally:
        duration = time.perf_counter() - start
        sec_per_unit = duration / unit_amount if (unit_amount is not None and unit_amount > 0) else np.nan

        row = {
            "stage_name": stage_name,
            "site_id": site_id,
            "source_name": source_name,
            "family_name": family_name,
            "duration_sec": duration,
            "unit_amount": unit_amount,
            "sec_per_unit": sec_per_unit,
            **(extra or {}),
        }
        RUNTIME_LOGS.append(row)
        RUNTIME_ACCUM[stage_name].append(row)

        suffix = ""
        if np.isfinite(sec_per_unit):
            suffix = f" | sec_per_unit={sec_per_unit:.4f}"

        log_info(
            "END   | stage=%s | site=%s | source=%s | family=%s | duration=%.2fs%s",
            stage_name, site_id, source_name, family_name, duration, suffix
        )

        if duration >= fe_cfg.timing.warn_if_seconds_over:
            log_info(
                "SLOW  | stage=%s | duration=%.2fs exceeded threshold=%.2fs",
                stage_name, duration, fe_cfg.timing.warn_if_seconds_over
            )


print("FE config signature:", fe_config_signature())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# FE config signature: b37e6b6ed0a9f107

# %% [markdown]
# ## Artifact Storage

# %%
def validate_drive_files(storage_cfg: StorageConfig) -> pd.DataFrame:
    rows = []
    for label, path in [
        ("client_secrets.json", storage_cfg.client_secrets_path),
        ("drive_config.yaml", storage_cfg.drive_config_path),
        ("pydrive_credentials.json", storage_cfg.credentials_path),
    ]:
        rows.append(
            {
                "file": label,
                "path": str(path),
                "exists": Path(path).exists(),
            }
        )
    return pd.DataFrame(rows)


def build_local_artifact_store(storage_cfg: StorageConfig) -> LocalArtifactStore:
    return LocalArtifactStore(
        repo_root=cfg.data.project_root,
        storage_root=storage_cfg.local_storage_root,
    )


def maybe_build_drive_artifact_store(storage_cfg: StorageConfig) -> DriveRegistryArtifactStore | None:
    if not storage_cfg.enable_drive_store:
        return None

    missing = []
    for p in [storage_cfg.client_secrets_path, storage_cfg.drive_config_path]:
        if not Path(p).exists():
            missing.append(str(p))

    if missing:
        msg = f"Missing Drive config files: {missing}"
        if storage_cfg.fail_if_drive_missing:
            raise FileNotFoundError(msg)
        LOGGER.warning(msg)
        return None

    return DriveRegistryArtifactStore(
        repo_root=cfg.data.project_root,
        registry_path=storage_cfg.drive_registry_path,
        drive_config_path=storage_cfg.drive_config_path,
        client_secrets_path=storage_cfg.client_secrets_path,
        credentials_path=storage_cfg.credentials_path,
    )


def build_artifact_store(storage_cfg: StorageConfig):
    local_store = build_local_artifact_store(storage_cfg)
    drive_store = maybe_build_drive_artifact_store(storage_cfg)

    if storage_cfg.use_hybrid_store and drive_store is not None:
        LOGGER.info("Using HybridArtifactStore")
        return HybridArtifactStore(local_store=local_store, remote_store=drive_store)

    if drive_store is not None and not storage_cfg.enable_local_store:
        LOGGER.info("Using DriveRegistryArtifactStore only")
        return drive_store

    LOGGER.info("Using LocalArtifactStore only")
    return local_store


artifact_store = build_artifact_store(fe_cfg.storage)

display(validate_drive_files(fe_cfg.storage))
print("Artifact store type:", type(artifact_store).__name__)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 2026-04-17 10:55:37,625 | INFO     | features.notebook | Using LocalArtifactStore only
#                        file  \
# 0       client_secrets.json
# 1         drive_config.yaml
# 2  pydrive_credentials.json
#
#                                                 path  exists
# 0  /home/jovyan/work/Dry-shRub/shrub/client_secre...    True
# 1  /home/jovyan/work/Dry-shRub/shrub/drive_config...    True
# 2  /home/jovyan/work/Dry-shRub/shrub/pydrive_cred...    True
# Artifact store type: LocalArtifactStore

# %%
def drive_root_id_from_config(path: str | Path) -> str | None:
    path = Path(path)
    if not path.exists():
        return None
    try:
        import yaml
        payload = yaml.safe_load(path.read_text(encoding="utf-8")) or {}
        return payload.get("drive_root_folder_id")
    except Exception as e:
        LOGGER.warning("Failed reading drive config %s: %s", path, e)
        return None


def drive_status_frame(storage_cfg: StorageConfig) -> pd.DataFrame:
    rows = []

    rows.append(
        {
            "check": "client_secrets_exists",
            "value": Path(storage_cfg.client_secrets_path).exists(),
            "detail": str(storage_cfg.client_secrets_path),
        }
    )
    rows.append(
        {
            "check": "drive_config_exists",
            "value": Path(storage_cfg.drive_config_path).exists(),
            "detail": str(storage_cfg.drive_config_path),
        }
    )
    rows.append(
        {
            "check": "credentials_exists",
            "value": Path(storage_cfg.credentials_path).exists(),
            "detail": str(storage_cfg.credentials_path),
        }
    )
    rows.append(
        {
            "check": "drive_root_folder_id_present",
            "value": drive_root_id_from_config(storage_cfg.drive_config_path) is not None,
            "detail": str(drive_root_id_from_config(storage_cfg.drive_config_path)),
        }
    )

    return pd.DataFrame(rows)


display(drive_status_frame(fe_cfg.storage))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                           check  value  \
# 0         client_secrets_exists   True
# 1           drive_config_exists   True
# 2            credentials_exists   True
# 3  drive_root_folder_id_present   True
#
#                                               detail
# 0  /home/jovyan/work/Dry-shRub/shrub/client_secre...
# 1  /home/jovyan/work/Dry-shRub/shrub/drive_config...
# 2  /home/jovyan/work/Dry-shRub/shrub/pydrive_cred...
# 3                  1F9AtiUfx_z48tQIkNbDpzZUpH6R5uoCN

# %%
def smoke_test_artifact_store_roundtrip(store, *, rel_path: str = "features/_smoke_test/roundtrip.txt") -> dict[str, Any]:
    temp_dir = Path(tempfile.mkdtemp(prefix="fe_artifact_smoke_"))
    local_path = temp_dir / "roundtrip.txt"
    local_path.write_text("artifact store smoke test", encoding="utf-8")

    result = {
        "store_type": type(store).__name__,
        "rel_path": rel_path,
        "push_ok": False,
        "pull_ok": False,
        "content_match": False,
        "remote_ref": None,
        "pulled_path": None,
    }

    try:
        remote_ref = store.push(local_path, rel_path=rel_path)
        result["push_ok"] = True
        result["remote_ref"] = remote_ref

        local_path.unlink(missing_ok=True)

        pulled_path = store.pull(rel_path, local_path=local_path)
        result["pull_ok"] = True
        result["pulled_path"] = str(pulled_path)

        content = Path(pulled_path).read_text(encoding="utf-8")
        result["content_match"] = (content == "artifact store smoke test")
    except Exception as e:
        result["error"] = str(e)
    finally:
        try:
            shutil.rmtree(temp_dir, ignore_errors=True)
        except Exception:
            pass

    return result


#smoke_result = smoke_test_artifact_store_roundtrip(artifact_store)
#display(pd.DataFrame([smoke_result]))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# # Contracts

# %%
@dataclass
class SiteAssetBundle:
    site_id: str
    source_assets: dict[str, Any] = field(default_factory=dict)
    notes: list[str] = field(default_factory=list)


@dataclass
class CanonicalGrid:
    site_id: str
    width: int
    height: int
    transform: Affine
    crs: Any
    source_name: str
    nodata: float | int | None = None

    @property
    def pixel_size(self) -> tuple[float, float]:
        return abs(self.transform.a), abs(self.transform.e)

    def profile(self, *, dtype: str = "float32", count: int = 1, nodata: float | int | None = None) -> dict[str, Any]:
        return {
            "driver": "GTiff",
            "width": self.width,
            "height": self.height,
            "count": count,
            "dtype": dtype,
            "crs": self.crs,
            "transform": self.transform,
            "nodata": self.nodata if nodata is None else nodata,
        }


@dataclass
class ChunkRecord:
    site_id: str
    chunk_id: str
    row_start: int
    row_end: int
    col_start: int
    col_end: int
    halo_px: int

    @property
    def height(self) -> int:
        return self.row_end - self.row_start

    @property
    def width(self) -> int:
        return self.col_end - self.col_start


@dataclass
class ChunkManifest:
    site_id: str
    chunk_size_px: int
    halo_px_default: int
    records: list[ChunkRecord]


@dataclass
class SourceRasterBundle:
    site_id: str
    source_name: str
    arrays: dict[str, np.ndarray]
    transform: Affine
    crs: Any
    nodata: float | int | None = None
    metadata: dict[str, Any] = field(default_factory=dict)

    @property
    def shape(self) -> tuple[int, int]:
        first = next(iter(self.arrays.values()))
        return first.shape


@dataclass
class FeatureFamilyResult:
    site_id: str
    source_name: str
    family_name: str
    arrays: dict[str, np.ndarray]
    metadata: dict[str, Any] = field(default_factory=dict)


@dataclass
class RasterLayerRecord:
    site_id: str
    source_name: str
    family_name: str
    layer_name: str
    rel_path: str | None = None
    local_path: str | None = None
    remote_ref: str | None = None
    chunked: bool = True
    dtype: str | None = None
    shape: tuple[int, int] | None = None
    notes: list[str] = field(default_factory=list)


@dataclass
class RasterStackRegistry:
    site_id: str
    config_signature: str
    layers: list[RasterLayerRecord] = field(default_factory=list)


@dataclass
class ObjectFeatureRegistry:
    site_id: str
    config_signature: str
    object_table_path: str | None = None
    notes: list[str] = field(default_factory=list)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def ensure_dir(path: str | Path) -> Path:
    path = Path(path)
    path.mkdir(parents=True, exist_ok=True)
    return path


def notebook_cache_root() -> Path:
    return ensure_dir(fe_cfg.cache_root)


def notebook_stage_cache_root(stage_name: str) -> Path:
    return ensure_dir(notebook_cache_root() / stage_name)


def stage_cache_dir(
    *,
    stage_name: str,
    site_id: str,
    source_name: str | None = None,
    data_signature: str | None = None,
    config_signature: str | None = None,
) -> Path:
    root = ensure_dir(notebook_stage_cache_root(stage_name) / site_id)
    if source_name is not None:
        root = ensure_dir(root / source_name)
    if data_signature is not None and config_signature is not None:
        root = ensure_dir(root / f"{data_signature}__{config_signature}")
    return root


def write_json(path: str | Path, payload: dict[str, Any]) -> Path:
    path = Path(path)
    path.parent.mkdir(parents=True, exist_ok=True)
    path.write_text(json.dumps(payload, indent=2, default=str), encoding="utf-8")
    return path


def read_json(path: str | Path) -> dict[str, Any]:
    return json.loads(Path(path).read_text(encoding="utf-8"))


def summarize_array(name: str, arr: np.ndarray) -> dict[str, Any]:
    finite = np.isfinite(arr)
    return {
        "name": name,
        "shape": arr.shape,
        "finite_fraction": float(finite.mean()) if finite.size else np.nan,
        "min": float(np.nanmin(arr)) if finite.any() else np.nan,
        "max": float(np.nanmax(arr)) if finite.any() else np.nan,
        "mean": float(np.nanmean(arr)) if finite.any() else np.nan,
        "std": float(np.nanstd(arr)) if finite.any() else np.nan,
    }


def feature_stack_frame(layer_dict: dict[str, np.ndarray]) -> pd.DataFrame:
    return pd.DataFrame([summarize_array(k, v) for k, v in layer_dict.items()]).sort_values("name").reset_index(drop=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def build_feature_pipeline_spec() -> PipelineSpec:
    modules = {
        "features.site_assets": ModuleSpec(
            key="features.site_assets",
            stage_name="site_assets",
        ),
        "features.canonical_grid": ModuleSpec(
            key="features.canonical_grid",
            stage_name="canonical_grid",
            param_keys=("canonical_grid_source",),
        ),
        "features.chunk_manifest": ModuleSpec(
            key="features.chunk_manifest",
            stage_name="chunk_manifest",
            enabled_key=None,
            param_keys=("chunking",),
        ),
        "features.source_ingest": ModuleSpec(
            key="features.source_ingest",
            stage_name="source_ingest",
            param_keys=("enabled_sources",),
        ),
        "features.source_align": ModuleSpec(
            key="features.source_align",
            stage_name="source_align",
        ),
        "features.family_compute": ModuleSpec(
            key="features.family_compute",
            stage_name="family_compute",
        ),
        "features.stack_finalize": ModuleSpec(
            key="features.stack_finalize",
            stage_name="stack_finalize",
        ),
        "features.object_aggregate": ModuleSpec(
            key="features.object_aggregate",
            stage_name="object_aggregate",
            enabled_key="object_table_enabled",
        ),
        "features.qa_summary": ModuleSpec(
            key="features.qa_summary",
            stage_name="qa_summary",
        ),
    }

    stages = [
        StageSpec(
            name="site_assets",
            module_keys=["features.site_assets"],
            cache_policy=CachePolicy(
                require_manifest=True,
                allow_legacy_reuse=False,
                retention_mode=CacheRetentionMode.LEAN,
            ),
        ),
        StageSpec(
            name="canonical_grid",
            module_keys=["features.canonical_grid"],
            cache_policy=CachePolicy(
                require_manifest=True,
                allow_legacy_reuse=False,
                retention_mode=CacheRetentionMode.LEAN,
            ),
        ),
        StageSpec(
            name="chunk_manifest",
            module_keys=["features.chunk_manifest"],
            cache_policy=CachePolicy(
                require_manifest=True,
                allow_legacy_reuse=False,
                retention_mode=CacheRetentionMode.LEAN,
            ),
        ),
        StageSpec(
            name="source_ingest",
            module_keys=["features.source_ingest"],
            cache_policy=CachePolicy(
                require_manifest=True,
                allow_legacy_reuse=False,
                retention_mode=CacheRetentionMode.LEAN,
            ),
        ),
        StageSpec(
            name="source_align",
            module_keys=["features.source_align"],
            cache_policy=CachePolicy(
                require_manifest=True,
                allow_legacy_reuse=False,
                retention_mode=CacheRetentionMode.LEAN,
            ),
        ),
        StageSpec(
            name="family_compute",
            module_keys=["features.family_compute"],
            cache_policy=CachePolicy(
                require_manifest=True,
                allow_legacy_reuse=False,
                retention_mode=CacheRetentionMode.LEAN,
            ),
        ),
        StageSpec(
            name="stack_finalize",
            module_keys=["features.stack_finalize"],
            cache_policy=CachePolicy(
                require_manifest=True,
                allow_legacy_reuse=False,
                retention_mode=CacheRetentionMode.LEAN,
            ),
        ),
        StageSpec(
            name="object_aggregate",
            module_keys=["features.object_aggregate"],
            cache_policy=CachePolicy(
                require_manifest=True,
                allow_legacy_reuse=False,
                retention_mode=CacheRetentionMode.LEAN,
            ),
        ),
        StageSpec(
            name="qa_summary",
            module_keys=["features.qa_summary"],
            cache_policy=CachePolicy(
                require_manifest=True,
                allow_legacy_reuse=False,
                retention_mode=CacheRetentionMode.MANIFEST_ONLY,
            ),
        ),
    ]

    search_axes = [
        SearchAxis(
            key="canonical_grid_source",
            values=["naip"],
            stage_name="canonical_grid",
            module_key="features.canonical_grid",
        ),
        SearchAxis(
            key="naip_enabled_families",
            values=[("raw", "veg_idx", "texture", "multiscale")],
            stage_name="family_compute",
            module_key="features.family_compute",
        ),
        SearchAxis(
            key="chunk_size_px",
            values=[512, 1024],
            stage_name="chunk_manifest",
            module_key="features.chunk_manifest",
        ),
    ]

    return PipelineSpec(
        pipeline_name="features",
        domain=PipelineDomain.FEATURES,
        stages=stages,
        modules=modules,
        search_axes=search_axes,
    )


FE_PIPELINE_SPEC = build_feature_pipeline_spec()

print("Pipeline:", FE_PIPELINE_SPEC.pipeline_name)
print("Stages:", [s.name for s in FE_PIPELINE_SPEC.stages])
print("Modules:", list(FE_PIPELINE_SPEC.modules.keys()))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Pipeline: features
# Stages: ['site_assets', 'canonical_grid', 'chunk_manifest', 'source_ingest', 'source_align', 'family_compute', 'stack_finalize', 'object_aggregate', 'qa_summary']
# Modules: ['features.site_assets', 'features.canonical_grid', 'features.chunk_manifest', 'features.source_ingest', 'features.source_align', 'features.family_compute', 'features.stack_finalize', 'features.object_aggregate', 'features.qa_summary']

# %%
def pipeline_spec_frame(spec: PipelineSpec) -> pd.DataFrame:
    rows = []
    for stage in spec.stages:
        rows.append(
            {
                "stage_name": stage.name,
                "module_keys": ", ".join(stage.module_keys),
                "require_manifest": stage.cache_policy.require_manifest,
                "allow_legacy_reuse": stage.cache_policy.allow_legacy_reuse,
                "retention_mode": stage.cache_policy.retention_mode.value,
                "prune_after_success": stage.cache_policy.prune_after_success,
            }
        )
    return pd.DataFrame(rows)


display(pipeline_spec_frame(FE_PIPELINE_SPEC))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#          stage_name                module_keys  require_manifest  \
# 0       site_assets       features.site_assets              True
# 1    canonical_grid    features.canonical_grid              True
# 2    chunk_manifest    features.chunk_manifest              True
# 3     source_ingest     features.source_ingest              True
# 4      source_align      features.source_align              True
# 5    family_compute    features.family_compute              True
# 6    stack_finalize    features.stack_finalize              True
# 7  object_aggregate  features.object_aggregate              True
# 8        qa_summary        features.qa_summary              True
#
#    allow_legacy_reuse retention_mode  prune_after_success
# 0               False           lean                False
# 1               False           lean                False
# 2               False           lean                False
# 3               False           lean                False
# 4               False           lean                False
# 5               False           lean                False
# 6               False           lean                False
# 7               False           lean                False
# 8               False  manifest_only                False

# %% [markdown]
# # Chunking

# %%
def chunk_manifest_cache_dir(site_id: str, data_signature: str, config_signature: str) -> Path:
    return stage_cache_dir(
        stage_name="chunk_manifest",
        site_id=site_id,
        source_name="canonical_grid",
        data_signature=data_signature,
        config_signature=config_signature,
    )


def chunk_manifest_signature(site_id: str, grid: CanonicalGrid) -> tuple[str, str]:
    data_sig = hash_payload(
        {
            "site_id": site_id,
            "width": grid.width,
            "height": grid.height,
            "transform": tuple(grid.transform)[:6],
            "crs": str(grid.crs),
            "source_name": grid.source_name,
        }
    )
    config_sig = hash_payload(
        {
            "chunk_size_px": fe_cfg.chunking.chunk_size_px,
            "halo_px_default": fe_cfg.chunking.halo_px_default,
            "version": fe_cfg.version,
        }
    )
    return data_sig, config_sig
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def build_chunk_manifest(grid: CanonicalGrid, *, force_refresh: bool = False) -> ChunkManifest:
    data_sig, config_sig = chunk_manifest_signature(grid.site_id, grid)
    cache_dir = chunk_manifest_cache_dir(grid.site_id, data_sig, config_sig)
    manifest_json = cache_dir / "chunk_manifest.json"
    stage_manifest = cache_dir / "stage_cache_manifest.json"

    if (not force_refresh) and is_valid_stage_cache(
        stage_cache_dir=cache_dir,
        expected_stage_name="chunk_manifest",
        expected_data_signature=data_sig,
        expected_config_signature=config_sig,
    ) and manifest_json.exists():
        payload = read_json(manifest_json)
        records = [ChunkRecord(**row) for row in payload["records"]]
        LOGGER.info(
            "Using cached chunk manifest | site=%s | n_chunks=%d",
            grid.site_id, len(records)
        )
        return ChunkManifest(
            site_id=payload["site_id"],
            chunk_size_px=payload["chunk_size_px"],
            halo_px_default=payload["halo_px_default"],
            records=records,
        )

    with timed_stage(
        "chunk_manifest",
        site_id=grid.site_id,
        source_name=grid.source_name,
        unit_amount=(grid.height * grid.width) / 1_000_000.0,
    ):
        chunk_size = fe_cfg.chunking.chunk_size_px
        halo = fe_cfg.chunking.halo_px_default

        records: list[ChunkRecord] = []
        chunk_idx = 0

        for row_start in range(0, grid.height, chunk_size):
            for col_start in range(0, grid.width, chunk_size):
                row_end = min(row_start + chunk_size, grid.height)
                col_end = min(col_start + chunk_size, grid.width)

                records.append(
                    ChunkRecord(
                        site_id=grid.site_id,
                        chunk_id=f"chunk_{chunk_idx:05d}",
                        row_start=row_start,
                        row_end=row_end,
                        col_start=col_start,
                        col_end=col_end,
                        halo_px=halo,
                    )
                )
                chunk_idx += 1

        chunk_manifest = ChunkManifest(
            site_id=grid.site_id,
            chunk_size_px=chunk_size,
            halo_px_default=halo,
            records=records,
        )

        write_json(
            manifest_json,
            {
                "site_id": chunk_manifest.site_id,
                "chunk_size_px": chunk_manifest.chunk_size_px,
                "halo_px_default": chunk_manifest.halo_px_default,
                "records": [asdict(r) for r in chunk_manifest.records],
            },
        )

        write_stage_cache_manifest(
            stage_cache_dir=cache_dir,
            stage_name="chunk_manifest",
            data_signature=data_sig,
            config_signature=config_sig,
            module_variants=[],
            artifact_paths={"chunk_manifest_json": str(manifest_json)},
            success=True,
            notes=[f"Built chunk manifest with {len(records)} chunks."],
        )

        LOGGER.info(
            "Built chunk manifest | site=%s | chunk_size=%d | n_chunks=%d",
            grid.site_id, chunk_size, len(records)
        )
        return chunk_manifest
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def chunk_manifest_frame(manifest: ChunkManifest) -> pd.DataFrame:
    return pd.DataFrame([asdict(r) for r in manifest.records])


def expanded_chunk_bounds(record: ChunkRecord, *, height: int, width: int, halo_px: int | None = None) -> dict[str, int]:
    halo = record.halo_px if halo_px is None else halo_px
    return {
        "row_start": max(0, record.row_start - halo),
        "row_end": min(height, record.row_end + halo),
        "col_start": max(0, record.col_start - halo),
        "col_end": min(width, record.col_end + halo),
    }


def chunk_window(record: ChunkRecord) -> Window:
    return Window(
        col_off=record.col_start,
        row_off=record.row_start,
        width=record.width,
        height=record.height,
    )


def expanded_chunk_window(record: ChunkRecord, *, height: int, width: int, halo_px: int | None = None) -> Window:
    b = expanded_chunk_bounds(record, height=height, width=width, halo_px=halo_px)
    return Window(
        col_off=b["col_start"],
        row_off=b["row_start"],
        width=b["col_end"] - b["col_start"],
        height=b["row_end"] - b["row_start"],
    )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Site assets and labeling bridges

# %%
def site_asset_cache_root(site_id: str) -> Path:
    return ensure_dir(fe_cfg.cache_root / "site_assets" / site_id)


def site_naip_cache_root(site_id: str) -> Path:
    return ensure_dir(site_asset_cache_root(site_id) / "naip")


def site_als_cache_root(site_id: str) -> Path:
    return ensure_dir(site_asset_cache_root(site_id) / "als_metadata")


def site_3dep_cache_root(site_id: str) -> Path:
    return ensure_dir(site_asset_cache_root(site_id) / "3dep")

def site_3dep_rel_path(site_id: str, filename: str | None = None) -> str:
    filename = filename or f"{site_id}_3dep_ee_10m.tif"
    return render_artifact_rel_path(
        "site_3dep_raster",
        site_id=site_id,
        filename=filename,
    )

def site_rap_rel_path(site_id: str, filename: str | None = None) -> str:
    filename = filename or f"{site_id}_rap_ee_10m.tif"
    return render_artifact_rel_path(
        "site_rap_raster",
        site_id=site_id,
        filename=filename,
    )

def site_rap_cache_root(site_id: str) -> Path:
    return ensure_dir(site_asset_cache_root(site_id) / "rap")


def site_metadata_manifest_local_path(site_id: str, config_sig: str | None = None) -> Path:
    config_sig = config_sig or current_fe_config_signature()
    rel_path = render_artifact_rel_path(
        "site_metadata_manifest",
        site_id=site_id,
        config_signature=config_sig,
    )
    return local_artifact_abs_path(rel_path)


def source_inventory_local_path(site_id: str, config_sig: str | None = None) -> Path:
    config_sig = config_sig or current_fe_config_signature()
    rel_path = render_artifact_rel_path(
        "source_inventory",
        site_id=site_id,
        config_signature=config_sig,
    )
    return local_artifact_abs_path(rel_path)


def validate_cached_raster(path: str | Path) -> bool:
    path = Path(path)
    if not path.exists():
        return False

    try:
        with rasterio.open(path) as src:
            if src.count < 1 or src.width <= 0 or src.height <= 0:
                return False

            # Probe multiple windows, not just the top-left corner
            windows = [
                Window(0, 0, min(32, src.width), min(32, src.height)),
                Window(
                    max(0, src.width // 2 - min(16, src.width // 2)),
                    max(0, src.height // 2 - min(16, src.height // 2)),
                    min(32, src.width),
                    min(32, src.height),
                ),
                Window(
                    max(0, src.width - min(32, src.width)),
                    max(0, src.height - min(32, src.height)),
                    min(32, src.width),
                    min(32, src.height),
                ),
            ]

            for w in windows:
                src.read([1], window=w)

        return True

    except Exception as e:
        LOGGER.warning("Cached raster validation failed for %s: %s", path, e)
        return False

def validate_optional_raster_asset(value: Any) -> bool:
    if value is None:
        return False
    try:
        return validate_cached_raster(Path(value))
    except Exception:
        return False
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def list_remote_tif_candidates(remote_dir: str) -> list[dict[str, Any]]:
    try:
        return list_files_with_suffix(remote_dir, (".tif", ".tiff"))
    except Exception as e:
        LOGGER.warning("Failed tif listing for remote_dir=%s | err=%s", remote_dir, e)
        return []


def score_3dep_candidate(entry: dict[str, Any], *, naip_name: str) -> tuple[int, int, str]:
    """
    Higher is better.
    We want a tif in the NAIP_3DEP product dir that is not the NAIP orthophoto.
    """
    name = str(entry.get("name", "")).lower()

    score = 0

    if name == str(naip_name).lower():
        score -= 1000

    keywords_hi = ["3dep", "dem", "elev", "elevation", "terrain", "dtm"]
    keywords_mid = ["dsm", "usgs", "slope"]

    for kw in keywords_hi:
        if kw in name:
            score += 50
    for kw in keywords_mid:
        if kw in name:
            score += 20

    if "naip" in name:
        score -= 50
    if "rgb" in name or "nir" in name or "ortho" in name or "ortho" in name:
        score -= 40

    return (score, -len(name), name)


def infer_3dep_entry_from_candidates(
    tif_candidates: list[dict[str, Any]],
    *,
    naip_name: str,
) -> dict[str, Any] | None:
    if not tif_candidates:
        return None

    ranked = sorted(
        tif_candidates,
        key=lambda x: score_3dep_candidate(x, naip_name=naip_name),
        reverse=True,
    )

    best = ranked[0]
    best_score = score_3dep_candidate(best, naip_name=naip_name)[0]

    if best_score < 0:
        return None
    return best

def ensure_ee_initialized(project: str | None = None):
    try:
        ee.Initialize(project=project) if project else ee.Initialize()
    except Exception:
        ee.Authenticate()
        ee.Initialize(project=project) if project else ee.Initialize()

def label_artifact_bounds_wgs84(site_id: str, resolution_m: float = 1.0) -> tuple[float, float, float, float]:
    art = best_label_artifact_for_site(site_id, resolution_m=resolution_m)
    if art is None:
        raise ValueError(f"No label artifact found for site={site_id}")

    mask_path = (
        art.get("binary_mask_path")
        or art.get("confidence_mask_path")
        or art.get("object_id_raster_path")
    )
    if mask_path is None:
        raise ValueError(f"No raster path available in label artifact row for site={site_id}")

    mask_path = Path(mask_path)
    if not mask_path.exists():
        raise FileNotFoundError(f"Label artifact raster missing for site={site_id}: {mask_path}")

    with rasterio.open(mask_path) as src:
        left, bottom, right, top = rasterio.transform.array_bounds(
            src.height,
            src.width,
            src.transform,
        )
        src_crs = CRS.from_user_input(src.crs)
        if str(src_crs).upper() == "EPSG:4326":
            out = (left, bottom, right, top)
        else:
            out = transform_bounds(
                src_crs,
                "EPSG:4326",
                left,
                bottom,
                right,
                top,
                densify_pts=21,
            )

    out = tuple(float(x) for x in out)
    if not np.all(np.isfinite(out)):
        raise ValueError(f"Non-finite label-derived bounds for site={site_id}: {out}")

    west, south, east, north = out
    west = max(-180.0, min(180.0, west))
    east = max(-180.0, min(180.0, east))
    south = max(-90.0, min(90.0, south))
    north = max(-90.0, min(90.0, north))

    if not (west < east and south < north):
        raise ValueError(f"Invalid label-derived bounds for site={site_id}: {(west, south, east, north)}")

    return west, south, east, north

def site_bounds_wgs84_for_naip_fallback(
    site_id: str,
    *,
    canonical_grid: CanonicalGrid | None = None,
    resolution_m: float = 1.0,
) -> tuple[float, float, float, float]:
    if canonical_grid is not None:
        return canonical_grid_bounds_wgs84(canonical_grid)
    return label_artifact_bounds_wgs84(site_id, resolution_m=resolution_m)


def site_region_coords_for_naip_fallback(
    site_id: str,
    *,
    canonical_grid: CanonicalGrid | None = None,
    resolution_m: float = 1.0,
) -> list[list[float]]:
    west, south, east, north = site_bounds_wgs84_for_naip_fallback(
        site_id,
        canonical_grid=canonical_grid,
        resolution_m=resolution_m,
    )
    return [
        [west, south],
        [east, south],
        [east, north],
        [west, north],
        [west, south],
    ]


def site_geometry_for_naip_fallback(
    site_id: str,
    *,
    canonical_grid: CanonicalGrid | None = None,
    resolution_m: float = 1.0,
) -> ee.Geometry:
    west, south, east, north = site_bounds_wgs84_for_naip_fallback(
        site_id,
        canonical_grid=canonical_grid,
        resolution_m=resolution_m,
    )
    return ee.Geometry.Rectangle([west, south, east, north], proj="EPSG:4326", geodesic=False)

def ee_naip_image_for_site(
    site_id: str,
    *,
    canonical_grid: CanonicalGrid | None = None,
    resolution_m: float = 1.0,
    year: int | None = None,
) -> ee.Image:
    geom = site_geometry_for_naip_fallback(
        site_id,
        canonical_grid=canonical_grid,
        resolution_m=resolution_m,
    )

    collection = ee.ImageCollection("USDA/NAIP/DOQQ").filterBounds(geom)

    if year is not None:
        collection = collection.filterDate(f"{year}-01-01", f"{year}-12-31")

    # Prefer newest available NAIP covering the site
    img = collection.sort("system:time_start", False).first()
    if img is None:
        raise ValueError(f"No NAIP image found in EE for site={site_id}")

    return ee.Image(img).clip(geom).toFloat()

def infer_naip_band_names_from_ee(image: ee.Image) -> list[str]:
    names = [str(x) for x in image.bandNames().getInfo()]
    # Normalize common NAIP naming to your expected convention
    lowered = [n.lower() for n in names]

    mapping = []
    for n in lowered:
        if n in {"r", "red"}:
            mapping.append("red")
        elif n in {"g", "green"}:
            mapping.append("green")
        elif n in {"b", "blue"}:
            mapping.append("blue")
        elif n in {"n", "nir"}:
            mapping.append("nir")
        else:
            mapping.append(n)

    return mapping

def canonical_grid_bounds_native(grid: CanonicalGrid) -> tuple[float, float, float, float]:
    left, bottom, right, top = rasterio.transform.array_bounds(
        grid.height,
        grid.width,
        grid.transform,
    )
    return float(left), float(bottom), float(right), float(top)


def canonical_grid_bounds_wgs84(grid: CanonicalGrid) -> tuple[float, float, float, float]:
    src_crs = CRS.from_user_input(grid.crs)
    left, bottom, right, top = canonical_grid_bounds_native(grid)

    if str(src_crs).upper() == "EPSG:4326":
        out = (left, bottom, right, top)
    else:
        out = transform_bounds(
            src_crs,
            "EPSG:4326",
            left,
            bottom,
            right,
            top,
            densify_pts=21,
        )

    out = tuple(float(x) for x in out)

    if not np.all(np.isfinite(out)):
        raise ValueError(f"Non-finite WGS84 bounds derived from canonical grid: {out}")

    west, south, east, north = out

    # Sanity checks / clamping
    west = max(-180.0, min(180.0, west))
    east = max(-180.0, min(180.0, east))
    south = max(-90.0, min(90.0, south))
    north = max(-90.0, min(90.0, north))

    if not (west < east and south < north):
        raise ValueError(
            f"Invalid WGS84 bounds after transformation: {(west, south, east, north)}"
        )

    return west, south, east, north


def canonical_grid_bbox_geometry(grid: CanonicalGrid) -> ee.Geometry:
    west, south, east, north = canonical_grid_bounds_wgs84(grid)
    return ee.Geometry.Rectangle([west, south, east, north], proj="EPSG:4326", geodesic=False)


def canonical_grid_bbox_region_coords(grid: CanonicalGrid) -> list[list[float]]:
    west, south, east, north = canonical_grid_bounds_wgs84(grid)
    return [
        [west, south],
        [east, south],
        [east, north],
        [west, north],
        [west, south],
    ]


def ee_3dep_elevation_for_grid(grid: CanonicalGrid) -> ee.Image:
    geom = canonical_grid_bbox_geometry(grid)

    dem = (
        ee.ImageCollection("USGS/3DEP/10m_collection")
        .select("elevation")
        .mosaic()
        .toFloat()
        .rename("elevation")
        .clip(geom)
    )
    return dem

def ee_rap_image_for_grid(
    grid: CanonicalGrid,
    *,
    image_id: str = "projects/rap-data-365417/assets/vegetation-cover-10m",
) -> ee.Image:
    geom = canonical_grid_bbox_geometry(grid)

    img = (
        ee.ImageCollection(image_id)
        .mosaic()
        .toFloat()
        .clip(geom)
    )
    return img


def infer_rap_band_names_from_ee(image: ee.Image) -> list[str]:
    names = image.bandNames().getInfo()
    return [str(x) for x in names]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def als_site_bounds_native(als_meta: list[dict[str, Any]]) -> tuple[float, float, float, float]:
    if not als_meta:
        raise ValueError("ALS metadata is empty; cannot derive site-wide bounds.")

    mins_x, mins_y, maxs_x, maxs_y = [], [], [], []

    for meta in als_meta:
        nb = meta.get("native_bounds")
        if not isinstance(nb, dict):
            continue
        mins_x.append(float(nb["minx"]))
        mins_y.append(float(nb["miny"]))
        maxs_x.append(float(nb["maxx"]))
        maxs_y.append(float(nb["maxy"]))

    if not mins_x:
        raise ValueError("ALS metadata had no usable native_bounds entries.")

    return min(mins_x), min(mins_y), max(maxs_x), max(maxs_y)

def als_site_bounds_wgs84(als_meta: list[dict[str, Any]]) -> tuple[float, float, float, float]:
    first = next((m for m in als_meta if m.get("srs_wkt")), None)
    if first is None:
        raise ValueError("No ALS metadata entry contains srs_wkt; cannot derive site-wide CRS.")

    src_crs = CRS.from_wkt(first["srs_wkt"])
    left, bottom, right, top = als_site_bounds_native(als_meta)

    if str(src_crs).upper() == "EPSG:4326":
        out = (left, bottom, right, top)
    else:
        out = transform_bounds(
            src_crs,
            "EPSG:4326",
            left,
            bottom,
            right,
            top,
            densify_pts=21,
        )

    out = tuple(float(x) for x in out)
    if not np.all(np.isfinite(out)):
        raise ValueError(f"Non-finite ALS-derived site bounds: {out}")

    west, south, east, north = out
    west = max(-180.0, min(180.0, west))
    east = max(-180.0, min(180.0, east))
    south = max(-90.0, min(90.0, south))
    north = max(-90.0, min(90.0, north))

    if not (west < east and south < north):
        raise ValueError(f"Invalid ALS-derived site bounds: {(west, south, east, north)}")

    return west, south, east, north

def site_bounds_wgs84_for_naip_sitewide_fallback(
    site_id: str,
    *,
    site_assets: SiteAssetBundle,
    canonical_grid: CanonicalGrid | None = None,
    resolution_m: float = 1.0,
) -> tuple[float, float, float, float]:
    if canonical_grid is not None:
        return canonical_grid_bounds_wgs84(canonical_grid)

    als_meta = site_assets.source_assets.get("als_metadata", [])
    if als_meta:
        return als_site_bounds_wgs84(als_meta)

    return label_artifact_bounds_wgs84(site_id, resolution_m=resolution_m)

def site_region_coords_for_naip_sitewide_fallback(
    site_id: str,
    *,
    site_assets: SiteAssetBundle,
    canonical_grid: CanonicalGrid | None = None,
    resolution_m: float = 1.0,
) -> list[list[float]]:
    west, south, east, north = site_bounds_wgs84_for_naip_sitewide_fallback(
        site_id,
        site_assets=site_assets,
        canonical_grid=canonical_grid,
        resolution_m=resolution_m,
    )
    return [
        [west, south],
        [east, south],
        [east, north],
        [west, north],
        [west, south],
    ]

def split_wgs84_bbox_into_tiles(
    bounds: tuple[float, float, float, float],
    *,
    nx: int,
    ny: int,
) -> list[tuple[float, float, float, float]]:
    west, south, east, north = bounds
    xs = np.linspace(west, east, nx + 1)
    ys = np.linspace(south, north, ny + 1)

    tiles = []
    for j in range(ny):
        for i in range(nx):
            tiles.append((xs[i], ys[j], xs[i + 1], ys[j + 1]))
    return tiles

def region_coords_from_bounds(bounds: tuple[float, float, float, float]) -> list[list[float]]:
    west, south, east, north = bounds
    return [
        [west, south],
        [east, south],
        [east, north],
        [west, north],
        [west, south],
    ]

def ee_geometry_from_bounds(bounds: tuple[float, float, float, float]) -> ee.Geometry:
    west, south, east, north = bounds
    return ee.Geometry.Rectangle([west, south, east, north], proj="EPSG:4326", geodesic=False)

def ee_naip_image_for_bounds(
    bounds: tuple[float, float, float, float],
    *,
    year: int | None = None,
) -> ee.Image:
    geom = ee_geometry_from_bounds(bounds)

    collection = ee.ImageCollection("USDA/NAIP/DOQQ").filterBounds(geom)
    if year is not None:
        collection = collection.filterDate(f"{year}-01-01", f"{year}-12-31")

    img = collection.sort("system:time_start", False).first()
    if img is None:
        raise ValueError(f"No NAIP image found in EE for bounds={bounds}")

    return ee.Image(img).clip(geom).toFloat()

def export_ee_naip_tiled_to_geotiff(
    *,
    out_path: str | Path,
    bounds_wgs84: tuple[float, float, float, float],
    scale: float = 1.0,
    crs: str = "EPSG:4326",
    nx: int = 2,
    ny: int = 2,
    year: int | None = None,
) -> Path:
    out_path = Path(out_path)
    out_path.parent.mkdir(parents=True, exist_ok=True)

    tile_bounds_list = split_wgs84_bbox_into_tiles(bounds_wgs84, nx=nx, ny=ny)
    tmp_dir = out_path.parent / f"{out_path.stem}_tiles"
    tmp_dir.mkdir(parents=True, exist_ok=True)

    tile_paths = []

    try:
        for idx, tile_bounds in enumerate(tile_bounds_list):
            tile_path = tmp_dir / f"tile_{idx:02d}.tif"
            tile_img = ee_naip_image_for_bounds(tile_bounds, year=year)

            export_ee_image_to_geotiff(
                tile_img,
                out_path=tile_path,
                region_coords=region_coords_from_bounds(tile_bounds),
                scale=scale,
                crs=crs,
            )

            if not validate_cached_raster(tile_path):
                raise RuntimeError(f"Exported NAIP tile unreadable: {tile_path}")

            tile_paths.append(tile_path)

        srcs = [rasterio.open(p) for p in tile_paths]
        try:
            mosaic_arr, mosaic_transform = rio_merge(srcs)
            meta = srcs[0].meta.copy()
            meta.update(
                {
                    "height": mosaic_arr.shape[1],
                    "width": mosaic_arr.shape[2],
                    "transform": mosaic_transform,
                    "count": mosaic_arr.shape[0],
                    "dtype": str(mosaic_arr.dtype),
                }
            )

            with rasterio.open(out_path, "w", **meta) as dst:
                dst.write(mosaic_arr)
        finally:
            for src in srcs:
                src.close()

    finally:
        shutil.rmtree(tmp_dir, ignore_errors=True)

    return out_path
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def build_source_inventory(site_id: str) -> dict[str, Any]:
    site_base = site_to_remote_base(cfg, site_id)
    product_dir = f"{site_base}/{cfg.data.naip_3dep_dir}"
    naip_name = site_to_tif_name(site_id)

    inventory = {
        "site_id": site_id,
        "site_base": site_base,
        "naip": {
            "expected_name": naip_name,
            "remote_url": f"{product_dir}/{naip_name}",
        },
        "als": {
            "remote_url": f"{site_base}/{cfg.data.als_dir}",
            "files": [],
        },
        "3dep": {
            "remote_dir": product_dir,
            "remote_url": None,
            "expected_name": None,
            "candidates": [],
        },
        "rap": {
            "remote_url": None,
        },
    }

    # ALS discovery
    try:
        als_files = list_files_with_suffix(
            inventory["als"]["remote_url"],
            (".las", ".laz", ".copc.laz"),
        )
        inventory["als"]["files"] = als_files
    except Exception as e:
        inventory["als"]["error"] = str(e)

    # 3DEP discovery from same NAIP_3DEP product directory
    try:
        tif_candidates = list_remote_tif_candidates(product_dir)
        inventory["3dep"]["candidates"] = tif_candidates

        chosen = infer_3dep_entry_from_candidates(
            tif_candidates,
            naip_name=naip_name,
        )
        if chosen is not None:
            inventory["3dep"]["expected_name"] = chosen["name"]
            inventory["3dep"]["remote_url"] = chosen["url"]
        else:
            inventory["3dep"]["warning"] = (
                "No convincing 3DEP tif candidate found in NAIP_3DEP product directory."
            )
    except Exception as e:
        inventory["3dep"]["error"] = str(e)

    return inventory


def persist_source_inventory(site_id: str, inventory: dict[str, Any], *, config_sig: str | None = None) -> PersistedArtifactRecord:
    return persist_json_artifact(
        inventory,
        artifact_key="source_inventory",
        site_id=site_id,
        config_sig=config_sig,
    )


def try_load_source_inventory(site_id: str, *, config_sig: str | None = None) -> dict[str, Any] | None:
    return try_load_json_artifact(
        artifact_key="source_inventory",
        site_id=site_id,
        config_sig=config_sig,
    )



def prepare_naip_asset(
    site_id: str,
    *,
    force_refresh: bool = False,
    inventory: dict[str, Any] | None = None,
    canonical_grid: CanonicalGrid | None = None,
    site_assets: SiteAssetBundle | None = None,
) -> Path:
    inventory = inventory or build_source_inventory(site_id)
    naip_name = inventory["naip"]["expected_name"]
    naip_url = inventory["naip"]["remote_url"]

    local_path = site_naip_cache_root(site_id) / naip_name
    rel_path = render_artifact_rel_path(
        "site_naip_raster",
        site_id=site_id,
        filename=naip_name,
    )

    # 1) valid local cache
    if (not force_refresh) and local_path.exists() and validate_cached_raster(local_path):
        LOGGER.info("Using cached NAIP | site=%s | path=%s", site_id, local_path)
        return local_path

    # 2) remove invalid local copy if present
    if local_path.exists():
        LOGGER.warning("Removing invalid cached NAIP | site=%s | path=%s", site_id, local_path)
        local_path.unlink(missing_ok=True)

    # 3) try remote artifact-store copy
    if not force_refresh and remote_artifact_exists(rel_path):
        LOGGER.info("Hydrating NAIP from artifact store | site=%s | rel_path=%s", site_id, rel_path)
        pulled = artifact_store.pull(rel_path, local_path=local_path)
        if validate_cached_raster(pulled):
            return pulled

        LOGGER.warning(
            "Hydrated NAIP failed validation; removing broken hydrated copy | site=%s | path=%s",
            site_id, pulled
        )
        Path(pulled).unlink(missing_ok=True)

    # 4) try DAV download first
    dav_ok = False
    try:
        LOGGER.info("Downloading NAIP | site=%s | url=%s", site_id, naip_url)
        download_file(naip_url, local_path)
        dav_ok = validate_cached_raster(local_path)
    except Exception as e:
        LOGGER.warning("DAV NAIP download failed | site=%s | err=%s", site_id, e)
        dav_ok = False

    if dav_ok:
        try:
            persist_existing_file_artifact(
                local_path,
                artifact_key="site_naip_raster",
                site_id=site_id,
                filename=naip_name,
            )
        except Exception as e:
            LOGGER.warning("Persisting DAV NAIP artifact failed | site=%s | err=%s", site_id, e)
        return local_path

    if local_path.exists():
        local_path.unlink(missing_ok=True)

    # 5) EE fallback
    ensure_ee_initialized(project="shrubwise-dc-488219")

    west, south, east, north = site_bounds_wgs84_for_naip_sitewide_fallback(
        site_id,
        site_assets=site_assets,
        canonical_grid=canonical_grid,
        resolution_m=1.0,
    )
    region_coords = site_region_coords_for_naip_sitewide_fallback(
        site_id,
        site_assets=site_assets,
        canonical_grid=canonical_grid,
        resolution_m=1.0,
    )
    image = ee_naip_image_for_site(
        site_id,
        canonical_grid=canonical_grid,
        resolution_m=1.0,
    )

    LOGGER.info(
        "Exporting NAIP from Earth Engine fallback | site=%s | out=%s | bounds_wgs84=(%.6f, %.6f, %.6f, %.6f)",
        site_id, local_path, west, south, east, north
    )

    bounds_wgs84 = site_bounds_wgs84_for_naip_sitewide_fallback(
        site_id,
        site_assets=site_assets,
        canonical_grid=canonical_grid,
        resolution_m=1.0,
    )

    LOGGER.info(
        "Exporting NAIP from Earth Engine fallback (tiled) | site=%s | out=%s | bounds_wgs84=(%.6f, %.6f, %.6f, %.6f)",
        site_id, local_path, *bounds_wgs84
    )

    export_ee_naip_tiled_to_geotiff(
        out_path=local_path,
        bounds_wgs84=bounds_wgs84,
        scale=1.0,
        crs="EPSG:4326",
        nx=2,
        ny=2,
        year=None,
    )

    if not validate_cached_raster(local_path):
        local_path.unlink(missing_ok=True)
        raise RuntimeError(
            f"NAIP unavailable for site={site_id}: DAV download failed validation and EE fallback export was unreadable."
        )

    try:
        persist_existing_file_artifact(
            local_path,
            artifact_key="site_naip_raster",
            site_id=site_id,
            filename=naip_name,
        )
    except Exception as e:
        LOGGER.warning("Persisting EE NAIP artifact failed | site=%s | err=%s", site_id, e)

    return local_path

def export_ee_image_to_geotiff(
    image: ee.Image,
    *,
    out_path: str | Path,
    region_coords: list[list[float]],
    scale: float = 10.0,
    crs: str = "EPSG:4326",
) -> Path:
    out_path = Path(out_path)
    out_path.parent.mkdir(parents=True, exist_ok=True)

    geemap.ee_export_image(
        image,
        filename=str(out_path),
        scale=scale,
        region=region_coords,
        file_per_band=False,
        crs=crs,
    )
    return out_path

def prepare_3dep_asset(
    site_id: str,
    *,
    canonical_grid: CanonicalGrid | None = None,
    force_refresh: bool = False,
    inventory: dict[str, Any] | None = None,
) -> Path:
    local_path = site_3dep_cache_root(site_id) / f"{site_id}_3dep_ee_10m.tif"
    rel_path = site_3dep_rel_path(site_id, filename=local_path.name)

    # 1) local cache
    if (not force_refresh) and local_path.exists() and validate_cached_raster(local_path):
        LOGGER.info("Using cached 3DEP | site=%s | path=%s", site_id, local_path)
        return local_path

    # 2) artifact-store hydration
    if not force_refresh and remote_artifact_exists(rel_path):
        LOGGER.info("Hydrating 3DEP from artifact store | site=%s | rel_path=%s", site_id, rel_path)
        pulled = artifact_store.pull(rel_path, local_path=local_path)
        if validate_cached_raster(pulled):
            return pulled
        LOGGER.warning("Hydrated 3DEP failed validation | site=%s | path=%s", site_id, pulled)
        pulled.unlink(missing_ok=True)

    # 3) build from Earth Engine
    if canonical_grid is None:
        raise ValueError(
            "prepare_3dep_asset requires canonical_grid when no cached 3DEP raster is available."
        )

    ensure_ee_initialized(project="shrubwise-dc-488219")

    west, south, east, north = canonical_grid_bounds_wgs84(canonical_grid)
    region_coords = canonical_grid_bbox_region_coords(canonical_grid)
    image = ee_3dep_elevation_for_grid(canonical_grid)

    LOGGER.info(
        "Exporting 3DEP from Earth Engine | site=%s | out=%s | bounds_wgs84=(%.6f, %.6f, %.6f, %.6f)",
        site_id, local_path, west, south, east, north
    )

    export_ee_image_to_geotiff(
        image,
        out_path=local_path,
        region_coords=region_coords,
        scale=10.0,
        crs="EPSG:4326",
    )

    if not validate_cached_raster(local_path):
        raise RuntimeError(f"Exported 3DEP is unreadable for site={site_id}: {local_path}")

    persist_existing_file_artifact(
        local_path,
        artifact_key="site_3dep_raster",
        site_id=site_id,
        filename=local_path.name,
    )

    # If policy pruned local after push, rehydrate immediately only if caller needs the file now.
    if not local_path.exists():
        LOGGER.info("3DEP local file was pruned after push; rehydrating for current use | site=%s", site_id)
        artifact_store.pull(rel_path, local_path=local_path)

    LOGGER.info("Prepared 3DEP asset | site=%s | path=%s", site_id, local_path)
    return local_path

def maybe_prune_local_site_3dep_after_load(site_id: str, tif_path: str | Path) -> None:
    tif_path = Path(tif_path)
    rel_path = site_3dep_rel_path(site_id, filename=tif_path.name)

    if not fe_cfg.persistence.prune_local_after_remote_push:
        return

    if not remote_artifact_exists(rel_path):
        return

    try:
        if tif_path.exists():
            tif_path.unlink()
            LOGGER.info("Pruned local 3DEP site asset after in-memory load | site=%s | path=%s", site_id, tif_path)
    except Exception as e:
        LOGGER.warning("Failed to prune local 3DEP asset | site=%s | path=%s | err=%s", site_id, tif_path, e)

def prepare_rap_asset(
    site_id: str,
    *,
    canonical_grid: CanonicalGrid | None = None,
    force_refresh: bool = False,
    inventory: dict[str, Any] | None = None,
) -> Path:
    local_path = site_rap_cache_root(site_id) / f"{site_id}_rap_ee_10m.tif"
    rel_path = site_rap_rel_path(site_id, filename=local_path.name)

    # 1) local cache
    if (not force_refresh) and local_path.exists() and validate_cached_raster(local_path):
        LOGGER.info("Using cached RAP | site=%s | path=%s", site_id, local_path)
        return local_path

    # 2) artifact-store hydration
    if not force_refresh and remote_artifact_exists(rel_path):
        LOGGER.info("Hydrating RAP from artifact store | site=%s | rel_path=%s", site_id, rel_path)
        pulled = artifact_store.pull(rel_path, local_path=local_path)
        if validate_cached_raster(pulled):
            return pulled
        LOGGER.warning("Hydrated RAP failed validation | site=%s | path=%s", site_id, pulled)
        pulled.unlink(missing_ok=True)

    # 3) build from Earth Engine
    if canonical_grid is None:
        raise ValueError(
            "prepare_rap_asset requires canonical_grid when no cached RAP raster is available."
        )

    ensure_ee_initialized(project="shrubwise-dc-488219")

    west, south, east, north = canonical_grid_bounds_wgs84(canonical_grid)
    region_coords = canonical_grid_bbox_region_coords(canonical_grid)
    image = ee_rap_image_for_grid(canonical_grid)

    LOGGER.info(
        "Exporting RAP from Earth Engine | site=%s | out=%s | bounds_wgs84=(%.6f, %.6f, %.6f, %.6f)",
        site_id, local_path, west, south, east, north
    )

    export_ee_image_to_geotiff(
        image,
        out_path=local_path,
        region_coords=region_coords,
        scale=10.0,
        crs="EPSG:4326",
    )

    if not validate_cached_raster(local_path):
        raise RuntimeError(f"Exported RAP is unreadable for site={site_id}: {local_path}")

    persist_existing_file_artifact(
        local_path,
        artifact_key="site_rap_raster",
        site_id=site_id,
        filename=local_path.name,
    )

    if not local_path.exists():
        LOGGER.info("RAP local file was pruned after push; rehydrating for current use | site=%s", site_id)
        artifact_store.pull(rel_path, local_path=local_path)

    LOGGER.info("Prepared RAP asset | site=%s | path=%s", site_id, local_path)
    return local_path

def prepare_als_metadata(
    site_id: str,
    *,
    force_refresh: bool = False,
    inventory: dict[str, Any] | None = None,
    config_sig: str | None = None,
) -> list[dict[str, Any]]:
    config_sig = config_sig or current_fe_config_signature()

    # First: try local cache in site asset dir
    out_json = site_als_cache_root(site_id) / "als_metadata.json"
    if (not force_refresh) and out_json.exists():
        LOGGER.info("Using cached ALS metadata (local site cache) | site=%s | path=%s", site_id, out_json)
        return json.loads(out_json.read_text(encoding="utf-8"))

    # Second: try remote/local artifact-store-backed manifest artifact
    payload = try_load_json_artifact(
        artifact_key="als_metadata_json",
        site_id=site_id,
        config_sig=config_sig,
    )
    if (not force_refresh) and payload is not None:
        LOGGER.info("Using cached ALS metadata (artifact store) | site=%s", site_id)
        rows = payload.get("rows", [])
        out_json.write_text(json.dumps(rows, indent=2), encoding="utf-8")
        return rows

    inventory = inventory or build_source_inventory(site_id)
    als_files = inventory.get("als", {}).get("files", [])

    if not als_files:
        LOGGER.warning("No ALS files discovered | site=%s", site_id)
        return []

    LOGGER.info("Discovered %d ALS files | site=%s", len(als_files), site_id)

    tmp_dir = Path(tempfile.mkdtemp(prefix=f"als_meta_{site_id}_"))
    rows = []

    try:
        for entry in als_files:
            local_file = tmp_dir / entry["name"]
            LOGGER.info("Downloading ALS for metadata | site=%s | file=%s", site_id, entry["name"])
            download_file(entry["url"], local_file)

            meta = extract_als_metadata(local_file)
            meta["source_file"] = entry.get("name")
            meta["name"] = entry.get("name")
            meta["url"] = entry.get("url")
            meta["href"] = entry.get("href")
            meta["download_url"] = entry.get("download_url") or entry.get("url") or entry.get("href")
            rows.append(meta)

            local_file.unlink(missing_ok=True)
    finally:
        shutil.rmtree(tmp_dir, ignore_errors=True)

    out_json.write_text(json.dumps(rows, indent=2), encoding="utf-8")

    persist_json_artifact(
        {"site_id": site_id, "rows": rows},
        artifact_key="als_metadata_json",
        site_id=site_id,
        config_sig=config_sig,
    )

    LOGGER.info("Wrote ALS metadata | site=%s | path=%s", site_id, out_json)
    return rows
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def find_cached_3dep_asset(site_id: str) -> Path | None:
    dep_cache_dir = site_3dep_cache_root(site_id)

    # Prefer the new EE-exported naming convention first
    preferred = sorted(dep_cache_dir.glob("*_3dep_ee_10m.tif"))
    fallback = sorted(dep_cache_dir.glob("*.tif"))

    candidates = preferred + [p for p in fallback if p not in preferred]

    for p in candidates:
        if validate_cached_raster(p):
            return p
        else:
            try:
                LOGGER.warning("Removing invalid cached 3DEP candidate | site=%s | path=%s", site_id, p)
                p.unlink(missing_ok=True)
            except Exception as e:
                LOGGER.warning("Failed to remove invalid cached 3DEP candidate | path=%s | err=%s", p, e)

    return None

def find_cached_rap_asset(site_id: str) -> Path | None:
    rap_cache_dir = site_rap_cache_root(site_id)
    tif_candidates = sorted(rap_cache_dir.glob("*.tif"))
    valid_candidates = [p for p in tif_candidates if validate_cached_raster(p)]
    return valid_candidates[0] if valid_candidates else None

def find_or_register_lazy_rap_asset(site_id: str) -> Path | None:
    return find_cached_rap_asset(site_id)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def enrich_existing_site_asset_bundle(
    bundle: SiteAssetBundle,
    *,
    site_id: str,
    inventory: dict[str, Any],
    force_refresh: bool = False,
) -> SiteAssetBundle:
    source_assets = dict(bundle.source_assets or {})
    notes = list(bundle.notes or [])

    # Repair or attach NAIP if missing/invalid
    if force_refresh or (not validate_optional_raster_asset(source_assets.get("naip"))):
        try:
            source_assets["naip"] = prepare_naip_asset(
                site_id,
                force_refresh=force_refresh,
                inventory=inventory,
                canonical_grid=None
            )
        except Exception as e:
            source_assets["naip"] = None
            notes.append(f"NAIP unavailable during manifest enrichment: {e}")

    # Repair or attach ALS metadata if missing/empty
    als_meta = source_assets.get("als_metadata")
    if force_refresh or als_meta is None or (isinstance(als_meta, list) and len(als_meta) == 0):
        try:
            source_assets["als_metadata"] = prepare_als_metadata(
                site_id,
                force_refresh=force_refresh,
                inventory=inventory,
                config_sig=current_fe_config_signature(),
            )
        except Exception as e:
            source_assets["als_metadata"] = []
            notes.append(f"ALS metadata unavailable during manifest enrichment: {e}")

    # 3DEP is lazy
    cached_3dep = source_assets.get("3dep")
    if force_refresh or (not validate_optional_raster_asset(cached_3dep)):
        source_assets["3dep"] = find_cached_3dep_asset(site_id)

    # RAP is lazy
    cached_rap = source_assets.get("rap")
    if force_refresh or (not validate_optional_raster_asset(cached_rap)):
        source_assets["rap"] = find_cached_rap_asset(site_id)

    source_assets["source_inventory"] = inventory

    out = SiteAssetBundle(site_id=site_id)
    out.source_assets.update(source_assets)
    out.notes.extend(notes)
    return out
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def serialize_site_asset_bundle(bundle: SiteAssetBundle) -> dict[str, Any]:
    payload = {
        "site_id": bundle.site_id,
        "source_assets": {},
        "notes": list(bundle.notes),
    }
    for key, value in bundle.source_assets.items():
        if isinstance(value, Path):
            payload["source_assets"][key] = {"kind": "path", "value": str(value)}
        else:
            payload["source_assets"][key] = {"kind": "json", "value": value}
    return payload


def deserialize_site_asset_bundle(payload: dict[str, Any]) -> SiteAssetBundle:
    bundle = SiteAssetBundle(site_id=payload["site_id"])
    bundle.notes = list(payload.get("notes", []))

    for key, wrapped in payload.get("source_assets", {}).items():
        if wrapped["kind"] == "path":
            bundle.source_assets[key] = Path(wrapped["value"])
        else:
            bundle.source_assets[key] = wrapped["value"]

    return bundle


def try_load_site_metadata_manifest(site_id: str, *, config_sig: str | None = None) -> SiteAssetBundle | None:
    payload = try_load_json_artifact(
        artifact_key="site_metadata_manifest",
        site_id=site_id,
        config_sig=config_sig,
    )
    if payload is None:
        return None
    LOGGER.info("Using site metadata manifest | site=%s", site_id)
    return deserialize_site_asset_bundle(payload)


def persist_site_metadata_manifest(bundle: SiteAssetBundle, *, config_sig: str | None = None) -> PersistedArtifactRecord:
    payload = serialize_site_asset_bundle(bundle)
    return persist_json_artifact(
        payload,
        artifact_key="site_metadata_manifest",
        site_id=bundle.site_id,
        config_sig=config_sig,
    )

def site_asset_bundle_payload(bundle: SiteAssetBundle) -> dict[str, Any]:
    return serialize_site_asset_bundle(bundle)

def prepare_site_assets(site_id: str, *, force_refresh: bool = False) -> SiteAssetBundle:
    with timed_stage("site_assets", site_id=site_id):
        config_sig = current_fe_config_signature()

        existing = None if force_refresh else try_load_site_metadata_manifest(site_id, config_sig=config_sig)

        inventory = None if force_refresh else try_load_source_inventory(site_id, config_sig=config_sig)
        if inventory is None:
            inventory = build_source_inventory(site_id)
            persist_source_inventory(site_id, inventory, config_sig=config_sig)
            LOGGER.info("Built and persisted source inventory | site=%s", site_id)
        else:
            LOGGER.info("Using cached source inventory | site=%s", site_id)

        if existing is not None:
            enriched = enrich_existing_site_asset_bundle(
                existing,
                site_id=site_id,
                inventory=inventory,
                force_refresh=force_refresh,
            )

            old_payload = site_asset_bundle_payload(existing)
            new_payload = site_asset_bundle_payload(enriched)

            if old_payload != new_payload:
                persist_site_metadata_manifest(enriched, config_sig=config_sig)
                LOGGER.info(
                    "Prepared site assets from enriched manifest reuse (persisted changes) | site=%s | keys=%s | notes=%d",
                    site_id, list(enriched.source_assets.keys()), len(enriched.notes)
                )
            else:
                LOGGER.info(
                    "Prepared site assets from enriched manifest reuse (no manifest changes) | site=%s | keys=%s | notes=%d",
                    site_id, list(enriched.source_assets.keys()), len(enriched.notes)
                )

            return enriched

        # Fresh build path
        bundle = SiteAssetBundle(site_id=site_id)

        try:
            bundle.source_assets["naip"] = prepare_naip_asset(
                site_id,
                force_refresh=force_refresh,
                inventory=inventory,
                site_assets=bundle,
            )
        except Exception as e:
            bundle.notes.append(f"NAIP unavailable: {e}")

        try:
            bundle.source_assets["als_metadata"] = prepare_als_metadata(
                site_id,
                force_refresh=force_refresh,
                inventory=inventory,
                config_sig=config_sig,
            )
        except Exception as e:
            bundle.notes.append(f"ALS metadata unavailable: {e}")

        bundle.source_assets["3dep"] = find_cached_3dep_asset(site_id)
        bundle.source_assets["rap"] = find_cached_rap_asset(site_id)
        bundle.source_assets["source_inventory"] = inventory

        persist_site_metadata_manifest(bundle, config_sig=config_sig)

        LOGGER.info(
            "Prepared site assets | site=%s | keys=%s | notes=%d",
            site_id, list(bundle.source_assets.keys()), len(bundle.notes)
        )
        return bundle
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Labeling bridge

# %%
def labeling_summary_dir() -> Path:
    return cfg.output.labeling_root / "summaries"


def labeling_manifest_dir() -> Path:
    return cfg.output.labeling_root / "manifests"


def labeling_pipeline_runs_root() -> Path:
    return cfg.output.labeling_root / "pipeline_runs"


def latest_labeling_run_summary_paths() -> tuple[Path | None, Path | None]:
    runs_root = labeling_pipeline_runs_root()
    if not runs_root.exists():
        return None, None

    candidate_dirs = [p for p in runs_root.iterdir() if p.is_dir()]
    candidate_dirs = sorted(candidate_dirs, key=lambda p: p.stat().st_mtime, reverse=True)

    for run_dir in candidate_dirs:
        objects_csv = run_dir / "summaries" / "objects_all.csv"
        artifacts_csv = run_dir / "summaries" / "artifacts_all.csv"
        if objects_csv.exists() and artifacts_csv.exists():
            return objects_csv, artifacts_csv

    return None, None


def normalize_site_id_value(x: Any) -> str:
    return str(x).strip().lower().replace("_", "-").replace(" ", "-")


def load_labeling_objects_summary() -> pd.DataFrame:
    # First prefer the newest config-specific run summaries
    run_objects_csv, _ = latest_labeling_run_summary_paths()
    if run_objects_csv is not None and run_objects_csv.exists():
        df = pd.read_csv(run_objects_csv)
        if "site_id" in df.columns:
            df["_site_id_norm"] = df["site_id"].map(normalize_site_id_value)
        LOGGER.info("Loaded labeling objects summary from latest pipeline run | rows=%d | path=%s", len(df), run_objects_csv)
        return df

    # Fall back to global summaries
    obj_csv = labeling_summary_dir() / "objects_all.csv"
    if obj_csv.exists():
        df = pd.read_csv(obj_csv)
        if "site_id" in df.columns:
            df["_site_id_norm"] = df["site_id"].map(normalize_site_id_value)
        LOGGER.info("Loaded labeling objects summary from global summaries | rows=%d | path=%s", len(df), obj_csv)
        return df

    LOGGER.warning("No labeling object summary found in pipeline_runs or global summaries.")
    return pd.DataFrame()


def load_labeling_artifacts_summary() -> pd.DataFrame:
    # First prefer the newest config-specific run summaries
    _, run_artifacts_csv = latest_labeling_run_summary_paths()
    if run_artifacts_csv is not None and run_artifacts_csv.exists():
        df = pd.read_csv(run_artifacts_csv)
        if "site_id" in df.columns:
            df["_site_id_norm"] = df["site_id"].map(normalize_site_id_value)
        LOGGER.info("Loaded labeling artifacts summary from latest pipeline run | rows=%d | path=%s", len(df), run_artifacts_csv)
        return df

    art_csv = labeling_summary_dir() / "artifacts_all.csv"
    if art_csv.exists():
        df = pd.read_csv(art_csv)
        if "site_id" in df.columns:
            df["_site_id_norm"] = df["site_id"].map(normalize_site_id_value)
        LOGGER.info("Loaded labeling artifacts summary from global summaries | rows=%d | path=%s", len(df), art_csv)
        return df

    manifest_csv = labeling_manifest_dir() / "sprint4_artifacts.csv"
    if manifest_csv.exists():
        df = pd.read_csv(manifest_csv)
        if "site_id" in df.columns:
            df["_site_id_norm"] = df["site_id"].map(normalize_site_id_value)
        LOGGER.info("Loaded labeling artifact manifest fallback | rows=%d | path=%s", len(df), manifest_csv)
        return df

    LOGGER.warning("No labeling artifact summary/manifest found.")
    return pd.DataFrame()


LABEL_OBJECTS_DF = load_labeling_objects_summary()
LABEL_ARTIFACTS_DF = load_labeling_artifacts_summary()

print("LABEL_OBJECTS_DF:", LABEL_OBJECTS_DF.shape)
print("LABEL_ARTIFACTS_DF:", LABEL_ARTIFACTS_DF.shape)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 2026-04-17 10:55:46,295 | INFO     | features.notebook | Loaded labeling objects summary from latest pipeline run | rows=202 | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/labeling/pipeline_runs/0bab4176c29e/summaries/objects_all.csv
# 2026-04-17 10:55:46,298 | INFO     | features.notebook | Loaded labeling artifacts summary from latest pipeline run | rows=48 | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/labeling/pipeline_runs/0bab4176c29e/summaries/artifacts_all.csv
# LABEL_OBJECTS_DF: (202, 46)
# LABEL_ARTIFACTS_DF: (48, 23)

# %%
def label_objects_for_site(site_id: str) -> pd.DataFrame:
    if LABEL_OBJECTS_DF.empty:
        LOGGER.warning("LABEL_OBJECTS_DF is empty.")
        return pd.DataFrame()

    wanted = normalize_site_id_value(site_id)

    if "_site_id_norm" in LABEL_OBJECTS_DF.columns:
        out = LABEL_OBJECTS_DF[LABEL_OBJECTS_DF["_site_id_norm"] == wanted].copy()
    else:
        out = LABEL_OBJECTS_DF[LABEL_OBJECTS_DF["site_id"].map(normalize_site_id_value) == wanted].copy()

    LOGGER.info(
        "label_objects_for_site | requested=%s | matched_rows=%d | unique_sites=%s",
        site_id,
        len(out),
        sorted(LABEL_OBJECTS_DF["site_id"].astype(str).unique().tolist())[:20] if "site_id" in LABEL_OBJECTS_DF.columns else [],
    )
    return out


def label_artifacts_for_site(site_id: str) -> pd.DataFrame:
    if LABEL_ARTIFACTS_DF.empty:
        return pd.DataFrame()

    wanted = normalize_site_id_value(site_id)

    if "_site_id_norm" in LABEL_ARTIFACTS_DF.columns:
        return LABEL_ARTIFACTS_DF[LABEL_ARTIFACTS_DF["_site_id_norm"] == wanted].copy()

    return LABEL_ARTIFACTS_DF[LABEL_ARTIFACTS_DF["site_id"].map(normalize_site_id_value) == wanted].copy()


def best_label_artifact_for_site(site_id: str, resolution_m: float = 1.0) -> pd.Series | None:
    site_df = label_artifacts_for_site(site_id)
    if site_df.empty:
        return None

    if "resolution_m" in site_df.columns:
        site_df = site_df[np.isclose(site_df["resolution_m"].astype(float), float(resolution_m))].copy()

    if site_df.empty:
        return None

    sort_cols = [c for c in ["plot_id", "source_version"] if c in site_df.columns]
    if sort_cols:
        site_df = site_df.sort_values(sort_cols)

    return site_df.iloc[0]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
TEST_SITE = fe_cfg.sites[0]

print("LABEL_OBJECTS_DF shape:", LABEL_OBJECTS_DF.shape)
if not LABEL_OBJECTS_DF.empty:
    print("Unique site_ids in labeling objects:")
    display(pd.Series(sorted(LABEL_OBJECTS_DF["site_id"].astype(str).unique())).to_frame("site_id"))

site_objects = label_objects_for_site(TEST_SITE)
print("site_objects shape:", site_objects.shape)
display(site_objects.head(5))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# LABEL_OBJECTS_DF shape: (202, 46)
# Unique site_ids in labeling objects:
#                  site_id
# 0    calaveras-big-trees
# 1               dl-bliss
# 2      independence-lake
# 3  pacific-union-college
# 4               sedgwick
# 5            shaver-lake
# 2026-04-17 10:14:59,954 | INFO     | features.notebook | label_objects_for_site | requested=calaveras-big-trees | matched_rows=36 | unique_sites=['calaveras-big-trees', 'dl-bliss', 'independence-lake', 'pacific-union-college', 'sedgwick', 'shaver-lake']
# site_objects shape: (36, 46)
#                site_id                plot_id               ptx_stem  \
# 0  calaveras-big-trees  CATCU_0009_20250615_1  CATCU_0009_20250615_1
# 1  calaveras-big-trees  CATCU_0009_20250615_1  CATCU_0009_20250615_1
# 2  calaveras-big-trees  CATCU_0009_20250615_1  CATCU_0009_20250615_1
# 3  calaveras-big-trees  CATCU_0009_20250615_1  CATCU_0009_20250615_1
# 4  calaveras-big-trees  CATCU_0009_20250615_1  CATCU_0009_20250615_1
#
#    ptx_date_token    ptx_date  object_id     x_tls      y_tls  height_tls  \
# 0        20250615  2025-06-15          1  3.046618  11.705575       2.984
# 1        20250615  2025-06-15          2  5.759161  11.264599       1.707
# 2        20250615  2025-06-15          3  9.113982   9.333501       2.987
# 3        20250615  2025-06-15          4 -8.062640   7.617650       2.994
# 4        20250615  2025-06-15          5 -1.666380   7.426122       2.997
#
#    area_tls  radius_m radius_source  n_points  valid_object  \
# 0     4.356  1.177522      observed      2170          True
# 1     2.119  0.821279      observed       854          True
# 2     0.199  0.251682      observed        46          True
# 3     1.773  0.751241      observed       455          True
# 4     0.177  0.237362      observed        74          True
#
#    object_confidence  temporal_confidence  transform_confidence  \
# 0                1.0                  NaN                   1.0
# 1                1.0                  NaN                   1.0
# 2                0.8                  NaN                   1.0
# 3                1.0                  NaN                   1.0
# 4                0.8                  NaN                   1.0
#
#   boundary_confidence_mode                                        source_file  \
# 0                  uniform  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 1                  uniform  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 2                  uniform  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 3                  uniform  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 4                  uniform  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
#
#      source_version   variant label_variant  \
# 0  sprint3_original  original          base
# 1  sprint3_original  original          base
# 2  sprint3_original  original          base
# 3  sprint3_original  original          base
# 4  sprint3_original  original          base
#
#                                              run_dir  \
# 0  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 1  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 2  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 3  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 4  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
#
#                                          metrics_csv  \
# 0  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 1  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 2  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 3  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 4  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
#
#                                   tree_inventory_csv  \
# 0  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 1  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 2  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 3  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 4  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
#
#                                         fuels_raster  \
# 0  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 1  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 2  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 3  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 4  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
#
#                                           dtm_raster  \
# 0  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 1  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 2  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 3  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 4  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
#
#                                           chm_raster  \
# 0  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 1  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 2  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 3  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 4  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
#
#                                            input_ptx  Unnamed: 0  \
# 0  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...           1
# 1  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...           2
# 2  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...           3
# 3  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...           4
# 4  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...           5
#
#    perimeter_tls  compactness  elongation  bbox_minx  bbox_miny  bbox_maxx  \
# 0       7.398588          1.0         NaN   3.046618  11.705575   3.046618
# 1       5.160246          1.0         NaN   5.759161  11.264599   5.759161
# 2       1.581363          1.0         NaN   9.113982   9.333501   9.113982
# 3       4.720188          1.0         NaN  -8.062640   7.617650  -8.062640
# 4       1.491391          1.0         NaN  -1.666380   7.426122  -1.666380
#
#    bbox_maxy  dedup_keep  dedup_reason          x_als         y_als  \
# 0  11.705575        True           NaN  743344.416325  4.237894e+06
# 1  11.264599        True           NaN  743344.449078  4.237897e+06
# 2   9.333501        True           NaN  743345.859812  4.237901e+06
# 3   7.617650        True           NaN  743350.110286  4.237884e+06
# 4   7.426122        True           NaN  743349.348689  4.237890e+06
#
#           x_naip        y_naip        row        col        _site_id_norm
# 0  743344.501108  4.237893e+06  48.390177  33.501847  calaveras-big-trees
# 1  743344.533888  4.237896e+06  43.810409  33.556480  calaveras-big-trees
# 2  743345.944654  4.237900e+06  37.803074  35.907757  calaveras-big-trees
# 3  743350.194959  4.237883e+06  65.687059  42.991599  calaveras-big-trees
# 4  743349.433425  4.237889e+06  55.097907  41.722376  calaveras-big-trees

# %% [markdown]
# # Canonical Grid Setup

# %%
def infer_naip_band_names(path: str | Path) -> list[str]:
    path = Path(path)
    with rasterio.open(path) as src:
        count = src.count

    if count == 4:
        return ["red", "green", "blue", "nir"]
    if count == 3:
        return ["red", "green", "blue"]
    return [f"band_{i}" for i in range(1, count + 1)]


def read_raster_bundle(
    path: str | Path,
    *,
    site_id: str,
    source_name: str,
    band_names: list[str] | None = None,
) -> SourceRasterBundle:
    path = Path(path)

    with rasterio.open(path) as src:
        arr = src.read().astype(np.float32)
        nodata = src.nodata

        if nodata is not None:
            arr = np.where(arr == nodata, np.nan, arr)

        if band_names is None:
            band_names = [f"{source_name}_band_{i}" for i in range(1, src.count + 1)]

        if len(band_names) != src.count:
            raise ValueError(f"Band name count mismatch for {path}: expected {src.count}, got {len(band_names)}")

        arrays = {band_names[i]: arr[i] for i in range(src.count)}

        return SourceRasterBundle(
            site_id=site_id,
            source_name=source_name,
            arrays=arrays,
            transform=src.transform,
            crs=src.crs,
            nodata=nodata,
            metadata={
                "path": str(path),
                "width": src.width,
                "height": src.height,
                "count": src.count,
            },
        )


def canonical_grid_cache_dir(site_id: str, data_signature: str, config_signature: str) -> Path:
    return stage_cache_dir(
        stage_name="canonical_grid",
        site_id=site_id,
        source_name="naip",
        data_signature=data_signature,
        config_signature=config_signature,
    )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def resolve_site_asset_for_read(
    site_id: str,
    *,
    asset_path: str | Path | None,
    artifact_key: str,
    filename: str | None = None,
) -> Path:
    if asset_path is None:
        raise ValueError(f"No asset path registered for site={site_id} and artifact_key={artifact_key}")

    p = Path(asset_path)

    if p.exists():
        return p

    if artifact_key == "site_naip_raster":
        rel_path = render_artifact_rel_path(
            "site_naip_raster",
            site_id=site_id,
            filename=filename or p.name,
        )
        local_path = site_naip_cache_root(site_id) / (filename or p.name)
    elif artifact_key == "site_3dep_raster":
        rel_path = render_artifact_rel_path(
            "site_3dep_raster",
            site_id=site_id,
            filename=filename or p.name,
        )
        local_path = site_3dep_cache_root(site_id) / (filename or p.name)
    elif artifact_key == "site_rap_raster":
        rel_path = render_artifact_rel_path(
            "site_rap_raster",
            site_id=site_id,
            filename=filename or p.name,
        )
        local_path = site_rap_cache_root(site_id) / (filename or p.name)
    else:
        raise ValueError(f"Unsupported artifact_key for site-asset rehydration: {artifact_key}")

    if remote_artifact_exists(rel_path):
        LOGGER.info(
            "Rehydrating pruned site asset | site=%s | key=%s | rel_path=%s",
            site_id, artifact_key, rel_path
        )
        pulled = artifact_store.pull(rel_path, local_path=local_path)
        return pulled

    raise FileNotFoundError(
        f"Site asset missing locally and not found remotely | site={site_id} | key={artifact_key} | path={p}"
    )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def build_canonical_grid_for_site(
    site_id: str,
    assets: SiteAssetBundle | None = None,
    *,
    force_refresh: bool = False,
) -> CanonicalGrid:
    if assets is None:
        assets = prepare_site_assets(site_id, force_refresh=force_refresh)

    naip_asset = assets.source_assets.get("naip")
    if naip_asset is None:
        raise ValueError(f"No NAIP asset available for site={site_id}; cannot build canonical grid.")

    naip_path = resolve_site_asset_for_read(
        site_id,
        asset_path=naip_asset,
        artifact_key="site_naip_raster",
        filename=Path(naip_asset).name if naip_asset is not None else None,
    )

    data_sig = hash_payload(
        {
            "site_id": site_id,
            "naip_path": str(naip_path.name),  # use stable file identity, not transient absolute path
            "canonical_grid_source": fe_cfg.canonical_grid_source,
        }
    )
    config_sig = hash_payload(
        {
            "canonical_grid_source": fe_cfg.canonical_grid_source,
            "version": fe_cfg.version,
        }
    )
    cache_dir = canonical_grid_cache_dir(site_id, data_sig, config_sig)
    grid_json = cache_dir / "canonical_grid.json"

    if (not force_refresh) and is_valid_stage_cache(
        stage_cache_dir=cache_dir,
        expected_stage_name="canonical_grid",
        expected_data_signature=data_sig,
        expected_config_signature=config_sig,
    ) and grid_json.exists():
        payload = read_json(grid_json)
        LOGGER.info("Using cached canonical grid | site=%s", site_id)
        return CanonicalGrid(
            site_id=payload["site_id"],
            width=payload["width"],
            height=payload["height"],
            transform=Affine(*payload["transform"]),
            crs=CRS.from_user_input(payload["crs"]),
            source_name=payload["source_name"],
            nodata=payload["nodata"],
        )

    with timed_stage("canonical_grid", site_id=site_id, source_name="naip"):
        band_names = infer_naip_band_names(naip_path)

        bundle = read_raster_bundle(
            naip_path,
            site_id=site_id,
            source_name="naip",
            band_names=band_names,
        )

        h, w = next(iter(bundle.arrays.values())).shape
        grid = CanonicalGrid(
            site_id=site_id,
            width=w,
            height=h,
            transform=bundle.transform,
            crs=bundle.crs,
            source_name="naip",
            nodata=np.nan,
        )

        write_json(
            grid_json,
            {
                "site_id": grid.site_id,
                "width": grid.width,
                "height": grid.height,
                "transform": list(grid.transform)[:6],
                "crs": str(grid.crs),
                "source_name": grid.source_name,
                "nodata": grid.nodata,
            },
        )

        write_stage_cache_manifest(
            stage_cache_dir=cache_dir,
            stage_name="canonical_grid",
            data_signature=data_sig,
            config_signature=config_sig,
            module_variants=[],
            artifact_paths={"canonical_grid_json": str(grid_json)},
            success=True,
            notes=["Built canonical grid from NAIP asset."],
        )

        LOGGER.info(
            "Built canonical grid | site=%s | shape=(%d, %d) | pixel_size=%s",
            site_id, grid.height, grid.width, grid.pixel_size
        )
        return grid
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Specs

# %%
@dataclass(frozen=True)
class SourceSpec:
    name: str
    native_kind: str
    default_resampling: Resampling
    notes: str = ""


SOURCE_SPECS = {
    "naip": SourceSpec(
        name="naip",
        native_kind="multiband_raster",
        default_resampling=Resampling.nearest,
        notes="Canonical appearance source and default canonical grid anchor.",
    ),
    "als": SourceSpec(
        name="als",
        native_kind="point_cloud_or_rasterized_structure",
        default_resampling=Resampling.bilinear,
        notes="Structural source for height, canopy context, and roughness.",
    ),
    "3dep": SourceSpec(
        name="3dep",
        native_kind="terrain_raster",
        default_resampling=Resampling.bilinear,
        notes="Terrain/site context source.",
    ),
    "rap": SourceSpec(
        name="rap",
        native_kind="coarse_vegetation_raster",
        default_resampling=Resampling.bilinear,
        notes="Coarse ecological prior source.",
    ),
}


def source_spec_frame() -> pd.DataFrame:
    rows = []
    for key, spec in SOURCE_SPECS.items():
        rows.append(
            {
                "source": key,
                "native_kind": spec.native_kind,
                "default_resampling": spec.default_resampling.name,
                "notes": spec.notes,
            }
        )
    return pd.DataFrame(rows)


display(source_spec_frame())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#   source                          native_kind default_resampling  \
# 0   naip                     multiband_raster            nearest
# 1    als  point_cloud_or_rasterized_structure           bilinear
# 2   3dep                       terrain_raster           bilinear
# 3    rap             coarse_vegetation_raster           bilinear
#
#                                                notes
# 0  Canonical appearance source and default canoni...
# 1  Structural source for height, canopy context, ...
# 2                       Terrain/site context source.
# 3                    Coarse ecological prior source.

# %%
FE_ARTIFACT_SPECS = {
    "site_metadata_manifest": ArtifactSpec(
        key="site_metadata_manifest",
        rel_path_template="features/{site_id}/{config_signature}/site_assets/site_metadata_manifest.json",
        storage_tier=StorageTier.LOCAL_THEN_REMOTE,
        required_for_resume=True,
        prune_local_after_push=False,
    ),
    "source_inventory": ArtifactSpec(
        key="source_inventory",
        rel_path_template="features/{site_id}/{config_signature}/site_assets/source_inventory.json",
        storage_tier=StorageTier.LOCAL_THEN_REMOTE,
        required_for_resume=True,
        prune_local_after_push=False,
    ),
    "site_3dep_raster": ArtifactSpec(
        key="site_3dep_raster",
        rel_path_template="features/{site_id}/shared/site_assets/3dep/{filename}",
        storage_tier=StorageTier.LOCAL_THEN_REMOTE,
        required_for_resume=False,
        prune_local_after_push=True,
    ),
    "site_rap_raster": ArtifactSpec(
        key="site_rap_raster",
        rel_path_template="features/{site_id}/shared/site_assets/rap/{filename}",
        storage_tier=StorageTier.LOCAL_THEN_REMOTE,
        required_for_resume=False,
        prune_local_after_push=True,
    ),
    "site_naip_raster": ArtifactSpec(
        key="site_naip_raster",
        rel_path_template="features/{site_id}/shared/site_assets/naip/{filename}",
        storage_tier=StorageTier.LOCAL_THEN_REMOTE,
        required_for_resume=False,
        prune_local_after_push=True,
    ),
    "als_metadata_json": ArtifactSpec(
        key="als_metadata_json",
        rel_path_template="features/{site_id}/{config_signature}/site_assets/als_metadata.json",
        storage_tier=StorageTier.LOCAL_THEN_REMOTE,
        required_for_resume=True,
        prune_local_after_push=False,
    ),
    "chunk_manifest": ArtifactSpec(
        key="chunk_manifest",
        rel_path_template="features/{site_id}/{config_signature}/chunk_manifest/chunk_manifest.json",
        storage_tier=StorageTier.LOCAL_ONLY,
        required_for_resume=True,
        prune_local_after_push=False,
    ),
    "canonical_grid": ArtifactSpec(
        key="canonical_grid",
        rel_path_template="features/{site_id}/{config_signature}/canonical_grid/canonical_grid.json",
        storage_tier=StorageTier.LOCAL_ONLY,
        required_for_resume=True,
        prune_local_after_push=False,
    ),
    "family_chunk_npz": ArtifactSpec(
        key="family_chunk_npz",
        rel_path_template="features/{site_id}/{config_signature}/{source_name}/{family_name}/{chunk_id}.npz",
        storage_tier=StorageTier.LOCAL_THEN_REMOTE,
        required_for_resume=False,
        prune_local_after_push=True,
    ),
    "stack_registry": ArtifactSpec(
        key="stack_registry",
        rel_path_template="features/{site_id}/{config_signature}/stack/stack_registry.json",
        storage_tier=StorageTier.LOCAL_THEN_REMOTE,
        required_for_resume=True,
        prune_local_after_push=False,
    ),
    "object_feature_table": ArtifactSpec(
        key="object_feature_table",
        rel_path_template="features/{site_id}/{config_signature}/objects/object_features.csv",
        storage_tier=StorageTier.LOCAL_THEN_REMOTE,
        required_for_resume=True,
        prune_local_after_push=False,
    ),
    "runtime_log": ArtifactSpec(
        key="runtime_log",
        rel_path_template="features/{site_id}/{config_signature}/qa/runtime_log.csv",
        storage_tier=StorageTier.LOCAL_ONLY,
        required_for_resume=False,
        prune_local_after_push=False,
    ),
}
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def artifact_spec_frame() -> pd.DataFrame:
    rows = []
    for key, spec in FE_ARTIFACT_SPECS.items():
        rows.append(
            {
                "key": key,
                "rel_path_template": spec.rel_path_template,
                "storage_tier": spec.storage_tier.value,
                "required_for_resume": spec.required_for_resume,
                "prune_local_after_push": spec.prune_local_after_push,
            }
        )
    return pd.DataFrame(rows)


display(artifact_spec_frame())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                        key                                  rel_path_template  \
# 0   site_metadata_manifest  features/{site_id}/{config_signature}/site_ass...
# 1         source_inventory  features/{site_id}/{config_signature}/site_ass...
# 2         site_3dep_raster  features/{site_id}/shared/site_assets/3dep/{fi...
# 3          site_rap_raster  features/{site_id}/shared/site_assets/rap/{fil...
# 4         site_naip_raster  features/{site_id}/shared/site_assets/naip/{fi...
# 5        als_metadata_json  features/{site_id}/{config_signature}/site_ass...
# 6           chunk_manifest  features/{site_id}/{config_signature}/chunk_ma...
# 7           canonical_grid  features/{site_id}/{config_signature}/canonica...
# 8         family_chunk_npz  features/{site_id}/{config_signature}/{source_...
# 9           stack_registry  features/{site_id}/{config_signature}/stack/st...
# 10    object_feature_table  features/{site_id}/{config_signature}/objects/...
# 11             runtime_log  features/{site_id}/{config_signature}/qa/runti...
#
#          storage_tier  required_for_resume  prune_local_after_push
# 0   local_then_remote                 True                   False
# 1   local_then_remote                 True                   False
# 2   local_then_remote                False                    True
# 3   local_then_remote                False                    True
# 4   local_then_remote                False                    True
# 5   local_then_remote                 True                   False
# 6          local_only                 True                   False
# 7          local_only                 True                   False
# 8   local_then_remote                False                    True
# 9   local_then_remote                 True                   False
# 10  local_then_remote                 True                   False
# 11         local_only                False                   False

# %%
TEST_SITE = fe_cfg.sites[0]

site_assets = prepare_site_assets(TEST_SITE, force_refresh=False)
canonical_grid = build_canonical_grid_for_site(TEST_SITE, assets=site_assets, force_refresh=True)

print("grid.crs:", canonical_grid.crs)
print("native bounds:", canonical_grid_bounds_native(canonical_grid))
print("wgs84 bounds:", canonical_grid_bounds_wgs84(canonical_grid))
print("region coords:", canonical_grid_bbox_region_coords(canonical_grid))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 2026-04-17 10:15:07,686 | INFO     | features.notebook | START | stage=site_assets | site=calaveras-big-trees | source=None | family=None
# 2026-04-17 10:15:07,687 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=source_inventory | rel_path=features/calaveras-big-trees/02dd149b925aa1d9/site_assets/source_inventory.json
# 2026-04-17 10:15:07,688 | INFO     | features.notebook | Using cached source inventory | site=calaveras-big-trees
# 2026-04-17 10:15:07,738 | INFO     | features.notebook | Using cached NAIP | site=calaveras-big-trees | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/calaveras-big-trees/naip/calaveras_big_trees.tif
# 2026-04-17 10:15:07,738 | INFO     | features.notebook | Using cached ALS metadata (local site cache) | site=calaveras-big-trees | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/calaveras-big-trees/als_metadata/als_metadata.json
# 2026-04-17 10:15:07,834 | INFO     | features.notebook | Prepared site assets | site=calaveras-big-trees | keys=['naip', 'als_metadata', '3dep', 'rap', 'source_inventory'] | notes=0
# 2026-04-17 10:15:07,834 | INFO     | features.notebook | END   | stage=site_assets | site=calaveras-big-trees | source=None | family=None | duration=0.15s
# 2026-04-17 10:15:07,835 | INFO     | features.notebook | START | stage=canonical_grid | site=calaveras-big-trees | source=naip | family=None
# 2026-04-17 10:15:08,710 | INFO     | features.notebook | Built canonical grid | site=calaveras-big-trees | shape=(5375, 7398) | pixel_size=(0.6000000000000063, 0.6)
# 2026-04-17 10:15:08,710 | INFO     | features.notebook | END   | stage=canonical_grid | site=calaveras-big-trees | source=naip | family=None | duration=0.88s
# grid.crs: EPSG:26910
# native bounds: (739384.2, 4235353.8, 743823.0, 4238578.8)
# wgs84 bounds: (-120.2649635196327, 38.23315720757365, -120.21319438695116, 38.26338170867955)
# region coords: [[-120.2649635196327, 38.23315720757365], [-120.21319438695116, 38.23315720757365], [-120.21319438695116, 38.26338170867955], [-120.2649635196327, 38.26338170867955], [-120.2649635196327, 38.23315720757365]]

# %%
# Small end-to-end dry-run of the new generic runtime pieces for one site.
TEST_SITE = fe_cfg.sites[0]

site_assets = prepare_site_assets(TEST_SITE, force_refresh=fe_cfg.force_refresh_assets)
canonical_grid = build_canonical_grid_for_site(TEST_SITE, assets=site_assets, force_refresh=fe_cfg.force_refresh_features)
chunk_manifest = build_chunk_manifest(canonical_grid, force_refresh=fe_cfg.force_rebuild_chunk_manifest)

site_manifest_payload = try_load_json_artifact(
    artifact_key="site_metadata_manifest",
    site_id=TEST_SITE,
)
source_inventory_payload = try_load_json_artifact(
    artifact_key="source_inventory",
    site_id=TEST_SITE,
)

print("TEST_SITE:", TEST_SITE)
print("Asset keys:", list(site_assets.source_assets.keys()))
print("3DEP asset:", site_assets.source_assets.get("3dep"))
print("3DEP valid:", validate_optional_raster_asset(site_assets.source_assets.get("3dep")))
print("Notes:", site_assets.notes)
print("Canonical grid shape:", (canonical_grid.height, canonical_grid.width))
print("Pixel size:", canonical_grid.pixel_size)
print("Chunk count:", len(chunk_manifest.records))
print("Site manifest loaded:", site_manifest_payload is not None)
print("Source inventory loaded:", source_inventory_payload is not None)

display(chunk_manifest_frame(chunk_manifest).head(10))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 2026-04-17 10:15:08,740 | INFO     | features.notebook | START | stage=site_assets | site=calaveras-big-trees | source=None | family=None
# 2026-04-17 10:15:08,741 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=site_metadata_manifest | rel_path=features/calaveras-big-trees/02dd149b925aa1d9/site_assets/site_metadata_manifest.json
# 2026-04-17 10:15:08,742 | INFO     | features.notebook | Using site metadata manifest | site=calaveras-big-trees
# 2026-04-17 10:15:08,742 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=source_inventory | rel_path=features/calaveras-big-trees/02dd149b925aa1d9/site_assets/source_inventory.json
# 2026-04-17 10:15:08,743 | INFO     | features.notebook | Using cached source inventory | site=calaveras-big-trees
# 2026-04-17 10:15:08,748 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse (no manifest changes) | site=calaveras-big-trees | keys=['naip', 'als_metadata', '3dep', 'rap', 'source_inventory'] | notes=0
# 2026-04-17 10:15:08,748 | INFO     | features.notebook | END   | stage=site_assets | site=calaveras-big-trees | source=None | family=None | duration=0.01s
# 2026-04-17 10:15:08,749 | INFO     | features.notebook | Using cached canonical grid | site=calaveras-big-trees
# 2026-04-17 10:15:08,750 | INFO     | features.notebook | Using cached chunk manifest | site=calaveras-big-trees | n_chunks=48
# 2026-04-17 10:15:08,751 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=site_metadata_manifest | rel_path=features/calaveras-big-trees/02dd149b925aa1d9/site_assets/site_metadata_manifest.json
# 2026-04-17 10:15:08,753 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=source_inventory | rel_path=features/calaveras-big-trees/02dd149b925aa1d9/site_assets/source_inventory.json
# TEST_SITE: calaveras-big-trees
# Asset keys: ['naip', 'als_metadata', '3dep', 'rap', 'source_inventory']
# 3DEP asset: None
# 3DEP valid: False
# Notes: []
# Canonical grid shape: (5375, 7398)
# Pixel size: (0.6000000000000063, 0.6)
# Chunk count: 48
# Site manifest loaded: True
# Source inventory loaded: True
#                site_id     chunk_id  row_start  row_end  col_start  col_end  \
# 0  calaveras-big-trees  chunk_00000          0     1024          0     1024
# 1  calaveras-big-trees  chunk_00001          0     1024       1024     2048
# 2  calaveras-big-trees  chunk_00002          0     1024       2048     3072
# 3  calaveras-big-trees  chunk_00003          0     1024       3072     4096
# 4  calaveras-big-trees  chunk_00004          0     1024       4096     5120
# 5  calaveras-big-trees  chunk_00005          0     1024       5120     6144
# 6  calaveras-big-trees  chunk_00006          0     1024       6144     7168
# 7  calaveras-big-trees  chunk_00007          0     1024       7168     7398
# 8  calaveras-big-trees  chunk_00008       1024     2048          0     1024
# 9  calaveras-big-trees  chunk_00009       1024     2048       1024     2048
#
#    halo_px
# 0       32
# 1       32
# 2       32
# 3       32
# 4       32
# 5       32
# 6       32
# 7       32
# 8       32
# 9       32

# %%
inventory = site_assets.source_assets.get("source_inventory", {})
print("3DEP inventory block:")
display(pd.DataFrame([inventory.get("3dep", {})]))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 3DEP inventory block:
#                                           remote_dir  \
# 0  https://wifire-data.sdsc.edu/nc/public.php/dav...
#
#                                           remote_url  \
# 0  https://wifire-data.sdsc.edu/nc/public.php/dav...
#
#                    expected_name  \
# 0  calaveras_big_trees_poly1.tif
#
#                                           candidates
# 0  [{'name': 'calaveras_big_trees.tif', 'url': 'h...

# %% [markdown]
# ## Remote Artifact Management

# %%
def current_fe_config_signature() -> str:
    return fe_config_signature()


def render_artifact_rel_path(
    artifact_key: str,
    *,
    site_id: str,
    config_signature: str | None = None,
    source_name: str | None = None,
    family_name: str | None = None,
    chunk_id: str | None = None,
    filename: str | None = None,
) -> str:
    spec = FE_ARTIFACT_SPECS[artifact_key]
    config_signature = config_signature or current_fe_config_signature()
    return spec.rel_path_template.format(
        site_id=site_id,
        config_signature=config_signature,
        source_name=source_name or "unknown_source",
        family_name=family_name or "unknown_family",
        chunk_id=chunk_id or "whole",
        filename=filename or "artifact.bin",
    )


def artifact_spec_for_key(artifact_key: str) -> ArtifactSpec:
    return FE_ARTIFACT_SPECS[artifact_key]


def local_artifact_abs_path(rel_path: str) -> Path:
    if isinstance(artifact_store, LocalArtifactStore):
        return artifact_store.storage_root / rel_path
    if isinstance(artifact_store, HybridArtifactStore):
        return ensure_dir(fe_cfg.cache_root / "_artifact_staging") / rel_path
    return ensure_dir(fe_cfg.cache_root / "_remote_stage") / rel_path
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
@dataclass
class PersistedArtifactRecord:
    artifact_key: str
    rel_path: str
    local_path: str | None = None
    remote_ref: str | None = None
    storage_tier: str | None = None
    exists_local: bool = False
    exists_remote: bool = False
    pruned_local: bool = False
    notes: list[str] = field(default_factory=list)


def remote_artifact_exists(rel_path: str) -> bool:
    try:
        if isinstance(artifact_store, LocalArtifactStore):
            return False
        if isinstance(artifact_store, HybridArtifactStore):
            if artifact_store.remote_store is None:
                return False
            return artifact_store.remote_store.exists(rel_path)
        return artifact_store.exists(rel_path)
    except Exception as e:
        LOGGER.warning("Remote existence check failed | rel_path=%s | err=%s", rel_path, e)
        return False


def push_artifact_if_needed(
    local_path: str | Path,
    *,
    artifact_key: str,
    rel_path: str,
) -> PersistedArtifactRecord:
    spec = artifact_spec_for_key(artifact_key)
    local_path = Path(local_path)

    rec = PersistedArtifactRecord(
        artifact_key=artifact_key,
        rel_path=rel_path,
        local_path=str(local_path),
        storage_tier=spec.storage_tier.value,
        exists_local=local_path.exists(),
    )

    if not local_path.exists():
        rec.notes.append("Local artifact missing before push.")
        return rec

    should_push_remote = (
        fe_cfg.persistence.push_large_artifacts_to_remote
        and spec.storage_tier in {StorageTier.LOCAL_THEN_REMOTE, StorageTier.REMOTE_ONLY}
        and isinstance(artifact_store, (HybridArtifactStore, DriveRegistryArtifactStore))
    )

    if should_push_remote:
        LOGGER.info(
            "PUSH ARTIFACT | key=%s | rel_path=%s",
            artifact_key, rel_path
        )
        try:
            remote_ref = artifact_store.push(local_path, rel_path=rel_path)
            rec.remote_ref = remote_ref
            rec.exists_remote = True
        except Exception as e:
            rec.exists_remote = False
            rec.notes.append(f"Remote push failed: {e}")
            LOGGER.warning(
                "Remote push failed | key=%s | rel_path=%s | err=%s",
                artifact_key, rel_path, e
            )
    else:
        rec.notes.append("Remote push skipped by policy or store type.")

    return rec


def prune_local_artifact_if_allowed(
    rec: PersistedArtifactRecord,
    *,
    local_path: str | Path,
) -> PersistedArtifactRecord:
    spec = artifact_spec_for_key(rec.artifact_key)
    local_path = Path(local_path)

    if not fe_cfg.persistence.prune_local_after_remote_push:
        rec.notes.append("Local pruning disabled by config.")
        return rec

    if not spec.prune_local_after_push:
        rec.notes.append("Artifact spec does not allow local prune.")
        return rec

    if not rec.exists_remote:
        rec.notes.append("Remote artifact not confirmed; skipping prune.")
        return rec

    if fe_cfg.persistence.verify_remote_before_prune:
        if not remote_artifact_exists(rec.rel_path):
            rec.notes.append("Remote artifact not verified; skipping prune.")
            return rec

    if local_path.exists():
        local_path.unlink()
        rec.pruned_local = True
        rec.exists_local = False
        rec.notes.append("Local artifact pruned after verified remote push.")
        LOGGER.info("PRUNED LOCAL ARTIFACT | rel_path=%s", rec.rel_path)

    return rec

def maybe_prune_local_site_naip_after_grid_build(site_id: str, naip_path: str | Path) -> None:
    naip_path = Path(naip_path)
    rel_path = render_artifact_rel_path(
        "site_naip_raster",
        site_id=site_id,
        filename=naip_path.name,
    )

    if not fe_cfg.persistence.prune_local_after_remote_push:
        return

    if not remote_artifact_exists(rel_path):
        return

    try:
        if naip_path.exists():
            naip_path.unlink()
            LOGGER.info("Pruned local NAIP site asset after canonical grid build | site=%s | path=%s", site_id, naip_path)
    except Exception as e:
        LOGGER.warning("Failed to prune local NAIP after canonical grid build | site=%s | path=%s | err=%s", site_id, naip_path, e)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def persist_json_artifact(
    payload: dict[str, Any],
    *,
    artifact_key: str,
    site_id: str,
    config_sig: str | None = None,
    source_name: str | None = None,
    family_name: str | None = None,
    chunk_id: str | None = None,
) -> PersistedArtifactRecord:
    config_sig = config_sig or current_fe_config_signature()
    rel_path = render_artifact_rel_path(
        artifact_key,
        site_id=site_id,
        config_signature=config_sig,
        source_name=source_name,
        family_name=family_name,
        chunk_id=chunk_id,
    )
    local_path = local_artifact_abs_path(rel_path)
    write_json(local_path, payload)

    rec = push_artifact_if_needed(local_path, artifact_key=artifact_key, rel_path=rel_path)
    rec = prune_local_artifact_if_allowed(rec, local_path=local_path)
    return rec

def persist_npz_artifact(
    arrays: dict[str, np.ndarray],
    *,
    artifact_key: str,
    site_id: str,
    config_sig: str | None = None,
    source_name: str,
    family_name: str,
    chunk_id: str,
) -> PersistedArtifactRecord:
    config_sig = config_sig or current_fe_config_signature()
    rel_path = render_artifact_rel_path(
        artifact_key,
        site_id=site_id,
        config_signature=config_sig,
        source_name=source_name,
        family_name=family_name,
        chunk_id=chunk_id,
    )
    local_path = local_artifact_abs_path(rel_path)
    local_path.parent.mkdir(parents=True, exist_ok=True)
    np.savez_compressed(local_path, **arrays)

    rec = push_artifact_if_needed(local_path, artifact_key=artifact_key, rel_path=rel_path)
    rec = prune_local_artifact_if_allowed(rec, local_path=local_path)
    return rec

def persist_existing_file_artifact(
    local_path: str | Path,
    *,
    artifact_key: str,
    site_id: str,
    config_sig: str | None = None,
    source_name: str | None = None,
    family_name: str | None = None,
    chunk_id: str | None = None,
    filename: str | None = None,
) -> PersistedArtifactRecord:
    config_sig = config_sig or current_fe_config_signature()
    local_path = Path(local_path)

    rel_path = render_artifact_rel_path(
        artifact_key,
        site_id=site_id,
        config_signature=config_sig,
        source_name=source_name,
        family_name=family_name,
        chunk_id=chunk_id,
        filename=filename or local_path.name,
    )

    rec = push_artifact_if_needed(
        local_path,
        artifact_key=artifact_key,
        rel_path=rel_path,
    )
    rec = prune_local_artifact_if_allowed(rec, local_path=local_path)
    return rec

def try_load_json_artifact(
    *,
    artifact_key: str,
    site_id: str,
    config_sig: str | None = None,
    source_name: str | None = None,
    family_name: str | None = None,
    chunk_id: str | None = None,
) -> dict[str, Any] | None:
    config_sig = config_sig or current_fe_config_signature()
    rel_path = render_artifact_rel_path(
        artifact_key,
        site_id=site_id,
        config_signature=config_sig,
        source_name=source_name,
        family_name=family_name,
        chunk_id=chunk_id,
    )
    local_path = local_artifact_abs_path(rel_path)

    if local_path.exists():
        LOGGER.info("LOAD ARTIFACT (local) | key=%s | rel_path=%s", artifact_key, rel_path)
        try:
            return read_json(local_path)
        except Exception as e:
            LOGGER.warning(
                "Local JSON artifact unreadable; removing stale staging file | key=%s | rel_path=%s | err=%s",
                artifact_key, rel_path, e
            )
            try:
                local_path.unlink()
            except Exception:
                pass

    if remote_artifact_exists(rel_path):
        LOGGER.info("LOAD ARTIFACT (remote) | key=%s | rel_path=%s", artifact_key, rel_path)

        if local_path.exists():
            try:
                local_path.unlink()
            except Exception:
                pass

        pulled = artifact_store.pull(rel_path, local_path=local_path)
        try:
            return read_json(pulled)
        finally:
            try:
                pulled = Path(pulled)
                if pulled.exists():
                    pulled.unlink()
                    LOGGER.info("PRUNED HYDRATED JSON | rel_path=%s", rel_path)
            except Exception as e:
                LOGGER.warning("Failed to prune hydrated JSON | rel_path=%s | err=%s", rel_path, e)

    return None
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Generic family and chunk registries

# %%
@dataclass(frozen=True)
class FeatureFamilySpec:
    key: str
    source_name: str
    runtime_tier: RuntimeTier
    required_halo_px: int
    representation_target: RepresentationTarget
    outputs_dense_layers: bool = True
    outputs_object_fields: bool = False
    notes: str = ""


NAIP_FAMILY_SPECS = {
    "raw": FeatureFamilySpec(
        key="raw",
        source_name="naip",
        runtime_tier=RuntimeTier.CHEAP,
        required_halo_px=0,
        representation_target=RepresentationTarget.RASTER,
        notes="Raw NAIP channels.",
    ),
    "veg_idx": FeatureFamilySpec(
        key="veg_idx",
        source_name="naip",
        runtime_tier=RuntimeTier.CHEAP,
        required_halo_px=0,
        representation_target=RepresentationTarget.RASTER,
        notes="Vegetation indices like NDVI / VARI.",
    ),
    "texture": FeatureFamilySpec(
        key="texture",
        source_name="naip",
        runtime_tier=RuntimeTier.MODERATE,
        required_halo_px=max(fe_cfg.naip.texture_entropy_window, max(fe_cfg.naip.texture_blur_sizes, default=0)),
        representation_target=RepresentationTarget.RASTER,
        notes="Entropy / LBP / blur / local structure features.",
    ),
    "multiscale": FeatureFamilySpec(
        key="multiscale",
        source_name="naip",
        runtime_tier=RuntimeTier.MODERATE,
        required_halo_px=max(fe_cfg.naip.multiscale_sizes, default=0),
        representation_target=RepresentationTarget.RASTER,
        notes="Multi-neighborhood statistics.",
    ),
    "color_diff": FeatureFamilySpec(
        key="color_diff",
        source_name="naip",
        runtime_tier=RuntimeTier.MODERATE,
        required_halo_px=1,
        representation_target=RepresentationTarget.RASTER,
    ),
    "granulometry": FeatureFamilySpec(
        key="granulometry",
        source_name="naip",
        runtime_tier=RuntimeTier.EXPENSIVE,
        required_halo_px=max(fe_cfg.naip.granulometry_scales, default=0),
        representation_target=RepresentationTarget.RASTER,
    ),
    "fractal": FeatureFamilySpec(
        key="fractal",
        source_name="naip",
        runtime_tier=RuntimeTier.EXPENSIVE,
        required_halo_px=max(fe_cfg.naip.fractal_scales, default=0),
        representation_target=RepresentationTarget.RASTER,
    ),
    "wavelet": FeatureFamilySpec(
        key="wavelet",
        source_name="naip",
        runtime_tier=RuntimeTier.EXPENSIVE,
        required_halo_px=16,
        representation_target=RepresentationTarget.RASTER,
    ),
    "gabor": FeatureFamilySpec(
        key="gabor",
        source_name="naip",
        runtime_tier=RuntimeTier.EXPENSIVE,
        required_halo_px=32,
        representation_target=RepresentationTarget.RASTER,
    ),
    "ldp": FeatureFamilySpec(
        key="ldp",
        source_name="naip",
        runtime_tier=RuntimeTier.MODERATE,
        required_halo_px=1,
        representation_target=RepresentationTarget.RASTER,
    ),
    "morphology": FeatureFamilySpec(
        key="morphology",
        source_name="naip",
        runtime_tier=RuntimeTier.EXPENSIVE,
        required_halo_px=max(fe_cfg.naip.morphology_window_sizes, default=0),
        representation_target=RepresentationTarget.RASTER,
    ),
}
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def family_spec_frame(specs: dict[str, FeatureFamilySpec]) -> pd.DataFrame:
    rows = []
    for key, spec in specs.items():
        rows.append(
            {
                "family": key,
                "source_name": spec.source_name,
                "runtime_tier": spec.runtime_tier.value,
                "required_halo_px": spec.required_halo_px,
                "target": spec.representation_target.value,
                "notes": spec.notes,
            }
        )
    return pd.DataFrame(rows).sort_values("family").reset_index(drop=True)


display(family_spec_frame(NAIP_FAMILY_SPECS))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#           family source_name runtime_tier  required_halo_px  target  \
# 0     color_diff        naip     moderate                 1  raster
# 1        fractal        naip    expensive                 9  raster
# 2          gabor        naip    expensive                32  raster
# 3   granulometry        naip    expensive                11  raster
# 4            ldp        naip     moderate                 1  raster
# 5     morphology        naip    expensive                11  raster
# 6     multiscale        naip     moderate                15  raster
# 7            raw        naip        cheap                 0  raster
# 8        texture        naip     moderate                11  raster
# 9        veg_idx        naip        cheap                 0  raster
# 10       wavelet        naip    expensive                16  raster
#
#                                                notes
# 0
# 1
# 2
# 3
# 4
# 5
# 6                     Multi-neighborhood statistics.
# 7                                 Raw NAIP channels.
# 8   Entropy / LBP / blur / local structure features.
# 9               Vegetation indices like NDVI / VARI.
# 10

# %%
def reproject_band_to_grid(
    src_band: np.ndarray,
    *,
    src_transform: Affine,
    src_crs: Any,
    dst_grid: CanonicalGrid,
    resampling: Resampling = Resampling.bilinear,
    dst_nodata: float = np.nan,
) -> np.ndarray:
    dst = np.full((dst_grid.height, dst_grid.width), dst_nodata, dtype=np.float32)

    reproject(
        source=src_band.astype(np.float32),
        destination=dst,
        src_transform=src_transform,
        src_crs=src_crs,
        dst_transform=dst_grid.transform,
        dst_crs=dst_grid.crs,
        src_nodata=np.nan,
        dst_nodata=dst_nodata,
        resampling=resampling,
    )
    return dst


def align_bundle_to_grid(
    bundle: SourceRasterBundle,
    *,
    dst_grid: CanonicalGrid,
    resampling: Resampling,
) -> SourceRasterBundle:
    aligned = {}
    for name, band in bundle.arrays.items():
        aligned[name] = reproject_band_to_grid(
            band,
            src_transform=bundle.transform,
            src_crs=bundle.crs,
            dst_grid=dst_grid,
            resampling=resampling,
        )

    return SourceRasterBundle(
        site_id=bundle.site_id,
        source_name=bundle.source_name,
        arrays=aligned,
        transform=dst_grid.transform,
        crs=dst_grid.crs,
        nodata=np.nan,
        metadata={**bundle.metadata, "aligned_to": dst_grid.source_name},
    )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def slice_chunk_from_arrays(
    arrays: dict[str, np.ndarray],
    record: ChunkRecord,
    *,
    full_height: int,
    full_width: int,
    halo_px: int | None = None,
) -> tuple[dict[str, np.ndarray], dict[str, int]]:
    bounds = expanded_chunk_bounds(record, height=full_height, width=full_width, halo_px=halo_px)
    out = {}
    for name, arr in arrays.items():
        out[name] = arr[
            bounds["row_start"]:bounds["row_end"],
            bounds["col_start"]:bounds["col_end"]
        ]
    return out, bounds


def crop_chunk_interior(
    expanded_arrays: dict[str, np.ndarray],
    record: ChunkRecord,
    expanded_bounds: dict[str, int],
) -> dict[str, np.ndarray]:
    row0 = record.row_start - expanded_bounds["row_start"]
    row1 = row0 + record.height
    col0 = record.col_start - expanded_bounds["col_start"]
    col1 = col0 + record.width

    cropped = {}
    for name, arr in expanded_arrays.items():
        cropped[name] = arr[row0:row1, col0:col1]
    return cropped
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## NAIP

# %%
def nan_to_num_copy(arr: np.ndarray, fill_value: float = 0.0) -> np.ndarray:
    out = arr.astype(np.float32, copy=True)
    out[~np.isfinite(out)] = fill_value
    return out


def safe_divide(num: np.ndarray, denom: np.ndarray, fill_value: float = 0.0) -> np.ndarray:
    out = np.full_like(num, fill_value, dtype=np.float32)
    mask = np.isfinite(num) & np.isfinite(denom) & (np.abs(denom) > 1e-12)
    out[mask] = (num[mask] / denom[mask]).astype(np.float32)
    return out


def quantize_image(arr: np.ndarray, levels: int = 256) -> np.ndarray:
    arr = nan_to_num_copy(arr)
    vmin = np.nanmin(arr)
    vmax = np.nanmax(arr)
    if abs(vmax - vmin) < 1e-12:
        return np.zeros_like(arr, dtype=np.uint8)
    scaled = (arr - vmin) / (vmax - vmin)
    scaled = np.clip(scaled, 0, 1)
    return (scaled * (levels - 1)).astype(np.uint8)


def gradient_magnitude(arr: np.ndarray) -> np.ndarray:
    arr = nan_to_num_copy(arr)
    gy, gx = np.gradient(arr)
    return np.sqrt(gx**2 + gy**2).astype(np.float32)


def local_std(arr: np.ndarray, size: int = 5) -> np.ndarray:
    arr = nan_to_num_copy(arr)
    mean = get_uniform_blur(arr, neighborhood_size=size)
    mean_sq = get_uniform_blur(arr**2, neighborhood_size=size)
    var = np.maximum(mean_sq - mean**2, 0.0)
    return np.sqrt(var).astype(np.float32)


def choose_base_band(arrays: dict[str, np.ndarray]) -> tuple[str, np.ndarray]:
    for name in fe_cfg.naip.base_band_preference:
        if name in arrays:
            return name, arrays[name]
    first = next(iter(arrays.keys()))
    return first, arrays[first]


def get_simple_color_diff_kernels() -> dict[str, np.ndarray]:
    return {
        "sobel_x_like": np.array([[-1, 0, 1], [-2, 0, 2], [-1, 0, 1]], dtype=np.float32),
        "sobel_y_like": np.array([[-1, -2, -1], [0, 0, 0], [1, 2, 1]], dtype=np.float32),
        "laplacian_like": np.array([[0, 1, 0], [1, -4, 1], [0, 1, 0]], dtype=np.float32),
    }
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def active_naip_family_names() -> tuple[str, ...]:
    enabled = set(fe_cfg.naip.enabled_families) | set(fe_cfg.naip.heavy_families_enabled)
    ordered = []
    for key in NAIP_FAMILY_SPECS:
        if key in enabled:
            ordered.append(key)
    return tuple(ordered)


def compute_naip_family_on_chunk(
    family_name: str,
    arrays: dict[str, np.ndarray],
) -> dict[str, np.ndarray]:
    out = {}

    if family_name == "raw":
        for name, arr in arrays.items():
            out[f"naip_raw_{name}"] = arr.astype(np.float32)
        return out

    if family_name == "veg_idx":
        red = arrays.get("red")
        green = arrays.get("green")
        blue = arrays.get("blue")
        nir = arrays.get("nir")
        if red is not None and nir is not None:
            out["naip_idx_ndvi"] = safe_divide(nir - red, nir + red)
        if red is not None and green is not None and blue is not None:
            out["naip_idx_vari"] = safe_divide(green - red, green + red - blue)
        if red is not None and green is not None:
            out["naip_idx_g_minus_r"] = (green - red).astype(np.float32)
        if green is not None and blue is not None:
            out["naip_idx_g_minus_b"] = (green - blue).astype(np.float32)
        return out

    base_name, base = choose_base_band(arrays)
    base_clean = nan_to_num_copy(base)
    base_tex = quantize_image(base_clean, levels=fe_cfg.naip.quantize_levels) if fe_cfg.naip.quantize_for_texture else base_clean

    if family_name == "texture":
        out["naip_tex_gradmag"] = gradient_magnitude(base_clean)
        out["naip_tex_localstd_5"] = local_std(base_clean, size=5)
        out["naip_tex_entropy"] = get_entropy_feature(
            base_tex,
            neighborhood_size=fe_cfg.naip.texture_entropy_window
        ).astype(np.float32)
        out[f"naip_tex_lbp_r{fe_cfg.naip.texture_lbp_radius}"] = get_fast_lbp_texture(
            base_tex, radius=fe_cfg.naip.texture_lbp_radius
        ).astype(np.float32)
        for size in fe_cfg.naip.texture_blur_sizes:
            out[f"naip_tex_blur_{size}"] = get_uniform_blur(base_clean, neighborhood_size=size).astype(np.float32)
        return out

    if family_name == "multiscale":
        selected = [name for name in ["red", "green", "nir"] if name in arrays]
        if not selected:
            selected = [base_name]
        for band_name in selected:
            band = nan_to_num_copy(arrays[band_name])
            for size in fe_cfg.naip.multiscale_sizes:
                out[f"naip_ms_mean_{band_name}_{size}"] = get_uniform_blur(band, neighborhood_size=size).astype(np.float32)
                out[f"naip_ms_std_{band_name}_{size}"] = local_std(band, size=size)
        return out

    if family_name == "color_diff":
        for kernel_name, kernel in get_simple_color_diff_kernels().items():
            out[f"naip_cd_{kernel_name}"] = get_color_diff(base_clean, kernel).astype(np.float32)
        return out

    if family_name == "granulometry":
        cube = get_granulometry_features(base_clean, scales=list(fe_cfg.naip.granulometry_scales))
        for i in range(cube.shape[2]):
            out[f"naip_gran_{i:02d}"] = cube[:, :, i].astype(np.float32)
        return out

    if family_name == "fractal":
        out["naip_frac_fd"] = get_fractal_dimension_map(base_clean, scales=list(fe_cfg.naip.fractal_scales)).astype(np.float32)
        return out

    if family_name == "wavelet":
        cube = get_wavelet_features(
            base_clean,
            wavelet_type=fe_cfg.naip.wavelet_type,
            level=fe_cfg.naip.wavelet_level,
        )
        for i in range(cube.shape[2]):
            out[f"naip_wav_{i:02d}"] = cube[:, :, i].astype(np.float32)
        return out

    if family_name == "gabor":
        idx = 0
        for freq in fe_cfg.naip.gabor_frequencies:
            for theta in fe_cfg.naip.gabor_thetas:
                out[f"naip_gabor_{idx:02d}"] = fast_cpu_gabor(base_clean, frequency=freq, theta=theta).astype(np.float32)
                idx += 1
        return out

    if family_name == "ldp":
        out["naip_ldp"] = get_ldp_feature(base_tex, k=fe_cfg.naip.ldp_k).astype(np.float32)
        return out

    if family_name == "morphology":
        for size in fe_cfg.naip.morphology_window_sizes:
            opened = grey_opening(base_clean, size=(size, size)).astype(np.float32)
            closed = grey_closing(base_clean, size=(size, size)).astype(np.float32)
            out[f"naip_morph_open_{size}"] = opened
            out[f"naip_morph_close_{size}"] = closed
            out[f"naip_morph_open_resid_{size}"] = (base_clean - opened).astype(np.float32)
            out[f"naip_morph_close_resid_{size}"] = (closed - base_clean).astype(np.float32)
        return out

    raise KeyError(f"Unsupported NAIP family: {family_name}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def family_chunk_stage_cache_dir(site_id: str, source_name: str, family_name: str, chunk_id: str, data_sig: str, config_sig: str) -> Path:
    return stage_cache_dir(
        stage_name="family_compute",
        site_id=site_id,
        source_name=f"{source_name}__{family_name}__{chunk_id}",
        data_signature=data_sig,
        config_signature=config_sig,
    )


def family_chunk_signatures(
    *,
    site_id: str,
    source_name: str,
    family_name: str,
    chunk_record: ChunkRecord,
    band_names: Iterable[str],
) -> tuple[str, str]:
    data_sig = hash_payload(
        {
            "site_id": site_id,
            "source_name": source_name,
            "family_name": family_name,
            "chunk_id": chunk_record.chunk_id,
            "chunk_bounds": asdict(chunk_record),
            "band_names": sorted(list(band_names)),
        }
    )
    config_sig = hash_payload(
        {
            "family_name": family_name,
            "naip_config": asdict(fe_cfg.naip),
            "version": fe_cfg.version,
        }
    )
    return data_sig, config_sig
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def load_npz_dict(path: str | Path) -> dict[str, np.ndarray]:
    data = np.load(path)
    return {k: data[k] for k in data.files}


def run_naip_family_on_chunk_with_cache(
    *,
    site_id: str,
    family_name: str,
    aligned_bundle: SourceRasterBundle,
    chunk_record: ChunkRecord,
    config_sig: str,
) -> tuple[dict[str, np.ndarray], PersistedArtifactRecord]:
    family_spec = NAIP_FAMILY_SPECS[family_name]
    chunk_arrays_expanded, expanded_bounds = slice_chunk_from_arrays(
        aligned_bundle.arrays,
        chunk_record,
        full_height=aligned_bundle.shape[0],
        full_width=aligned_bundle.shape[1],
        halo_px=family_spec.required_halo_px,
    )

    data_sig, family_cfg_sig = family_chunk_signatures(
        site_id=site_id,
        source_name="naip",
        family_name=family_name,
        chunk_record=chunk_record,
        band_names=chunk_arrays_expanded.keys(),
    )
    cache_dir = family_chunk_stage_cache_dir(
        site_id,
        "naip",
        family_name,
        chunk_record.chunk_id,
        data_sig,
        family_cfg_sig,
    )

    rel_path = render_artifact_rel_path(
        "family_chunk_npz",
        site_id=site_id,
        config_signature=config_sig,
        source_name="naip",
        family_name=family_name,
        chunk_id=chunk_record.chunk_id,
    )
    local_npz = local_artifact_abs_path(rel_path)

    def build_cache_record() -> PersistedArtifactRecord:
        remote_exists = remote_artifact_exists(rel_path)
        remote_ref = None
        # If the local file exists but remote_ref is unknown, we at least preserve the fact
        # that the artifact is remotely addressable by rel_path.
        if remote_exists:
            remote_ref = rel_path
        return PersistedArtifactRecord(
            artifact_key="family_chunk_npz",
            rel_path=rel_path,
            local_path=str(local_npz),
            remote_ref=remote_ref,
            storage_tier=FE_ARTIFACT_SPECS["family_chunk_npz"].storage_tier.value,
            exists_local=local_npz.exists(),
            exists_remote=remote_exists,
            pruned_local=(not local_npz.exists()) and remote_exists,
            notes=["Recovered persistence metadata from cache-hit path."],
        )

    if is_valid_stage_cache(
        stage_cache_dir=cache_dir,
        expected_stage_name="family_compute",
        expected_data_signature=data_sig,
        expected_config_signature=family_cfg_sig,
    ):
        if local_npz.exists():
            LOGGER.info(
                "FAMILY CHUNK CACHE HIT (local) | site=%s | family=%s | chunk=%s",
                site_id, family_name, chunk_record.chunk_id
            )
            return load_npz_dict(local_npz), build_cache_record()

        if remote_artifact_exists(rel_path):
            LOGGER.info(
                "FAMILY CHUNK CACHE HIT (remote) | site=%s | family=%s | chunk=%s",
                site_id, family_name, chunk_record.chunk_id
            )
            pulled = artifact_store.pull(rel_path, local_path=local_npz)
            rec = build_cache_record()
            rec.exists_local = True
            rec.local_path = str(pulled)
            return load_npz_dict(pulled), rec

    with timed_stage(
        "family_chunk_compute",
        site_id=site_id,
        source_name="naip",
        family_name=f"{family_name}:{chunk_record.chunk_id}",
        unit_amount=array_megapixels(next(iter(chunk_arrays_expanded.values()))),
    ):
        expanded_result = compute_naip_family_on_chunk(family_name, chunk_arrays_expanded)
        interior_result = crop_chunk_interior(expanded_result, chunk_record, expanded_bounds)

        persist_rec = persist_npz_artifact(
            interior_result,
            artifact_key="family_chunk_npz",
            site_id=site_id,
            config_sig=config_sig,
            source_name="naip",
            family_name=family_name,
            chunk_id=chunk_record.chunk_id,
        )

        write_stage_cache_manifest(
            stage_cache_dir=cache_dir,
            stage_name="family_compute",
            data_signature=data_sig,
            config_signature=family_cfg_sig,
            module_variants=[],
            artifact_paths={
                "family_chunk_rel_path": rel_path,
                "persisted_local_path": persist_rec.local_path,
                "persisted_remote_ref": persist_rec.remote_ref,
            },
            success=True,
            notes=[f"Computed family chunk for {family_name} / {chunk_record.chunk_id}"],
        )

        return interior_result, persist_rec
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def stack_registry_cache_dir(site_id: str, config_sig: str) -> Path:
    return stage_cache_dir(
        stage_name="stack_finalize",
        site_id=site_id,
        source_name="stack_registry",
        data_signature=site_id,
        config_signature=config_sig,
    )


def _layer_registry_key(layer: RasterLayerRecord) -> tuple:
    return (
        layer.site_id,
        layer.source_name,
        layer.family_name,
        layer.layer_name,
        layer.rel_path,
    )


def deduplicate_stack_registry(registry: RasterStackRegistry) -> RasterStackRegistry:
    seen = set()
    deduped = []
    for layer in registry.layers:
        key = _layer_registry_key(layer)
        if key not in seen:
            seen.add(key)
            deduped.append(layer)
    registry.layers = deduped
    return registry


def load_or_init_stack_registry(site_id: str, config_sig: str) -> RasterStackRegistry:
    cache_dir = stack_registry_cache_dir(site_id, config_sig)
    path = cache_dir / "stack_registry.json"

    if path.exists():
        payload = read_json(path)
        layers = [RasterLayerRecord(**row) for row in payload["layers"]]
        reg = RasterStackRegistry(site_id=payload["site_id"], config_signature=payload["config_signature"], layers=layers)
        return deduplicate_stack_registry(reg)

    return RasterStackRegistry(site_id=site_id, config_signature=config_sig, layers=[])


def save_stack_registry(registry: RasterStackRegistry) -> PersistedArtifactRecord:
    registry = deduplicate_stack_registry(registry)

    cache_dir = stack_registry_cache_dir(registry.site_id, registry.config_signature)
    path = cache_dir / "stack_registry.json"

    write_json(
        path,
        {
            "site_id": registry.site_id,
            "config_signature": registry.config_signature,
            "layers": [asdict(layer) for layer in registry.layers],
        },
    )

    rel_path = render_artifact_rel_path(
        "stack_registry",
        site_id=registry.site_id,
        config_signature=registry.config_signature,
    )
    final_local = local_artifact_abs_path(rel_path)
    final_local.parent.mkdir(parents=True, exist_ok=True)
    shutil.copy2(path, final_local)

    rec = push_artifact_if_needed(final_local, artifact_key="stack_registry", rel_path=rel_path)
    return rec


def register_family_chunk_outputs(
    registry: RasterStackRegistry,
    *,
    family_name: str,
    chunk_record: ChunkRecord,
    chunk_arrays: dict[str, np.ndarray],
    persist_rec: PersistedArtifactRecord,
):
    existing = {_layer_registry_key(layer) for layer in registry.layers}

    for layer_name, arr in chunk_arrays.items():
        layer = RasterLayerRecord(
            site_id=registry.site_id,
            source_name="naip",
            family_name=family_name,
            layer_name=f"{layer_name}::{chunk_record.chunk_id}",
            rel_path=persist_rec.rel_path,
            local_path=persist_rec.local_path,
            remote_ref=persist_rec.remote_ref,
            chunked=True,
            dtype=str(arr.dtype),
            shape=tuple(arr.shape),
            notes=[chunk_record.chunk_id] + list(persist_rec.notes),
        )
        key = _layer_registry_key(layer)
        if key not in existing:
            registry.layers.append(layer)
            existing.add(key)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def source_family_stage_cache_dir(
    site_id: str,
    source_name: str,
    family_name: str,
    chunk_id: str,
    data_sig: str,
    config_sig: str,
) -> Path:
    return stage_cache_dir(
        stage_name="family_compute",
        site_id=site_id,
        source_name=f"{source_name}__{family_name}__{chunk_id}",
        data_signature=data_sig,
        config_signature=config_sig,
    )


def source_family_chunk_signatures(
    *,
    site_id: str,
    source_name: str,
    family_name: str,
    chunk_record: ChunkRecord,
    band_names: Iterable[str],
    family_cfg_payload: dict[str, Any] | None = None,
) -> tuple[str, str]:
    data_sig = hash_payload(
        {
            "site_id": site_id,
            "source_name": source_name,
            "family_name": family_name,
            "chunk_id": chunk_record.chunk_id,
            "chunk_bounds": asdict(chunk_record),
            "band_names": sorted(list(band_names)),
        }
    )
    config_sig = hash_payload(
        {
            "source_name": source_name,
            "family_name": family_name,
            "family_cfg_payload": family_cfg_payload or {},
            "version": fe_cfg.version,
        }
    )
    return data_sig, config_sig


def register_source_family_chunk_outputs(
    registry: RasterStackRegistry,
    *,
    source_name: str,
    family_name: str,
    chunk_record: ChunkRecord,
    chunk_arrays: dict[str, np.ndarray],
    persist_rec: PersistedArtifactRecord,
):
    existing = {
        (
            layer.site_id,
            layer.source_name,
            layer.family_name,
            layer.layer_name,
            layer.rel_path,
        )
        for layer in registry.layers
    }

    for layer_name, arr in chunk_arrays.items():
        layer = RasterLayerRecord(
            site_id=registry.site_id,
            source_name=source_name,
            family_name=family_name,
            layer_name=f"{layer_name}::{chunk_record.chunk_id}",
            rel_path=persist_rec.rel_path,
            local_path=persist_rec.local_path,
            remote_ref=persist_rec.remote_ref,
            chunked=True,
            dtype=str(arr.dtype),
            shape=tuple(arr.shape),
            notes=[chunk_record.chunk_id] + list(persist_rec.notes),
        )
        key = (
            layer.site_id,
            layer.source_name,
            layer.family_name,
            layer.layer_name,
            layer.rel_path,
        )
        if key not in existing:
            registry.layers.append(layer)
            existing.add(key)


def run_source_family_on_chunk_with_cache(
    *,
    site_id: str,
    source_name: str,
    family_name: str,
    aligned_bundle: SourceRasterBundle,
    chunk_record: ChunkRecord,
    family_spec: FeatureFamilySpec,
    family_compute_fn,
    family_cfg_payload: dict[str, Any] | None = None,
    config_sig: str | None = None,
) -> tuple[dict[str, np.ndarray], PersistedArtifactRecord]:
    config_sig = config_sig or fe_config_signature()

    chunk_arrays_expanded, expanded_bounds = slice_chunk_from_arrays(
        aligned_bundle.arrays,
        chunk_record,
        full_height=aligned_bundle.shape[0],
        full_width=aligned_bundle.shape[1],
        halo_px=family_spec.required_halo_px,
    )

    data_sig, family_cfg_sig = source_family_chunk_signatures(
        site_id=site_id,
        source_name=source_name,
        family_name=family_name,
        chunk_record=chunk_record,
        band_names=chunk_arrays_expanded.keys(),
        family_cfg_payload=family_cfg_payload,
    )

    cache_dir = source_family_stage_cache_dir(
        site_id=site_id,
        source_name=source_name,
        family_name=family_name,
        chunk_id=chunk_record.chunk_id,
        data_sig=data_sig,
        config_sig=family_cfg_sig,
    )

    rel_path = render_artifact_rel_path(
        "family_chunk_npz",
        site_id=site_id,
        config_signature=config_sig,
        source_name=source_name,
        family_name=family_name,
        chunk_id=chunk_record.chunk_id,
    )
    local_npz = local_artifact_abs_path(rel_path)

    def build_cache_record() -> PersistedArtifactRecord:
        remote_exists = remote_artifact_exists(rel_path)
        remote_ref = rel_path if remote_exists else None
        return PersistedArtifactRecord(
            artifact_key="family_chunk_npz",
            rel_path=rel_path,
            local_path=str(local_npz),
            remote_ref=remote_ref,
            storage_tier=FE_ARTIFACT_SPECS["family_chunk_npz"].storage_tier.value,
            exists_local=local_npz.exists(),
            exists_remote=remote_exists,
            pruned_local=(not local_npz.exists()) and remote_exists,
            notes=[f"Recovered persistence metadata from cache-hit path ({source_name}/{family_name})."],
        )

    if is_valid_stage_cache(
        stage_cache_dir=cache_dir,
        expected_stage_name="family_compute",
        expected_data_signature=data_sig,
        expected_config_signature=family_cfg_sig,
    ):
        if local_npz.exists():
            LOGGER.info(
                "FAMILY CHUNK CACHE HIT (local) | site=%s | source=%s | family=%s | chunk=%s",
                site_id, source_name, family_name, chunk_record.chunk_id
            )
            return load_npz_dict(local_npz), build_cache_record()

        if remote_artifact_exists(rel_path):
            LOGGER.info(
                "FAMILY CHUNK CACHE HIT (remote) | site=%s | source=%s | family=%s | chunk=%s",
                site_id, source_name, family_name, chunk_record.chunk_id
            )
            pulled = artifact_store.pull(rel_path, local_path=local_npz)
            rec = build_cache_record()
            rec.exists_local = True
            rec.local_path = str(pulled)
            return load_npz_dict(pulled), rec

    with timed_stage(
        "family_chunk_compute",
        site_id=site_id,
        source_name=source_name,
        family_name=f"{family_name}:{chunk_record.chunk_id}",
        unit_amount=array_megapixels(next(iter(chunk_arrays_expanded.values()))),
    ):
        expanded_result = family_compute_fn(chunk_arrays_expanded)
        interior_result = crop_chunk_interior(expanded_result, chunk_record, expanded_bounds)

        persist_rec = persist_npz_artifact(
            interior_result,
            artifact_key="family_chunk_npz",
            site_id=site_id,
            config_sig=config_sig,
            source_name=source_name,
            family_name=family_name,
            chunk_id=chunk_record.chunk_id,
        )

        write_stage_cache_manifest(
            stage_cache_dir=cache_dir,
            stage_name="family_compute",
            data_signature=data_sig,
            config_signature=family_cfg_sig,
            module_variants=[],
            artifact_paths={
                "family_chunk_rel_path": rel_path,
                "persisted_local_path": persist_rec.local_path,
                "persisted_remote_ref": persist_rec.remote_ref,
            },
            success=True,
            notes=[f"Computed family chunk for {source_name}/{family_name}/{chunk_record.chunk_id}"],
        )

        return interior_result, persist_rec


def run_source_chunked_pipeline(
    *,
    site_id: str,
    source_name: str,
    raw_bundle: SourceRasterBundle,
    canonical_grid: CanonicalGrid,
    chunk_manifest: ChunkManifest,
    family_specs: dict[str, FeatureFamilySpec],
    family_compute_fns: dict[str, Any],
    family_cfg_payloads: dict[str, dict[str, Any]] | None = None,
    registry: RasterStackRegistry | None = None,
    rebuild_registry: bool = False,
) -> RasterStackRegistry:
    config_sig = fe_config_signature()

    aligned_bundle = align_bundle_to_grid(
        raw_bundle,
        dst_grid=canonical_grid,
        resampling=SOURCE_SPECS[source_name].default_resampling,
    )

    if registry is None or rebuild_registry:
        registry = RasterStackRegistry(site_id=site_id, config_signature=config_sig, layers=[])

    LOGGER.info(
        "SOURCE CHUNKED RUN | site=%s | source=%s | families=%s | n_chunks=%d",
        site_id, source_name, tuple(family_specs.keys()), len(chunk_manifest.records)
    )

    for family_name, family_spec in family_specs.items():
        compute_fn = family_compute_fns[family_name]
        cfg_payload = (family_cfg_payloads or {}).get(family_name, {})

        LOGGER.info(
            "SOURCE FAMILY START | site=%s | source=%s | family=%s",
            site_id, source_name, family_name
        )

        for idx, record in enumerate(chunk_manifest.records, start=1):
            est_remaining = estimate_remaining_time(
                "family_chunk_compute",
                remaining_units=max(len(chunk_manifest.records) - idx, 0),
            )
            if est_remaining is not None:
                LOGGER.info(
                    "SOURCE ETA | site=%s | source=%s | family=%s | chunk=%s | est_remaining_sec=%.2f",
                    site_id, source_name, family_name, record.chunk_id, est_remaining
                )

            chunk_arrays, persist_rec = run_source_family_on_chunk_with_cache(
                site_id=site_id,
                source_name=source_name,
                family_name=family_name,
                aligned_bundle=aligned_bundle,
                chunk_record=record,
                family_spec=family_spec,
                family_compute_fn=compute_fn,
                family_cfg_payload=cfg_payload,
                config_sig=config_sig,
            )

            register_source_family_chunk_outputs(
                registry,
                source_name=source_name,
                family_name=family_name,
                chunk_record=record,
                chunk_arrays=chunk_arrays,
                persist_rec=persist_rec,
            )

        LOGGER.info(
            "SOURCE FAMILY DONE | site=%s | source=%s | family=%s",
            site_id, source_name, family_name
        )

    registry = deduplicate_stack_registry(registry)
    save_stack_registry(registry)
    LOGGER.info(
        "SOURCE CHUNKED RUN COMPLETE | site=%s | source=%s | registered_layers=%d",
        site_id, source_name, len(registry.layers)
    )
    return registry
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def run_naip_chunked_pipeline(
    site_id: str,
    *,
    assets: SiteAssetBundle | None = None,
    grid: CanonicalGrid | None = None,
    chunk_manifest: ChunkManifest | None = None,
    rebuild_registry: bool = True,
) -> RasterStackRegistry:
    config_sig = fe_config_signature()

    if assets is None:
        assets = prepare_site_assets(site_id, force_refresh=fe_cfg.force_refresh_assets)
    if grid is None:
        grid = build_canonical_grid_for_site(site_id, assets=assets, force_refresh=fe_cfg.force_refresh_features)
    if chunk_manifest is None:
        chunk_manifest = build_chunk_manifest(grid, force_refresh=fe_cfg.force_rebuild_chunk_manifest)

    naip_path = assets.source_assets["naip"]
    raw_bundle = read_raster_bundle(
        naip_path,
        site_id=site_id,
        source_name="naip",
        band_names=infer_naip_band_names(naip_path),
    )
    aligned_bundle = align_bundle_to_grid(
        raw_bundle,
        dst_grid=grid,
        resampling=SOURCE_SPECS["naip"].default_resampling,
    )

    family_names = active_naip_family_names()
    registry = RasterStackRegistry(site_id=site_id, config_signature=config_sig, layers=[]) if rebuild_registry else load_or_init_stack_registry(site_id, config_sig)

    LOGGER.info(
        "NAIP CHUNKED RUN | site=%s | families=%s | n_chunks=%d",
        site_id, family_names, len(chunk_manifest.records)
    )

    for family_name in family_names:
        LOGGER.info("NAIP FAMILY START | site=%s | family=%s", site_id, family_name)

        for idx, record in enumerate(chunk_manifest.records, start=1):
            est_remaining = estimate_remaining_time(
                "family_chunk_compute",
                remaining_units=max(len(chunk_manifest.records) - idx, 0),
            )
            if est_remaining is not None:
                LOGGER.info(
                    "NAIP ETA | site=%s | family=%s | chunk=%s | est_remaining_sec=%.2f",
                    site_id, family_name, record.chunk_id, est_remaining
                )

            chunk_arrays, persist_rec = run_naip_family_on_chunk_with_cache(
                site_id=site_id,
                family_name=family_name,
                aligned_bundle=aligned_bundle,
                chunk_record=record,
                config_sig=config_sig,
            )

            register_family_chunk_outputs(
                registry,
                family_name=family_name,
                chunk_record=record,
                chunk_arrays=chunk_arrays,
                persist_rec=persist_rec,
            )

        LOGGER.info("NAIP FAMILY DONE | site=%s | family=%s", site_id, family_name)

    registry = deduplicate_stack_registry(registry)
    save_stack_registry(registry)
    LOGGER.info("NAIP CHUNKED RUN COMPLETE | site=%s | registered_layers=%d", site_id, len(registry.layers))
    return registry
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def refresh_artifact_store():
    global artifact_store
    artifact_store = build_artifact_store(fe_cfg.storage)
    LOGGER.info("Refreshed artifact store | type=%s", type(artifact_store).__name__)
    return artifact_store
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
fe_cfg.storage.enable_drive_store = True
fe_cfg.storage.use_hybrid_store = True
fe_cfg.storage.enable_local_store = True

fe_cfg.persistence.push_large_artifacts_to_remote = True
fe_cfg.persistence.prune_local_after_remote_push = True
fe_cfg.persistence.verify_remote_before_prune = True

artifact_store = refresh_artifact_store()
print(type(artifact_store).__name__)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 2026-04-17 10:56:05,544 | INFO     | features.notebook | Using HybridArtifactStore
# 2026-04-17 10:56:05,544 | INFO     | features.notebook | Refreshed artifact store | type=HybridArtifactStore
# HybridArtifactStore

# %%
TEST_SITE = fe_cfg.sites[0]

naip_stack_registry = run_naip_chunked_pipeline(
    TEST_SITE,
    assets=site_assets,
    grid=canonical_grid,
    chunk_manifest=chunk_manifest,
    rebuild_registry=True,
)

print("Registered layers:", len(naip_stack_registry.layers))
display(pd.DataFrame([asdict(x) for x in naip_stack_registry.layers[:10]]))

# %% [markdown]
# # Object aggregation and stack assembly

# %%
def pixel_from_xy(transform: Affine, x: float, y: float) -> tuple[int, int]:
    col, row = ~transform * (x, y)
    return int(round(row)), int(round(col))


def clip_window(row: int, col: int, radius: int, height: int, width: int) -> tuple[slice, slice]:
    r0 = max(0, row - radius)
    r1 = min(height, row + radius + 1)
    c0 = max(0, col - radius)
    c1 = min(width, col + radius + 1)
    return slice(r0, r1), slice(c0, c1)


def summarize_patch(arr: np.ndarray, rs: slice, cs: slice, stats: tuple[str, ...]) -> dict[str, float]:
    patch = arr[rs, cs]
    vals = patch[np.isfinite(patch)]
    if vals.size == 0:
        return {stat: np.nan for stat in stats}

    out = {}
    if "mean" in stats:
        out["mean"] = float(np.mean(vals))
    if "std" in stats:
        out["std"] = float(np.std(vals))
    if "min" in stats:
        out["min"] = float(np.min(vals))
    if "max" in stats:
        out["max"] = float(np.max(vals))
    return out
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def stack_registry_frame(registry: RasterStackRegistry) -> pd.DataFrame:
    return pd.DataFrame([asdict(x) for x in registry.layers]) if registry.layers else pd.DataFrame()


def parse_chunked_layer_name(layer_name: str) -> tuple[str, str]:
    if "::" not in layer_name:
        raise ValueError(f"Expected chunked layer name with '::', got: {layer_name}")
    base_name, chunk_id = layer_name.split("::", 1)
    return base_name, chunk_id


def selected_registry_rows(
    registry: RasterStackRegistry,
    *,
    source_name: str | None = None,
    family_names: Iterable[str] | None = None,
    base_layer_names: Iterable[str] | None = None,
) -> pd.DataFrame:
    df = stack_registry_frame(registry)
    if df.empty:
        return df

    if source_name is not None:
        df = df[df["source_name"] == source_name].copy()

    if family_names is not None:
        family_names = set(family_names)
        df = df[df["family_name"].isin(family_names)].copy()

    if base_layer_names is not None:
        wanted = set(base_layer_names)
        df["base_layer_name"] = df["layer_name"].str.split("::").str[0]
        df = df[df["base_layer_name"].isin(wanted)].copy()

    return df.reset_index(drop=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def load_chunk_layer_array(row: pd.Series) -> np.ndarray:
    layer_name = row["layer_name"]
    base_name, _ = parse_chunked_layer_name(layer_name)

    local_path = row.get("local_path")
    rel_path = row.get("rel_path")

    path = Path(local_path) if local_path is not None else None

    if path is not None and path.exists():
        payload = load_npz_dict(path)
        if base_name not in payload:
            raise KeyError(f"Base layer {base_name} not present in chunk npz at {path}. Keys={list(payload.keys())}")
        return payload[base_name]

    if rel_path is not None and remote_artifact_exists(rel_path):
        LOGGER.info("PULL CHUNK ARTIFACT | rel_path=%s", rel_path)
        target_local = local_artifact_abs_path(rel_path)
        target_local.parent.mkdir(parents=True, exist_ok=True)

        pulled = artifact_store.pull(rel_path, local_path=target_local)
        try:
            payload = load_npz_dict(pulled)
            if base_name not in payload:
                raise KeyError(f"Base layer {base_name} not present in pulled chunk npz at {pulled}. Keys={list(payload.keys())}")
            return payload[base_name]
        finally:
            try:
                pulled = Path(pulled)
                if pulled.exists():
                    pulled.unlink()
                    LOGGER.info("PRUNED HYDRATED CHUNK NPZ | rel_path=%s", rel_path)
            except Exception as e:
                LOGGER.warning("Failed to prune hydrated chunk NPZ | rel_path=%s | err=%s", rel_path, e)

    raise FileNotFoundError(
        f"Chunk artifact unavailable for layer={layer_name}. "
        f"local_path={local_path}, rel_path={rel_path}, remote_ref={row.get('remote_ref')}"
    )

def modeling_stack_layer_selection(registry: RasterStackRegistry) -> dict[str, list[str]]:
    df = stack_registry_frame(registry)
    if df.empty:
        return {"pixel_layers": [], "object_layers": []}

    df["base_layer_name"] = df["layer_name"].str.split("::").str[0]

    pixel_layers = sorted(df["base_layer_name"].unique().tolist())

    # For now object aggregation can use the same layer universe;
    # later you may restrict to compact/high-value families only.
    object_layers = pixel_layers.copy()

    return {
        "pixel_layers": pixel_layers,
        "object_layers": object_layers,
    }

def assemble_full_layer_from_registry(
    registry: RasterStackRegistry,
    chunk_manifest: ChunkManifest,
    canonical_grid: CanonicalGrid,
    *,
    target_layer_name: str,
) -> np.ndarray:
    rows = selected_registry_rows(registry, base_layer_names=[target_layer_name])
    if rows.empty:
        raise ValueError(f"No registered chunks found for target layer {target_layer_name}")

    out = np.full((canonical_grid.height, canonical_grid.width), np.nan, dtype=np.float32)
    chunk_lookup = {r.chunk_id: r for r in chunk_manifest.records}

    with timed_stage(
        "stack_assemble",
        site_id=canonical_grid.site_id,
        source_name="assembled_stack",
        family_name=target_layer_name,
        unit_amount=(canonical_grid.height * canonical_grid.width) / 1_000_000.0,
    ):
        for _, row in rows.iterrows():
            _, chunk_id = parse_chunked_layer_name(row["layer_name"])
            record = chunk_lookup[chunk_id]
            arr = load_chunk_layer_array(row)

            if arr.shape != (record.height, record.width):
                raise ValueError(
                    f"Chunk array shape mismatch for {chunk_id}: expected {(record.height, record.width)}, got {arr.shape}"
                )

            out[record.row_start:record.row_end, record.col_start:record.col_end] = arr

    return out
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def assemble_selected_layers(
    registry: RasterStackRegistry,
    chunk_manifest: ChunkManifest,
    canonical_grid: CanonicalGrid,
    *,
    source_name: str | None = None,
    family_names: Iterable[str] | None = None,
    base_layer_names: Iterable[str] | None = None,
) -> dict[str, np.ndarray]:
    rows = selected_registry_rows(
        registry,
        source_name=source_name,
        family_names=family_names,
        base_layer_names=base_layer_names,
    )
    if rows.empty:
        return {}

    rows = rows.copy()
    rows["base_layer_name"] = rows["layer_name"].str.split("::").str[0]

    arrays = {}
    for base_layer_name in sorted(rows["base_layer_name"].unique()):
        arrays[base_layer_name] = assemble_full_layer_from_registry(
            registry,
            chunk_manifest,
            canonical_grid,
            target_layer_name=base_layer_name,
        )
    return arrays
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def aggregate_selected_registered_layers_to_objects(
    registry: RasterStackRegistry,
    *,
    site_id: str,
    canonical_grid: CanonicalGrid,
    chunk_manifest: ChunkManifest,
    objects_df: pd.DataFrame,
    source_name: str | None = None,
    family_names: Iterable[str] | None = None,
    base_layer_names: Iterable[str] | None = None,
) -> pd.DataFrame:
    if objects_df.empty:
        LOGGER.info("OBJECT AGG | site=%s | no objects provided", site_id)
        return pd.DataFrame()

    layers = assemble_selected_layers(
        registry,
        chunk_manifest,
        canonical_grid,
        source_name=source_name,
        family_names=family_names,
        base_layer_names=base_layer_names,
    )
    if not layers:
        LOGGER.warning("OBJECT AGG | site=%s | no assembled layers selected", site_id)
        return pd.DataFrame()

    work = objects_df.copy()

    x_col = "x_naip" if "x_naip" in work.columns else ("x_als" if "x_als" in work.columns else None)
    y_col = "y_naip" if "y_naip" in work.columns else ("y_als" if "y_als" in work.columns else None)
    if x_col is None or y_col is None:
        raise ValueError("Could not find object coordinates for aggregation.")

    rows = []
    h, w = canonical_grid.height, canonical_grid.width
    px_size = canonical_grid.pixel_size[0]

    with timed_stage(
        "object_aggregation",
        site_id=site_id,
        source_name=source_name or "selected_layers",
        unit_amount=len(work),
        extra={"n_layers": len(layers)},
    ):
        for _, obj in work.iterrows():
            x = float(obj[x_col])
            y = float(obj[y_col])
            row, col = pixel_from_xy(canonical_grid.transform, x, y)

            base = {
                "site_id": site_id,
                "object_id": obj.get("object_id"),
                "plot_id": obj.get("plot_id"),
                "row": row,
                "col": col,
            }

            radius_px = fe_cfg.object_agg.square_window_radius_px
            if fe_cfg.object_agg.use_radius_scaled_window and "radius_m" in obj and pd.notna(obj["radius_m"]):
                radius_px = int(round(float(obj["radius_m"]) / px_size))
                radius_px = max(fe_cfg.object_agg.min_radius_px, min(fe_cfg.object_agg.max_radius_px, radius_px))

            if row < 0 or row >= h or col < 0 or col >= w:
                base["valid_sample"] = False
                rows.append(base)
                continue

            base["valid_sample"] = True
            rs, cs = clip_window(row, col, radius_px, h, w)

            for feat_name, arr in layers.items():
                if fe_cfg.object_agg.include_centroid_sample:
                    base[f"{feat_name}__centroid"] = float(arr[row, col]) if np.isfinite(arr[row, col]) else np.nan

                if not fe_cfg.object_agg.centroid_only:
                    stats = summarize_patch(arr, rs, cs, fe_cfg.object_agg.stats)
                    for stat_name, value in stats.items():
                        base[f"{feat_name}__{stat_name}"] = value

            rows.append(base)

    out_df = pd.DataFrame(rows)
    LOGGER.info(
        "OBJECT AGG DONE | site=%s | n_objects=%d | n_rows=%d | n_cols=%d",
        site_id, len(work), len(out_df), out_df.shape[1]
    )
    return out_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def persist_object_feature_table(
    obj_df: pd.DataFrame,
    *,
    site_id: str,
    config_sig: str | None = None,
) -> PersistedArtifactRecord:
    config_sig = config_sig or current_fe_config_signature()
    rel_path = render_artifact_rel_path(
        "object_feature_table",
        site_id=site_id,
        config_signature=config_sig,
    )
    local_path = local_artifact_abs_path(rel_path)
    local_path.parent.mkdir(parents=True, exist_ok=True)

    obj_df.to_csv(local_path, index=False)

    rec = push_artifact_if_needed(local_path, artifact_key="object_feature_table", rel_path=rel_path)
    return rec


def build_and_persist_object_feature_table(
    registry: RasterStackRegistry,
    *,
    site_id: str,
    canonical_grid: CanonicalGrid,
    chunk_manifest: ChunkManifest,
    objects_df: pd.DataFrame,
    source_name: str | None = None,
    family_names: Iterable[str] | None = None,
    base_layer_names: Iterable[str] | None = None,
) -> tuple[pd.DataFrame, PersistedArtifactRecord | None]:
    obj_df = aggregate_selected_registered_layers_to_objects(
        registry,
        site_id=site_id,
        canonical_grid=canonical_grid,
        chunk_manifest=chunk_manifest,
        objects_df=objects_df,
        source_name=source_name,
        family_names=family_names,
        base_layer_names=base_layer_names,
    )

    if obj_df.empty:
        LOGGER.warning("No object features produced for site=%s; skipping persistence.", site_id)
        return obj_df, None

    rec = persist_object_feature_table(obj_df, site_id=site_id)
    LOGGER.info("Persisted object feature table | site=%s | path=%s", site_id, rec.local_path)
    return obj_df, rec
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def export_single_band_geotiff(
    arr: np.ndarray,
    *,
    canonical_grid: CanonicalGrid,
    out_path: str | Path,
    nodata: float = np.nan,
):
    out_path = Path(out_path)
    out_path.parent.mkdir(parents=True, exist_ok=True)

    profile = canonical_grid.profile(dtype="float32", count=1, nodata=nodata)
    with rasterio.open(out_path, "w", **profile) as dst:
        dst.write(arr.astype(np.float32), 1)


def export_selected_layers_as_geotiffs(
    assembled_layers: dict[str, np.ndarray],
    *,
    canonical_grid: CanonicalGrid,
    site_id: str,
    export_root: str | Path | None = None,
) -> dict[str, Path]:
    export_root = Path(export_root) if export_root is not None else ensure_dir(fe_cfg.summary_root / site_id / "selected_stack_exports")
    export_root.mkdir(parents=True, exist_ok=True)

    out_paths = {}
    for layer_name, arr in assembled_layers.items():
        out_path = export_root / f"{layer_name}.tif"
        export_single_band_geotiff(arr, canonical_grid=canonical_grid, out_path=out_path)
        out_paths[layer_name] = out_path

    LOGGER.info("Exported %d selected layers as GeoTIFFs | site=%s | root=%s", len(out_paths), site_id, export_root)
    return out_paths


def export_selected_layers_as_npz(
    assembled_layers: dict[str, np.ndarray],
    *,
    site_id: str,
    export_root: str | Path | None = None,
) -> Path:
    export_root = Path(export_root) if export_root is not None else ensure_dir(fe_cfg.summary_root / site_id / "selected_stack_exports")
    export_root.mkdir(parents=True, exist_ok=True)

    out_path = export_root / "selected_layers.npz"
    np.savez_compressed(out_path, **assembled_layers)
    LOGGER.info("Exported selected layers as NPZ | site=%s | path=%s", site_id, out_path)
    return out_path
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# # 3DEP

# %%
TERRAIN_FAMILY_SPECS = {
    "terrain": FeatureFamilySpec(
        key="terrain",
        source_name="3dep",
        runtime_tier=RuntimeTier.MODERATE,
        required_halo_px=16,
        representation_target=RepresentationTarget.RASTER,
        notes="Elevation, slope, aspect, northness/eastness, curvature, ruggedness, TPI, exposure.",
    ),
}
display(family_spec_frame(TERRAIN_FAMILY_SPECS))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#     family source_name runtime_tier  required_halo_px  target  \
# 0  terrain        3dep     moderate                16  raster
#
#                                                notes
# 0  Elevation, slope, aspect, northness/eastness, ...

# %%
def make_terrain_family_compute_fn(
    *,
    pixel_size_m: float,
    ruggedness_kernel_radius: int,
    tpi_radius_meters: float,
    hillshade_azimuth: float,
    hillshade_zenith: float,
):
    def _compute(arrays: dict[str, np.ndarray]) -> dict[str, np.ndarray]:
        elevation = nan_to_num_copy(next(iter(arrays.values())))

        gy, gx = np.gradient(elevation)
        slope = np.sqrt(gx**2 + gy**2).astype(np.float32)

        aspect = np.arctan2(gy, gx).astype(np.float32)
        northness = np.cos(aspect).astype(np.float32)
        eastness = np.sin(aspect).astype(np.float32)

        gyy, gyx = np.gradient(gy)
        gxy, gxx = np.gradient(gx)
        curvature = (gxx + gyy).astype(np.float32)

        ruggedness = local_std(
            elevation,
            size=max(3, 2 * ruggedness_kernel_radius + 1),
        )

        tpi_window = max(5, int(round(tpi_radius_meters / max(pixel_size_m, 1e-6))))
        local_mean = get_uniform_blur(elevation, neighborhood_size=tpi_window)
        tpi = (elevation - local_mean).astype(np.float32)

        az = math.radians(hillshade_azimuth)
        zen = math.radians(hillshade_zenith)
        hillshade = (
            np.cos(zen) * np.cos(slope) +
            np.sin(zen) * np.sin(slope) * np.cos(az - aspect)
        ).astype(np.float32)

        return {
            "terrain_elevation": elevation.astype(np.float32),
            "terrain_slope": slope,
            "terrain_aspect": aspect,
            "terrain_northness": northness,
            "terrain_eastness": eastness,
            "terrain_curvature": curvature,
            "terrain_ruggedness": ruggedness,
            "terrain_tpi": tpi,
            "terrain_hillshade_exposure": hillshade,
        }

    return _compute
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def expected_3dep_filename(site_id: str) -> str:
    slug = site_id.replace("-", "_")
    return f"{slug}_3dep.tif"


def render_3dep_asset_rel_path(site_id: str, filename: str | None = None) -> str:
    filename = filename or expected_3dep_filename(site_id)
    return f"features/{site_id}/shared/site_assets/3dep/{filename}"


def local_3dep_asset_path(site_id: str, filename: str | None = None) -> Path:
    filename = filename or expected_3dep_filename(site_id)
    return site_3dep_cache_root(site_id) / filename


def validate_cached_3dep(tif_path: str | Path) -> bool:
    tif_path = Path(tif_path)
    if not tif_path.exists():
        return False

    try:
        with rasterio.open(tif_path) as src:
            if src.count < 1 or src.width <= 0 or src.height <= 0:
                return False

            # tiny probe read
            w = min(16, src.width)
            h = min(16, src.height)
            _ = src.read(1, window=rasterio.windows.Window(0, 0, w, h))
        return True
    except Exception as e:
        LOGGER.warning("Cached 3DEP validation failed for %s: %s", tif_path, e)
        return False


def persist_site_3dep_asset(site_id: str, local_path: str | Path) -> PersistedArtifactRecord:
    local_path = Path(local_path)
    rel_path = render_3dep_asset_rel_path(site_id, filename=local_path.name)
    remote_ref = artifact_store.push(local_path, rel_path=rel_path)

    return PersistedArtifactRecord(
        artifact_key="site_3dep_raster",
        rel_path=rel_path,
        local_path=str(local_path),
        remote_ref=remote_ref,
        storage_tier="shared",
        exists_local=local_path.exists(),
        exists_remote=True,
        pruned_local=False,
        notes=[f"Persisted 3DEP asset for site={site_id}"],
    )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def build_3dep_source_inventory_record(
    site_id: str,
    *,
    site_assets: SiteAssetBundle,
) -> SourceIngestRecord:
    local_cached = site_assets.source_assets.get("3dep")
    if validate_optional_raster_asset(local_cached):
        return SourceIngestRecord(
            site_id=site_id,
            source_name="3dep",
            asset_path=str(local_cached),
            status="cached_local",
            notes=["3DEP cached locally."],
        )

    rel_path = site_3dep_rel_path(site_id)
    if remote_artifact_exists(rel_path):
        return SourceIngestRecord(
            site_id=site_id,
            source_name="3dep",
            asset_path=rel_path,
            status="cached_remote_lazy",
            notes=["3DEP cached remotely and will be hydrated lazily."],
        )

    return SourceIngestRecord(
        site_id=site_id,
        source_name="3dep",
        asset_path=None,
        status="not_materialized_yet",
        notes=["3DEP has not been materialized yet."],
    )

def site_rap_rel_path(site_id: str, filename: str | None = None) -> str:
    filename = filename or f"{site_id}_rap_ee_10m.tif"
    return render_artifact_rel_path(
        "site_rap_raster",
        site_id=site_id,
        filename=filename,
    )

def build_rap_source_inventory_record(
    site_id: str,
    *,
    site_assets: SiteAssetBundle,
) -> SourceIngestRecord:
    local_cached = site_assets.source_assets.get("rap")
    if validate_optional_raster_asset(local_cached):
        return SourceIngestRecord(
            site_id=site_id,
            source_name="rap",
            asset_path=str(local_cached),
            status="cached_local",
            notes=["RAP cached locally."],
        )

    rel_path = site_rap_rel_path(site_id)
    if remote_artifact_exists(rel_path):
        return SourceIngestRecord(
            site_id=site_id,
            source_name="rap",
            asset_path=rel_path,
            status="cached_remote_lazy",
            notes=["RAP cached remotely and will be hydrated lazily."],
        )

    return SourceIngestRecord(
        site_id=site_id,
        source_name="rap",
        asset_path=None,
        status="not_materialized_yet",
        notes=["RAP has not been materialized yet."],
    )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
@dataclass
class SourceIngestRecord:
    site_id: str
    source_name: str
    asset_path: str | None = None
    status: str = "unknown"
    notes: list[str] = field(default_factory=list)


def prepare_3dep_asset(
    site_id: str,
    *,
    canonical_grid: CanonicalGrid | None = None,
    force_refresh: bool = False,
    inventory: dict[str, Any] | None = None,
) -> Path:
    local_path = site_3dep_cache_root(site_id) / f"{site_id}_3dep_ee_10m.tif"
    rel_path = site_3dep_rel_path(site_id, filename=local_path.name)

    # 1) local cache
    if (not force_refresh) and local_path.exists() and validate_cached_raster(local_path):
        LOGGER.info("Using cached 3DEP | site=%s | path=%s", site_id, local_path)
        return local_path

    # 2) artifact-store hydration
    if not force_refresh and remote_artifact_exists(rel_path):
        LOGGER.info("Hydrating 3DEP from artifact store | site=%s | rel_path=%s", site_id, rel_path)
        pulled = artifact_store.pull(rel_path, local_path=local_path)
        if validate_cached_raster(pulled):
            return pulled
        LOGGER.warning("Hydrated 3DEP failed validation | site=%s | path=%s", site_id, pulled)
        pulled.unlink(missing_ok=True)

    # 3) build from Earth Engine
    if canonical_grid is None:
        raise ValueError(
            "prepare_3dep_asset requires canonical_grid when no cached 3DEP raster is available."
        )

    ensure_ee_initialized(project="shrubwise-dc-488219")

    west, south, east, north = canonical_grid_bounds_wgs84(canonical_grid)
    region_coords = canonical_grid_bbox_region_coords(canonical_grid)
    image = ee_3dep_elevation_for_grid(canonical_grid)

    LOGGER.info(
        "Exporting 3DEP from Earth Engine | site=%s | out=%s | bounds_wgs84=(%.6f, %.6f, %.6f, %.6f)",
        site_id, local_path, west, south, east, north
    )

    export_ee_image_to_geotiff(
        image,
        out_path=local_path,
        region_coords=region_coords,
        scale=10.0,
        crs="EPSG:4326",
    )

    if not validate_cached_raster(local_path):
        raise RuntimeError(f"Exported 3DEP is unreadable for site={site_id}: {local_path}")

    persist_existing_file_artifact(
        local_path,
        artifact_key="site_3dep_raster",
        site_id=site_id,
        filename=local_path.name,
    )

    # If policy pruned local after push, rehydrate immediately only if caller needs the file now.
    if not local_path.exists():
        LOGGER.info("3DEP local file was pruned after push; rehydrating for current use | site=%s", site_id)
        artifact_store.pull(rel_path, local_path=local_path)

    LOGGER.info("Prepared 3DEP asset | site=%s | path=%s", site_id, local_path)
    return local_path

def maybe_prune_local_site_3dep_after_load(site_id: str, tif_path: str | Path) -> None:
    tif_path = Path(tif_path)
    rel_path = site_3dep_rel_path(site_id, filename=tif_path.name)

    if not fe_cfg.persistence.prune_local_after_remote_push:
        return

    if not remote_artifact_exists(rel_path):
        return

    try:
        if tif_path.exists():
            tif_path.unlink()
            LOGGER.info("Pruned local 3DEP site asset after in-memory load | site=%s | path=%s", site_id, tif_path)
    except Exception as e:
        LOGGER.warning("Failed to prune local 3DEP asset | site=%s | path=%s | err=%s", site_id, tif_path, e)

def load_3dep_source_bundle(
    site_id: str,
    *,
    site_assets: SiteAssetBundle,
    canonical_grid: CanonicalGrid,
    force_refresh: bool = False,
) -> SourceRasterBundle:
    tif_path = prepare_3dep_asset(
        site_id,
        canonical_grid=canonical_grid,
        force_refresh=force_refresh,
        inventory=site_assets.source_assets.get("source_inventory"),
    )

    bundle = read_raster_bundle(
        tif_path,
        site_id=site_id,
        source_name="3dep",
        band_names=["elevation"],
    )

    # Keep notebook disk footprint low: after the raster is in memory, let remote store hold the durable copy.
    maybe_prune_local_site_3dep_after_load(site_id, tif_path)

    return bundle


def align_3dep_to_canonical_grid(
    bundle: SourceRasterBundle,
    *,
    canonical_grid: CanonicalGrid,
) -> SourceRasterBundle:
    return align_bundle_to_grid(
        bundle,
        dst_grid=canonical_grid,
        resampling=SOURCE_SPECS["3dep"].default_resampling,
    )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def run_3dep_chunked_pipeline(
    site_id: str,
    *,
    site_assets: SiteAssetBundle,
    canonical_grid: CanonicalGrid,
    chunk_manifest: ChunkManifest,
    registry: RasterStackRegistry | None = None,
    force_refresh_source: bool = False,
) -> RasterStackRegistry:
    raw_bundle = load_3dep_source_bundle(
        site_id,
        site_assets=site_assets,
        canonical_grid=canonical_grid,
        force_refresh=force_refresh_source,
    )

    terrain_compute_fn = make_terrain_family_compute_fn(
        pixel_size_m=canonical_grid.pixel_size[0],
        ruggedness_kernel_radius=fe_cfg.terrain.ruggedness_kernel_radius,
        tpi_radius_meters=fe_cfg.terrain.tpi_radius_meters,
        hillshade_azimuth=fe_cfg.terrain.hillshade_azimuth,
        hillshade_zenith=fe_cfg.terrain.hillshade_zenith,
    )

    return run_source_chunked_pipeline(
        site_id=site_id,
        source_name="3dep",
        raw_bundle=raw_bundle,
        canonical_grid=canonical_grid,
        chunk_manifest=chunk_manifest,
        family_specs=TERRAIN_FAMILY_SPECS,
        family_compute_fns={
            "terrain": terrain_compute_fn,
        },
        family_cfg_payloads={
            "terrain": {
                "ruggedness_kernel_radius": fe_cfg.terrain.ruggedness_kernel_radius,
                "tpi_radius_meters": fe_cfg.terrain.tpi_radius_meters,
                "hillshade_azimuth": fe_cfg.terrain.hillshade_azimuth,
                "hillshade_zenith": fe_cfg.terrain.hillshade_zenith,
                "pixel_size_m": canonical_grid.pixel_size[0],
            }
        },
        registry=registry,
    )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
TEST_SITE = fe_cfg.sites[0]

site_assets = prepare_site_assets(TEST_SITE, force_refresh=False)
canonical_grid = build_canonical_grid_for_site(TEST_SITE, assets=site_assets, force_refresh=True)

print("grid.crs:", canonical_grid.crs)
print("native bounds:", canonical_grid_bounds_native(canonical_grid))
print("wgs84 bounds:", canonical_grid_bounds_wgs84(canonical_grid))
print("region coords:", canonical_grid_bbox_region_coords(canonical_grid))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 2026-04-17 08:30:19,479 | INFO     | features.notebook | START | stage=site_assets | site=calaveras-big-trees | source=None | family=None
# 2026-04-17 08:30:19,481 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=source_inventory | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 08:30:19,481 | INFO     | features.notebook | Using cached source inventory | site=calaveras-big-trees
# 2026-04-17 08:30:19,482 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=site_metadata_manifest | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:30:19,527 | INFO     | features.notebook | Using site metadata manifest | site=calaveras-big-trees
# 2026-04-17 08:30:19,717 | INFO     | features.notebook | PUSH ARTIFACT | key=site_metadata_manifest | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# [artifact_store] Using cached Google Drive credentials.
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:30:28,278 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse | site=calaveras-big-trees | keys=['naip', 'als_metadata', 'source_inventory', '3dep', 'rap'] | notes=1
# 2026-04-17 08:30:28,278 | INFO     | features.notebook | END   | stage=site_assets | site=calaveras-big-trees | source=None | family=None | duration=8.80s
# 2026-04-17 08:30:28,279 | INFO     | features.notebook | START | stage=canonical_grid | site=calaveras-big-trees | source=naip | family=None
# 2026-04-17 08:30:33,956 | INFO     | features.notebook | Built canonical grid | site=calaveras-big-trees | shape=(5375, 7398) | pixel_size=(0.6000000000000063, 0.6)
# 2026-04-17 08:30:33,957 | INFO     | features.notebook | END   | stage=canonical_grid | site=calaveras-big-trees | source=naip | family=None | duration=5.68s
# grid.crs: EPSG:26910
# native bounds: (739384.2, 4235353.8, 743823.0, 4238578.8)
# wgs84 bounds: (-120.2649635196327, 38.23315720757365, -120.21319438695116, 38.26338170867955)
# region coords: [[-120.2649635196327, 38.23315720757365], [-120.21319438695116, 38.23315720757365], [-120.21319438695116, 38.26338170867955], [-120.2649635196327, 38.26338170867955], [-120.2649635196327, 38.23315720757365]]

# %%
rows = []
for site_id in fe_cfg.sites:
    try:
        site_assets = prepare_site_assets(site_id, force_refresh=False)
        rows.append({
            "site_id": site_id,
            "naip_ok": site_assets.source_assets.get("naip") is not None,
            "naip_path": str(site_assets.source_assets.get("naip")),
            "notes": " | ".join(site_assets.notes),
        })
    except Exception as e:
        rows.append({
            "site_id": site_id,
            "naip_ok": False,
            "naip_path": None,
            "notes": str(e),
        })

display(pd.DataFrame(rows))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 2026-04-17 08:30:33,968 | INFO     | features.notebook | START | stage=site_assets | site=calaveras-big-trees | source=None | family=None
# 2026-04-17 08:30:33,969 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=source_inventory | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 08:30:33,976 | INFO     | features.notebook | Using cached source inventory | site=calaveras-big-trees
# 2026-04-17 08:30:33,976 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=site_metadata_manifest | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:30:33,978 | INFO     | features.notebook | Using site metadata manifest | site=calaveras-big-trees
# 2026-04-17 08:30:34,104 | INFO     | features.notebook | PUSH ARTIFACT | key=site_metadata_manifest | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:30:40,834 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse | site=calaveras-big-trees | keys=['naip', 'als_metadata', 'source_inventory', '3dep', 'rap'] | notes=1
# 2026-04-17 08:30:40,835 | INFO     | features.notebook | END   | stage=site_assets | site=calaveras-big-trees | source=None | family=None | duration=6.87s
# 2026-04-17 08:30:40,835 | INFO     | features.notebook | START | stage=site_assets | site=dl-bliss | source=None | family=None
# 2026-04-17 08:30:40,836 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=source_inventory | rel_path=features/dl-bliss/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 08:30:40,837 | INFO     | features.notebook | Using cached source inventory | site=dl-bliss
# 2026-04-17 08:30:40,837 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=site_metadata_manifest | rel_path=features/dl-bliss/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:30:40,881 | INFO     | features.notebook | Using site metadata manifest | site=dl-bliss
# 2026-04-17 08:30:40,882 | INFO     | features.notebook | Hydrating NAIP from artifact store | site=dl-bliss | rel_path=features/dl-bliss/shared/site_assets/naip/dl_bliss.tif
# 2026-04-17 08:30:42,416 | WARNING  | rasterio._env | CPLE_AppDefined in dl_bliss.tif: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 08:30:42,465 | WARNING  | rasterio._env | CPLE_AppDefined in TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 08:30:42,604 | INFO     | features.notebook | PUSH ARTIFACT | key=site_metadata_manifest | rel_path=features/dl-bliss/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# [artifact_store] Updating existing Drive artifact for features/dl-bliss/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:30:48,977 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse | site=dl-bliss | keys=['naip', 'als_metadata', '3dep', 'source_inventory', 'rap'] | notes=4
# 2026-04-17 08:30:48,977 | INFO     | features.notebook | END   | stage=site_assets | site=dl-bliss | source=None | family=None | duration=8.14s
# 2026-04-17 08:30:48,978 | INFO     | features.notebook | START | stage=site_assets | site=independence-lake | source=None | family=None
# 2026-04-17 08:30:48,979 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=source_inventory | rel_path=features/independence-lake/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 08:30:49,023 | INFO     | features.notebook | Using cached source inventory | site=independence-lake
# 2026-04-17 08:30:49,023 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=site_metadata_manifest | rel_path=features/independence-lake/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:30:49,067 | INFO     | features.notebook | Using site metadata manifest | site=independence-lake
# 2026-04-17 08:30:49,283 | INFO     | features.notebook | PUSH ARTIFACT | key=site_metadata_manifest | rel_path=features/independence-lake/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# [artifact_store] Updating existing Drive artifact for features/independence-lake/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:30:55,837 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse | site=independence-lake | keys=['naip', 'als_metadata', '3dep', 'source_inventory', 'rap'] | notes=0
# 2026-04-17 08:30:55,838 | INFO     | features.notebook | END   | stage=site_assets | site=independence-lake | source=None | family=None | duration=6.86s
# 2026-04-17 08:30:55,838 | INFO     | features.notebook | START | stage=site_assets | site=pacific-union-college | source=None | family=None
# 2026-04-17 08:30:55,839 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=source_inventory | rel_path=features/pacific-union-college/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 08:30:56,084 | INFO     | features.notebook | Using cached source inventory | site=pacific-union-college
# 2026-04-17 08:30:56,085 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=site_metadata_manifest | rel_path=features/pacific-union-college/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:30:56,128 | INFO     | features.notebook | Using site metadata manifest | site=pacific-union-college
# 2026-04-17 08:30:56,216 | INFO     | features.notebook | Hydrating NAIP from artifact store | site=pacific-union-college | rel_path=features/pacific-union-college/shared/site_assets/naip/pacific_union_college.tif
# 2026-04-17 08:31:00,263 | INFO     | features.notebook | PUSH ARTIFACT | key=site_metadata_manifest | rel_path=features/pacific-union-college/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# [artifact_store] Updating existing Drive artifact for features/pacific-union-college/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:31:06,240 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse | site=pacific-union-college | keys=['naip', 'als_metadata', '3dep', 'source_inventory', 'rap'] | notes=0
# 2026-04-17 08:31:06,241 | INFO     | features.notebook | END   | stage=site_assets | site=pacific-union-college | source=None | family=None | duration=10.40s
# 2026-04-17 08:31:06,241 | INFO     | features.notebook | START | stage=site_assets | site=sedgwick | source=None | family=None
# 2026-04-17 08:31:06,242 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=source_inventory | rel_path=features/sedgwick/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 08:31:06,242 | INFO     | features.notebook | Using cached source inventory | site=sedgwick
# 2026-04-17 08:31:06,243 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=site_metadata_manifest | rel_path=features/sedgwick/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:31:06,287 | INFO     | features.notebook | Using site metadata manifest | site=sedgwick
# 2026-04-17 08:31:06,374 | INFO     | features.notebook | Hydrating NAIP from artifact store | site=sedgwick | rel_path=features/sedgwick/shared/site_assets/naip/sedgwick.tif
# 2026-04-17 08:31:12,475 | INFO     | features.notebook | PUSH ARTIFACT | key=site_metadata_manifest | rel_path=features/sedgwick/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# [artifact_store] Updating existing Drive artifact for features/sedgwick/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:32:06,290 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse | site=sedgwick | keys=['naip', 'als_metadata', '3dep', 'source_inventory', 'rap'] | notes=0
# 2026-04-17 08:32:06,290 | INFO     | features.notebook | END   | stage=site_assets | site=sedgwick | source=None | family=None | duration=60.05s
# 2026-04-17 08:32:06,290 | INFO     | features.notebook | SLOW  | stage=site_assets | duration=60.05s exceeded threshold=30.00s
# 2026-04-17 08:32:06,291 | INFO     | features.notebook | START | stage=site_assets | site=shaver-lake | source=None | family=None
# 2026-04-17 08:32:06,292 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=source_inventory | rel_path=features/shaver-lake/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 08:32:06,335 | INFO     | features.notebook | Using cached source inventory | site=shaver-lake
# 2026-04-17 08:32:06,336 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=site_metadata_manifest | rel_path=features/shaver-lake/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:32:06,379 | INFO     | features.notebook | Using site metadata manifest | site=shaver-lake
# 2026-04-17 08:32:06,466 | INFO     | features.notebook | Hydrating NAIP from artifact store | site=shaver-lake | rel_path=features/shaver-lake/shared/site_assets/naip/shaver_lake.tif
# 2026-04-17 08:32:09,419 | INFO     | features.notebook | PUSH ARTIFACT | key=site_metadata_manifest | rel_path=features/shaver-lake/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# [artifact_store] Updating existing Drive artifact for features/shaver-lake/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:32:15,681 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse | site=shaver-lake | keys=['naip', 'als_metadata', '3dep', 'source_inventory', 'rap'] | notes=0
# 2026-04-17 08:32:15,682 | INFO     | features.notebook | END   | stage=site_assets | site=shaver-lake | source=None | family=None | duration=9.39s
#                  site_id  naip_ok  \
# 0    calaveras-big-trees     True
# 1               dl-bliss     True
# 2      independence-lake     True
# 3  pacific-union-college     True
# 4               sedgwick     True
# 5            shaver-lake     True
#
#                                            naip_path  \
# 0  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 1  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 2  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 3  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 4  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 5  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
#
#                                                notes
# 0  3DEP unavailable: Downloaded 3DEP is unreadabl...
# 1  NAIP unavailable during manifest enrichment: D...
# 2
# 3
# 4
# 5

# %%
TEST_SITE = fe_cfg.sites[0]

registry_3dep = run_3dep_chunked_pipeline(
    TEST_SITE,
    site_assets=site_assets,
    canonical_grid=canonical_grid,
    chunk_manifest=chunk_manifest,
    registry=RasterStackRegistry(
        site_id=TEST_SITE,
        config_signature=fe_config_signature(),
        layers=[],
    ),
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 2026-04-17 06:26:55,445 | INFO     | features.notebook | Hydrating 3DEP from artifact store | site=calaveras-big-trees | rel_path=features/calaveras-big-trees/shared/site_assets/3dep/calaveras-big-trees_3dep_ee_10m.tif
# 2026-04-17 06:26:55,604 | INFO     | features.notebook | Pruned local 3DEP site asset after in-memory load | site=calaveras-big-trees | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/calaveras-big-trees/3dep/calaveras-big-trees_3dep_ee_10m.tif
# 2026-04-17 06:26:57,902 | INFO     | features.notebook | SOURCE CHUNKED RUN | site=calaveras-big-trees | source=3dep | families=('terrain',) | n_chunks=48
# 2026-04-17 06:26:57,903 | INFO     | features.notebook | SOURCE FAMILY START | site=calaveras-big-trees | source=3dep | family=terrain
# 2026-04-17 06:26:57,903 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00000 | est_remaining_sec=95.92
# 2026-04-17 06:26:58,952 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00000
# 2026-04-17 06:27:01,783 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00000.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00000.npz
# 2026-04-17 06:27:08,020 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00000.npz
# 2026-04-17 06:27:08,127 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00000 | duration=9.18s | sec_per_unit=8.4834
# 2026-04-17 06:27:08,128 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00001 | est_remaining_sec=99.80
# 2026-04-17 06:27:09,685 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00001
# 2026-04-17 06:27:11,812 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00001.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00001.npz
# 2026-04-17 06:27:16,719 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00001.npz
# 2026-04-17 06:27:16,920 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00001 | duration=7.23s | sec_per_unit=6.5872
# 2026-04-17 06:27:16,921 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00002 | est_remaining_sec=101.53
# 2026-04-17 06:27:18,489 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00002
# 2026-04-17 06:27:20,559 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00002.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00002.npz
# 2026-04-17 06:27:25,159 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00002.npz
# 2026-04-17 06:27:25,264 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00002 | duration=6.78s | sec_per_unit=6.1691
# 2026-04-17 06:27:25,264 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00003 | est_remaining_sec=102.59
# 2026-04-17 06:27:26,895 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00003
# 2026-04-17 06:27:29,017 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00003.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00003.npz
# 2026-04-17 06:27:33,548 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00003.npz
# 2026-04-17 06:27:33,650 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00003 | duration=6.76s | sec_per_unit=6.1509
# 2026-04-17 06:27:33,653 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00004 | est_remaining_sec=103.35
# 2026-04-17 06:27:35,077 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00004
# 2026-04-17 06:27:37,204 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00004.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00004.npz
# 2026-04-17 06:27:41,856 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00004.npz
# 2026-04-17 06:27:41,956 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00004 | duration=6.88s | sec_per_unit=6.2636
# 2026-04-17 06:27:41,957 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00005 | est_remaining_sec=103.95
# 2026-04-17 06:27:43,655 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00005
# 2026-04-17 06:27:46,098 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00005.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00005.npz
# 2026-04-17 06:27:50,467 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00005.npz
# 2026-04-17 06:27:50,568 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00005 | duration=6.91s | sec_per_unit=6.2944
# 2026-04-17 06:27:50,568 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00006 | est_remaining_sec=104.33
# 2026-04-17 06:27:52,044 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00006
# 2026-04-17 06:27:54,114 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00006.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00006.npz
# 2026-04-17 06:27:59,083 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00006.npz
# 2026-04-17 06:27:59,245 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00006 | duration=7.20s | sec_per_unit=6.5568
# 2026-04-17 06:27:59,247 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00007 | est_remaining_sec=104.65
# 2026-04-17 06:28:01,045 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00007
# 2026-04-17 06:28:02,237 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00007.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00007.npz
# 2026-04-17 06:28:06,236 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00007.npz
# 2026-04-17 06:28:06,366 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00007 | duration=5.32s | sec_per_unit=20.7982
# 2026-04-17 06:28:06,366 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00008 | est_remaining_sec=114.47
# 2026-04-17 06:28:07,903 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00008
# 2026-04-17 06:28:10,024 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00008.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00008.npz
# 2026-04-17 06:28:14,587 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00008.npz
# 2026-04-17 06:28:15,100 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00008 | duration=7.20s | sec_per_unit=6.5526
# 2026-04-17 06:28:15,100 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00009 | est_remaining_sec=113.91
# 2026-04-17 06:28:16,614 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00009
# 2026-04-17 06:28:18,699 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00009.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00009.npz
# 2026-04-17 06:28:23,417 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00009.npz
# 2026-04-17 06:28:23,539 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00009 | duration=6.92s | sec_per_unit=6.2100
# 2026-04-17 06:28:23,539 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00010 | est_remaining_sec=112.92
# 2026-04-17 06:28:24,990 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00010
# 2026-04-17 06:28:27,044 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00010.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00010.npz
# 2026-04-17 06:28:31,728 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00010.npz
# 2026-04-17 06:28:31,839 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00010 | duration=6.85s | sec_per_unit=6.1413
# 2026-04-17 06:28:31,839 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00011 | est_remaining_sec=111.72
# 2026-04-17 06:28:33,365 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00011
# 2026-04-17 06:28:35,698 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00011.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00011.npz
# 2026-04-17 06:28:40,094 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00011.npz
# 2026-04-17 06:28:40,204 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00011 | duration=6.84s | sec_per_unit=6.1330
# 2026-04-17 06:28:40,205 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00012 | est_remaining_sec=110.36
# 2026-04-17 06:28:41,718 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00012
# 2026-04-17 06:28:43,954 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00012.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00012.npz
# 2026-04-17 06:28:48,380 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00012.npz
# 2026-04-17 06:28:48,493 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00012 | duration=6.77s | sec_per_unit=6.0750
# 2026-04-17 06:28:48,493 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00013 | est_remaining_sec=108.81
# 2026-04-17 06:28:49,965 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00013
# 2026-04-17 06:28:52,110 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00013.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00013.npz
# 2026-04-17 06:28:56,438 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00013.npz
# 2026-04-17 06:28:56,527 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00013 | duration=6.56s | sec_per_unit=5.8846
# 2026-04-17 06:28:56,528 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00014 | est_remaining_sec=107.01
# 2026-04-17 06:28:58,200 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00014
# 2026-04-17 06:29:00,255 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00014.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00014.npz
# 2026-04-17 06:29:04,877 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00014.npz
# 2026-04-17 06:29:04,971 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00014 | duration=6.77s | sec_per_unit=6.0721
# 2026-04-17 06:29:04,971 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00015 | est_remaining_sec=105.19
# 2026-04-17 06:29:06,556 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00015
# 2026-04-17 06:29:07,112 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00015.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00015.npz
# 2026-04-17 06:29:11,389 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00015.npz
# 2026-04-17 06:29:11,503 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00015 | duration=4.95s | sec_per_unit=19.0435
# 2026-04-17 06:29:11,506 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00016 | est_remaining_sec=109.41
# 2026-04-17 06:29:13,514 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00016
# 2026-04-17 06:29:15,766 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00016.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00016.npz
# 2026-04-17 06:29:20,212 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00016.npz
# 2026-04-17 06:29:20,306 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00016 | duration=6.79s | sec_per_unit=6.1844
# 2026-04-17 06:29:20,307 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00017 | est_remaining_sec=107.09
# 2026-04-17 06:29:21,779 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00017
# 2026-04-17 06:29:23,901 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00017.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00017.npz
# 2026-04-17 06:29:28,432 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00017.npz
# 2026-04-17 06:29:28,529 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00017 | duration=6.75s | sec_per_unit=6.0532
# 2026-04-17 06:29:28,529 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00018 | est_remaining_sec=104.60
# 2026-04-17 06:29:30,098 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00018
# 2026-04-17 06:29:32,241 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00018.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00018.npz
# 2026-04-17 06:29:36,354 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00018.npz
# 2026-04-17 06:29:36,452 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00018 | duration=6.35s | sec_per_unit=5.6972
# 2026-04-17 06:29:36,452 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00019 | est_remaining_sec=101.85
# 2026-04-17 06:29:37,831 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00019
# 2026-04-17 06:29:40,008 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00019.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00019.npz
# 2026-04-17 06:29:44,347 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00019.npz
# 2026-04-17 06:29:44,444 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00019 | duration=6.61s | sec_per_unit=5.9305
# 2026-04-17 06:29:44,445 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00020 | est_remaining_sec=99.11
# 2026-04-17 06:29:45,862 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00020
# 2026-04-17 06:29:47,945 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00020.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00020.npz
# 2026-04-17 06:29:52,554 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00020.npz
# 2026-04-17 06:29:52,651 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00020 | duration=6.79s | sec_per_unit=6.0885
# 2026-04-17 06:29:52,652 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00021 | est_remaining_sec=96.34
# 2026-04-17 06:29:54,274 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00021
# 2026-04-17 06:29:56,411 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00021.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00021.npz
# 2026-04-17 06:30:00,549 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00021.npz
# 2026-04-17 06:30:00,750 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00021 | duration=6.48s | sec_per_unit=5.8071
# 2026-04-17 06:30:00,751 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00022 | est_remaining_sec=93.37
# 2026-04-17 06:30:02,133 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00022
# 2026-04-17 06:30:05,026 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00022.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00022.npz
# 2026-04-17 06:30:10,143 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00022.npz
# 2026-04-17 06:30:10,253 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00022 | duration=8.12s | sec_per_unit=7.2815
# 2026-04-17 06:30:10,254 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00023 | est_remaining_sec=90.82
# 2026-04-17 06:30:11,740 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00023
# 2026-04-17 06:30:12,308 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00023.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00023.npz
# 2026-04-17 06:30:16,773 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00023.npz
# 2026-04-17 06:30:16,887 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00023 | duration=5.15s | sec_per_unit=19.8132
# 2026-04-17 06:30:16,888 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00024 | est_remaining_sec=92.09
# 2026-04-17 06:30:18,666 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00024
# 2026-04-17 06:30:20,796 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00024.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00024.npz
# 2026-04-17 06:30:25,245 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00024.npz
# 2026-04-17 06:30:25,379 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00024 | duration=6.71s | sec_per_unit=6.1132
# 2026-04-17 06:30:25,381 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00025 | est_remaining_sec=88.71
# 2026-04-17 06:30:26,919 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00025
# 2026-04-17 06:30:29,102 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00025.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00025.npz
# 2026-04-17 06:30:33,558 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00025.npz
# 2026-04-17 06:30:33,648 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00025 | duration=6.73s | sec_per_unit=6.0348
# 2026-04-17 06:30:33,649 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00026 | est_remaining_sec=85.24
# 2026-04-17 06:30:35,139 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00026
# 2026-04-17 06:30:37,236 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00026.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00026.npz
# 2026-04-17 06:30:41,841 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00026.npz
# 2026-04-17 06:30:41,935 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00026 | duration=6.80s | sec_per_unit=6.0941
# 2026-04-17 06:30:41,936 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00027 | est_remaining_sec=81.71
# 2026-04-17 06:30:43,482 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00027
# 2026-04-17 06:30:45,563 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00027.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00027.npz
# 2026-04-17 06:30:49,687 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00027.npz
# 2026-04-17 06:30:49,776 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00027 | duration=6.29s | sec_per_unit=5.6442
# 2026-04-17 06:30:49,777 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00028 | est_remaining_sec=78.01
# 2026-04-17 06:30:51,368 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00028
# 2026-04-17 06:30:53,505 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00028.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00028.npz
# 2026-04-17 06:30:57,908 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00028.npz
# 2026-04-17 06:30:57,998 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00028 | duration=6.63s | sec_per_unit=5.9455
# 2026-04-17 06:30:57,999 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00029 | est_remaining_sec=74.33
# 2026-04-17 06:30:59,779 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00029
# 2026-04-17 06:31:01,917 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00029.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00029.npz
# 2026-04-17 06:31:06,325 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00029.npz
# 2026-04-17 06:31:06,441 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00029 | duration=6.66s | sec_per_unit=5.9737
# 2026-04-17 06:31:06,441 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00030 | est_remaining_sec=70.60
# 2026-04-17 06:31:07,868 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00030
# 2026-04-17 06:31:09,972 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00030.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00030.npz
# 2026-04-17 06:31:14,773 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00030.npz
# 2026-04-17 06:31:14,882 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00030 | duration=7.01s | sec_per_unit=6.2898
# 2026-04-17 06:31:14,884 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00031 | est_remaining_sec=66.87
# 2026-04-17 06:31:16,267 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00031
# 2026-04-17 06:31:16,799 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00031.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00031.npz
# 2026-04-17 06:31:21,087 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00031.npz
# 2026-04-17 06:31:21,207 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00031 | duration=4.94s | sec_per_unit=19.0161
# 2026-04-17 06:31:21,208 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00032 | est_remaining_sec=65.44
# 2026-04-17 06:31:22,625 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00032
# 2026-04-17 06:31:24,724 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00032.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00032.npz
# 2026-04-17 06:31:29,056 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00032.npz
# 2026-04-17 06:31:29,196 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00032 | duration=6.57s | sec_per_unit=5.9833
# 2026-04-17 06:31:29,197 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00033 | est_remaining_sec=61.36
# 2026-04-17 06:31:30,686 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00033
# 2026-04-17 06:31:32,878 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00033.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00033.npz
# 2026-04-17 06:31:37,001 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00033.npz
# 2026-04-17 06:31:37,102 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00033 | duration=6.42s | sec_per_unit=5.7532
# 2026-04-17 06:31:37,103 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00034 | est_remaining_sec=57.19
# 2026-04-17 06:31:38,588 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00034
# 2026-04-17 06:31:41,287 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00034.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00034.npz
# 2026-04-17 06:31:45,513 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00034.npz
# 2026-04-17 06:31:45,604 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00034 | duration=7.02s | sec_per_unit=6.2913
# 2026-04-17 06:31:45,605 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00035 | est_remaining_sec=53.06
# 2026-04-17 06:31:47,245 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00035
# 2026-04-17 06:31:49,356 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00035.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00035.npz
# 2026-04-17 06:31:53,760 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00035.npz
# 2026-04-17 06:31:53,851 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00035 | duration=6.61s | sec_per_unit=5.9237
# 2026-04-17 06:31:53,852 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00036 | est_remaining_sec=48.83
# 2026-04-17 06:31:55,265 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00036
# 2026-04-17 06:31:57,355 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00036.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00036.npz
# 2026-04-17 06:32:01,539 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00036.npz
# 2026-04-17 06:32:01,632 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00036 | duration=6.37s | sec_per_unit=5.7094
# 2026-04-17 06:32:01,632 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00037 | est_remaining_sec=44.54
# 2026-04-17 06:32:03,095 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00037
# 2026-04-17 06:32:05,199 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00037.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00037.npz
# 2026-04-17 06:32:09,417 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00037.npz
# 2026-04-17 06:32:09,519 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00037 | duration=6.42s | sec_per_unit=5.7613
# 2026-04-17 06:32:09,520 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00038 | est_remaining_sec=40.22
# 2026-04-17 06:32:11,190 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00038
# 2026-04-17 06:32:13,292 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00038.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00038.npz
# 2026-04-17 06:32:18,055 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00038.npz
# 2026-04-17 06:32:18,151 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00038 | duration=6.96s | sec_per_unit=6.2419
# 2026-04-17 06:32:18,152 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00039 | est_remaining_sec=35.91
# 2026-04-17 06:32:19,487 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00039
# 2026-04-17 06:32:20,015 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00039.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00039.npz
# 2026-04-17 06:32:24,123 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00039.npz
# 2026-04-17 06:32:24,218 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00039 | duration=4.73s | sec_per_unit=18.2115
# 2026-04-17 06:32:24,224 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00040 | est_remaining_sec=32.50
# 2026-04-17 06:32:25,925 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00040
# 2026-04-17 06:32:26,491 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00040.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00040.npz
# 2026-04-17 06:32:30,198 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00040.npz
# 2026-04-17 06:32:30,542 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00040 | duration=4.62s | sec_per_unit=16.3813
# 2026-04-17 06:32:30,543 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00041 | est_remaining_sec=28.64
# 2026-04-17 06:32:32,106 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00041
# 2026-04-17 06:32:32,780 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00041.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00041.npz
# 2026-04-17 06:32:37,158 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00041.npz
# 2026-04-17 06:32:37,331 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00041 | duration=5.23s | sec_per_unit=18.2582
# 2026-04-17 06:32:37,332 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00042 | est_remaining_sec=24.61
# 2026-04-17 06:32:39,298 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00042
# 2026-04-17 06:32:40,157 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00042.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00042.npz
# 2026-04-17 06:32:44,392 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00042.npz
# 2026-04-17 06:32:44,850 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00042 | duration=5.55s | sec_per_unit=19.3988
# 2026-04-17 06:32:44,850 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00043 | est_remaining_sec=20.32
# 2026-04-17 06:32:46,270 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00043
# 2026-04-17 06:32:46,840 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00043.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00043.npz
# 2026-04-17 06:32:50,913 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00043.npz
# 2026-04-17 06:32:51,016 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00043 | duration=4.75s | sec_per_unit=16.5823
# 2026-04-17 06:32:51,017 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00044 | est_remaining_sec=15.61
# 2026-04-17 06:32:52,466 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00044
# 2026-04-17 06:32:53,031 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00044.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00044.npz
# 2026-04-17 06:32:57,238 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00044.npz
# 2026-04-17 06:32:57,341 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00044 | duration=4.87s | sec_per_unit=17.0334
# 2026-04-17 06:32:57,341 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00045 | est_remaining_sec=10.66
# 2026-04-17 06:32:58,759 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00045
# 2026-04-17 06:32:59,315 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00045.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00045.npz
# 2026-04-17 06:33:03,389 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00045.npz
# 2026-04-17 06:33:03,552 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00045 | duration=4.79s | sec_per_unit=16.7510
# 2026-04-17 06:33:03,553 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00046 | est_remaining_sec=5.45
# 2026-04-17 06:33:05,031 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00046
# 2026-04-17 06:33:05,580 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00046.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00046.npz
# 2026-04-17 06:33:09,658 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00046.npz
# 2026-04-17 06:33:09,760 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00046 | duration=4.73s | sec_per_unit=16.5250
# 2026-04-17 06:33:09,761 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00047 | est_remaining_sec=0.00
# 2026-04-17 06:33:11,331 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00047
# 2026-04-17 06:33:11,491 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00047.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00047.npz
# 2026-04-17 06:33:15,342 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00047.npz
# 2026-04-17 06:33:15,444 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00047 | duration=4.11s | sec_per_unit=61.6941
# 2026-04-17 06:33:15,445 | INFO     | features.notebook | SOURCE FAMILY DONE | site=calaveras-big-trees | source=3dep | family=terrain
# 2026-04-17 06:33:15,680 | INFO     | features.notebook | PUSH ARTIFACT | key=stack_registry | rel_path=features/calaveras-big-trees/91fef1517fca02cc/stack/stack_registry.json
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/stack/stack_registry.json
# 2026-04-17 06:33:19,605 | INFO     | features.notebook | SOURCE CHUNKED RUN COMPLETE | site=calaveras-big-trees | source=3dep | registered_layers=432

# %%
display(stack_registry_frame(registry_3dep).head(30))
print(f"3DEP layers registered: {len(registry_3dep.layers)}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                 site_id source_name family_name  \
# 0   calaveras-big-trees        3dep     terrain
# 1   calaveras-big-trees        3dep     terrain
# 2   calaveras-big-trees        3dep     terrain
# 3   calaveras-big-trees        3dep     terrain
# 4   calaveras-big-trees        3dep     terrain
# 5   calaveras-big-trees        3dep     terrain
# 6   calaveras-big-trees        3dep     terrain
# 7   calaveras-big-trees        3dep     terrain
# 8   calaveras-big-trees        3dep     terrain
# 9   calaveras-big-trees        3dep     terrain
# 10  calaveras-big-trees        3dep     terrain
# 11  calaveras-big-trees        3dep     terrain
# 12  calaveras-big-trees        3dep     terrain
# 13  calaveras-big-trees        3dep     terrain
# 14  calaveras-big-trees        3dep     terrain
# 15  calaveras-big-trees        3dep     terrain
# 16  calaveras-big-trees        3dep     terrain
# 17  calaveras-big-trees        3dep     terrain
# 18  calaveras-big-trees        3dep     terrain
# 19  calaveras-big-trees        3dep     terrain
# 20  calaveras-big-trees        3dep     terrain
# 21  calaveras-big-trees        3dep     terrain
# 22  calaveras-big-trees        3dep     terrain
# 23  calaveras-big-trees        3dep     terrain
# 24  calaveras-big-trees        3dep     terrain
# 25  calaveras-big-trees        3dep     terrain
# 26  calaveras-big-trees        3dep     terrain
# 27  calaveras-big-trees        3dep     terrain
# 28  calaveras-big-trees        3dep     terrain
# 29  calaveras-big-trees        3dep     terrain
#
#                                  layer_name  \
# 0            terrain_elevation::chunk_00000
# 1                terrain_slope::chunk_00000
# 2               terrain_aspect::chunk_00000
# 3            terrain_northness::chunk_00000
# 4             terrain_eastness::chunk_00000
# 5            terrain_curvature::chunk_00000
# 6           terrain_ruggedness::chunk_00000
# 7                  terrain_tpi::chunk_00000
# 8   terrain_hillshade_exposure::chunk_00000
# 9            terrain_elevation::chunk_00001
# 10               terrain_slope::chunk_00001
# 11              terrain_aspect::chunk_00001
# 12           terrain_northness::chunk_00001
# 13            terrain_eastness::chunk_00001
# 14           terrain_curvature::chunk_00001
# 15          terrain_ruggedness::chunk_00001
# 16                 terrain_tpi::chunk_00001
# 17  terrain_hillshade_exposure::chunk_00001
# 18           terrain_elevation::chunk_00002
# 19               terrain_slope::chunk_00002
# 20              terrain_aspect::chunk_00002
# 21           terrain_northness::chunk_00002
# 22            terrain_eastness::chunk_00002
# 23           terrain_curvature::chunk_00002
# 24          terrain_ruggedness::chunk_00002
# 25                 terrain_tpi::chunk_00002
# 26  terrain_hillshade_exposure::chunk_00002
# 27           terrain_elevation::chunk_00003
# 28               terrain_slope::chunk_00003
# 29              terrain_aspect::chunk_00003
#
#                                              rel_path  \
# 0   features/calaveras-big-trees/91fef1517fca02cc/...
# 1   features/calaveras-big-trees/91fef1517fca02cc/...
# 2   features/calaveras-big-trees/91fef1517fca02cc/...
# 3   features/calaveras-big-trees/91fef1517fca02cc/...
# 4   features/calaveras-big-trees/91fef1517fca02cc/...
# 5   features/calaveras-big-trees/91fef1517fca02cc/...
# 6   features/calaveras-big-trees/91fef1517fca02cc/...
# 7   features/calaveras-big-trees/91fef1517fca02cc/...
# 8   features/calaveras-big-trees/91fef1517fca02cc/...
# 9   features/calaveras-big-trees/91fef1517fca02cc/...
# 10  features/calaveras-big-trees/91fef1517fca02cc/...
# 11  features/calaveras-big-trees/91fef1517fca02cc/...
# 12  features/calaveras-big-trees/91fef1517fca02cc/...
# 13  features/calaveras-big-trees/91fef1517fca02cc/...
# 14  features/calaveras-big-trees/91fef1517fca02cc/...
# 15  features/calaveras-big-trees/91fef1517fca02cc/...
# 16  features/calaveras-big-trees/91fef1517fca02cc/...
# 17  features/calaveras-big-trees/91fef1517fca02cc/...
# 18  features/calaveras-big-trees/91fef1517fca02cc/...
# 19  features/calaveras-big-trees/91fef1517fca02cc/...
# 20  features/calaveras-big-trees/91fef1517fca02cc/...
# 21  features/calaveras-big-trees/91fef1517fca02cc/...
# 22  features/calaveras-big-trees/91fef1517fca02cc/...
# 23  features/calaveras-big-trees/91fef1517fca02cc/...
# 24  features/calaveras-big-trees/91fef1517fca02cc/...
# 25  features/calaveras-big-trees/91fef1517fca02cc/...
# 26  features/calaveras-big-trees/91fef1517fca02cc/...
# 27  features/calaveras-big-trees/91fef1517fca02cc/...
# 28  features/calaveras-big-trees/91fef1517fca02cc/...
# 29  features/calaveras-big-trees/91fef1517fca02cc/...
#
#                                            local_path  \
# 0   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 1   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 2   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 3   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 4   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 5   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 6   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 7   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 8   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 9   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 10  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 11  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 12  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 13  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 14  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 15  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 16  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 17  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 18  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 19  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 20  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 21  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 22  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 23  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 24  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 25  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 26  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 27  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 28  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 29  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
#
#                            remote_ref  chunked    dtype         shape  \
# 0   1a7HukP-xzj1bjVxv3jJPWSKQfevRbCbu     True  float32  (1024, 1024)
# 1   1a7HukP-xzj1bjVxv3jJPWSKQfevRbCbu     True  float32  (1024, 1024)
# 2   1a7HukP-xzj1bjVxv3jJPWSKQfevRbCbu     True  float32  (1024, 1024)
# 3   1a7HukP-xzj1bjVxv3jJPWSKQfevRbCbu     True  float32  (1024, 1024)
# 4   1a7HukP-xzj1bjVxv3jJPWSKQfevRbCbu     True  float32  (1024, 1024)
# 5   1a7HukP-xzj1bjVxv3jJPWSKQfevRbCbu     True  float32  (1024, 1024)
# 6   1a7HukP-xzj1bjVxv3jJPWSKQfevRbCbu     True  float32  (1024, 1024)
# 7   1a7HukP-xzj1bjVxv3jJPWSKQfevRbCbu     True  float32  (1024, 1024)
# 8   1a7HukP-xzj1bjVxv3jJPWSKQfevRbCbu     True  float32  (1024, 1024)
# 9   1EvDuVY1eFjpxbQaAQoybCewRul136yVG     True  float32  (1024, 1024)
# 10  1EvDuVY1eFjpxbQaAQoybCewRul136yVG     True  float32  (1024, 1024)
# 11  1EvDuVY1eFjpxbQaAQoybCewRul136yVG     True  float32  (1024, 1024)
# 12  1EvDuVY1eFjpxbQaAQoybCewRul136yVG     True  float32  (1024, 1024)
# 13  1EvDuVY1eFjpxbQaAQoybCewRul136yVG     True  float32  (1024, 1024)
# 14  1EvDuVY1eFjpxbQaAQoybCewRul136yVG     True  float32  (1024, 1024)
# 15  1EvDuVY1eFjpxbQaAQoybCewRul136yVG     True  float32  (1024, 1024)
# 16  1EvDuVY1eFjpxbQaAQoybCewRul136yVG     True  float32  (1024, 1024)
# 17  1EvDuVY1eFjpxbQaAQoybCewRul136yVG     True  float32  (1024, 1024)
# 18  1uQQrqQU-11t59CbE0ZV4TzEXGya4ZXZx     True  float32  (1024, 1024)
# 19  1uQQrqQU-11t59CbE0ZV4TzEXGya4ZXZx     True  float32  (1024, 1024)
# 20  1uQQrqQU-11t59CbE0ZV4TzEXGya4ZXZx     True  float32  (1024, 1024)
# 21  1uQQrqQU-11t59CbE0ZV4TzEXGya4ZXZx     True  float32  (1024, 1024)
# 22  1uQQrqQU-11t59CbE0ZV4TzEXGya4ZXZx     True  float32  (1024, 1024)
# 23  1uQQrqQU-11t59CbE0ZV4TzEXGya4ZXZx     True  float32  (1024, 1024)
# 24  1uQQrqQU-11t59CbE0ZV4TzEXGya4ZXZx     True  float32  (1024, 1024)
# 25  1uQQrqQU-11t59CbE0ZV4TzEXGya4ZXZx     True  float32  (1024, 1024)
# 26  1uQQrqQU-11t59CbE0ZV4TzEXGya4ZXZx     True  float32  (1024, 1024)
# 27  1tcAnn5of2XitGgEQqIiedK9DCSwp6ihK     True  float32  (1024, 1024)
# 28  1tcAnn5of2XitGgEQqIiedK9DCSwp6ihK     True  float32  (1024, 1024)
# 29  1tcAnn5of2XitGgEQqIiedK9DCSwp6ihK     True  float32  (1024, 1024)
#
#                                                 notes
# 0   [chunk_00000, Local artifact pruned after veri...
# 1   [chunk_00000, Local artifact pruned after veri...
# 2   [chunk_00000, Local artifact pruned after veri...
# 3   [chunk_00000, Local artifact pruned after veri...
# 4   [chunk_00000, Local artifact pruned after veri...
# 5   [chunk_00000, Local artifact pruned after veri...
# 6   [chunk_00000, Local artifact pruned after veri...
# 7   [chunk_00000, Local artifact pruned after veri...
# 8   [chunk_00000, Local artifact pruned after veri...
# 9   [chunk_00001, Local artifact pruned after veri...
# 10  [chunk_00001, Local artifact pruned after veri...
# 11  [chunk_00001, Local artifact pruned after veri...
# 12  [chunk_00001, Local artifact pruned after veri...
# 13  [chunk_00001, Local artifact pruned after veri...
# 14  [chunk_00001, Local artifact pruned after veri...
# 15  [chunk_00001, Local artifact pruned after veri...
# 16  [chunk_00001, Local artifact pruned after veri...
# 17  [chunk_00001, Local artifact pruned after veri...
# 18  [chunk_00002, Local artifact pruned after veri...
# 19  [chunk_00002, Local artifact pruned after veri...
# 20  [chunk_00002, Local artifact pruned after veri...
# 21  [chunk_00002, Local artifact pruned after veri...
# 22  [chunk_00002, Local artifact pruned after veri...
# 23  [chunk_00002, Local artifact pruned after veri...
# 24  [chunk_00002, Local artifact pruned after veri...
# 25  [chunk_00002, Local artifact pruned after veri...
# 26  [chunk_00002, Local artifact pruned after veri...
# 27  [chunk_00003, Local artifact pruned after veri...
# 28  [chunk_00003, Local artifact pruned after veri...
# 29  [chunk_00003, Local artifact pruned after veri...
# 3DEP layers registered: 432

# %%
def clear_artifact_staging_dir() -> None:
    staging_dir = ensure_dir(fe_cfg.cache_root / "_artifact_staging")
    for p in staging_dir.rglob("*"):
        if p.is_file():
            try:
                p.unlink()
            except Exception:
                pass
    LOGGER.info("Cleared artifact staging directory | path=%s", staging_dir)

def run_3dep_all_sites(
    *,
    force_refresh_assets: bool = False,
    force_refresh_source: bool = False,
) -> dict[str, Any]:
    out = {}

    for site_id in fe_cfg.sites:
        LOGGER.info("=" * 80)
        LOGGER.info("RUN 3DEP ALL SITES | site=%s", site_id)

        try:
            site_assets = prepare_site_assets(
                site_id,
                force_refresh=force_refresh_assets,
            )

            if site_assets.source_assets.get("naip") is None:
                raise RuntimeError(f"NAIP unavailable for site={site_id}")

            canonical_grid = build_canonical_grid_for_site(
                site_id,
                assets=site_assets,
                force_refresh=fe_cfg.force_refresh_features,
            )

            chunk_manifest = build_chunk_manifest(
                canonical_grid,
                force_refresh=fe_cfg.force_rebuild_chunk_manifest,
            )

            naip_asset = site_assets.source_assets.get("naip")
            if naip_asset is not None:
                maybe_prune_local_site_naip_after_grid_build(site_id, naip_asset)

            registry = run_3dep_chunked_pipeline(
                site_id,
                site_assets=site_assets,
                canonical_grid=canonical_grid,
                chunk_manifest=chunk_manifest,
                registry=RasterStackRegistry(
                    site_id=site_id,
                    config_signature=fe_config_signature(),
                    layers=[],
                ),
                force_refresh_source=force_refresh_source,
            )

            out[site_id] = {
                "status": "success",
                "registry": registry,
                "notes": list(site_assets.notes),
            }

        except Exception as e:
            LOGGER.warning("RUN 3DEP ALL SITES FAILED | site=%s | err=%s", site_id, e)
            out[site_id] = {
                "status": "failed",
                "registry": None,
                "notes": [str(e)],
            }

        finally:
            clear_artifact_staging_dir()

    return out
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
rows = []
for site_id in fe_cfg.sites:
    site_assets = prepare_site_assets(site_id, force_refresh=False)
    rec = build_3dep_source_inventory_record(site_id, site_assets=site_assets)
    rows.append({
        "site_id": site_id,
        "status": rec.status,
        "asset_path": rec.asset_path,
        "notes": " | ".join(rec.notes),
    })

display(pd.DataFrame(rows))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 2026-04-17 08:56:49,050 | INFO     | features.notebook | START | stage=site_assets | site=calaveras-big-trees | source=None | family=None
# 2026-04-17 08:56:49,276 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=source_inventory | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 08:56:50,825 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 08:56:50,825 | INFO     | features.notebook | Using cached source inventory | site=calaveras-big-trees
# 2026-04-17 08:56:50,826 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=site_metadata_manifest | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:56:51,360 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:56:51,360 | INFO     | features.notebook | Using site metadata manifest | site=calaveras-big-trees
# 2026-04-17 08:56:51,529 | INFO     | features.notebook | Hydrating NAIP from artifact store | site=calaveras-big-trees | rel_path=features/calaveras-big-trees/shared/site_assets/naip/calaveras_big_trees.tif
# 2026-04-17 08:56:55,622 | INFO     | features.notebook | PUSH ARTIFACT | key=site_metadata_manifest | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:56:59,916 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse | site=calaveras-big-trees | keys=['naip', 'als_metadata', 'source_inventory', '3dep', 'rap'] | notes=1
# 2026-04-17 08:56:59,917 | INFO     | features.notebook | END   | stage=site_assets | site=calaveras-big-trees | source=None | family=None | duration=10.87s
# 2026-04-17 08:56:59,917 | INFO     | features.notebook | START | stage=site_assets | site=dl-bliss | source=None | family=None
# 2026-04-17 08:56:59,918 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=source_inventory | rel_path=features/dl-bliss/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 08:57:00,776 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/dl-bliss/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 08:57:00,777 | INFO     | features.notebook | Using cached source inventory | site=dl-bliss
# 2026-04-17 08:57:00,777 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=site_metadata_manifest | rel_path=features/dl-bliss/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:57:01,514 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/dl-bliss/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:57:01,514 | INFO     | features.notebook | Using site metadata manifest | site=dl-bliss
# 2026-04-17 08:57:01,602 | INFO     | features.notebook | Hydrating NAIP from artifact store | site=dl-bliss | rel_path=features/dl-bliss/shared/site_assets/naip/dl_bliss.tif
# 2026-04-17 08:57:02,127 | INFO     | features.notebook | PUSH ARTIFACT | key=site_metadata_manifest | rel_path=features/dl-bliss/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# [artifact_store] Updating existing Drive artifact for features/dl-bliss/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:57:06,097 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse | site=dl-bliss | keys=['naip', 'als_metadata', '3dep', 'source_inventory', 'rap'] | notes=4
# 2026-04-17 08:57:06,097 | INFO     | features.notebook | END   | stage=site_assets | site=dl-bliss | source=None | family=None | duration=6.18s
# 2026-04-17 08:57:06,098 | INFO     | features.notebook | START | stage=site_assets | site=independence-lake | source=None | family=None
# 2026-04-17 08:57:06,099 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=source_inventory | rel_path=features/independence-lake/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 08:57:06,900 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/independence-lake/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 08:57:06,901 | INFO     | features.notebook | Using cached source inventory | site=independence-lake
# 2026-04-17 08:57:06,901 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=site_metadata_manifest | rel_path=features/independence-lake/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:57:07,590 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/independence-lake/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:57:07,590 | INFO     | features.notebook | Using site metadata manifest | site=independence-lake
# 2026-04-17 08:57:07,677 | INFO     | features.notebook | Hydrating NAIP from artifact store | site=independence-lake | rel_path=features/independence-lake/shared/site_assets/naip/independence_lake.tif
# 2026-04-17 08:57:33,151 | INFO     | features.notebook | PUSH ARTIFACT | key=site_metadata_manifest | rel_path=features/independence-lake/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# [artifact_store] Updating existing Drive artifact for features/independence-lake/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:57:37,220 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse | site=independence-lake | keys=['naip', 'als_metadata', '3dep', 'source_inventory', 'rap'] | notes=0
# 2026-04-17 08:57:37,220 | INFO     | features.notebook | END   | stage=site_assets | site=independence-lake | source=None | family=None | duration=31.12s
# 2026-04-17 08:57:37,221 | INFO     | features.notebook | SLOW  | stage=site_assets | duration=31.12s exceeded threshold=30.00s
# 2026-04-17 08:57:37,221 | INFO     | features.notebook | START | stage=site_assets | site=pacific-union-college | source=None | family=None
# 2026-04-17 08:57:37,222 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=source_inventory | rel_path=features/pacific-union-college/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 08:57:38,334 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/pacific-union-college/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 08:57:38,334 | INFO     | features.notebook | Using cached source inventory | site=pacific-union-college
# 2026-04-17 08:57:38,335 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=site_metadata_manifest | rel_path=features/pacific-union-college/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:57:39,027 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/pacific-union-college/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:57:39,027 | INFO     | features.notebook | Using site metadata manifest | site=pacific-union-college
# 2026-04-17 08:57:39,115 | INFO     | features.notebook | Hydrating NAIP from artifact store | site=pacific-union-college | rel_path=features/pacific-union-college/shared/site_assets/naip/pacific_union_college.tif
# 2026-04-17 08:57:40,428 | INFO     | features.notebook | PUSH ARTIFACT | key=site_metadata_manifest | rel_path=features/pacific-union-college/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# [artifact_store] Updating existing Drive artifact for features/pacific-union-college/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:57:44,052 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse | site=pacific-union-college | keys=['naip', 'als_metadata', '3dep', 'source_inventory', 'rap'] | notes=0
# 2026-04-17 08:57:44,053 | INFO     | features.notebook | END   | stage=site_assets | site=pacific-union-college | source=None | family=None | duration=6.83s
# 2026-04-17 08:57:44,054 | INFO     | features.notebook | START | stage=site_assets | site=sedgwick | source=None | family=None
# 2026-04-17 08:57:44,055 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=source_inventory | rel_path=features/sedgwick/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 08:57:44,847 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/sedgwick/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 08:57:44,848 | INFO     | features.notebook | Using cached source inventory | site=sedgwick
# 2026-04-17 08:57:44,848 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=site_metadata_manifest | rel_path=features/sedgwick/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:57:45,567 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/sedgwick/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:57:45,567 | INFO     | features.notebook | Using site metadata manifest | site=sedgwick
# 2026-04-17 08:57:45,655 | INFO     | features.notebook | Hydrating NAIP from artifact store | site=sedgwick | rel_path=features/sedgwick/shared/site_assets/naip/sedgwick.tif
# 2026-04-17 08:57:47,591 | INFO     | features.notebook | PUSH ARTIFACT | key=site_metadata_manifest | rel_path=features/sedgwick/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# [artifact_store] Updating existing Drive artifact for features/sedgwick/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:57:51,276 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse | site=sedgwick | keys=['naip', 'als_metadata', '3dep', 'source_inventory', 'rap'] | notes=0
# 2026-04-17 08:57:51,276 | INFO     | features.notebook | END   | stage=site_assets | site=sedgwick | source=None | family=None | duration=7.22s
# 2026-04-17 08:57:51,277 | INFO     | features.notebook | START | stage=site_assets | site=shaver-lake | source=None | family=None
# 2026-04-17 08:57:51,278 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=source_inventory | rel_path=features/shaver-lake/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 08:57:52,088 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/shaver-lake/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 08:57:52,088 | INFO     | features.notebook | Using cached source inventory | site=shaver-lake
# 2026-04-17 08:57:52,089 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=site_metadata_manifest | rel_path=features/shaver-lake/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:57:52,799 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/shaver-lake/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:57:52,799 | INFO     | features.notebook | Using site metadata manifest | site=shaver-lake
# 2026-04-17 08:57:52,987 | INFO     | features.notebook | Hydrating NAIP from artifact store | site=shaver-lake | rel_path=features/shaver-lake/shared/site_assets/naip/shaver_lake.tif
# 2026-04-17 08:57:54,161 | INFO     | features.notebook | PUSH ARTIFACT | key=site_metadata_manifest | rel_path=features/shaver-lake/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# [artifact_store] Updating existing Drive artifact for features/shaver-lake/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:57:57,839 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse | site=shaver-lake | keys=['naip', 'als_metadata', '3dep', 'source_inventory', 'rap'] | notes=0
# 2026-04-17 08:57:57,840 | INFO     | features.notebook | END   | stage=site_assets | site=shaver-lake | source=None | family=None | duration=6.56s
#                  site_id                status  \
# 0    calaveras-big-trees    cached_remote_lazy
# 1               dl-bliss    cached_remote_lazy
# 2      independence-lake    cached_remote_lazy
# 3  pacific-union-college    cached_remote_lazy
# 4               sedgwick    cached_remote_lazy
# 5            shaver-lake  not_materialized_yet
#
#                                           asset_path  \
# 0  features/calaveras-big-trees/shared/site_asset...
# 1  features/dl-bliss/shared/site_assets/3dep/dl-b...
# 2  features/independence-lake/shared/site_assets/...
# 3  features/pacific-union-college/shared/site_ass...
# 4  features/sedgwick/shared/site_assets/3dep/sedg...
# 5                                               None
#
#                                                notes
# 0  3DEP cached remotely and will be hydrated lazily.
# 1  3DEP cached remotely and will be hydrated lazily.
# 2  3DEP cached remotely and will be hydrated lazily.
# 3  3DEP cached remotely and will be hydrated lazily.
# 4  3DEP cached remotely and will be hydrated lazily.
# 5                3DEP has not been materialized yet.

# %%
TEST_SITE = "dl-bliss"

site_assets = prepare_site_assets(TEST_SITE, force_refresh=False)
canonical_grid = build_canonical_grid_for_site(TEST_SITE, assets=site_assets, force_refresh=True)
chunk_manifest = build_chunk_manifest(canonical_grid, force_refresh=True)

print("Canonical grid shape:", (canonical_grid.height, canonical_grid.width))
print("Canonical grid pixel size:", canonical_grid.pixel_size)
print("Chunk count:", len(chunk_manifest.records))
print("Canonical grid bounds:", canonical_grid_bounds_wgs84(canonical_grid))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 2026-04-17 08:42:12,624 | INFO     | features.notebook | START | stage=site_assets | site=dl-bliss | source=None | family=None
# 2026-04-17 08:42:12,625 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=source_inventory | rel_path=features/dl-bliss/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 08:42:12,625 | INFO     | features.notebook | Using cached source inventory | site=dl-bliss
# 2026-04-17 08:42:12,626 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=site_metadata_manifest | rel_path=features/dl-bliss/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:42:12,627 | INFO     | features.notebook | Using site metadata manifest | site=dl-bliss
# 2026-04-17 08:42:12,803 | INFO     | features.notebook | PUSH ARTIFACT | key=site_metadata_manifest | rel_path=features/dl-bliss/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# [artifact_store] Updating existing Drive artifact for features/dl-bliss/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:42:16,789 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse | site=dl-bliss | keys=['naip', 'als_metadata', '3dep', 'source_inventory', 'rap'] | notes=4
# 2026-04-17 08:42:16,789 | INFO     | features.notebook | END   | stage=site_assets | site=dl-bliss | source=None | family=None | duration=4.17s
# 2026-04-17 08:42:16,790 | INFO     | features.notebook | START | stage=canonical_grid | site=dl-bliss | source=naip | family=None
# 2026-04-17 08:42:17,072 | INFO     | features.notebook | Built canonical grid | site=dl-bliss | shape=(2068, 2651) | pixel_size=(8.983152841195214e-06, 8.983152841195214e-06)
# 2026-04-17 08:42:17,072 | INFO     | features.notebook | END   | stage=canonical_grid | site=dl-bliss | source=naip | family=None | duration=0.28s
# 2026-04-17 08:42:17,117 | INFO     | features.notebook | START | stage=chunk_manifest | site=dl-bliss | source=naip | family=None
# 2026-04-17 08:42:17,208 | INFO     | features.notebook | Built chunk manifest | site=dl-bliss | chunk_size=1024 | n_chunks=9
# 2026-04-17 08:42:17,208 | INFO     | features.notebook | END   | stage=chunk_manifest | site=dl-bliss | source=naip | family=None | duration=0.09s | sec_per_unit=0.0167
# Canonical grid shape: (2068, 2651)
# Canonical grid pixel size: (8.983152841195214e-06, 8.983152841195214e-06)
# Chunk count: 9
# Canonical grid bounds: (-120.11379053853825, 38.98374821044565, -120.08997620035625, 39.00232537052124)

# %%
all_3dep_runs = run_3dep_all_sites(
    force_refresh_assets=False,
    force_refresh_source=False,
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 2026-04-17 08:57:59,296 | INFO     | features.notebook | ================================================================================
# 2026-04-17 08:57:59,297 | INFO     | features.notebook | RUN 3DEP ALL SITES | site=calaveras-big-trees
# 2026-04-17 08:57:59,297 | INFO     | features.notebook | START | stage=site_assets | site=calaveras-big-trees | source=None | family=None
# 2026-04-17 08:57:59,298 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=source_inventory | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 08:57:59,968 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 08:57:59,969 | INFO     | features.notebook | Using cached source inventory | site=calaveras-big-trees
# 2026-04-17 08:57:59,969 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=site_metadata_manifest | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:57:59,971 | INFO     | features.notebook | Using site metadata manifest | site=calaveras-big-trees
# 2026-04-17 08:58:00,134 | INFO     | features.notebook | PUSH ARTIFACT | key=site_metadata_manifest | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 08:58:04,204 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse | site=calaveras-big-trees | keys=['naip', 'als_metadata', 'source_inventory', '3dep', 'rap'] | notes=1
# 2026-04-17 08:58:04,205 | INFO     | features.notebook | END   | stage=site_assets | site=calaveras-big-trees | source=None | family=None | duration=4.91s
# 2026-04-17 08:58:04,382 | INFO     | features.notebook | START | stage=canonical_grid | site=calaveras-big-trees | source=naip | family=None
# 2026-04-17 08:58:06,418 | INFO     | features.notebook | Built canonical grid | site=calaveras-big-trees | shape=(5375, 7398) | pixel_size=(0.6000000000000063, 0.6)
# 2026-04-17 08:58:06,418 | INFO     | features.notebook | END   | stage=canonical_grid | site=calaveras-big-trees | source=naip | family=None | duration=2.04s
# 2026-04-17 08:58:06,596 | INFO     | features.notebook | START | stage=chunk_manifest | site=calaveras-big-trees | source=naip | family=None
# 2026-04-17 08:58:06,691 | INFO     | features.notebook | Built chunk manifest | site=calaveras-big-trees | chunk_size=1024 | n_chunks=48
# 2026-04-17 08:58:06,691 | INFO     | features.notebook | END   | stage=chunk_manifest | site=calaveras-big-trees | source=naip | family=None | duration=0.10s | sec_per_unit=0.0024
# 2026-04-17 08:58:06,736 | INFO     | features.notebook | Pruned local NAIP site asset after canonical grid build | site=calaveras-big-trees | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/calaveras-big-trees/naip/calaveras_big_trees.tif
# 2026-04-17 08:58:06,737 | INFO     | features.notebook | Hydrating 3DEP from artifact store | site=calaveras-big-trees | rel_path=features/calaveras-big-trees/shared/site_assets/3dep/calaveras-big-trees_3dep_ee_10m.tif
# 2026-04-17 08:58:07,530 | INFO     | features.notebook | Pruned local 3DEP site asset after in-memory load | site=calaveras-big-trees | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/calaveras-big-trees/3dep/calaveras-big-trees_3dep_ee_10m.tif
# 2026-04-17 08:58:09,793 | INFO     | features.notebook | SOURCE CHUNKED RUN | site=calaveras-big-trees | source=3dep | families=('terrain',) | n_chunks=48
# 2026-04-17 08:58:09,794 | INFO     | features.notebook | SOURCE FAMILY START | site=calaveras-big-trees | source=3dep | family=terrain
# 2026-04-17 08:58:09,794 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00000 | est_remaining_sec=1142.17
# 2026-04-17 08:58:09,973 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00000
# 2026-04-17 08:58:12,128 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00000.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00000.npz
# 2026-04-17 08:58:18,841 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00000.npz
# 2026-04-17 08:58:18,885 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00000 | duration=8.91s | sec_per_unit=8.2396
# 2026-04-17 08:58:18,886 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00001 | est_remaining_sec=1109.47
# 2026-04-17 08:58:18,973 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00001
# 2026-04-17 08:58:21,095 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00001.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00001.npz
# 2026-04-17 08:58:26,106 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00001.npz
# 2026-04-17 08:58:26,151 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00001 | duration=7.18s | sec_per_unit=6.5358
# 2026-04-17 08:58:26,152 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00002 | est_remaining_sec=1076.46
# 2026-04-17 08:58:26,239 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00002
# 2026-04-17 08:58:28,316 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00002.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00002.npz
# 2026-04-17 08:58:33,431 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00002.npz
# 2026-04-17 08:58:33,475 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00002 | duration=7.24s | sec_per_unit=6.5889
# 2026-04-17 08:58:33,476 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00003 | est_remaining_sec=1044.07
# 2026-04-17 08:58:33,563 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00003
# 2026-04-17 08:58:35,690 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00003.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00003.npz
# 2026-04-17 08:58:40,794 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00003.npz
# 2026-04-17 08:58:40,838 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00003 | duration=7.27s | sec_per_unit=6.6238
# 2026-04-17 08:58:40,839 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00004 | est_remaining_sec=1012.26
# 2026-04-17 08:58:40,926 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00004
# 2026-04-17 08:58:43,067 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00004.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00004.npz
# 2026-04-17 08:58:48,344 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00004.npz
# 2026-04-17 08:58:48,388 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00004 | duration=7.46s | sec_per_unit=6.7946
# 2026-04-17 08:58:48,389 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00005 | est_remaining_sec=981.07
# 2026-04-17 08:58:48,477 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00005
# 2026-04-17 08:58:50,619 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00005.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00005.npz
# 2026-04-17 08:58:55,563 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00005.npz
# 2026-04-17 08:58:55,607 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00005 | duration=7.13s | sec_per_unit=6.4920
# 2026-04-17 08:58:55,608 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00006 | est_remaining_sec=950.27
# 2026-04-17 08:58:55,695 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00006
# 2026-04-17 08:58:57,766 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00006.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00006.npz
# 2026-04-17 08:59:03,504 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00006.npz
# 2026-04-17 08:59:03,548 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00006 | duration=7.85s | sec_per_unit=7.1505
# 2026-04-17 08:59:03,548 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00007 | est_remaining_sec=920.28
# 2026-04-17 08:59:03,636 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00007
# 2026-04-17 08:59:04,318 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00007.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00007.npz
# 2026-04-17 08:59:08,639 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00007.npz
# 2026-04-17 08:59:08,683 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00007 | duration=5.05s | sec_per_unit=19.7301
# 2026-04-17 08:59:08,684 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00008 | est_remaining_sec=895.93
# 2026-04-17 08:59:08,771 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00008
# 2026-04-17 08:59:11,549 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00008.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00008.npz
# 2026-04-17 08:59:16,757 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00008.npz
# 2026-04-17 08:59:16,801 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00008 | duration=8.03s | sec_per_unit=7.3115
# 2026-04-17 08:59:16,802 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00009 | est_remaining_sec=866.75
# 2026-04-17 08:59:16,889 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00009
# 2026-04-17 08:59:19,102 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00009.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00009.npz
# 2026-04-17 08:59:24,118 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00009.npz
# 2026-04-17 08:59:24,163 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00009 | duration=7.27s | sec_per_unit=6.5228
# 2026-04-17 08:59:24,164 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00010 | est_remaining_sec=837.73
# 2026-04-17 08:59:24,251 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00010
# 2026-04-17 08:59:26,320 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00010.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00010.npz
# 2026-04-17 08:59:31,863 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00010.npz
# 2026-04-17 08:59:31,907 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00010 | duration=7.66s | sec_per_unit=6.8655
# 2026-04-17 08:59:31,908 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00011 | est_remaining_sec=809.30
# 2026-04-17 08:59:31,995 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00011
# 2026-04-17 08:59:34,182 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00011.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00011.npz
# 2026-04-17 08:59:38,703 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00011.npz
# 2026-04-17 08:59:38,747 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00011 | duration=6.75s | sec_per_unit=6.0552
# 2026-04-17 08:59:38,748 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00012 | est_remaining_sec=781.01
# 2026-04-17 08:59:38,849 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00012
# 2026-04-17 08:59:41,087 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00012.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00012.npz
# 2026-04-17 08:59:46,007 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00012.npz
# 2026-04-17 08:59:46,053 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00012 | duration=7.20s | sec_per_unit=6.4602
# 2026-04-17 08:59:46,054 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00013 | est_remaining_sec=753.30
# 2026-04-17 08:59:46,145 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00013
# 2026-04-17 08:59:48,290 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00013.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00013.npz
# 2026-04-17 08:59:53,485 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00013.npz
# 2026-04-17 08:59:53,529 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00013 | duration=7.38s | sec_per_unit=6.6222
# 2026-04-17 08:59:53,530 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00014 | est_remaining_sec=726.07
# 2026-04-17 08:59:53,617 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00014
# 2026-04-17 08:59:55,671 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00014.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00014.npz
# 2026-04-17 09:00:00,531 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00014.npz
# 2026-04-17 09:00:00,575 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00014 | duration=6.96s | sec_per_unit=6.2396
# 2026-04-17 09:00:00,576 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00015 | est_remaining_sec=699.12
# 2026-04-17 09:00:00,663 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00015
# 2026-04-17 09:00:01,217 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00015.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00015.npz
# 2026-04-17 09:00:06,122 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00015.npz
# 2026-04-17 09:00:06,166 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00015 | duration=5.50s | sec_per_unit=21.1839
# 2026-04-17 09:00:06,167 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00016 | est_remaining_sec=677.08
# 2026-04-17 09:00:06,254 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00016
# 2026-04-17 09:00:08,343 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00016.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00016.npz
# 2026-04-17 09:00:13,214 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00016.npz
# 2026-04-17 09:00:13,272 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00016 | duration=7.02s | sec_per_unit=6.3897
# 2026-04-17 09:00:13,273 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00017 | est_remaining_sec=650.78
# 2026-04-17 09:00:13,360 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00017
# 2026-04-17 09:00:15,846 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00017.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00017.npz
# 2026-04-17 09:00:21,430 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00017.npz
# 2026-04-17 09:00:21,474 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00017 | duration=8.11s | sec_per_unit=7.2762
# 2026-04-17 09:00:21,475 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00018 | est_remaining_sec=625.10
# 2026-04-17 09:00:21,568 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00018
# 2026-04-17 09:00:23,705 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00018.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00018.npz
# 2026-04-17 09:00:28,422 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00018.npz
# 2026-04-17 09:00:28,492 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00018 | duration=6.92s | sec_per_unit=6.2095
# 2026-04-17 09:00:28,493 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00019 | est_remaining_sec=599.50
# 2026-04-17 09:00:28,581 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00019
# 2026-04-17 09:00:31,068 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00019.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00019.npz
# 2026-04-17 09:00:35,835 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00019.npz
# 2026-04-17 09:00:35,879 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00019 | duration=7.30s | sec_per_unit=6.5442
# 2026-04-17 09:00:35,879 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00020 | est_remaining_sec=574.33
# 2026-04-17 09:00:35,967 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00020
# 2026-04-17 09:00:38,052 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00020.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00020.npz
# 2026-04-17 09:00:43,066 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00020.npz
# 2026-04-17 09:00:43,111 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00020 | duration=7.14s | sec_per_unit=6.4063
# 2026-04-17 09:00:43,111 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00021 | est_remaining_sec=549.48
# 2026-04-17 09:00:43,199 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00021
# 2026-04-17 09:00:45,339 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00021.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00021.npz
# 2026-04-17 09:00:50,144 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00021.npz
# 2026-04-17 09:00:50,188 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00021 | duration=6.99s | sec_per_unit=6.2680
# 2026-04-17 09:00:50,189 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00022 | est_remaining_sec=524.94
# 2026-04-17 09:00:50,277 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00022
# 2026-04-17 09:00:52,385 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00022.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00022.npz
# 2026-04-17 09:00:57,079 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00022.npz
# 2026-04-17 09:00:57,123 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00022 | duration=6.85s | sec_per_unit=6.1395
# 2026-04-17 09:00:57,124 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00023 | est_remaining_sec=500.70
# 2026-04-17 09:00:57,211 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00023
# 2026-04-17 09:00:57,773 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00023.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00023.npz
# 2026-04-17 09:01:02,393 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00023.npz
# 2026-04-17 09:01:02,437 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00023 | duration=5.23s | sec_per_unit=20.1165
# 2026-04-17 09:01:02,438 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00024 | est_remaining_sec=479.68
# 2026-04-17 09:01:02,526 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00024
# 2026-04-17 09:01:04,655 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00024.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00024.npz
# 2026-04-17 09:01:09,812 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00024.npz
# 2026-04-17 09:01:09,856 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00024 | duration=7.33s | sec_per_unit=6.6741
# 2026-04-17 09:01:09,857 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00025 | est_remaining_sec=456.04
# 2026-04-17 09:01:09,944 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00025
# 2026-04-17 09:01:12,118 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00025.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00025.npz
# 2026-04-17 09:01:16,861 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00025.npz
# 2026-04-17 09:01:16,905 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00025 | duration=6.96s | sec_per_unit=6.2418
# 2026-04-17 09:01:16,906 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00026 | est_remaining_sec=432.62
# 2026-04-17 09:01:16,993 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00026
# 2026-04-17 09:01:19,093 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00026.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00026.npz
# 2026-04-17 09:01:23,963 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00026.npz
# 2026-04-17 09:01:24,007 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00026 | duration=7.01s | sec_per_unit=6.2892
# 2026-04-17 09:01:24,008 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00027 | est_remaining_sec=409.51
# 2026-04-17 09:01:24,095 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00027
# 2026-04-17 09:01:26,181 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00027.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00027.npz
# 2026-04-17 09:01:31,244 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00027.npz
# 2026-04-17 09:01:31,288 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00027 | duration=7.19s | sec_per_unit=6.4509
# 2026-04-17 09:01:31,289 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00028 | est_remaining_sec=386.72
# 2026-04-17 09:01:31,377 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00028
# 2026-04-17 09:01:33,530 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00028.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00028.npz
# 2026-04-17 09:01:38,231 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00028.npz
# 2026-04-17 09:01:38,275 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00028 | duration=6.90s | sec_per_unit=6.1864
# 2026-04-17 09:01:38,276 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00029 | est_remaining_sec=364.16
# 2026-04-17 09:01:38,363 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00029
# 2026-04-17 09:01:40,895 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00029.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00029.npz
# 2026-04-17 09:01:45,693 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00029.npz
# 2026-04-17 09:01:45,737 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00029 | duration=7.37s | sec_per_unit=6.6127
# 2026-04-17 09:01:45,738 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00030 | est_remaining_sec=341.95
# 2026-04-17 09:01:45,825 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00030
# 2026-04-17 09:01:47,949 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00030.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00030.npz
# 2026-04-17 09:01:53,166 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00030.npz
# 2026-04-17 09:01:53,210 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00030 | duration=7.38s | sec_per_unit=6.6224
# 2026-04-17 09:01:53,211 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00031 | est_remaining_sec=320.01
# 2026-04-17 09:01:53,299 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00031
# 2026-04-17 09:01:53,829 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00031.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00031.npz
# 2026-04-17 09:01:58,071 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00031.npz
# 2026-04-17 09:01:58,116 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00031 | duration=4.82s | sec_per_unit=18.5442
# 2026-04-17 09:01:58,117 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00032 | est_remaining_sec=299.83
# 2026-04-17 09:01:58,205 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00032
# 2026-04-17 09:02:00,301 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00032.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00032.npz
# 2026-04-17 09:02:04,955 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00032.npz
# 2026-04-17 09:02:04,999 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00032 | duration=6.79s | sec_per_unit=6.1868
# 2026-04-17 09:02:05,000 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00033 | est_remaining_sec=278.23
# 2026-04-17 09:02:05,087 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00033
# 2026-04-17 09:02:07,268 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00033.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00033.npz
# 2026-04-17 09:02:12,329 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00033.npz
# 2026-04-17 09:02:12,373 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00033 | duration=7.29s | sec_per_unit=6.5332
# 2026-04-17 09:02:12,373 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00034 | est_remaining_sec=256.92
# 2026-04-17 09:02:12,461 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00034
# 2026-04-17 09:02:15,223 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00034.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00034.npz
# 2026-04-17 09:02:19,895 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00034.npz
# 2026-04-17 09:02:19,939 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00034 | duration=7.48s | sec_per_unit=6.7062
# 2026-04-17 09:02:19,940 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00035 | est_remaining_sec=235.87
# 2026-04-17 09:02:20,027 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00035
# 2026-04-17 09:02:22,144 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00035.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00035.npz
# 2026-04-17 09:02:26,865 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00035.npz
# 2026-04-17 09:02:26,910 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00035 | duration=6.88s | sec_per_unit=6.1717
# 2026-04-17 09:02:26,911 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00036 | est_remaining_sec=215.01
# 2026-04-17 09:02:27,012 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00036
# 2026-04-17 09:02:29,107 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00036.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00036.npz
# 2026-04-17 09:02:33,957 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00036.npz
# 2026-04-17 09:02:34,001 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00036 | duration=6.99s | sec_per_unit=6.2670
# 2026-04-17 09:02:34,002 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00037 | est_remaining_sec=194.39
# 2026-04-17 09:02:34,089 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00037
# 2026-04-17 09:02:36,589 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00037.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00037.npz
# 2026-04-17 09:02:41,669 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00037.npz
# 2026-04-17 09:02:41,714 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00037 | duration=7.62s | sec_per_unit=6.8371
# 2026-04-17 09:02:41,715 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00038 | est_remaining_sec=174.05
# 2026-04-17 09:02:41,802 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00038
# 2026-04-17 09:02:44,126 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00038.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00038.npz
# 2026-04-17 09:02:49,249 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00038.npz
# 2026-04-17 09:02:49,293 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00038 | duration=7.49s | sec_per_unit=6.7175
# 2026-04-17 09:02:49,294 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00039 | est_remaining_sec=153.91
# 2026-04-17 09:02:49,387 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00039
# 2026-04-17 09:02:49,903 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00039.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00039.npz
# 2026-04-17 09:02:55,202 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00039.npz
# 2026-04-17 09:02:55,246 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00039 | duration=5.86s | sec_per_unit=22.5559
# 2026-04-17 09:02:55,247 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00040 | est_remaining_sec=134.85
# 2026-04-17 09:02:55,334 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00040
# 2026-04-17 09:02:55,901 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00040.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00040.npz
# 2026-04-17 09:03:00,472 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00040.npz
# 2026-04-17 09:03:00,517 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00040 | duration=5.18s | sec_per_unit=18.3871
# 2026-04-17 09:03:00,517 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00041 | est_remaining_sec=115.55
# 2026-04-17 09:03:00,605 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00041
# 2026-04-17 09:03:01,175 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00041.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00041.npz
# 2026-04-17 09:03:05,325 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00041.npz
# 2026-04-17 09:03:05,369 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00041 | duration=4.76s | sec_per_unit=16.6479
# 2026-04-17 09:03:05,370 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=3dep | family=terrain | chunk=chunk_00042 | est_remaining_sec=96.19
# 2026-04-17 09:03:05,457 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=3dep | family=terrain:chunk_00042
# 2026-04-17 09:03:06,015 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00042.npz
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00042.npz
# 2026-04-17 09:03:10,466 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/3dep/terrain/chunk_00042.npz
# ...
# 2026-04-17 09:20:45,003 | INFO     | features.notebook | START | stage=family_chunk_compute | site=sedgwick | source=3dep | family=terrain:chunk_00000
# 2026-04-17 09:20:47,211 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/sedgwick/91fef1517fca02cc/3dep/terrain/chunk_00000.npz
# [artifact_store] Creating new Drive artifact for features/sedgwick/91fef1517fca02cc/3dep/terrain/chunk_00000.npz
# 2026-04-17 09:20:53,311 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/sedgwick/91fef1517fca02cc/3dep/terrain/chunk_00000.npz
# 2026-04-17 09:20:53,355 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=sedgwick | source=3dep | family=terrain:chunk_00000 | duration=8.35s | sec_per_unit=7.7218
# 2026-04-17 09:20:53,356 | INFO     | features.notebook | SOURCE ETA | site=sedgwick | source=3dep | family=terrain | chunk=chunk_00001 | est_remaining_sec=115.35
# 2026-04-17 09:20:53,443 | INFO     | features.notebook | START | stage=family_chunk_compute | site=sedgwick | source=3dep | family=terrain:chunk_00001
# 2026-04-17 09:20:55,083 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/sedgwick/91fef1517fca02cc/3dep/terrain/chunk_00001.npz
# [artifact_store] Creating new Drive artifact for features/sedgwick/91fef1517fca02cc/3dep/terrain/chunk_00001.npz
# 2026-04-17 09:20:59,451 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/sedgwick/91fef1517fca02cc/3dep/terrain/chunk_00001.npz
# 2026-04-17 09:20:59,498 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=sedgwick | source=3dep | family=terrain:chunk_00001 | duration=6.05s | sec_per_unit=7.9211
# 2026-04-17 09:20:59,499 | INFO     | features.notebook | SOURCE ETA | site=sedgwick | source=3dep | family=terrain | chunk=chunk_00002 | est_remaining_sec=86.24
# 2026-04-17 09:20:59,586 | INFO     | features.notebook | START | stage=family_chunk_compute | site=sedgwick | source=3dep | family=terrain:chunk_00002
# 2026-04-17 09:21:01,608 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/sedgwick/91fef1517fca02cc/3dep/terrain/chunk_00002.npz
# [artifact_store] Creating new Drive artifact for features/sedgwick/91fef1517fca02cc/3dep/terrain/chunk_00002.npz
# 2026-04-17 09:21:06,244 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/sedgwick/91fef1517fca02cc/3dep/terrain/chunk_00002.npz
# 2026-04-17 09:21:06,292 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=sedgwick | source=3dep | family=terrain:chunk_00002 | duration=6.71s | sec_per_unit=6.1055
# 2026-04-17 09:21:06,292 | INFO     | features.notebook | SOURCE ETA | site=sedgwick | source=3dep | family=terrain | chunk=chunk_00003 | est_remaining_sec=57.30
# 2026-04-17 09:21:06,379 | INFO     | features.notebook | START | stage=family_chunk_compute | site=sedgwick | source=3dep | family=terrain:chunk_00003
# 2026-04-17 09:21:07,810 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/sedgwick/91fef1517fca02cc/3dep/terrain/chunk_00003.npz
# [artifact_store] Creating new Drive artifact for features/sedgwick/91fef1517fca02cc/3dep/terrain/chunk_00003.npz
# 2026-04-17 09:21:12,066 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/sedgwick/91fef1517fca02cc/3dep/terrain/chunk_00003.npz
# 2026-04-17 09:21:12,111 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=sedgwick | source=3dep | family=terrain:chunk_00003 | duration=5.73s | sec_per_unit=7.3839
# 2026-04-17 09:21:12,111 | INFO     | features.notebook | SOURCE ETA | site=sedgwick | source=3dep | family=terrain | chunk=chunk_00004 | est_remaining_sec=28.56
# 2026-04-17 09:21:12,201 | INFO     | features.notebook | START | stage=family_chunk_compute | site=sedgwick | source=3dep | family=terrain:chunk_00004
# 2026-04-17 09:21:13,950 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/sedgwick/91fef1517fca02cc/3dep/terrain/chunk_00004.npz
# [artifact_store] Creating new Drive artifact for features/sedgwick/91fef1517fca02cc/3dep/terrain/chunk_00004.npz
# 2026-04-17 09:21:18,688 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/sedgwick/91fef1517fca02cc/3dep/terrain/chunk_00004.npz
# 2026-04-17 09:21:18,732 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=sedgwick | source=3dep | family=terrain:chunk_00004 | duration=6.53s | sec_per_unit=7.0239
# 2026-04-17 09:21:18,733 | INFO     | features.notebook | SOURCE ETA | site=sedgwick | source=3dep | family=terrain | chunk=chunk_00005 | est_remaining_sec=0.00
# 2026-04-17 09:21:18,820 | INFO     | features.notebook | START | stage=family_chunk_compute | site=sedgwick | source=3dep | family=terrain:chunk_00005
# 2026-04-17 09:21:20,369 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/sedgwick/91fef1517fca02cc/3dep/terrain/chunk_00005.npz
# [artifact_store] Creating new Drive artifact for features/sedgwick/91fef1517fca02cc/3dep/terrain/chunk_00005.npz
# 2026-04-17 09:21:24,849 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/sedgwick/91fef1517fca02cc/3dep/terrain/chunk_00005.npz
# 2026-04-17 09:21:24,893 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=sedgwick | source=3dep | family=terrain:chunk_00005 | duration=6.07s | sec_per_unit=9.2426
# 2026-04-17 09:21:24,893 | INFO     | features.notebook | SOURCE FAMILY DONE | site=sedgwick | source=3dep | family=terrain
# 2026-04-17 09:21:25,160 | INFO     | features.notebook | PUSH ARTIFACT | key=stack_registry | rel_path=features/sedgwick/91fef1517fca02cc/stack/stack_registry.json
# [artifact_store] Creating new Drive artifact for features/sedgwick/91fef1517fca02cc/stack/stack_registry.json
# 2026-04-17 09:21:29,352 | INFO     | features.notebook | SOURCE CHUNKED RUN COMPLETE | site=sedgwick | source=3dep | registered_layers=54
# 2026-04-17 09:21:29,792 | INFO     | features.notebook | Cleared artifact staging directory | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/_artifact_staging
# 2026-04-17 09:21:29,792 | INFO     | features.notebook | ================================================================================
# 2026-04-17 09:21:29,792 | INFO     | features.notebook | RUN 3DEP ALL SITES | site=shaver-lake
# 2026-04-17 09:21:29,793 | INFO     | features.notebook | START | stage=site_assets | site=shaver-lake | source=None | family=None
# 2026-04-17 09:21:29,793 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=source_inventory | rel_path=features/shaver-lake/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 09:21:30,592 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/shaver-lake/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 09:21:30,592 | INFO     | features.notebook | Using cached source inventory | site=shaver-lake
# 2026-04-17 09:21:30,593 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=site_metadata_manifest | rel_path=features/shaver-lake/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 09:21:31,371 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/shaver-lake/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 09:21:31,371 | INFO     | features.notebook | Using site metadata manifest | site=shaver-lake
# 2026-04-17 09:21:31,642 | INFO     | features.notebook | PUSH ARTIFACT | key=site_metadata_manifest | rel_path=features/shaver-lake/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# [artifact_store] Updating existing Drive artifact for features/shaver-lake/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 09:21:35,941 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse | site=shaver-lake | keys=['naip', 'als_metadata', '3dep', 'source_inventory', 'rap'] | notes=0
# 2026-04-17 09:21:35,941 | INFO     | features.notebook | END   | stage=site_assets | site=shaver-lake | source=None | family=None | duration=6.15s
# 2026-04-17 09:21:36,072 | INFO     | features.notebook | START | stage=canonical_grid | site=shaver-lake | source=naip | family=None
# 2026-04-17 09:21:36,390 | INFO     | features.notebook | Built canonical grid | site=shaver-lake | shape=(1773, 1880) | pixel_size=(0.6, 0.599999999999895)
# 2026-04-17 09:21:36,391 | INFO     | features.notebook | END   | stage=canonical_grid | site=shaver-lake | source=naip | family=None | duration=0.32s
# 2026-04-17 09:21:36,524 | INFO     | features.notebook | START | stage=chunk_manifest | site=shaver-lake | source=naip | family=None
# 2026-04-17 09:21:36,612 | INFO     | features.notebook | Built chunk manifest | site=shaver-lake | chunk_size=1024 | n_chunks=4
# 2026-04-17 09:21:36,612 | INFO     | features.notebook | END   | stage=chunk_manifest | site=shaver-lake | source=naip | family=None | duration=0.09s | sec_per_unit=0.0263
# 2026-04-17 09:21:36,656 | INFO     | features.notebook | Pruned local NAIP site asset after canonical grid build | site=shaver-lake | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/shaver-lake/naip/shaver_lake.tif
# 2026-04-17 09:21:39,392 | INFO     | features.notebook | Exporting 3DEP from Earth Engine | site=shaver-lake | out=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/shaver-lake/3dep/shaver-lake_3dep_ee_10m.tif | bounds_wgs84=(-119.282259, 37.097463, -119.269287, 37.107288)
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/shrubwise-dc-488219/thumbnails/04bb2d336f40106c1d74390ddf98680c-700a18aa9e4d90042adf07f2ccc183fd:getPixels
# Please wait ...
# 2026-04-17 09:21:40,778 | INFO     | features.notebook | PUSH ARTIFACT | key=site_3dep_raster | rel_path=features/shaver-lake/shared/site_assets/3dep/shaver-lake_3dep_ee_10m.tif
# Data downloaded to /home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/shaver-lake/3dep/shaver-lake_3dep_ee_10m.tif
# [artifact_store] Creating new Drive artifact for features/shaver-lake/shared/site_assets/3dep/shaver-lake_3dep_ee_10m.tif
# 2026-04-17 09:21:45,309 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/shaver-lake/shared/site_assets/3dep/shaver-lake_3dep_ee_10m.tif
# 2026-04-17 09:21:45,310 | INFO     | features.notebook | 3DEP local file was pruned after push; rehydrating for current use | site=shaver-lake
# 2026-04-17 09:21:45,905 | INFO     | features.notebook | Prepared 3DEP asset | site=shaver-lake | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/shaver-lake/3dep/shaver-lake_3dep_ee_10m.tif
# 2026-04-17 09:21:45,995 | INFO     | features.notebook | Pruned local 3DEP site asset after in-memory load | site=shaver-lake | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/shaver-lake/3dep/shaver-lake_3dep_ee_10m.tif
# 2026-04-17 09:21:46,282 | INFO     | features.notebook | SOURCE CHUNKED RUN | site=shaver-lake | source=3dep | families=('terrain',) | n_chunks=4
# 2026-04-17 09:21:46,282 | INFO     | features.notebook | SOURCE FAMILY START | site=shaver-lake | source=3dep | family=terrain
# 2026-04-17 09:21:46,283 | INFO     | features.notebook | SOURCE ETA | site=shaver-lake | source=3dep | family=terrain | chunk=chunk_00000 | est_remaining_sec=85.16
# 2026-04-17 09:21:46,414 | INFO     | features.notebook | START | stage=family_chunk_compute | site=shaver-lake | source=3dep | family=terrain:chunk_00000
# 2026-04-17 09:21:48,559 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/shaver-lake/91fef1517fca02cc/3dep/terrain/chunk_00000.npz
# [artifact_store] Creating new Drive artifact for features/shaver-lake/91fef1517fca02cc/3dep/terrain/chunk_00000.npz
# 2026-04-17 09:21:54,638 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/shaver-lake/91fef1517fca02cc/3dep/terrain/chunk_00000.npz
# 2026-04-17 09:21:54,682 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=shaver-lake | source=3dep | family=terrain:chunk_00000 | duration=8.27s | sec_per_unit=7.6441
# 2026-04-17 09:21:54,683 | INFO     | features.notebook | SOURCE ETA | site=shaver-lake | source=3dep | family=terrain | chunk=chunk_00001 | est_remaining_sec=56.60
# 2026-04-17 09:21:54,770 | INFO     | features.notebook | START | stage=family_chunk_compute | site=shaver-lake | source=3dep | family=terrain:chunk_00001
# 2026-04-17 09:21:56,629 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/shaver-lake/91fef1517fca02cc/3dep/terrain/chunk_00001.npz
# [artifact_store] Creating new Drive artifact for features/shaver-lake/91fef1517fca02cc/3dep/terrain/chunk_00001.npz
# 2026-04-17 09:22:01,088 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/shaver-lake/91fef1517fca02cc/3dep/terrain/chunk_00001.npz
# 2026-04-17 09:22:01,132 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=shaver-lake | source=3dep | family=terrain:chunk_00001 | duration=6.36s | sec_per_unit=7.0154
# 2026-04-17 09:22:01,133 | INFO     | features.notebook | SOURCE ETA | site=shaver-lake | source=3dep | family=terrain | chunk=chunk_00002 | est_remaining_sec=28.21
# 2026-04-17 09:22:01,223 | INFO     | features.notebook | START | stage=family_chunk_compute | site=shaver-lake | source=3dep | family=terrain:chunk_00002
# 2026-04-17 09:22:02,726 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/shaver-lake/91fef1517fca02cc/3dep/terrain/chunk_00002.npz
# [artifact_store] Creating new Drive artifact for features/shaver-lake/91fef1517fca02cc/3dep/terrain/chunk_00002.npz
# 2026-04-17 09:22:06,847 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/shaver-lake/91fef1517fca02cc/3dep/terrain/chunk_00002.npz
# 2026-04-17 09:22:06,891 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=shaver-lake | source=3dep | family=terrain:chunk_00002 | duration=5.67s | sec_per_unit=7.1243
# 2026-04-17 09:22:06,892 | INFO     | features.notebook | SOURCE ETA | site=shaver-lake | source=3dep | family=terrain | chunk=chunk_00003 | est_remaining_sec=0.00
# 2026-04-17 09:22:06,979 | INFO     | features.notebook | START | stage=family_chunk_compute | site=shaver-lake | source=3dep | family=terrain:chunk_00003
# 2026-04-17 09:22:08,311 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/shaver-lake/91fef1517fca02cc/3dep/terrain/chunk_00003.npz
# [artifact_store] Creating new Drive artifact for features/shaver-lake/91fef1517fca02cc/3dep/terrain/chunk_00003.npz
# 2026-04-17 09:22:12,763 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/shaver-lake/91fef1517fca02cc/3dep/terrain/chunk_00003.npz
# 2026-04-17 09:22:12,807 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=shaver-lake | source=3dep | family=terrain:chunk_00003 | duration=5.83s | sec_per_unit=8.7366
# 2026-04-17 09:22:12,808 | INFO     | features.notebook | SOURCE FAMILY DONE | site=shaver-lake | source=3dep | family=terrain
# 2026-04-17 09:22:13,070 | INFO     | features.notebook | PUSH ARTIFACT | key=stack_registry | rel_path=features/shaver-lake/91fef1517fca02cc/stack/stack_registry.json
# [artifact_store] Creating new Drive artifact for features/shaver-lake/91fef1517fca02cc/stack/stack_registry.json
# 2026-04-17 09:22:17,084 | INFO     | features.notebook | SOURCE CHUNKED RUN COMPLETE | site=shaver-lake | source=3dep | registered_layers=36
# 2026-04-17 09:22:17,477 | INFO     | features.notebook | Cleared artifact staging directory | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/_artifact_staging

# %%
summary_rows = []
#print(all_3dep_runs['dl-bliss'])
for site_id, registry in all_3dep_runs.items():
    df = stack_registry_frame(registry['registry'])
    summary_rows.append({
        "site_id": site_id,
        "n_layers": len(registry['registry'].layers),
        "families": sorted(df["family_name"].unique().tolist()) if not df.empty else [],
        "sources": sorted(df["source_name"].unique().tolist()) if not df.empty else [],
    })

display(pd.DataFrame(summary_rows))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                  site_id  n_layers   families sources
# 0    calaveras-big-trees       432  [terrain]  [3dep]
# 1               dl-bliss        81  [terrain]  [3dep]
# 2      independence-lake       720  [terrain]  [3dep]
# 3  pacific-union-college        54  [terrain]  [3dep]
# 4               sedgwick        54  [terrain]  [3dep]
# 5            shaver-lake        36  [terrain]  [3dep]

# %% [markdown]
# # RAP

# %%
RAP_FAMILY_SPECS = {
    "prior": FeatureFamilySpec(
        key="prior",
        source_name="rap",
        runtime_tier=RuntimeTier.CHEAP,
        required_halo_px=8,
        representation_target=RepresentationTarget.RASTER,
        notes="Local shrub presence and neighborhood ecological priors.",
    ),
}
display(family_spec_frame(RAP_FAMILY_SPECS))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#   family source_name runtime_tier  required_halo_px  target  \
# 0  prior         rap        cheap                 8  raster
#
#                                                notes
# 0  Local shrub presence and neighborhood ecologic...

# %%
def prepare_rap_asset(
    site_id: str,
    *,
    canonical_grid: CanonicalGrid | None = None,
    force_refresh: bool = False,
    inventory: dict[str, Any] | None = None,
) -> Path:
    local_path = site_rap_cache_root(site_id) / f"{site_id}_rap_ee_10m.tif"
    rel_path = site_rap_rel_path(site_id, filename=local_path.name)

    # 1) local cache
    if (not force_refresh) and local_path.exists() and validate_cached_raster(local_path):
        LOGGER.info("Using cached RAP | site=%s | path=%s", site_id, local_path)
        return local_path

    # 2) artifact-store hydration
    if not force_refresh and remote_artifact_exists(rel_path):
        LOGGER.info("Hydrating RAP from artifact store | site=%s | rel_path=%s", site_id, rel_path)
        pulled = artifact_store.pull(rel_path, local_path=local_path)
        if validate_cached_raster(pulled):
            return pulled
        LOGGER.warning("Hydrated RAP failed validation | site=%s | path=%s", site_id, pulled)
        pulled.unlink(missing_ok=True)

    # 3) build from Earth Engine
    if canonical_grid is None:
        raise ValueError(
            "prepare_rap_asset requires canonical_grid when no cached RAP raster is available."
        )

    ensure_ee_initialized(project="shrubwise-dc-488219")

    west, south, east, north = canonical_grid_bounds_wgs84(canonical_grid)
    region_coords = canonical_grid_bbox_region_coords(canonical_grid)
    image = ee_rap_image_for_grid(canonical_grid)

    LOGGER.info(
        "Exporting RAP from Earth Engine | site=%s | out=%s | bounds_wgs84=(%.6f, %.6f, %.6f, %.6f)",
        site_id, local_path, west, south, east, north
    )

    export_ee_image_to_geotiff(
        image,
        out_path=local_path,
        region_coords=region_coords,
        scale=10.0,
        crs="EPSG:4326",
    )

    if not validate_cached_raster(local_path):
        raise RuntimeError(f"Exported RAP is unreadable for site={site_id}: {local_path}")

    persist_existing_file_artifact(
        local_path,
        artifact_key="site_rap_raster",
        site_id=site_id,
        filename=local_path.name,
    )

    if not local_path.exists():
        LOGGER.info("RAP local file was pruned after push; rehydrating for current use | site=%s", site_id)
        artifact_store.pull(rel_path, local_path=local_path)

    LOGGER.info("Prepared RAP asset | site=%s | path=%s", site_id, local_path)
    return local_path

def infer_rap_band_names(path: str | Path) -> list[str]:
    path = Path(path)
    with rasterio.open(path) as src:
        count = src.count

    if count >= 4:
        default = ["SHR", "TRE", "PFG", "AFG"]
        if count > 4:
            default += [f"band_{i}" for i in range(5, count + 1)]
        return default[:count]

    return [f"band_{i}" for i in range(1, count + 1)]


def maybe_prune_local_site_rap_after_load(site_id: str, tif_path: str | Path) -> None:
    tif_path = Path(tif_path)
    rel_path = site_rap_rel_path(site_id, filename=tif_path.name)

    if not fe_cfg.persistence.prune_local_after_remote_push:
        return

    if not remote_artifact_exists(rel_path):
        return

    try:
        if tif_path.exists():
            tif_path.unlink()
            LOGGER.info("Pruned local RAP site asset after in-memory load | site=%s | path=%s", site_id, tif_path)
    except Exception as e:
        LOGGER.warning("Failed to prune local RAP asset | site=%s | path=%s | err=%s", site_id, tif_path, e)


def load_rap_source_bundle(
    site_id: str,
    *,
    site_assets: SiteAssetBundle,
    canonical_grid: CanonicalGrid,
    force_refresh: bool = False,
) -> SourceRasterBundle:
    tif_path = prepare_rap_asset(
        site_id,
        canonical_grid=canonical_grid,
        force_refresh=force_refresh,
        inventory=site_assets.source_assets.get("source_inventory"),
    )

    bundle = read_raster_bundle(
        tif_path,
        site_id=site_id,
        source_name="rap",
        band_names=infer_rap_band_names(tif_path),
    )

    maybe_prune_local_site_rap_after_load(site_id, tif_path)
    return bundle

def align_rap_to_canonical_grid(
    bundle: SourceRasterBundle,
    *,
    canonical_grid: CanonicalGrid,
) -> SourceRasterBundle:
    return align_bundle_to_grid(
        bundle,
        dst_grid=canonical_grid,
        resampling=SOURCE_SPECS["rap"].default_resampling,
    )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def make_rap_prior_compute_fn(
    *,
    context_radius_meters: float,
    approx_native_resolution_m: float = 10.0,
):
    def _compute(arrays: dict[str, np.ndarray]) -> dict[str, np.ndarray]:
        out = {}

        shrub_name = "SHR" if "SHR" in arrays else next(iter(arrays.keys()))
        shrub = nan_to_num_copy(arrays[shrub_name]).astype(np.float32)

        window = max(5, int(round(context_radius_meters / approx_native_resolution_m)))

        out["rap_local_shrub_presence"] = shrub
        out["rap_shrub_fraction_prior"] = get_uniform_blur(
            shrub,
            neighborhood_size=window,
        ).astype(np.float32)

        comp_names = [name for name in arrays.keys() if name != shrub_name]
        for name in comp_names:
            out[f"rap_{name}_prior"] = get_uniform_blur(
                nan_to_num_copy(arrays[name]),
                neighborhood_size=window,
            ).astype(np.float32)

        return out

    return _compute


def run_rap_chunked_pipeline(
    site_id: str,
    *,
    site_assets: SiteAssetBundle,
    canonical_grid: CanonicalGrid,
    chunk_manifest: ChunkManifest,
    registry: RasterStackRegistry | None = None,
    force_refresh_source: bool = False,
) -> RasterStackRegistry:
    raw_bundle = load_rap_source_bundle(
        site_id,
        site_assets=site_assets,
        canonical_grid=canonical_grid,
        force_refresh=force_refresh_source,
    )

    prior_compute_fn = make_rap_prior_compute_fn(
        context_radius_meters=fe_cfg.rap.context_radius_meters,
        approx_native_resolution_m=10.0,
    )

    return run_source_chunked_pipeline(
        site_id=site_id,
        source_name="rap",
        raw_bundle=raw_bundle,
        canonical_grid=canonical_grid,
        chunk_manifest=chunk_manifest,
        family_specs=RAP_FAMILY_SPECS,
        family_compute_fns={
            "prior": prior_compute_fn,
        },
        family_cfg_payloads={
            "prior": {
                "context_radius_meters": fe_cfg.rap.context_radius_meters,
                "approx_native_resolution_m": 10.0,
            }
        },
        registry=registry,
    )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
TEST_SITE = fe_cfg.sites[0]

site_assets = prepare_site_assets(TEST_SITE, force_refresh=False)
canonical_grid = build_canonical_grid_for_site(TEST_SITE, assets=site_assets, force_refresh=False)
chunk_manifest = build_chunk_manifest(canonical_grid, force_refresh=False)

registry_rap = run_rap_chunked_pipeline(
    TEST_SITE,
    site_assets=site_assets,
    canonical_grid=canonical_grid,
    chunk_manifest=chunk_manifest,
    registry=RasterStackRegistry(
        site_id=TEST_SITE,
        config_signature=fe_config_signature(),
        layers=[],
    ),
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 2026-04-17 09:29:17,665 | INFO     | features.notebook | START | stage=site_assets | site=calaveras-big-trees | source=None | family=None
# 2026-04-17 09:29:17,666 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=source_inventory | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/source_inventory.json
# ERROR! Session/line number was not unique in database. History logging moved to new session 32
# 2026-04-17 09:29:18,255 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 09:29:18,255 | INFO     | features.notebook | Using cached source inventory | site=calaveras-big-trees
# 2026-04-17 09:29:18,256 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=site_metadata_manifest | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 09:29:18,301 | INFO     | features.notebook | Using site metadata manifest | site=calaveras-big-trees
# 2026-04-17 09:29:18,505 | INFO     | features.notebook | PUSH ARTIFACT | key=site_metadata_manifest | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 09:29:22,229 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse | site=calaveras-big-trees | keys=['naip', 'als_metadata', 'source_inventory', '3dep', 'rap'] | notes=1
# 2026-04-17 09:29:22,230 | INFO     | features.notebook | END   | stage=site_assets | site=calaveras-big-trees | source=None | family=None | duration=4.57s
# 2026-04-17 09:29:22,231 | INFO     | features.notebook | Using cached canonical grid | site=calaveras-big-trees
# 2026-04-17 09:29:22,232 | INFO     | features.notebook | Using cached chunk manifest | site=calaveras-big-trees | n_chunks=48
# 2026-04-17 09:29:22,233 | INFO     | features.notebook | Hydrating RAP from artifact store | site=calaveras-big-trees | rel_path=features/calaveras-big-trees/shared/site_assets/rap/calaveras-big-trees_rap_ee_10m.tif
# 2026-04-17 09:29:22,870 | WARNING  | rasterio._env | CPLE_AppDefined in calaveras-big-trees_rap_ee_10m.tif: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 09:29:22,916 | WARNING  | rasterio._env | CPLE_AppDefined in TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 09:29:22,922 | WARNING  | rasterio._env | CPLE_AppDefined in calaveras-big-trees_rap_ee_10m.tif: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 09:29:22,923 | WARNING  | rasterio._env | CPLE_AppDefined in calaveras-big-trees_rap_ee_10m.tif: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 09:29:22,923 | WARNING  | rasterio._env | CPLE_AppDefined in TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 09:29:22,980 | INFO     | features.notebook | Pruned local RAP site asset after in-memory load | site=calaveras-big-trees | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/calaveras-big-trees/rap/calaveras-big-trees_rap_ee_10m.tif
# 2026-04-17 09:29:36,313 | INFO     | features.notebook | SOURCE CHUNKED RUN | site=calaveras-big-trees | source=rap | families=('prior',) | n_chunks=48
# 2026-04-17 09:29:36,314 | INFO     | features.notebook | SOURCE FAMILY START | site=calaveras-big-trees | source=rap | family=prior
# 2026-04-17 09:29:36,315 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00000 | est_remaining_sec=1308.77
# 2026-04-17 09:29:36,359 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00000
# 2026-04-17 09:29:38,064 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00001 | est_remaining_sec=1280.92
# 2026-04-17 09:29:38,065 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00001
# 2026-04-17 09:29:39,338 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00001.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00001.npz
# 2026-04-17 09:29:45,283 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00001.npz
# 2026-04-17 09:29:45,328 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00001 | duration=7.26s | sec_per_unit=6.7670
# 2026-04-17 09:29:45,329 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00002 | est_remaining_sec=1249.17
# 2026-04-17 09:29:45,416 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00002
# 2026-04-17 09:29:46,629 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00002.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00002.npz
# 2026-04-17 09:29:51,058 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00002.npz
# 2026-04-17 09:29:51,104 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00002 | duration=5.69s | sec_per_unit=5.2991
# 2026-04-17 09:29:51,104 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00003 | est_remaining_sec=1217.37
# 2026-04-17 09:29:51,196 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00003
# 2026-04-17 09:29:52,461 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00003.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00003.npz
# 2026-04-17 09:29:56,469 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00003.npz
# 2026-04-17 09:29:56,513 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00003 | duration=5.32s | sec_per_unit=4.9540
# 2026-04-17 09:29:56,514 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00004 | est_remaining_sec=1185.71
# 2026-04-17 09:29:56,602 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00004
# 2026-04-17 09:29:58,028 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00004.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00004.npz
# 2026-04-17 09:30:02,449 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00004.npz
# 2026-04-17 09:30:02,495 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00004 | duration=5.89s | sec_per_unit=5.4905
# 2026-04-17 09:30:02,495 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00005 | est_remaining_sec=1154.37
# 2026-04-17 09:30:02,585 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00005
# 2026-04-17 09:30:03,892 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00005.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00005.npz
# 2026-04-17 09:30:09,226 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00005.npz
# 2026-04-17 09:30:09,270 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00005 | duration=6.68s | sec_per_unit=6.2284
# 2026-04-17 09:30:09,271 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00006 | est_remaining_sec=1123.35
# 2026-04-17 09:30:09,360 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00006
# 2026-04-17 09:30:10,782 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00006.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00006.npz
# 2026-04-17 09:30:15,181 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00006.npz
# 2026-04-17 09:30:15,226 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00006 | duration=5.87s | sec_per_unit=5.4656
# 2026-04-17 09:30:15,227 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00007 | est_remaining_sec=1092.42
# 2026-04-17 09:30:15,314 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00007
# 2026-04-17 09:30:15,671 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00007.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00007.npz
# 2026-04-17 09:30:19,636 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00007.npz
# 2026-04-17 09:30:19,681 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00007 | duration=4.37s | sec_per_unit=17.7767
# 2026-04-17 09:30:19,681 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00008 | est_remaining_sec=1063.61
# 2026-04-17 09:30:19,769 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00008
# 2026-04-17 09:30:21,025 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00008.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00008.npz
# 2026-04-17 09:30:26,293 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00008.npz
# 2026-04-17 09:30:26,338 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00008 | duration=6.57s | sec_per_unit=6.1208
# 2026-04-17 09:30:26,339 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00009 | est_remaining_sec=1033.13
# 2026-04-17 09:30:26,426 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00009
# 2026-04-17 09:30:27,529 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00009.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00009.npz
# 2026-04-17 09:30:31,495 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00009.npz
# 2026-04-17 09:30:31,540 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00009 | duration=5.11s | sec_per_unit=4.7276
# 2026-04-17 09:30:31,540 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00010 | est_remaining_sec=1002.63
# 2026-04-17 09:30:31,628 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00010
# 2026-04-17 09:30:32,982 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00010.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00010.npz
# 2026-04-17 09:30:37,636 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00010.npz
# 2026-04-17 09:30:37,681 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00010 | duration=6.05s | sec_per_unit=5.5971
# 2026-04-17 09:30:37,682 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00011 | est_remaining_sec=972.46
# 2026-04-17 09:30:37,772 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00011
# 2026-04-17 09:30:39,252 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00011.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00011.npz
# 2026-04-17 09:30:43,809 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00011.npz
# 2026-04-17 09:30:43,855 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00011 | duration=6.08s | sec_per_unit=5.6237
# 2026-04-17 09:30:43,856 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00012 | est_remaining_sec=942.49
# 2026-04-17 09:30:43,944 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00012
# 2026-04-17 09:30:45,390 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00012.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00012.npz
# 2026-04-17 09:30:50,288 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00012.npz
# 2026-04-17 09:30:50,335 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00012 | duration=6.39s | sec_per_unit=5.9092
# 2026-04-17 09:30:50,336 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00013 | est_remaining_sec=912.74
# 2026-04-17 09:30:50,423 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00013
# 2026-04-17 09:30:52,353 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00013.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00013.npz
# 2026-04-17 09:30:56,728 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00013.npz
# 2026-04-17 09:30:56,772 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00013 | duration=6.35s | sec_per_unit=5.8693
# 2026-04-17 09:30:56,773 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00014 | est_remaining_sec=883.18
# 2026-04-17 09:30:56,864 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00014
# 2026-04-17 09:30:58,302 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00014.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00014.npz
# 2026-04-17 09:31:02,824 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00014.npz
# 2026-04-17 09:31:02,868 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00014 | duration=6.00s | sec_per_unit=5.5514
# 2026-04-17 09:31:02,869 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00015 | est_remaining_sec=853.77
# 2026-04-17 09:31:02,957 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00015
# 2026-04-17 09:31:03,307 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00015.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00015.npz
# 2026-04-17 09:31:07,351 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00015.npz
# 2026-04-17 09:31:07,395 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00015 | duration=4.44s | sec_per_unit=17.9318
# 2026-04-17 09:31:07,396 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00016 | est_remaining_sec=826.03
# 2026-04-17 09:31:07,484 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00016
# 2026-04-17 09:31:08,585 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00016.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00016.npz
# 2026-04-17 09:31:12,593 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00016.npz
# 2026-04-17 09:31:12,638 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00016 | duration=5.15s | sec_per_unit=4.8018
# 2026-04-17 09:31:12,639 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00017 | est_remaining_sec=796.85
# 2026-04-17 09:31:12,726 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00017
# 2026-04-17 09:31:13,829 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00017.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00017.npz
# 2026-04-17 09:31:18,071 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00017.npz
# 2026-04-17 09:31:18,115 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00017 | duration=5.39s | sec_per_unit=4.9826
# 2026-04-17 09:31:18,116 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00018 | est_remaining_sec=767.87
# 2026-04-17 09:31:18,204 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00018
# 2026-04-17 09:31:19,558 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00018.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00018.npz
# 2026-04-17 09:31:23,737 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00018.npz
# 2026-04-17 09:31:23,781 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00018 | duration=5.58s | sec_per_unit=5.1564
# 2026-04-17 09:31:23,782 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00019 | est_remaining_sec=739.10
# 2026-04-17 09:31:23,872 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00019
# 2026-04-17 09:31:25,245 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00019.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00019.npz
# 2026-04-17 09:31:29,466 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00019.npz
# 2026-04-17 09:31:29,510 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00019 | duration=5.64s | sec_per_unit=5.2126
# 2026-04-17 09:31:29,511 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00020 | est_remaining_sec=710.51
# 2026-04-17 09:31:29,598 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00020
# 2026-04-17 09:31:30,954 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00020.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00020.npz
# 2026-04-17 09:31:35,254 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00020.npz
# 2026-04-17 09:31:35,298 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00020 | duration=5.70s | sec_per_unit=5.2699
# 2026-04-17 09:31:35,299 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00021 | est_remaining_sec=682.10
# 2026-04-17 09:31:35,386 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00021
# 2026-04-17 09:31:36,786 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00021.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00021.npz
# 2026-04-17 09:31:41,015 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00021.npz
# 2026-04-17 09:31:41,062 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00021 | duration=5.68s | sec_per_unit=5.2470
# 2026-04-17 09:31:41,063 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00022 | est_remaining_sec=653.87
# 2026-04-17 09:31:41,150 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00022
# 2026-04-17 09:31:42,544 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00022.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00022.npz
# 2026-04-17 09:31:46,750 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00022.npz
# 2026-04-17 09:31:46,795 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00022 | duration=5.64s | sec_per_unit=5.2187
# 2026-04-17 09:31:46,795 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00023 | est_remaining_sec=625.82
# 2026-04-17 09:31:46,883 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00023
# 2026-04-17 09:31:47,336 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00023.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00023.npz
# 2026-04-17 09:31:51,286 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00023.npz
# 2026-04-17 09:31:51,330 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00023 | duration=4.45s | sec_per_unit=17.9699
# 2026-04-17 09:31:51,332 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00024 | est_remaining_sec=599.04
# 2026-04-17 09:31:51,419 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00024
# 2026-04-17 09:31:52,725 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00024.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00024.npz
# 2026-04-17 09:31:56,862 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00024.npz
# 2026-04-17 09:31:56,906 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00024 | duration=5.49s | sec_per_unit=5.1124
# 2026-04-17 09:31:56,907 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00025 | est_remaining_sec=571.26
# 2026-04-17 09:31:56,997 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00025
# 2026-04-17 09:31:58,292 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00025.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00025.npz
# 2026-04-17 09:32:02,134 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00025.npz
# 2026-04-17 09:32:02,179 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00025 | duration=5.18s | sec_per_unit=4.7906
# 2026-04-17 09:32:02,180 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00026 | est_remaining_sec=543.63
# 2026-04-17 09:32:02,270 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00026
# 2026-04-17 09:32:03,808 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00026.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00026.npz
# 2026-04-17 09:32:07,804 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00026.npz
# 2026-04-17 09:32:07,849 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00026 | duration=5.58s | sec_per_unit=5.1588
# 2026-04-17 09:32:07,850 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00027 | est_remaining_sec=516.19
# 2026-04-17 09:32:07,938 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00027
# 2026-04-17 09:32:09,224 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00027.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00027.npz
# 2026-04-17 09:32:13,503 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00027.npz
# 2026-04-17 09:32:13,547 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00027 | duration=5.61s | sec_per_unit=5.1854
# 2026-04-17 09:32:13,548 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00028 | est_remaining_sec=488.93
# 2026-04-17 09:32:13,635 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00028
# 2026-04-17 09:32:15,055 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00028.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00028.npz
# 2026-04-17 09:32:19,175 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00028.npz
# 2026-04-17 09:32:19,219 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00028 | duration=5.58s | sec_per_unit=5.1625
# 2026-04-17 09:32:19,220 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00029 | est_remaining_sec=461.82
# 2026-04-17 09:32:19,307 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00029
# 2026-04-17 09:32:20,782 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00029.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00029.npz
# 2026-04-17 09:32:25,135 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00029.npz
# 2026-04-17 09:32:25,180 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00029 | duration=5.87s | sec_per_unit=5.4298
# 2026-04-17 09:32:25,181 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00030 | est_remaining_sec=434.90
# 2026-04-17 09:32:25,268 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00030
# 2026-04-17 09:32:26,620 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00030.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00030.npz
# 2026-04-17 09:32:31,350 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00030.npz
# 2026-04-17 09:32:31,394 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00030 | duration=6.13s | sec_per_unit=5.6636
# 2026-04-17 09:32:31,395 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00031 | est_remaining_sec=408.14
# 2026-04-17 09:32:31,482 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00031
# 2026-04-17 09:32:32,059 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00031.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00031.npz
# 2026-04-17 09:32:35,878 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00031.npz
# 2026-04-17 09:32:35,922 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00031 | duration=4.44s | sec_per_unit=17.9372
# 2026-04-17 09:32:35,923 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00032 | est_remaining_sec=382.22
# 2026-04-17 09:32:36,010 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00032
# 2026-04-17 09:32:37,208 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00032.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00032.npz
# 2026-04-17 09:32:41,492 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00032.npz
# 2026-04-17 09:32:41,536 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00032 | duration=5.53s | sec_per_unit=5.1480
# 2026-04-17 09:32:41,537 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00033 | est_remaining_sec=355.70
# 2026-04-17 09:32:41,624 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00033
# 2026-04-17 09:32:43,001 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00033.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00033.npz
# 2026-04-17 09:32:47,884 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00033.npz
# 2026-04-17 09:32:47,929 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00033 | duration=6.30s | sec_per_unit=5.8290
# 2026-04-17 09:32:47,929 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00034 | est_remaining_sec=329.37
# 2026-04-17 09:32:48,017 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00034
# 2026-04-17 09:32:49,765 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00034.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00034.npz
# 2026-04-17 09:32:54,187 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00034.npz
# 2026-04-17 09:32:54,232 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00034 | duration=6.22s | sec_per_unit=5.7462
# 2026-04-17 09:32:54,233 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00035 | est_remaining_sec=303.18
# 2026-04-17 09:32:54,322 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00035
# 2026-04-17 09:32:55,690 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00035.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00035.npz
# 2026-04-17 09:33:00,153 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00035.npz
# 2026-04-17 09:33:00,198 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00035 | duration=5.88s | sec_per_unit=5.4324
# 2026-04-17 09:33:00,199 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00036 | est_remaining_sec=277.13
# 2026-04-17 09:33:00,303 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00036
# 2026-04-17 09:33:01,732 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00036.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00036.npz
# 2026-04-17 09:33:06,131 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00036.npz
# 2026-04-17 09:33:06,175 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00036 | duration=5.87s | sec_per_unit=5.4293
# 2026-04-17 09:33:06,176 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00037 | est_remaining_sec=251.22
# 2026-04-17 09:33:06,264 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00037
# 2026-04-17 09:33:07,660 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00037.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00037.npz
# 2026-04-17 09:33:12,533 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00037.npz
# 2026-04-17 09:33:12,578 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00037 | duration=6.31s | sec_per_unit=5.8378
# 2026-04-17 09:33:12,579 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00038 | est_remaining_sec=225.48
# 2026-04-17 09:33:12,672 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00038
# 2026-04-17 09:33:14,047 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00038.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00038.npz
# 2026-04-17 09:33:18,724 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00038.npz
# 2026-04-17 09:33:18,768 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00038 | duration=6.10s | sec_per_unit=5.6361
# 2026-04-17 09:33:18,769 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00039 | est_remaining_sec=199.87
# 2026-04-17 09:33:18,858 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00039
# 2026-04-17 09:33:19,195 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00039.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00039.npz
# 2026-04-17 09:33:23,238 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00039.npz
# 2026-04-17 09:33:23,283 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00039 | duration=4.42s | sec_per_unit=17.8767
# 2026-04-17 09:33:23,284 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00040 | est_remaining_sec=174.71
# 2026-04-17 09:33:23,415 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00040
# 2026-04-17 09:33:23,775 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00040.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00040.npz
# 2026-04-17 09:33:28,040 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00040.npz
# 2026-04-17 09:33:28,087 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00040 | duration=4.67s | sec_per_unit=17.2105
# 2026-04-17 09:33:28,088 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00041 | est_remaining_sec=149.59
# 2026-04-17 09:33:28,177 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00041
# 2026-04-17 09:33:28,555 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00041.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00041.npz
# 2026-04-17 09:33:33,009 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00041.npz
# 2026-04-17 09:33:33,053 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00041 | duration=4.88s | sec_per_unit=17.8258
# 2026-04-17 09:33:33,054 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00042 | est_remaining_sec=124.53
# 2026-04-17 09:33:33,230 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00042
# 2026-04-17 09:33:33,598 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00042.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00042.npz
# 2026-04-17 09:33:37,295 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00042.npz
# 2026-04-17 09:33:37,339 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00042 | duration=4.11s | sec_per_unit=15.0237
# 2026-04-17 09:33:37,340 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00043 | est_remaining_sec=99.48
# 2026-04-17 09:33:37,435 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00043
# 2026-04-17 09:33:37,809 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00043.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00043.npz
# 2026-04-17 09:33:42,096 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00043.npz
# 2026-04-17 09:33:42,141 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00043 | duration=4.71s | sec_per_unit=17.2044
# 2026-04-17 09:33:42,142 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00044 | est_remaining_sec=74.53
# 2026-04-17 09:33:42,230 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00044
# 2026-04-17 09:33:42,654 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00044.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00044.npz
# 2026-04-17 09:33:47,330 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00044.npz
# 2026-04-17 09:33:47,377 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00044 | duration=5.15s | sec_per_unit=18.8178
# 2026-04-17 09:33:47,379 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00045 | est_remaining_sec=49.65
# 2026-04-17 09:33:47,466 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00045
# 2026-04-17 09:33:47,979 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00045.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00045.npz
# 2026-04-17 09:33:52,335 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00045.npz
# 2026-04-17 09:33:52,379 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00045 | duration=4.91s | sec_per_unit=17.9644
# 2026-04-17 09:33:52,380 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00046 | est_remaining_sec=24.80
# 2026-04-17 09:33:52,468 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00046
# 2026-04-17 09:33:52,983 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00046.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00046.npz
# 2026-04-17 09:33:56,807 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00046.npz
# 2026-04-17 09:33:56,851 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00046 | duration=4.38s | sec_per_unit=16.0253
# 2026-04-17 09:33:56,852 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00047 | est_remaining_sec=0.00
# 2026-04-17 09:33:56,939 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00047
# 2026-04-17 09:33:57,043 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00047.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00047.npz
# 2026-04-17 09:34:01,286 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/91fef1517fca02cc/rap/prior/chunk_00047.npz
# 2026-04-17 09:34:01,332 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=rap | family=prior:chunk_00047 | duration=4.39s | sec_per_unit=70.1754
# 2026-04-17 09:34:01,332 | INFO     | features.notebook | SOURCE FAMILY DONE | site=calaveras-big-trees | source=rap | family=prior
# 2026-04-17 09:34:01,475 | INFO     | features.notebook | PUSH ARTIFACT | key=stack_registry | rel_path=features/calaveras-big-trees/91fef1517fca02cc/stack/stack_registry.json
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/stack/stack_registry.json
# 2026-04-17 09:34:06,450 | INFO     | features.notebook | SOURCE CHUNKED RUN COMPLETE | site=calaveras-big-trees | source=rap | registered_layers=336

# %%
display(stack_registry_frame(registry_rap).head(30))
print("RAP layers registered:", len(registry_rap.layers))
print("RAP cached asset after run:", find_cached_rap_asset(TEST_SITE))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                 site_id source_name family_name  \
# 0   calaveras-big-trees         rap       prior
# 1   calaveras-big-trees         rap       prior
# 2   calaveras-big-trees         rap       prior
# 3   calaveras-big-trees         rap       prior
# 4   calaveras-big-trees         rap       prior
# 5   calaveras-big-trees         rap       prior
# 6   calaveras-big-trees         rap       prior
# 7   calaveras-big-trees         rap       prior
# 8   calaveras-big-trees         rap       prior
# 9   calaveras-big-trees         rap       prior
# 10  calaveras-big-trees         rap       prior
# 11  calaveras-big-trees         rap       prior
# 12  calaveras-big-trees         rap       prior
# 13  calaveras-big-trees         rap       prior
# 14  calaveras-big-trees         rap       prior
# 15  calaveras-big-trees         rap       prior
# 16  calaveras-big-trees         rap       prior
# 17  calaveras-big-trees         rap       prior
# 18  calaveras-big-trees         rap       prior
# 19  calaveras-big-trees         rap       prior
# 20  calaveras-big-trees         rap       prior
# 21  calaveras-big-trees         rap       prior
# 22  calaveras-big-trees         rap       prior
# 23  calaveras-big-trees         rap       prior
# 24  calaveras-big-trees         rap       prior
# 25  calaveras-big-trees         rap       prior
# 26  calaveras-big-trees         rap       prior
# 27  calaveras-big-trees         rap       prior
# 28  calaveras-big-trees         rap       prior
# 29  calaveras-big-trees         rap       prior
#
#                                layer_name  \
# 0   rap_local_shrub_presence::chunk_00000
# 1   rap_shrub_fraction_prior::chunk_00000
# 2              rap_TRE_prior::chunk_00000
# 3              rap_PFG_prior::chunk_00000
# 4              rap_AFG_prior::chunk_00000
# 5           rap_band_5_prior::chunk_00000
# 6           rap_band_6_prior::chunk_00000
# 7   rap_local_shrub_presence::chunk_00001
# 8   rap_shrub_fraction_prior::chunk_00001
# 9              rap_TRE_prior::chunk_00001
# 10             rap_PFG_prior::chunk_00001
# 11             rap_AFG_prior::chunk_00001
# 12          rap_band_5_prior::chunk_00001
# 13          rap_band_6_prior::chunk_00001
# 14  rap_local_shrub_presence::chunk_00002
# 15  rap_shrub_fraction_prior::chunk_00002
# 16             rap_TRE_prior::chunk_00002
# 17             rap_PFG_prior::chunk_00002
# 18             rap_AFG_prior::chunk_00002
# 19          rap_band_5_prior::chunk_00002
# 20          rap_band_6_prior::chunk_00002
# 21  rap_local_shrub_presence::chunk_00003
# 22  rap_shrub_fraction_prior::chunk_00003
# 23             rap_TRE_prior::chunk_00003
# 24             rap_PFG_prior::chunk_00003
# 25             rap_AFG_prior::chunk_00003
# 26          rap_band_5_prior::chunk_00003
# 27          rap_band_6_prior::chunk_00003
# 28  rap_local_shrub_presence::chunk_00004
# 29  rap_shrub_fraction_prior::chunk_00004
#
#                                              rel_path  \
# 0   features/calaveras-big-trees/91fef1517fca02cc/...
# 1   features/calaveras-big-trees/91fef1517fca02cc/...
# 2   features/calaveras-big-trees/91fef1517fca02cc/...
# 3   features/calaveras-big-trees/91fef1517fca02cc/...
# 4   features/calaveras-big-trees/91fef1517fca02cc/...
# 5   features/calaveras-big-trees/91fef1517fca02cc/...
# 6   features/calaveras-big-trees/91fef1517fca02cc/...
# 7   features/calaveras-big-trees/91fef1517fca02cc/...
# 8   features/calaveras-big-trees/91fef1517fca02cc/...
# 9   features/calaveras-big-trees/91fef1517fca02cc/...
# 10  features/calaveras-big-trees/91fef1517fca02cc/...
# 11  features/calaveras-big-trees/91fef1517fca02cc/...
# 12  features/calaveras-big-trees/91fef1517fca02cc/...
# 13  features/calaveras-big-trees/91fef1517fca02cc/...
# 14  features/calaveras-big-trees/91fef1517fca02cc/...
# 15  features/calaveras-big-trees/91fef1517fca02cc/...
# 16  features/calaveras-big-trees/91fef1517fca02cc/...
# 17  features/calaveras-big-trees/91fef1517fca02cc/...
# 18  features/calaveras-big-trees/91fef1517fca02cc/...
# 19  features/calaveras-big-trees/91fef1517fca02cc/...
# 20  features/calaveras-big-trees/91fef1517fca02cc/...
# 21  features/calaveras-big-trees/91fef1517fca02cc/...
# 22  features/calaveras-big-trees/91fef1517fca02cc/...
# 23  features/calaveras-big-trees/91fef1517fca02cc/...
# 24  features/calaveras-big-trees/91fef1517fca02cc/...
# 25  features/calaveras-big-trees/91fef1517fca02cc/...
# 26  features/calaveras-big-trees/91fef1517fca02cc/...
# 27  features/calaveras-big-trees/91fef1517fca02cc/...
# 28  features/calaveras-big-trees/91fef1517fca02cc/...
# 29  features/calaveras-big-trees/91fef1517fca02cc/...
#
#                                            local_path  \
# 0   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 1   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 2   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 3   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 4   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 5   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 6   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 7   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 8   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 9   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 10  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 11  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 12  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 13  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 14  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 15  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 16  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 17  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 18  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 19  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 20  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 21  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 22  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 23  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 24  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 25  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 26  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 27  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 28  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 29  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
#
#                                            remote_ref  chunked    dtype  \
# 0   features/calaveras-big-trees/91fef1517fca02cc/...     True  float32
# 1   features/calaveras-big-trees/91fef1517fca02cc/...     True  float32
# 2   features/calaveras-big-trees/91fef1517fca02cc/...     True  float32
# 3   features/calaveras-big-trees/91fef1517fca02cc/...     True  float32
# 4   features/calaveras-big-trees/91fef1517fca02cc/...     True  float32
# 5   features/calaveras-big-trees/91fef1517fca02cc/...     True  float32
# 6   features/calaveras-big-trees/91fef1517fca02cc/...     True  float32
# 7                   1W9C6N7cgQl1OXfIcL-NGECQa_QvxDfBk     True  float32
# 8                   1W9C6N7cgQl1OXfIcL-NGECQa_QvxDfBk     True  float32
# 9                   1W9C6N7cgQl1OXfIcL-NGECQa_QvxDfBk     True  float32
# 10                  1W9C6N7cgQl1OXfIcL-NGECQa_QvxDfBk     True  float32
# 11                  1W9C6N7cgQl1OXfIcL-NGECQa_QvxDfBk     True  float32
# 12                  1W9C6N7cgQl1OXfIcL-NGECQa_QvxDfBk     True  float32
# 13                  1W9C6N7cgQl1OXfIcL-NGECQa_QvxDfBk     True  float32
# 14                  1yJVQZtDlW-pINDXCfmjYBLlG36WDKAKh     True  float32
# 15                  1yJVQZtDlW-pINDXCfmjYBLlG36WDKAKh     True  float32
# 16                  1yJVQZtDlW-pINDXCfmjYBLlG36WDKAKh     True  float32
# 17                  1yJVQZtDlW-pINDXCfmjYBLlG36WDKAKh     True  float32
# 18                  1yJVQZtDlW-pINDXCfmjYBLlG36WDKAKh     True  float32
# 19                  1yJVQZtDlW-pINDXCfmjYBLlG36WDKAKh     True  float32
# 20                  1yJVQZtDlW-pINDXCfmjYBLlG36WDKAKh     True  float32
# 21                  1abUHGUYhA5CQ6MX6ZU_F6R5E0JIRuLJG     True  float32
# 22                  1abUHGUYhA5CQ6MX6ZU_F6R5E0JIRuLJG     True  float32
# 23                  1abUHGUYhA5CQ6MX6ZU_F6R5E0JIRuLJG     True  float32
# 24                  1abUHGUYhA5CQ6MX6ZU_F6R5E0JIRuLJG     True  float32
# 25                  1abUHGUYhA5CQ6MX6ZU_F6R5E0JIRuLJG     True  float32
# 26                  1abUHGUYhA5CQ6MX6ZU_F6R5E0JIRuLJG     True  float32
# 27                  1abUHGUYhA5CQ6MX6ZU_F6R5E0JIRuLJG     True  float32
# 28                  1yv8HpY7N-KxgoQxgOmPS5REzpuK0JBE_     True  float32
# 29                  1yv8HpY7N-KxgoQxgOmPS5REzpuK0JBE_     True  float32
#
#            shape                                              notes
# 0   (1024, 1024)  [chunk_00000, Recovered persistence metadata f...
# 1   (1024, 1024)  [chunk_00000, Recovered persistence metadata f...
# 2   (1024, 1024)  [chunk_00000, Recovered persistence metadata f...
# 3   (1024, 1024)  [chunk_00000, Recovered persistence metadata f...
# 4   (1024, 1024)  [chunk_00000, Recovered persistence metadata f...
# 5   (1024, 1024)  [chunk_00000, Recovered persistence metadata f...
# 6   (1024, 1024)  [chunk_00000, Recovered persistence metadata f...
# 7   (1024, 1024)  [chunk_00001, Local artifact pruned after veri...
# 8   (1024, 1024)  [chunk_00001, Local artifact pruned after veri...
# 9   (1024, 1024)  [chunk_00001, Local artifact pruned after veri...
# 10  (1024, 1024)  [chunk_00001, Local artifact pruned after veri...
# 11  (1024, 1024)  [chunk_00001, Local artifact pruned after veri...
# 12  (1024, 1024)  [chunk_00001, Local artifact pruned after veri...
# 13  (1024, 1024)  [chunk_00001, Local artifact pruned after veri...
# 14  (1024, 1024)  [chunk_00002, Local artifact pruned after veri...
# 15  (1024, 1024)  [chunk_00002, Local artifact pruned after veri...
# 16  (1024, 1024)  [chunk_00002, Local artifact pruned after veri...
# 17  (1024, 1024)  [chunk_00002, Local artifact pruned after veri...
# 18  (1024, 1024)  [chunk_00002, Local artifact pruned after veri...
# 19  (1024, 1024)  [chunk_00002, Local artifact pruned after veri...
# 20  (1024, 1024)  [chunk_00002, Local artifact pruned after veri...
# 21  (1024, 1024)  [chunk_00003, Local artifact pruned after veri...
# 22  (1024, 1024)  [chunk_00003, Local artifact pruned after veri...
# 23  (1024, 1024)  [chunk_00003, Local artifact pruned after veri...
# 24  (1024, 1024)  [chunk_00003, Local artifact pruned after veri...
# 25  (1024, 1024)  [chunk_00003, Local artifact pruned after veri...
# 26  (1024, 1024)  [chunk_00003, Local artifact pruned after veri...
# 27  (1024, 1024)  [chunk_00003, Local artifact pruned after veri...
# 28  (1024, 1024)  [chunk_00004, Local artifact pruned after veri...
# 29  (1024, 1024)  [chunk_00004, Local artifact pruned after veri...
# RAP layers registered: 336
# RAP cached asset after run: None

# %%
def run_rap_all_sites(
    *,
    force_refresh_assets: bool = False,
    force_refresh_source: bool = False,
) -> dict[str, Any]:
    out: dict[str, Any] = {}

    for site_id in fe_cfg.sites:
        LOGGER.info("=" * 80)
        LOGGER.info("RUN RAP ALL SITES | site=%s", site_id)

        try:
            site_assets = prepare_site_assets(
                site_id,
                force_refresh=force_refresh_assets,
            )

            if site_assets.source_assets.get("naip") is None:
                raise RuntimeError(f"NAIP unavailable for site={site_id}")

            if site_assets.source_assets.get("rap") is None and not build_rap_source_inventory_record(site_id, site_assets=site_assets):
                LOGGER.info("RAP not yet materialized locally for site=%s; will attempt lazy preparation.", site_id)

            canonical_grid = build_canonical_grid_for_site(
                site_id,
                assets=site_assets,
                force_refresh=fe_cfg.force_refresh_features,
            )

            chunk_manifest = build_chunk_manifest(
                canonical_grid,
                force_refresh=fe_cfg.force_rebuild_chunk_manifest,
            )

            # For RAP-only runs, NAIP is only needed to define canonical space.
            naip_asset = site_assets.source_assets.get("naip")
            if naip_asset is not None:
                maybe_prune_local_site_naip_after_grid_build(site_id, naip_asset)

            registry = run_rap_chunked_pipeline(
                site_id,
                site_assets=site_assets,
                canonical_grid=canonical_grid,
                chunk_manifest=chunk_manifest,
                registry=RasterStackRegistry(
                    site_id=site_id,
                    config_signature=fe_config_signature(),
                    layers=[],
                ),
                force_refresh_source=force_refresh_source,
            )

            out[site_id] = {
                "status": "success",
                "registry": registry,
                "notes": list(site_assets.notes),
            }

        except Exception as e:
            LOGGER.warning("RUN RAP ALL SITES FAILED | site=%s | err=%s", site_id, e)
            out[site_id] = {
                "status": "failed",
                "registry": None,
                "notes": [str(e)],
            }

        finally:
            try:
                clear_artifact_staging_dir()
            except Exception as e:
                LOGGER.warning("Failed clearing artifact staging after RAP site run | site=%s | err=%s", site_id, e)

    return out
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
rows = []
for site_id in fe_cfg.sites:
    site_assets = prepare_site_assets(site_id, force_refresh=False)
    rec = build_rap_source_inventory_record(site_id, site_assets=site_assets)
    rows.append(
        {
            "site_id": site_id,
            "status": rec.status,
            "asset_path": rec.asset_path,
            "notes": " | ".join(rec.notes),
        }
    )

display(pd.DataFrame(rows))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 2026-04-17 10:15:52,275 | INFO     | features.notebook | START | stage=site_assets | site=calaveras-big-trees | source=None | family=None
# 2026-04-17 10:15:52,554 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=site_metadata_manifest | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 10:15:52,645 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 10:15:52,645 | INFO     | features.notebook | Using site metadata manifest | site=calaveras-big-trees
# 2026-04-17 10:15:52,646 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=source_inventory | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 10:15:52,733 | WARNING  | features.notebook | Local JSON artifact unreadable; removing stale staging file | key=source_inventory | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/source_inventory.json | err='utf-8' codec can't decode byte 0x98 in position 4: invalid start byte
# 2026-04-17 10:15:52,789 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=source_inventory | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/source_inventory.json
# [artifact_store] Using cached Google Drive credentials.
# 2026-04-17 10:15:54,052 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 10:15:54,053 | INFO     | features.notebook | Using cached source inventory | site=calaveras-big-trees
# 2026-04-17 10:15:54,059 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse (no manifest changes) | site=calaveras-big-trees | keys=['naip', 'als_metadata', 'source_inventory', '3dep', 'rap'] | notes=1
# 2026-04-17 10:15:54,059 | INFO     | features.notebook | END   | stage=site_assets | site=calaveras-big-trees | source=None | family=None | duration=1.78s
# 2026-04-17 10:15:54,060 | INFO     | features.notebook | START | stage=site_assets | site=dl-bliss | source=None | family=None
# 2026-04-17 10:15:54,061 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=site_metadata_manifest | rel_path=features/dl-bliss/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 10:15:54,878 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/dl-bliss/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 10:15:54,879 | INFO     | features.notebook | Using site metadata manifest | site=dl-bliss
# 2026-04-17 10:15:54,879 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=source_inventory | rel_path=features/dl-bliss/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 10:15:55,537 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/dl-bliss/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 10:15:55,537 | INFO     | features.notebook | Using cached source inventory | site=dl-bliss
# 2026-04-17 10:15:55,584 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse (no manifest changes) | site=dl-bliss | keys=['naip', 'als_metadata', '3dep', 'source_inventory', 'rap'] | notes=4
# 2026-04-17 10:15:55,585 | INFO     | features.notebook | END   | stage=site_assets | site=dl-bliss | source=None | family=None | duration=1.52s
# 2026-04-17 10:15:56,692 | INFO     | features.notebook | START | stage=site_assets | site=independence-lake | source=None | family=None
# 2026-04-17 10:15:56,693 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=site_metadata_manifest | rel_path=features/independence-lake/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 10:15:57,962 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/independence-lake/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 10:15:57,962 | INFO     | features.notebook | Using site metadata manifest | site=independence-lake
# 2026-04-17 10:15:57,963 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=source_inventory | rel_path=features/independence-lake/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 10:15:58,688 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/independence-lake/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 10:15:58,689 | INFO     | features.notebook | Using cached source inventory | site=independence-lake
# 2026-04-17 10:15:58,694 | INFO     | rasterio._err | GDAL signalled an error: err_no=1, msg='TIFFReadEncodedStrip:Read error at scanline 4294967295; got 0 bytes, expected 186540'
# 2026-04-17 10:15:58,694 | INFO     | rasterio._err | GDAL signalled an error: err_no=1, msg='TIFFReadEncodedStrip() failed.'
# 2026-04-17 10:15:58,695 | INFO     | rasterio._err | GDAL signalled an error: err_no=1, msg='independence_lake.tif, band 1: IReadBlock failed at X offset 0, Y offset 3671: TIFFReadEncodedStrip() failed.'
# 2026-04-17 10:15:58,695 | WARNING  | features.notebook | Cached raster validation failed for /home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/independence-lake/naip/independence_lake.tif: Read failed. See previous exception for details.
# 2026-04-17 10:15:58,699 | INFO     | rasterio._err | GDAL signalled an error: err_no=1, msg='TIFFReadEncodedStrip:Read error at scanline 4294967295; got 0 bytes, expected 186540'
# 2026-04-17 10:15:58,699 | INFO     | rasterio._err | GDAL signalled an error: err_no=1, msg='TIFFReadEncodedStrip() failed.'
# 2026-04-17 10:15:58,699 | INFO     | rasterio._err | GDAL signalled an error: err_no=1, msg='independence_lake.tif, band 1: IReadBlock failed at X offset 0, Y offset 3671: TIFFReadEncodedStrip() failed.'
# 2026-04-17 10:15:58,700 | WARNING  | features.notebook | Cached raster validation failed for /home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/independence-lake/naip/independence_lake.tif: Read failed. See previous exception for details.
# 2026-04-17 10:15:58,700 | WARNING  | features.notebook | Removing invalid cached NAIP | site=independence-lake | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/independence-lake/naip/independence_lake.tif
# 2026-04-17 10:15:58,743 | INFO     | features.notebook | Hydrating NAIP from artifact store | site=independence-lake | rel_path=features/independence-lake/shared/site_assets/naip/independence_lake.tif
# 2026-04-17 10:16:17,332 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse (no manifest changes) | site=independence-lake | keys=['naip', 'als_metadata', '3dep', 'source_inventory', 'rap'] | notes=0
# 2026-04-17 10:16:17,333 | INFO     | features.notebook | END   | stage=site_assets | site=independence-lake | source=None | family=None | duration=20.64s
# 2026-04-17 10:16:18,374 | INFO     | features.notebook | START | stage=site_assets | site=pacific-union-college | source=None | family=None
# 2026-04-17 10:16:18,375 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=site_metadata_manifest | rel_path=features/pacific-union-college/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 10:16:19,056 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/pacific-union-college/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 10:16:19,056 | INFO     | features.notebook | Using site metadata manifest | site=pacific-union-college
# 2026-04-17 10:16:19,057 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=source_inventory | rel_path=features/pacific-union-college/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 10:16:19,845 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/pacific-union-college/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 10:16:19,846 | INFO     | features.notebook | Using cached source inventory | site=pacific-union-college
# 2026-04-17 10:16:19,846 | INFO     | features.notebook | Hydrating NAIP from artifact store | site=pacific-union-college | rel_path=features/pacific-union-college/shared/site_assets/naip/pacific_union_college.tif
# 2026-04-17 10:16:20,781 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse (no manifest changes) | site=pacific-union-college | keys=['naip', 'als_metadata', '3dep', 'source_inventory', 'rap'] | notes=0
# 2026-04-17 10:16:20,782 | INFO     | features.notebook | END   | stage=site_assets | site=pacific-union-college | source=None | family=None | duration=2.41s
# 2026-04-17 10:16:21,799 | INFO     | features.notebook | START | stage=site_assets | site=sedgwick | source=None | family=None
# 2026-04-17 10:16:21,800 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=site_metadata_manifest | rel_path=features/sedgwick/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 10:16:22,487 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/sedgwick/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 10:16:22,487 | INFO     | features.notebook | Using site metadata manifest | site=sedgwick
# 2026-04-17 10:16:22,488 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=source_inventory | rel_path=features/sedgwick/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 10:16:23,107 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/sedgwick/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 10:16:23,108 | INFO     | features.notebook | Using cached source inventory | site=sedgwick
# 2026-04-17 10:16:23,109 | INFO     | features.notebook | Hydrating NAIP from artifact store | site=sedgwick | rel_path=features/sedgwick/shared/site_assets/naip/sedgwick.tif
# 2026-04-17 10:16:25,164 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse (no manifest changes) | site=sedgwick | keys=['naip', 'als_metadata', '3dep', 'source_inventory', 'rap'] | notes=0
# 2026-04-17 10:16:25,165 | INFO     | features.notebook | END   | stage=site_assets | site=sedgwick | source=None | family=None | duration=3.37s
# 2026-04-17 10:16:26,268 | INFO     | features.notebook | START | stage=site_assets | site=shaver-lake | source=None | family=None
# 2026-04-17 10:16:26,269 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=site_metadata_manifest | rel_path=features/shaver-lake/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 10:16:27,075 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/shaver-lake/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 10:16:27,076 | INFO     | features.notebook | Using site metadata manifest | site=shaver-lake
# 2026-04-17 10:16:27,076 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=source_inventory | rel_path=features/shaver-lake/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 10:16:27,813 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/shaver-lake/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 10:16:27,813 | INFO     | features.notebook | Using cached source inventory | site=shaver-lake
# 2026-04-17 10:16:27,814 | INFO     | features.notebook | Hydrating NAIP from artifact store | site=shaver-lake | rel_path=features/shaver-lake/shared/site_assets/naip/shaver_lake.tif
# 2026-04-17 10:16:28,861 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse (no manifest changes) | site=shaver-lake | keys=['naip', 'als_metadata', '3dep', 'source_inventory', 'rap'] | notes=0
# 2026-04-17 10:16:28,861 | INFO     | features.notebook | END   | stage=site_assets | site=shaver-lake | source=None | family=None | duration=2.59s
#                  site_id                status  \
# 0    calaveras-big-trees    cached_remote_lazy
# 1               dl-bliss  not_materialized_yet
# 2      independence-lake  not_materialized_yet
# 3  pacific-union-college  not_materialized_yet
# 4               sedgwick  not_materialized_yet
# 5            shaver-lake  not_materialized_yet
#
#                                           asset_path  \
# 0  features/calaveras-big-trees/shared/site_asset...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
#
#                                               notes
# 0  RAP cached remotely and will be hydrated lazily.
# 1                RAP has not been materialized yet.
# 2                RAP has not been materialized yet.
# 3                RAP has not been materialized yet.
# 4                RAP has not been materialized yet.
# 5                RAP has not been materialized yet.

# %%
rap_runs = run_rap_all_sites(
    force_refresh_assets=False,
    force_refresh_source=False,
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 2026-04-17 10:16:30,100 | INFO     | features.notebook | ================================================================================
# 2026-04-17 10:16:30,101 | INFO     | features.notebook | RUN RAP ALL SITES | site=calaveras-big-trees
# 2026-04-17 10:16:30,101 | INFO     | features.notebook | START | stage=site_assets | site=calaveras-big-trees | source=None | family=None
# 2026-04-17 10:16:30,102 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=site_metadata_manifest | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 10:16:30,193 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 10:16:30,193 | INFO     | features.notebook | Using site metadata manifest | site=calaveras-big-trees
# 2026-04-17 10:16:30,194 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=source_inventory | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 10:16:30,847 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/calaveras-big-trees/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 10:16:30,847 | INFO     | features.notebook | Using cached source inventory | site=calaveras-big-trees
# 2026-04-17 10:16:30,852 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse (no manifest changes) | site=calaveras-big-trees | keys=['naip', 'als_metadata', 'source_inventory', '3dep', 'rap'] | notes=1
# 2026-04-17 10:16:30,853 | INFO     | features.notebook | END   | stage=site_assets | site=calaveras-big-trees | source=None | family=None | duration=0.75s
# 2026-04-17 10:16:30,854 | INFO     | features.notebook | Using cached canonical grid | site=calaveras-big-trees
# 2026-04-17 10:16:30,855 | INFO     | features.notebook | Using cached chunk manifest | site=calaveras-big-trees | n_chunks=48
# 2026-04-17 10:16:30,899 | INFO     | features.notebook | Pruned local NAIP site asset after canonical grid build | site=calaveras-big-trees | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/calaveras-big-trees/naip/calaveras_big_trees.tif
# 2026-04-17 10:16:30,900 | INFO     | features.notebook | Hydrating RAP from artifact store | site=calaveras-big-trees | rel_path=features/calaveras-big-trees/shared/site_assets/rap/calaveras-big-trees_rap_ee_10m.tif
# 2026-04-17 10:16:31,570 | WARNING  | rasterio._env | CPLE_AppDefined in calaveras-big-trees_rap_ee_10m.tif: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 10:16:31,615 | WARNING  | rasterio._env | CPLE_AppDefined in TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 10:16:31,620 | WARNING  | rasterio._env | CPLE_AppDefined in calaveras-big-trees_rap_ee_10m.tif: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 10:16:31,621 | WARNING  | rasterio._env | CPLE_AppDefined in calaveras-big-trees_rap_ee_10m.tif: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 10:16:31,622 | WARNING  | rasterio._env | CPLE_AppDefined in TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 10:16:31,678 | INFO     | features.notebook | Pruned local RAP site asset after in-memory load | site=calaveras-big-trees | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/calaveras-big-trees/rap/calaveras-big-trees_rap_ee_10m.tif
# 2026-04-17 10:16:45,356 | INFO     | features.notebook | SOURCE CHUNKED RUN | site=calaveras-big-trees | source=rap | families=('prior',) | n_chunks=48
# 2026-04-17 10:16:45,357 | INFO     | features.notebook | SOURCE FAMILY START | site=calaveras-big-trees | source=rap | family=prior
# 2026-04-17 10:16:45,358 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00000
# 2026-04-17 10:16:47,293 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00001
# 2026-04-17 10:16:49,439 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00002
# 2026-04-17 10:16:52,162 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00003
# 2026-04-17 10:16:54,230 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00004
# 2026-04-17 10:16:57,039 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00005
# 2026-04-17 10:16:59,207 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00006
# 2026-04-17 10:17:01,845 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00007
# 2026-04-17 10:17:02,936 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00008
# 2026-04-17 10:17:05,206 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00009
# 2026-04-17 10:17:07,481 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00010
# 2026-04-17 10:17:09,748 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00011
# 2026-04-17 10:17:11,915 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00012
# 2026-04-17 10:17:14,289 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00013
# 2026-04-17 10:17:16,436 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00014
# 2026-04-17 10:17:19,044 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00015
# 2026-04-17 10:17:20,431 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00016
# 2026-04-17 10:17:22,351 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00017
# 2026-04-17 10:17:24,048 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00018
# 2026-04-17 10:17:26,400 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00019
# 2026-04-17 10:17:28,965 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00020
# 2026-04-17 10:17:31,766 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00021
# 2026-04-17 10:17:34,374 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00022
# 2026-04-17 10:17:36,613 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00023
# 2026-04-17 10:17:37,604 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00024
# 2026-04-17 10:17:39,484 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00025
# 2026-04-17 10:17:41,609 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00026
# 2026-04-17 10:17:43,936 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00027
# 2026-04-17 10:17:45,849 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00028
# 2026-04-17 10:17:49,031 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00029
# 2026-04-17 10:17:51,496 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00030
# 2026-04-17 10:17:53,984 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00031
# 2026-04-17 10:17:55,374 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00032
# 2026-04-17 10:17:57,860 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00033
# 2026-04-17 10:17:59,670 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00034
# 2026-04-17 10:18:01,723 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00035
# 2026-04-17 10:18:04,076 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00036
# 2026-04-17 10:18:06,411 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00037
# 2026-04-17 10:18:09,035 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00038
# 2026-04-17 10:18:10,909 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00039
# 2026-04-17 10:18:12,355 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00040
# 2026-04-17 10:18:14,055 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00041
# 2026-04-17 10:18:15,312 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00042
# 2026-04-17 10:18:16,936 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00043
# 2026-04-17 10:18:19,554 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00044
# 2026-04-17 10:18:21,437 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00045
# 2026-04-17 10:18:23,419 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00046
# 2026-04-17 10:18:24,410 | INFO     | features.notebook | FAMILY CHUNK CACHE HIT (remote) | site=calaveras-big-trees | source=rap | family=prior | chunk=chunk_00047
# 2026-04-17 10:18:25,346 | INFO     | features.notebook | SOURCE FAMILY DONE | site=calaveras-big-trees | source=rap | family=prior
# 2026-04-17 10:18:25,492 | INFO     | features.notebook | PUSH ARTIFACT | key=stack_registry | rel_path=features/calaveras-big-trees/91fef1517fca02cc/stack/stack_registry.json
# [artifact_store] Updating existing Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/stack/stack_registry.json
# 2026-04-17 10:18:29,022 | INFO     | features.notebook | SOURCE CHUNKED RUN COMPLETE | site=calaveras-big-trees | source=rap | registered_layers=336
# 2026-04-17 10:18:31,639 | INFO     | features.notebook | Cleared artifact staging directory | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/_artifact_staging
# 2026-04-17 10:18:31,640 | INFO     | features.notebook | ================================================================================
# 2026-04-17 10:18:31,640 | INFO     | features.notebook | RUN RAP ALL SITES | site=dl-bliss
# 2026-04-17 10:18:31,640 | INFO     | features.notebook | START | stage=site_assets | site=dl-bliss | source=None | family=None
# 2026-04-17 10:18:31,642 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=site_metadata_manifest | rel_path=features/dl-bliss/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 10:18:32,295 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/dl-bliss/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 10:18:32,295 | INFO     | features.notebook | Using site metadata manifest | site=dl-bliss
# 2026-04-17 10:18:32,296 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=source_inventory | rel_path=features/dl-bliss/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 10:18:32,993 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/dl-bliss/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 10:18:32,994 | INFO     | features.notebook | Using cached source inventory | site=dl-bliss
# 2026-04-17 10:18:33,043 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse (no manifest changes) | site=dl-bliss | keys=['naip', 'als_metadata', '3dep', 'source_inventory', 'rap'] | notes=4
# 2026-04-17 10:18:33,043 | INFO     | features.notebook | END   | stage=site_assets | site=dl-bliss | source=None | family=None | duration=1.40s
# 2026-04-17 10:18:34,163 | INFO     | features.notebook | Using cached canonical grid | site=dl-bliss
# 2026-04-17 10:18:34,250 | INFO     | features.notebook | Using cached chunk manifest | site=dl-bliss | n_chunks=9
# 2026-04-17 10:18:34,294 | INFO     | features.notebook | Pruned local NAIP site asset after canonical grid build | site=dl-bliss | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/dl-bliss/naip/dl_bliss.tif
# 2026-04-17 10:18:37,516 | INFO     | features.notebook | Exporting RAP from Earth Engine | site=dl-bliss | out=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/dl-bliss/rap/dl-bliss_rap_ee_10m.tif | bounds_wgs84=(-120.113791, 38.983748, -120.089976, 39.002325)
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/shrubwise-dc-488219/thumbnails/d76af4480642bd3f91c29e35f5f89bf9-dd00d1733348196595b1abee934369b5:getPixels
# Please wait ...
# 2026-04-17 10:18:40,797 | WARNING  | rasterio._env | CPLE_AppDefined in dl-bliss_rap_ee_10m.tif: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 10:18:40,867 | WARNING  | rasterio._env | CPLE_AppDefined in TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 10:18:40,875 | INFO     | features.notebook | PUSH ARTIFACT | key=site_rap_raster | rel_path=features/dl-bliss/shared/site_assets/rap/dl-bliss_rap_ee_10m.tif
# Data downloaded to /home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/dl-bliss/rap/dl-bliss_rap_ee_10m.tif
# [artifact_store] Creating new Drive artifact for features/dl-bliss/shared/site_assets/rap/dl-bliss_rap_ee_10m.tif
# 2026-04-17 10:18:45,143 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/dl-bliss/shared/site_assets/rap/dl-bliss_rap_ee_10m.tif
# 2026-04-17 10:18:45,143 | INFO     | features.notebook | RAP local file was pruned after push; rehydrating for current use | site=dl-bliss
# 2026-04-17 10:18:45,705 | INFO     | features.notebook | Prepared RAP asset | site=dl-bliss | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/dl-bliss/rap/dl-bliss_rap_ee_10m.tif
# 2026-04-17 10:18:45,706 | WARNING  | rasterio._env | CPLE_AppDefined in dl-bliss_rap_ee_10m.tif: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 10:18:45,750 | WARNING  | rasterio._env | CPLE_AppDefined in dl-bliss_rap_ee_10m.tif: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 10:18:45,751 | WARNING  | rasterio._env | CPLE_AppDefined in TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 10:18:45,803 | INFO     | features.notebook | Pruned local RAP site asset after in-memory load | site=dl-bliss | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/dl-bliss/rap/dl-bliss_rap_ee_10m.tif
# 2026-04-17 10:18:47,888 | INFO     | features.notebook | SOURCE CHUNKED RUN | site=dl-bliss | source=rap | families=('prior',) | n_chunks=9
# 2026-04-17 10:18:47,889 | INFO     | features.notebook | SOURCE FAMILY START | site=dl-bliss | source=rap | family=prior
# 2026-04-17 10:18:47,977 | INFO     | features.notebook | START | stage=family_chunk_compute | site=dl-bliss | source=rap | family=prior:chunk_00000
# 2026-04-17 10:18:49,547 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00000.npz
# [artifact_store] Creating new Drive artifact for features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00000.npz
# 2026-04-17 10:18:54,676 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00000.npz
# 2026-04-17 10:18:54,720 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=dl-bliss | source=rap | family=prior:chunk_00000 | duration=6.74s | sec_per_unit=6.3315
# 2026-04-17 10:18:54,720 | INFO     | features.notebook | SOURCE ETA | site=dl-bliss | source=rap | family=prior | chunk=chunk_00001 | est_remaining_sec=44.32
# 2026-04-17 10:18:54,808 | INFO     | features.notebook | START | stage=family_chunk_compute | site=dl-bliss | source=rap | family=prior:chunk_00001
# 2026-04-17 10:18:55,881 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00001.npz
# [artifact_store] Creating new Drive artifact for features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00001.npz
# 2026-04-17 10:19:00,022 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00001.npz
# 2026-04-17 10:19:00,130 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=dl-bliss | source=rap | family=prior:chunk_00001 | duration=5.32s | sec_per_unit=4.9586
# 2026-04-17 10:19:00,130 | INFO     | features.notebook | SOURCE ETA | site=dl-bliss | source=rap | family=prior | chunk=chunk_00002 | est_remaining_sec=33.87
# 2026-04-17 10:19:00,217 | INFO     | features.notebook | START | stage=family_chunk_compute | site=dl-bliss | source=rap | family=prior:chunk_00002
# 2026-04-17 10:19:00,445 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00002.npz
# [artifact_store] Creating new Drive artifact for features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00002.npz
# 2026-04-17 10:19:03,911 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00002.npz
# 2026-04-17 10:19:03,957 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=dl-bliss | source=rap | family=prior:chunk_00002 | duration=3.74s | sec_per_unit=5.9308
# 2026-04-17 10:19:03,957 | INFO     | features.notebook | SOURCE ETA | site=dl-bliss | source=rap | family=prior | chunk=chunk_00003 | est_remaining_sec=28.70
# 2026-04-17 10:19:04,044 | INFO     | features.notebook | START | stage=family_chunk_compute | site=dl-bliss | source=rap | family=prior:chunk_00003
# 2026-04-17 10:19:05,863 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00003.npz
# [artifact_store] Creating new Drive artifact for features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00003.npz
# 2026-04-17 10:19:09,689 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00003.npz
# 2026-04-17 10:19:09,733 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=dl-bliss | source=rap | family=prior:chunk_00003 | duration=5.69s | sec_per_unit=5.3005
# 2026-04-17 10:19:09,734 | INFO     | features.notebook | SOURCE ETA | site=dl-bliss | source=rap | family=prior | chunk=chunk_00004 | est_remaining_sec=22.52
# 2026-04-17 10:19:09,899 | INFO     | features.notebook | START | stage=family_chunk_compute | site=dl-bliss | source=rap | family=prior:chunk_00004
# 2026-04-17 10:19:11,185 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00004.npz
# [artifact_store] Creating new Drive artifact for features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00004.npz
# 2026-04-17 10:19:14,885 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00004.npz
# 2026-04-17 10:19:14,934 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=dl-bliss | source=rap | family=prior:chunk_00004 | duration=5.04s | sec_per_unit=4.6557
# 2026-04-17 10:19:14,935 | INFO     | features.notebook | SOURCE ETA | site=dl-bliss | source=rap | family=prior | chunk=chunk_00005 | est_remaining_sec=16.31
# 2026-04-17 10:19:15,022 | INFO     | features.notebook | START | stage=family_chunk_compute | site=dl-bliss | source=rap | family=prior:chunk_00005
# 2026-04-17 10:19:15,347 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00005.npz
# [artifact_store] Creating new Drive artifact for features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00005.npz
# 2026-04-17 10:19:18,874 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00005.npz
# 2026-04-17 10:19:18,920 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=dl-bliss | source=rap | family=prior:chunk_00005 | duration=3.90s | sec_per_unit=6.1337
# 2026-04-17 10:19:18,921 | INFO     | features.notebook | SOURCE ETA | site=dl-bliss | source=rap | family=prior | chunk=chunk_00006 | est_remaining_sec=11.10
# 2026-04-17 10:19:19,014 | INFO     | features.notebook | START | stage=family_chunk_compute | site=dl-bliss | source=rap | family=prior:chunk_00006
# 2026-04-17 10:19:19,083 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00006.npz
# [artifact_store] Creating new Drive artifact for features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00006.npz
# 2026-04-17 10:19:22,319 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00006.npz
# 2026-04-17 10:19:22,364 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=dl-bliss | source=rap | family=prior:chunk_00006 | duration=3.35s | sec_per_unit=115.9050
# 2026-04-17 10:19:22,367 | INFO     | features.notebook | SOURCE ETA | site=dl-bliss | source=rap | family=prior | chunk=chunk_00007 | est_remaining_sec=21.32
# 2026-04-17 10:19:22,454 | INFO     | features.notebook | START | stage=family_chunk_compute | site=dl-bliss | source=rap | family=prior:chunk_00007
# 2026-04-17 10:19:22,519 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00007.npz
# [artifact_store] Creating new Drive artifact for features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00007.npz
# 2026-04-17 10:19:25,988 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00007.npz
# 2026-04-17 10:19:26,033 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=dl-bliss | source=rap | family=prior:chunk_00007 | duration=3.58s | sec_per_unit=122.9227
# 2026-04-17 10:19:26,034 | INFO     | features.notebook | SOURCE ETA | site=dl-bliss | source=rap | family=prior | chunk=chunk_00008 | est_remaining_sec=0.00
# 2026-04-17 10:19:26,121 | INFO     | features.notebook | START | stage=family_chunk_compute | site=dl-bliss | source=rap | family=prior:chunk_00008
# 2026-04-17 10:19:26,171 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00008.npz
# [artifact_store] Creating new Drive artifact for features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00008.npz
# 2026-04-17 10:19:29,651 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/dl-bliss/91fef1517fca02cc/rap/prior/chunk_00008.npz
# 2026-04-17 10:19:29,695 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=dl-bliss | source=rap | family=prior:chunk_00008 | duration=3.57s | sec_per_unit=208.8902
# 2026-04-17 10:19:29,695 | INFO     | features.notebook | SOURCE FAMILY DONE | site=dl-bliss | source=rap | family=prior
# 2026-04-17 10:19:29,894 | INFO     | features.notebook | PUSH ARTIFACT | key=stack_registry | rel_path=features/dl-bliss/91fef1517fca02cc/stack/stack_registry.json
# [artifact_store] Updating existing Drive artifact for features/dl-bliss/91fef1517fca02cc/stack/stack_registry.json
# 2026-04-17 10:19:33,056 | INFO     | features.notebook | SOURCE CHUNKED RUN COMPLETE | site=dl-bliss | source=rap | registered_layers=63
# 2026-04-17 10:19:33,571 | INFO     | features.notebook | Cleared artifact staging directory | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/_artifact_staging
# 2026-04-17 10:19:33,572 | INFO     | features.notebook | ================================================================================
# 2026-04-17 10:19:33,572 | INFO     | features.notebook | RUN RAP ALL SITES | site=independence-lake
# 2026-04-17 10:19:33,572 | INFO     | features.notebook | START | stage=site_assets | site=independence-lake | source=None | family=None
# 2026-04-17 10:19:33,573 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=site_metadata_manifest | rel_path=features/independence-lake/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 10:19:34,203 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/independence-lake/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 10:19:34,204 | INFO     | features.notebook | Using site metadata manifest | site=independence-lake
# 2026-04-17 10:19:34,204 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=source_inventory | rel_path=features/independence-lake/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 10:19:34,867 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/independence-lake/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 10:19:34,868 | INFO     | features.notebook | Using cached source inventory | site=independence-lake
# 2026-04-17 10:19:34,920 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse (no manifest changes) | site=independence-lake | keys=['naip', 'als_metadata', '3dep', 'source_inventory', 'rap'] | notes=0
# 2026-04-17 10:19:34,920 | INFO     | features.notebook | END   | stage=site_assets | site=independence-lake | source=None | family=None | duration=1.35s
# 2026-04-17 10:19:36,057 | INFO     | features.notebook | Using cached canonical grid | site=independence-lake
# 2026-04-17 10:19:36,058 | INFO     | features.notebook | Using cached chunk manifest | site=independence-lake | n_chunks=80
# 2026-04-17 10:19:36,102 | INFO     | features.notebook | Pruned local NAIP site asset after canonical grid build | site=independence-lake | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/independence-lake/naip/independence_lake.tif
# 2026-04-17 10:19:37,983 | INFO     | features.notebook | Exporting RAP from Earth Engine | site=independence-lake | out=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/independence-lake/rap/independence-lake_rap_ee_10m.tif | bounds_wgs84=(-120.335672, 39.422564, -120.269171, 39.463894)
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/shrubwise-dc-488219/thumbnails/3a74f4e66e1983bff6a32c0941b1caac-ee1224a670133aad192ce25c184499c0:getPixels
# Please wait ...
# 2026-04-17 10:19:49,834 | WARNING  | rasterio._env | CPLE_AppDefined in independence-lake_rap_ee_10m.tif: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 10:19:49,885 | WARNING  | rasterio._env | CPLE_AppDefined in TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 10:19:49,893 | INFO     | features.notebook | PUSH ARTIFACT | key=site_rap_raster | rel_path=features/independence-lake/shared/site_assets/rap/independence-lake_rap_ee_10m.tif
# Data downloaded to /home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/independence-lake/rap/independence-lake_rap_ee_10m.tif
# [artifact_store] Creating new Drive artifact for features/independence-lake/shared/site_assets/rap/independence-lake_rap_ee_10m.tif
# 2026-04-17 10:19:53,899 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/independence-lake/shared/site_assets/rap/independence-lake_rap_ee_10m.tif
# 2026-04-17 10:19:53,899 | INFO     | features.notebook | RAP local file was pruned after push; rehydrating for current use | site=independence-lake
# 2026-04-17 10:19:54,670 | INFO     | features.notebook | Prepared RAP asset | site=independence-lake | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/independence-lake/rap/independence-lake_rap_ee_10m.tif
# 2026-04-17 10:19:54,671 | WARNING  | rasterio._env | CPLE_AppDefined in independence-lake_rap_ee_10m.tif: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 10:19:54,716 | WARNING  | rasterio._env | CPLE_AppDefined in independence-lake_rap_ee_10m.tif: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 10:19:54,717 | WARNING  | rasterio._env | CPLE_AppDefined in TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 10:19:54,782 | INFO     | features.notebook | Pruned local RAP site asset after in-memory load | site=independence-lake | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/independence-lake/rap/independence-lake_rap_ee_10m.tif
# 2026-04-17 10:20:17,593 | INFO     | features.notebook | SOURCE CHUNKED RUN | site=independence-lake | source=rap | families=('prior',) | n_chunks=80
# 2026-04-17 10:20:17,595 | INFO     | features.notebook | SOURCE FAMILY START | site=independence-lake | source=rap | family=prior
# 2026-04-17 10:20:17,596 | INFO     | features.notebook | SOURCE ETA | site=independence-lake | source=rap | family=prior | chunk=chunk_00000 | est_remaining_sec=4222.36
# 2026-04-17 10:20:17,739 | INFO     | features.notebook | START | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00000
# 2026-04-17 10:20:19,243 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00000.npz
# [artifact_store] Creating new Drive artifact for features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00000.npz
# 2026-04-17 10:20:24,344 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00000.npz
# 2026-04-17 10:20:24,388 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00000 | duration=6.65s | sec_per_unit=6.2429
# 2026-04-17 10:20:24,388 | INFO     | features.notebook | SOURCE ETA | site=independence-lake | source=rap | family=prior | chunk=chunk_00001 | est_remaining_sec=3800.72
# 2026-04-17 10:20:24,476 | INFO     | features.notebook | START | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00001
# 2026-04-17 10:20:25,847 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00001.npz
# [artifact_store] Creating new Drive artifact for features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00001.npz
# 2026-04-17 10:20:29,631 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00001.npz
# 2026-04-17 10:20:29,676 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00001 | duration=5.20s | sec_per_unit=4.8449
# 2026-04-17 10:20:29,676 | INFO     | features.notebook | SOURCE ETA | site=independence-lake | source=rap | family=prior | chunk=chunk_00002 | est_remaining_sec=3444.82
# 2026-04-17 10:20:29,763 | INFO     | features.notebook | START | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00002
# 2026-04-17 10:20:31,153 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00002.npz
# [artifact_store] Creating new Drive artifact for features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00002.npz
# 2026-04-17 10:20:34,920 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00002.npz
# 2026-04-17 10:20:34,964 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00002 | duration=5.20s | sec_per_unit=4.8455
# 2026-04-17 10:20:34,964 | INFO     | features.notebook | SOURCE ETA | site=independence-lake | source=rap | family=prior | chunk=chunk_00003 | est_remaining_sec=3147.43
# 2026-04-17 10:20:35,053 | INFO     | features.notebook | START | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00003
# 2026-04-17 10:20:36,441 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00003.npz
# [artifact_store] Creating new Drive artifact for features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00003.npz
# 2026-04-17 10:20:40,265 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00003.npz
# 2026-04-17 10:20:40,312 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00003 | duration=5.26s | sec_per_unit=4.8995
# 2026-04-17 10:20:40,312 | INFO     | features.notebook | SOURCE ETA | site=independence-lake | source=rap | family=prior | chunk=chunk_00004 | est_remaining_sec=2895.36
# 2026-04-17 10:20:40,400 | INFO     | features.notebook | START | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00004
# 2026-04-17 10:20:41,747 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00004.npz
# [artifact_store] Creating new Drive artifact for features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00004.npz
# 2026-04-17 10:20:45,388 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00004.npz
# 2026-04-17 10:20:45,433 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00004 | duration=5.03s | sec_per_unit=4.6888
# 2026-04-17 10:20:45,433 | INFO     | features.notebook | SOURCE ETA | site=independence-lake | source=rap | family=prior | chunk=chunk_00005 | est_remaining_sec=2677.48
# 2026-04-17 10:20:45,521 | INFO     | features.notebook | START | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00005
# 2026-04-17 10:20:46,911 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00005.npz
# [artifact_store] Creating new Drive artifact for features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00005.npz
# 2026-04-17 10:20:50,872 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00005.npz
# 2026-04-17 10:20:50,920 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00005 | duration=5.40s | sec_per_unit=5.0303
# 2026-04-17 10:20:50,921 | INFO     | features.notebook | SOURCE ETA | site=independence-lake | source=rap | family=prior | chunk=chunk_00006 | est_remaining_sec=2489.69
# 2026-04-17 10:20:51,008 | INFO     | features.notebook | START | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00006
# 2026-04-17 10:20:52,398 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00006.npz
# [artifact_store] Creating new Drive artifact for features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00006.npz
# 2026-04-17 10:20:57,034 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00006.npz
# 2026-04-17 10:20:57,078 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00006 | duration=6.07s | sec_per_unit=5.6560
# 2026-04-17 10:20:57,079 | INFO     | features.notebook | SOURCE ETA | site=independence-lake | source=rap | family=prior | chunk=chunk_00007 | est_remaining_sec=2327.57
# 2026-04-17 10:20:57,166 | INFO     | features.notebook | START | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00007
# 2026-04-17 10:20:58,494 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00007.npz
# [artifact_store] Creating new Drive artifact for features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00007.npz
# 2026-04-17 10:21:03,831 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00007.npz
# 2026-04-17 10:21:03,898 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00007 | duration=6.73s | sec_per_unit=6.2723
# 2026-04-17 10:21:03,899 | INFO     | features.notebook | SOURCE ETA | site=independence-lake | source=rap | family=prior | chunk=chunk_00008 | est_remaining_sec=2186.42
# 2026-04-17 10:21:03,986 | INFO     | features.notebook | START | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00008
# 2026-04-17 10:21:05,352 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00008.npz
# [artifact_store] Creating new Drive artifact for features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00008.npz
# 2026-04-17 10:21:09,555 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00008.npz
# 2026-04-17 10:21:09,600 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00008 | duration=5.61s | sec_per_unit=5.2305
# 2026-04-17 10:21:09,600 | INFO     | features.notebook | SOURCE ETA | site=independence-lake | source=rap | family=prior | chunk=chunk_00009 | est_remaining_sec=2056.21
# 2026-04-17 10:21:09,687 | INFO     | features.notebook | START | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00009
# 2026-04-17 10:21:09,876 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00009.npz
# [artifact_store] Creating new Drive artifact for features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00009.npz
# 2026-04-17 10:21:13,721 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00009.npz
# 2026-04-17 10:21:13,767 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00009 | duration=4.08s | sec_per_unit=33.2241
# 2026-04-17 10:21:13,768 | INFO     | features.notebook | SOURCE ETA | site=independence-lake | source=rap | family=prior | chunk=chunk_00010 | est_remaining_sec=2040.82
# 2026-04-17 10:21:13,855 | INFO     | features.notebook | START | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00010
# 2026-04-17 10:21:15,482 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00010.npz
# [artifact_store] Creating new Drive artifact for features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00010.npz
# 2026-04-17 10:21:19,743 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00010.npz
# 2026-04-17 10:21:19,787 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00010 | duration=5.93s | sec_per_unit=5.5270
# 2026-04-17 10:21:19,788 | INFO     | features.notebook | SOURCE ETA | site=independence-lake | source=rap | family=prior | chunk=chunk_00011 | est_remaining_sec=1929.47
# 2026-04-17 10:21:19,876 | INFO     | features.notebook | START | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00011
# 2026-04-17 10:21:21,336 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00011.npz
# [artifact_store] Creating new Drive artifact for features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00011.npz
# 2026-04-17 10:21:25,371 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00011.npz
# 2026-04-17 10:21:25,415 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00011 | duration=5.54s | sec_per_unit=5.1216
# 2026-04-17 10:21:25,416 | INFO     | features.notebook | SOURCE ETA | site=independence-lake | source=rap | family=prior | chunk=chunk_00012 | est_remaining_sec=1826.91
# 2026-04-17 10:21:25,503 | INFO     | features.notebook | START | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00012
# 2026-04-17 10:21:26,846 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00012.npz
# [artifact_store] Creating new Drive artifact for features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00012.npz
# 2026-04-17 10:21:30,604 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00012.npz
# 2026-04-17 10:21:30,648 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00012 | duration=5.14s | sec_per_unit=4.7567
# 2026-04-17 10:21:30,648 | INFO     | features.notebook | SOURCE ETA | site=independence-lake | source=rap | family=prior | chunk=chunk_00013 | est_remaining_sec=1732.11
# 2026-04-17 10:21:30,736 | INFO     | features.notebook | START | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00013
# 2026-04-17 10:21:32,137 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00013.npz
# [artifact_store] Creating new Drive artifact for features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00013.npz
# 2026-04-17 10:21:36,054 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00013.npz
# 2026-04-17 10:21:36,098 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00013 | duration=5.36s | sec_per_unit=4.9578
# 2026-04-17 10:21:36,099 | INFO     | features.notebook | SOURCE ETA | site=independence-lake | source=rap | family=prior | chunk=chunk_00014 | est_remaining_sec=1645.71
# 2026-04-17 10:21:36,186 | INFO     | features.notebook | START | stage=family_chunk_compute | site=independence-lake | source=rap | family=prior:chunk_00014
# 2026-04-17 10:21:37,565 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00014.npz
# [artifact_store] Creating new Drive artifact for features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00014.npz
# 2026-04-17 10:21:41,682 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/independence-lake/91fef1517fca02cc/rap/prior/chunk_00014.npz
# ...
# 2026-04-17 10:28:12,343 | INFO     | features.notebook | START | stage=family_chunk_compute | site=sedgwick | source=rap | family=prior:chunk_00000
# 2026-04-17 10:28:14,220 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/sedgwick/91fef1517fca02cc/rap/prior/chunk_00000.npz
# [artifact_store] Creating new Drive artifact for features/sedgwick/91fef1517fca02cc/rap/prior/chunk_00000.npz
# 2026-04-17 10:28:21,071 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/sedgwick/91fef1517fca02cc/rap/prior/chunk_00000.npz
# 2026-04-17 10:28:21,182 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=sedgwick | source=rap | family=prior:chunk_00000 | duration=8.84s | sec_per_unit=8.2989
# 2026-04-17 10:28:21,182 | INFO     | features.notebook | SOURCE ETA | site=sedgwick | source=rap | family=prior | chunk=chunk_00001 | est_remaining_sec=57.36
# 2026-04-17 10:28:21,430 | INFO     | features.notebook | START | stage=family_chunk_compute | site=sedgwick | source=rap | family=prior:chunk_00001
# 2026-04-17 10:28:24,369 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/sedgwick/91fef1517fca02cc/rap/prior/chunk_00001.npz
# [artifact_store] Creating new Drive artifact for features/sedgwick/91fef1517fca02cc/rap/prior/chunk_00001.npz
# 2026-04-17 10:28:30,181 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/sedgwick/91fef1517fca02cc/rap/prior/chunk_00001.npz
# 2026-04-17 10:28:30,292 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=sedgwick | source=rap | family=prior:chunk_00001 | duration=8.86s | sec_per_unit=11.8119
# 2026-04-17 10:28:30,293 | INFO     | features.notebook | SOURCE ETA | site=sedgwick | source=rap | family=prior | chunk=chunk_00002 | est_remaining_sec=42.94
# 2026-04-17 10:28:30,507 | INFO     | features.notebook | START | stage=family_chunk_compute | site=sedgwick | source=rap | family=prior:chunk_00002
# 2026-04-17 10:28:32,476 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/sedgwick/91fef1517fca02cc/rap/prior/chunk_00002.npz
# [artifact_store] Creating new Drive artifact for features/sedgwick/91fef1517fca02cc/rap/prior/chunk_00002.npz
# 2026-04-17 10:28:37,241 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/sedgwick/91fef1517fca02cc/rap/prior/chunk_00002.npz
# 2026-04-17 10:28:37,319 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=sedgwick | source=rap | family=prior:chunk_00002 | duration=6.81s | sec_per_unit=6.3473
# 2026-04-17 10:28:37,320 | INFO     | features.notebook | SOURCE ETA | site=sedgwick | source=rap | family=prior | chunk=chunk_00003 | est_remaining_sec=28.47
# 2026-04-17 10:28:37,727 | INFO     | features.notebook | START | stage=family_chunk_compute | site=sedgwick | source=rap | family=prior:chunk_00003
# 2026-04-17 10:28:38,764 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/sedgwick/91fef1517fca02cc/rap/prior/chunk_00003.npz
# [artifact_store] Creating new Drive artifact for features/sedgwick/91fef1517fca02cc/rap/prior/chunk_00003.npz
# 2026-04-17 10:28:43,120 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/sedgwick/91fef1517fca02cc/rap/prior/chunk_00003.npz
# 2026-04-17 10:28:43,187 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=sedgwick | source=rap | family=prior:chunk_00003 | duration=5.46s | sec_per_unit=7.2208
# 2026-04-17 10:28:43,188 | INFO     | features.notebook | SOURCE ETA | site=sedgwick | source=rap | family=prior | chunk=chunk_00004 | est_remaining_sec=14.16
# 2026-04-17 10:28:43,329 | INFO     | features.notebook | START | stage=family_chunk_compute | site=sedgwick | source=rap | family=prior:chunk_00004
# 2026-04-17 10:28:44,695 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/sedgwick/91fef1517fca02cc/rap/prior/chunk_00004.npz
# [artifact_store] Creating new Drive artifact for features/sedgwick/91fef1517fca02cc/rap/prior/chunk_00004.npz
# 2026-04-17 10:28:49,531 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/sedgwick/91fef1517fca02cc/rap/prior/chunk_00004.npz
# 2026-04-17 10:28:49,595 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=sedgwick | source=rap | family=prior:chunk_00004 | duration=6.27s | sec_per_unit=6.8531
# 2026-04-17 10:28:49,596 | INFO     | features.notebook | SOURCE ETA | site=sedgwick | source=rap | family=prior | chunk=chunk_00005 | est_remaining_sec=0.00
# 2026-04-17 10:28:49,975 | INFO     | features.notebook | START | stage=family_chunk_compute | site=sedgwick | source=rap | family=prior:chunk_00005
# 2026-04-17 10:28:50,873 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/sedgwick/91fef1517fca02cc/rap/prior/chunk_00005.npz
# [artifact_store] Creating new Drive artifact for features/sedgwick/91fef1517fca02cc/rap/prior/chunk_00005.npz
# 2026-04-17 10:28:55,311 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/sedgwick/91fef1517fca02cc/rap/prior/chunk_00005.npz
# 2026-04-17 10:28:55,403 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=sedgwick | source=rap | family=prior:chunk_00005 | duration=5.43s | sec_per_unit=8.4270
# 2026-04-17 10:28:55,403 | INFO     | features.notebook | SOURCE FAMILY DONE | site=sedgwick | source=rap | family=prior
# 2026-04-17 10:28:55,691 | INFO     | features.notebook | PUSH ARTIFACT | key=stack_registry | rel_path=features/sedgwick/91fef1517fca02cc/stack/stack_registry.json
# [artifact_store] Updating existing Drive artifact for features/sedgwick/91fef1517fca02cc/stack/stack_registry.json
# 2026-04-17 10:28:59,072 | INFO     | features.notebook | SOURCE CHUNKED RUN COMPLETE | site=sedgwick | source=rap | registered_layers=42
# 2026-04-17 10:28:59,998 | INFO     | features.notebook | Cleared artifact staging directory | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/_artifact_staging
# 2026-04-17 10:28:59,998 | INFO     | features.notebook | ================================================================================
# 2026-04-17 10:28:59,999 | INFO     | features.notebook | RUN RAP ALL SITES | site=shaver-lake
# 2026-04-17 10:28:59,999 | INFO     | features.notebook | START | stage=site_assets | site=shaver-lake | source=None | family=None
# 2026-04-17 10:29:00,000 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=site_metadata_manifest | rel_path=features/shaver-lake/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 10:29:01,154 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/shaver-lake/91fef1517fca02cc/site_assets/site_metadata_manifest.json
# 2026-04-17 10:29:01,155 | INFO     | features.notebook | Using site metadata manifest | site=shaver-lake
# 2026-04-17 10:29:01,156 | INFO     | features.notebook | LOAD ARTIFACT (remote) | key=source_inventory | rel_path=features/shaver-lake/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 10:29:02,264 | INFO     | features.notebook | PRUNED HYDRATED JSON | rel_path=features/shaver-lake/91fef1517fca02cc/site_assets/source_inventory.json
# 2026-04-17 10:29:02,264 | INFO     | features.notebook | Using cached source inventory | site=shaver-lake
# 2026-04-17 10:29:02,392 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse (no manifest changes) | site=shaver-lake | keys=['naip', 'als_metadata', '3dep', 'source_inventory', 'rap'] | notes=0
# 2026-04-17 10:29:02,392 | INFO     | features.notebook | END   | stage=site_assets | site=shaver-lake | source=None | family=None | duration=2.39s
# 2026-04-17 10:29:03,836 | INFO     | features.notebook | Using cached canonical grid | site=shaver-lake
# 2026-04-17 10:29:03,837 | INFO     | features.notebook | Using cached chunk manifest | site=shaver-lake | n_chunks=4
# 2026-04-17 10:29:03,940 | INFO     | features.notebook | Pruned local NAIP site asset after canonical grid build | site=shaver-lake | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/shaver-lake/naip/shaver_lake.tif
# 2026-04-17 10:29:06,519 | INFO     | features.notebook | Exporting RAP from Earth Engine | site=shaver-lake | out=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/shaver-lake/rap/shaver-lake_rap_ee_10m.tif | bounds_wgs84=(-119.282259, 37.097463, -119.269287, 37.107288)
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/shrubwise-dc-488219/thumbnails/4b03c4faededf53377708fb7bdd42064-4bd72d58f68a3d97bcc7fda7dbcebce3:getPixels
# Please wait ...
# 2026-04-17 10:29:08,784 | WARNING  | rasterio._env | CPLE_AppDefined in shaver-lake_rap_ee_10m.tif: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 10:29:08,851 | WARNING  | rasterio._env | CPLE_AppDefined in TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 10:29:08,856 | INFO     | features.notebook | PUSH ARTIFACT | key=site_rap_raster | rel_path=features/shaver-lake/shared/site_assets/rap/shaver-lake_rap_ee_10m.tif
# Data downloaded to /home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/shaver-lake/rap/shaver-lake_rap_ee_10m.tif
# [artifact_store] Creating new Drive artifact for features/shaver-lake/shared/site_assets/rap/shaver-lake_rap_ee_10m.tif
# 2026-04-17 10:29:12,869 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/shaver-lake/shared/site_assets/rap/shaver-lake_rap_ee_10m.tif
# 2026-04-17 10:29:12,869 | INFO     | features.notebook | RAP local file was pruned after push; rehydrating for current use | site=shaver-lake
# 2026-04-17 10:29:13,486 | INFO     | features.notebook | Prepared RAP asset | site=shaver-lake | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/shaver-lake/rap/shaver-lake_rap_ee_10m.tif
# 2026-04-17 10:29:13,487 | WARNING  | rasterio._env | CPLE_AppDefined in shaver-lake_rap_ee_10m.tif: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 10:29:13,547 | WARNING  | rasterio._env | CPLE_AppDefined in shaver-lake_rap_ee_10m.tif: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 10:29:13,548 | WARNING  | rasterio._env | CPLE_AppDefined in TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 2026-04-17 10:29:13,608 | INFO     | features.notebook | Pruned local RAP site asset after in-memory load | site=shaver-lake | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/shaver-lake/rap/shaver-lake_rap_ee_10m.tif
# 2026-04-17 10:29:15,285 | INFO     | features.notebook | SOURCE CHUNKED RUN | site=shaver-lake | source=rap | families=('prior',) | n_chunks=4
# 2026-04-17 10:29:15,286 | INFO     | features.notebook | SOURCE FAMILY START | site=shaver-lake | source=rap | family=prior
# 2026-04-17 10:29:15,286 | INFO     | features.notebook | SOURCE ETA | site=shaver-lake | source=rap | family=prior | chunk=chunk_00000 | est_remaining_sec=42.10
# 2026-04-17 10:29:15,404 | INFO     | features.notebook | START | stage=family_chunk_compute | site=shaver-lake | source=rap | family=prior:chunk_00000
# 2026-04-17 10:29:16,922 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/shaver-lake/91fef1517fca02cc/rap/prior/chunk_00000.npz
# [artifact_store] Creating new Drive artifact for features/shaver-lake/91fef1517fca02cc/rap/prior/chunk_00000.npz
# 2026-04-17 10:29:22,642 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/shaver-lake/91fef1517fca02cc/rap/prior/chunk_00000.npz
# 2026-04-17 10:29:22,690 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=shaver-lake | source=rap | family=prior:chunk_00000 | duration=7.29s | sec_per_unit=6.8419
# 2026-04-17 10:29:22,691 | INFO     | features.notebook | SOURCE ETA | site=shaver-lake | source=rap | family=prior | chunk=chunk_00001 | est_remaining_sec=27.92
# 2026-04-17 10:29:22,784 | INFO     | features.notebook | START | stage=family_chunk_compute | site=shaver-lake | source=rap | family=prior:chunk_00001
# 2026-04-17 10:29:23,952 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/shaver-lake/91fef1517fca02cc/rap/prior/chunk_00001.npz
# [artifact_store] Creating new Drive artifact for features/shaver-lake/91fef1517fca02cc/rap/prior/chunk_00001.npz
# 2026-04-17 10:29:27,654 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/shaver-lake/91fef1517fca02cc/rap/prior/chunk_00001.npz
# 2026-04-17 10:29:27,704 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=shaver-lake | source=rap | family=prior:chunk_00001 | duration=4.92s | sec_per_unit=5.5173
# 2026-04-17 10:29:27,705 | INFO     | features.notebook | SOURCE ETA | site=shaver-lake | source=rap | family=prior | chunk=chunk_00002 | est_remaining_sec=13.88
# 2026-04-17 10:29:27,805 | INFO     | features.notebook | START | stage=family_chunk_compute | site=shaver-lake | source=rap | family=prior:chunk_00002
# 2026-04-17 10:29:28,852 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/shaver-lake/91fef1517fca02cc/rap/prior/chunk_00002.npz
# [artifact_store] Creating new Drive artifact for features/shaver-lake/91fef1517fca02cc/rap/prior/chunk_00002.npz
# 2026-04-17 10:29:33,012 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/shaver-lake/91fef1517fca02cc/rap/prior/chunk_00002.npz
# 2026-04-17 10:29:33,059 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=shaver-lake | source=rap | family=prior:chunk_00002 | duration=5.25s | sec_per_unit=6.7261
# 2026-04-17 10:29:33,060 | INFO     | features.notebook | SOURCE ETA | site=shaver-lake | source=rap | family=prior | chunk=chunk_00003 | est_remaining_sec=0.00
# 2026-04-17 10:29:33,183 | INFO     | features.notebook | START | stage=family_chunk_compute | site=shaver-lake | source=rap | family=prior:chunk_00003
# 2026-04-17 10:29:34,229 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/shaver-lake/91fef1517fca02cc/rap/prior/chunk_00003.npz
# [artifact_store] Creating new Drive artifact for features/shaver-lake/91fef1517fca02cc/rap/prior/chunk_00003.npz
# 2026-04-17 10:29:38,029 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/shaver-lake/91fef1517fca02cc/rap/prior/chunk_00003.npz
# 2026-04-17 10:29:38,075 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=shaver-lake | source=rap | family=prior:chunk_00003 | duration=4.89s | sec_per_unit=7.4801
# 2026-04-17 10:29:38,076 | INFO     | features.notebook | SOURCE FAMILY DONE | site=shaver-lake | source=rap | family=prior
# 2026-04-17 10:29:38,243 | INFO     | features.notebook | PUSH ARTIFACT | key=stack_registry | rel_path=features/shaver-lake/91fef1517fca02cc/stack/stack_registry.json
# [artifact_store] Updating existing Drive artifact for features/shaver-lake/91fef1517fca02cc/stack/stack_registry.json
# 2026-04-17 10:29:41,129 | INFO     | features.notebook | SOURCE CHUNKED RUN COMPLETE | site=shaver-lake | source=rap | registered_layers=28
# 2026-04-17 10:29:41,466 | INFO     | features.notebook | Cleared artifact staging directory | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/_artifact_staging

# %%
rap_summary_rows = []
for site_id, payload in rap_runs.items():
    registry = payload["registry"]
    rap_summary_rows.append(
        {
            "site_id": site_id,
            "status": payload["status"],
            "n_layers": 0 if registry is None else len(registry.layers),
            "notes": " | ".join(payload["notes"]),
        }
    )

rap_summary_df = pd.DataFrame(rap_summary_rows)
display(rap_summary_df)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                  site_id   status  n_layers  \
# 0    calaveras-big-trees  success       336
# 1               dl-bliss  success        63
# 2      independence-lake  success       560
# 3  pacific-union-college  success        42
# 4               sedgwick  success        42
# 5            shaver-lake  success        28
#
#                                                notes
# 0  3DEP unavailable: Downloaded 3DEP is unreadabl...
# 1  NAIP unavailable during manifest enrichment: D...
# 2
# 3
# 4
# 5

# %% [markdown]
# # ALS

# %%
ALS_WORKFLOW_STAGES = pd.DataFrame(
    [
        {
            "stage": "als_select_inputs",
            "purpose": "Select ALS files/tiles intersecting the site or chunk.",
            "output": "tile inventory / selected ALS paths",
        },
        {
            "stage": "als_prepare_hag",
            "purpose": "Ensure Height Above Ground exists for selected LAS/LAZ tiles.",
            "output": "HAG-enabled LAS/LAZ",
        },
        {
            "stage": "als_structural_rasters",
            "purpose": "Create CHM / mean height / distance-to-canopy / local relief / KNN metrics.",
            "output": "rasterized structural products",
        },
        {
            "stage": "als_align_to_canonical",
            "purpose": "Align ALS-derived rasters to canonical grid/chunks.",
            "output": "chunk-ready structural arrays",
        },
        {
            "stage": "als_family_compute",
            "purpose": "Emit ALS feature families under the same artifact/caching contract.",
            "output": "chunked ALS family outputs",
        },
    ]
)
display(ALS_WORKFLOW_STAGES)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                     stage                                            purpose  \
# 0       als_select_inputs  Select ALS files/tiles intersecting the site o...
# 1         als_prepare_hag  Ensure Height Above Ground exists for selected...
# 2  als_structural_rasters  Create CHM / mean height / distance-to-canopy ...
# 3  als_align_to_canonical  Align ALS-derived rasters to canonical grid/ch...
# 4      als_family_compute  Emit ALS feature families under the same artif...
#
#                                 output
# 0  tile inventory / selected ALS paths
# 1                  HAG-enabled LAS/LAZ
# 2       rasterized structural products
# 3        chunk-ready structural arrays
# 4           chunked ALS family outputs

# %%
ALS_EXPECTED_PRODUCTS = pd.DataFrame(
    [
        {"product": "als_chm_max", "source_logic": "create_height_rasters / CHM Max", "target_family": "height"},
        {"product": "als_height_mean", "source_logic": "create_height_rasters / Mean", "target_family": "height"},
        {"product": "als_distance_to_tall_canopy", "source_logic": "calculate_distance_to_tall_canopy", "target_family": "canopy_context"},
        {"product": "als_local_relief", "source_logic": "calculate_local_relief", "target_family": "canopy_context"},
        {"product": "als_knn_variance", "source_logic": "calculate_knn_node_metrics", "target_family": "structure"},
        {"product": "als_knn_roughness", "source_logic": "calculate_knn_node_metrics", "target_family": "structure"},
        {"product": "als_knn_heterogeneity", "source_logic": "calculate_knn_node_metrics", "target_family": "structure"},
        {"product": "als_knn_maxima_density", "source_logic": "calculate_knn_node_metrics", "target_family": "structure"},
    ]
)
display(ALS_EXPECTED_PRODUCTS)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                        product                       source_logic  \
# 0                  als_chm_max    create_height_rasters / CHM Max
# 1              als_height_mean       create_height_rasters / Mean
# 2  als_distance_to_tall_canopy  calculate_distance_to_tall_canopy
# 3             als_local_relief             calculate_local_relief
# 4             als_knn_variance         calculate_knn_node_metrics
# 5            als_knn_roughness         calculate_knn_node_metrics
# 6        als_knn_heterogeneity         calculate_knn_node_metrics
# 7       als_knn_maxima_density         calculate_knn_node_metrics
#
#     target_family
# 0          height
# 1          height
# 2  canopy_context
# 3  canopy_context
# 4       structure
# 5       structure
# 6       structure
# 7       structure

# %%
def als_metadata_frame(site_assets: SiteAssetBundle) -> pd.DataFrame:
    rows = site_assets.source_assets.get("als_metadata", [])
    return pd.DataFrame(rows) if rows else pd.DataFrame()


def normalize_als_bounds(df: pd.DataFrame) -> pd.DataFrame:
    out = df.copy()

    rename_map = {}
    for src, dst in [
        ("minx", "min_x"),
        ("maxx", "max_x"),
        ("miny", "min_y"),
        ("maxy", "max_y"),
        ("xmin", "min_x"),
        ("xmax", "max_x"),
        ("ymin", "min_y"),
        ("ymax", "max_y"),
    ]:
        if src in out.columns and dst not in out.columns:
            rename_map[src] = dst
    if rename_map:
        out = out.rename(columns=rename_map)

    return out


def canonical_grid_bounds(grid: CanonicalGrid) -> dict[str, float]:
    x_min, y_max = grid.transform * (0, 0)
    x_max, y_min = grid.transform * (grid.width, grid.height)
    return {
        "min_x": min(x_min, x_max),
        "max_x": max(x_min, x_max),
        "min_y": min(y_min, y_max),
        "max_y": max(y_min, y_max),
    }


def bbox_intersects(a: dict[str, float], b: dict[str, float]) -> bool:
    return not (
        a["max_x"] < b["min_x"] or
        a["min_x"] > b["max_x"] or
        a["max_y"] < b["min_y"] or
        a["min_y"] > b["max_y"]
    )

def enrich_als_metadata_with_inventory_urls(
    df: pd.DataFrame,
    *,
    site_assets: SiteAssetBundle,
) -> pd.DataFrame:
    if df.empty:
        return df

    out = df.copy()
    inventory = site_assets.source_assets.get("source_inventory", {}) or {}
    inv_files = inventory.get("als", {}).get("files", []) or []

    if not inv_files:
        return out

    inv_by_name = {}
    for entry in inv_files:
        name = entry.get("name")
        if name is not None:
            inv_by_name[str(name)] = entry

    def _lookup_entry(row: pd.Series) -> dict[str, Any] | None:
        candidates = [
            row.get("source_file"),
            row.get("name"),
            row.get("filename"),
            row.get("tile_name"),
        ]
        for c in candidates:
            if c is None:
                continue
            c = str(c)
            if c in inv_by_name:
                return inv_by_name[c]
        return None

    hrefs = []
    urls = []
    download_urls = []
    names = []

    for _, row in out.iterrows():
        entry = _lookup_entry(row)
        if entry is None:
            hrefs.append(None)
            urls.append(None)
            download_urls.append(None)
            names.append(row.get("source_file") or row.get("name"))
        else:
            hrefs.append(entry.get("href"))
            urls.append(entry.get("url"))
            download_urls.append(entry.get("download_url") or entry.get("url") or entry.get("href"))
            names.append(entry.get("name"))

    if "href" not in out.columns:
        out["href"] = hrefs
    else:
        out["href"] = out["href"].where(out["href"].notna(), pd.Series(hrefs, index=out.index))

    if "url" not in out.columns:
        out["url"] = urls
    else:
        out["url"] = out["url"].where(out["url"].notna(), pd.Series(urls, index=out.index))

    if "download_url" not in out.columns:
        out["download_url"] = download_urls
    else:
        out["download_url"] = out["download_url"].where(
            out["download_url"].notna(),
            pd.Series(download_urls, index=out.index),
        )

    if "name" not in out.columns:
        out["name"] = names
    else:
        out["name"] = out["name"].where(out["name"].notna(), pd.Series(names, index=out.index))

    return out

def build_als_tile_inventory(site_assets: SiteAssetBundle, canonical_grid: CanonicalGrid) -> pd.DataFrame:
    df = als_metadata_frame(site_assets)
    if df.empty:
        LOGGER.warning("ALS tile inventory empty.")
        return df

    df = normalize_als_bounds(df)
    df = enrich_als_metadata_with_inventory_urls(df, site_assets=site_assets)

    grid_bbox = canonical_grid_bounds(canonical_grid)

    if {"min_x", "max_x", "min_y", "max_y"}.issubset(df.columns):
        overlaps = []
        for _, row in df.iterrows():
            tile_bbox = {
                "min_x": float(row["min_x"]),
                "max_x": float(row["max_x"]),
                "min_y": float(row["min_y"]),
                "max_y": float(row["max_y"]),
            }
            overlaps.append(bbox_intersects(tile_bbox, grid_bbox))
        df["intersects_canonical_grid"] = overlaps
    else:
        df["intersects_canonical_grid"] = True

    LOGGER.info("Built ALS tile inventory | rows=%d", len(df))
    return df

def validate_als_tile_inventory(
    tiles_df: pd.DataFrame,
    *,
    site_id: str,
) -> pd.DataFrame:
    if tiles_df.empty:
        raise ValueError(f"ALS tile inventory is empty for site={site_id}")

    out = tiles_df.copy()

    if "intersects_canonical_grid" in out.columns:
        out = out[out["intersects_canonical_grid"]].copy()

    if out.empty:
        raise ValueError(f"No ALS tiles intersect the canonical grid for site={site_id}")

    url_cols = [c for c in ["href", "url", "download_url"] if c in out.columns]
    if not url_cols:
        raise ValueError(
            f"ALS tile inventory has no URL-bearing columns for site={site_id}. "
            f"Columns={list(out.columns)}"
        )

    has_url = pd.Series(False, index=out.index)
    for c in url_cols:
        has_url = has_url | out[c].notna()

    n_bad = int((~has_url).sum())
    if n_bad > 0:
        LOGGER.warning(
            "ALS inventory has rows with no download URL | site=%s | n_bad=%d",
            site_id,
            n_bad,
        )
        out = out[has_url].copy()

    if out.empty:
        raise ValueError(f"ALS tile inventory became empty after URL validation for site={site_id}")

    return out.reset_index(drop=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def structural_raster_cache_root(site_id: str) -> Path:
    return ensure_dir(fe_cfg.cache_root / "als_structural_rasters" / site_id)


def structural_raster_manifest_path(site_id: str) -> Path:
    return structural_raster_cache_root(site_id) / "structural_raster_manifest.json"


def load_structural_raster_manifest(site_id: str) -> dict[str, Any]:
    path = structural_raster_manifest_path(site_id)
    if path.exists():
        return read_json(path)
    return {"site_id": site_id, "products": []}


def save_structural_raster_manifest(site_id: str, payload: dict[str, Any]) -> Path:
    path = structural_raster_manifest_path(site_id)
    write_json(path, payload)
    LOGGER.info("Saved structural raster manifest | site=%s | path=%s", site_id, path)
    return path

def maybe_prune_local_raw_als_tile(local_tile: str | Path) -> None:
    local_tile = Path(local_tile)

    if not fe_cfg.persistence.prune_local_after_remote_push:
        return

    try:
        if local_tile.exists():
            local_tile.unlink()
            LOGGER.info("Pruned local raw ALS tile | path=%s", local_tile)
    except Exception as e:
        LOGGER.warning("Failed to prune local raw ALS tile | path=%s | err=%s", local_tile, e)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ALS_FAMILY_SPECS = {
    "height_structure": FeatureFamilySpec(
        key="height_structure",
        source_name="als",
        runtime_tier=RuntimeTier.EXPENSIVE,
        required_halo_px=8,
        representation_target=RepresentationTarget.RASTER,
        notes="ALS-derived structural rasters: canopy height, mean height, density, canopy distance, local relief, and roughness proxies.",
    ),
}
display(family_spec_frame(ALS_FAMILY_SPECS))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#              family source_name runtime_tier  required_halo_px  target  \
# 0  height_structure         als    expensive                 8  raster
#
#                                                notes
# 0  ALS-derived structural rasters: canopy height,...

# %%
def select_intersecting_als_tiles(
    site_assets: SiteAssetBundle,
    canonical_grid: CanonicalGrid,
) -> pd.DataFrame:
    df = build_als_tile_inventory(site_assets, canonical_grid)
    if df.empty:
        return df

    df = validate_als_tile_inventory(df, site_id=canonical_grid.site_id)
    return df.reset_index(drop=True)


def _safe_height_values_from_las(las) -> np.ndarray:
    if hasattr(las, "HeightAboveGround"):
        return np.asarray(las.HeightAboveGround, dtype=np.float32)
    return np.asarray(las.z, dtype=np.float32)


def rasterize_als_structural_metrics_from_las(
    las_path: str | Path,
    *,
    site_id: str,
    tile_id: str,
    resolution: float = 1.0,
) -> SourceRasterBundle:
    las_path = Path(las_path)
    las = laspy.read(las_path)

    x = np.asarray(las.x, dtype=np.float64)
    y = np.asarray(las.y, dtype=np.float64)
    z = _safe_height_values_from_las(las)

    valid = np.isfinite(x) & np.isfinite(y) & np.isfinite(z)
    x = x[valid]
    y = y[valid]
    z = z[valid]

    if x.size == 0:
        raise ValueError(f"No valid ALS points found in {las_path}")

    x_min, x_max = float(np.min(x)), float(np.max(x))
    y_min, y_max = float(np.min(y)), float(np.max(y))

    cols = max(1, int(np.ceil((x_max - x_min) / resolution)))
    rows = max(1, int(np.ceil((y_max - y_min) / resolution)))

    x_edges = np.linspace(x_min, x_max, cols + 1)
    y_edges = np.linspace(y_min, y_max, rows + 1)

    chm_grid, _, _, _ = binned_statistic_2d(x, y, z, statistic="max", bins=[x_edges, y_edges])
    mean_grid, _, _, _ = binned_statistic_2d(x, y, z, statistic="mean", bins=[x_edges, y_edges])
    count_grid, _, _, _ = binned_statistic_2d(x, y, z, statistic="count", bins=[x_edges, y_edges])
    std_grid, _, _, _ = binned_statistic_2d(x, y, z, statistic="std", bins=[x_edges, y_edges])

    chm_grid = np.rot90(chm_grid).astype(np.float32)
    mean_grid = np.rot90(mean_grid).astype(np.float32)
    count_grid = np.rot90(count_grid).astype(np.float32)
    std_grid = np.rot90(std_grid).astype(np.float32)

    safe_chm = np.nan_to_num(chm_grid, nan=0.0)
    dist_to_canopy = calculate_distance_to_tall_canopy(
        safe_chm,
        resolution=resolution,
        height_threshold=fe_cfg.als.tall_canopy_threshold_m,
    ).astype(np.float32)
    local_relief = calculate_local_relief(
        safe_chm,
        window_size_pixels=fe_cfg.als.local_relief_window_px,
    ).astype(np.float32)

    transform = from_origin(x_min, y_max, resolution, resolution)

    arrays = {
        "als_chm_max": chm_grid,
        "als_height_mean": mean_grid,
        "als_point_count": count_grid,
        "als_height_std": std_grid,
        "als_distance_to_tall_canopy": dist_to_canopy,
        "als_local_relief": local_relief,
    }

    return SourceRasterBundle(
        site_id=site_id,
        source_name="als",
        arrays=arrays,
        transform=transform,
        crs=las.header.parse_crs(),
        nodata=np.nan,
        metadata={
            "tile_id": tile_id,
            "path": str(las_path),
            "resolution": resolution,
            "has_hag": hasattr(las, "HeightAboveGround"),
        },
    )

def validate_als_merged_bundle(bundle: SourceRasterBundle, *, site_id: str) -> None:
    if not bundle.arrays:
        raise ValueError(f"Merged ALS bundle has no arrays for site={site_id}")

    expected_core = {"als_chm_max", "als_height_mean", "als_point_count"}
    missing = sorted(expected_core - set(bundle.arrays.keys()))
    if missing:
        raise ValueError(f"Merged ALS bundle missing core layers for site={site_id}: {missing}")

    sample = next(iter(bundle.arrays.values()))
    if sample.ndim != 2:
        raise ValueError(f"Merged ALS bundle arrays are not 2D for site={site_id}")

    LOGGER.info(
        "Validated ALS merged bundle | site=%s | layers=%d | shape=%s",
        site_id,
        len(bundle.arrays),
        sample.shape,
    )

def validate_cached_als_tile(path: str | Path) -> bool:
    path = Path(path)
    if not path.exists() or path.stat().st_size == 0:
        return False

    try:
        backends = laspy.LazBackend.detect_available()
        las = laspy.read(
            path,
            laz_backend=backends[0] if backends else None,
        )
        # touch a little real data so a truncated file fails here
        _ = las.header.point_count
        _ = np.asarray(las.x[: min(32, len(las.x))])
        return True
    except Exception as e:
        LOGGER.warning("ALS tile validation failed | path=%s | err=%s", path, e)
        return False
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def prepare_als_tile_local_copy(
    site_id: str,
    *,
    tile_row: pd.Series,
    force_refresh: bool = False,
    max_download_attempts: int = 3,
) -> Path:
    local_dir = structural_raster_cache_root(site_id) / "raw_tiles"
    local_dir.mkdir(parents=True, exist_ok=True)

    name = tile_row.get("name") or tile_row.get("filename") or f"{tile_row.name}.laz"
    local_path = local_dir / str(name)

    href = tile_row.get("href") or tile_row.get("url") or tile_row.get("download_url")
    if href is None:
        raise ValueError(f"Could not find ALS download URL for tile row: {tile_row.to_dict()}")

    if not force_refresh and local_path.exists():
        if validate_cached_als_tile(local_path):
            return local_path
        LOGGER.warning("Removing invalid cached ALS tile | site=%s | tile=%s | path=%s", site_id, name, local_path)
        local_path.unlink(missing_ok=True)

    last_err = None
    for attempt in range(1, max_download_attempts + 1):
        try:
            local_path.unlink(missing_ok=True)
            download_file(href, local_path)

            if not validate_cached_als_tile(local_path):
                raise RuntimeError("Downloaded ALS tile failed validation.")

            LOGGER.info(
                "Downloaded ALS tile | site=%s | tile=%s | attempt=%d | path=%s",
                site_id, name, attempt, local_path,
            )
            return local_path

        except Exception as e:
            last_err = e
            LOGGER.warning(
                "ALS tile download/validation failed | site=%s | tile=%s | attempt=%d | err=%s",
                site_id, name, attempt, e,
            )
            local_path.unlink(missing_ok=True)

    raise RuntimeError(f"Failed to prepare ALS tile after {max_download_attempts} attempts: {name} | err={last_err}")


def align_and_merge_als_tile_bundles(
    bundles: list[SourceRasterBundle],
    *,
    canonical_grid: CanonicalGrid,
) -> SourceRasterBundle:
    if not bundles:
        raise ValueError("No ALS bundles provided for merge.")

    aligned_bundles = [
        align_bundle_to_grid(
            bundle,
            dst_grid=canonical_grid,
            resampling=SOURCE_SPECS["als"].default_resampling,
        )
        for bundle in bundles
    ]

    layer_names = sorted(set().union(*[set(b.arrays.keys()) for b in aligned_bundles]))
    merged: dict[str, np.ndarray] = {}

    for layer_name in layer_names:
        stack = []
        for bundle in aligned_bundles:
            if layer_name in bundle.arrays:
                stack.append(bundle.arrays[layer_name])

        if not stack:
            continue

        stacked = np.stack(stack, axis=0)

        if layer_name == "als_point_count":
            merged[layer_name] = np.nansum(stacked, axis=0).astype(np.float32)
        else:
            with np.errstate(all="ignore"):
                merged_arr = np.nanmax(stacked, axis=0)
            merged[layer_name] = merged_arr.astype(np.float32)

    out = SourceRasterBundle(
        site_id=canonical_grid.site_id,
        source_name="als",
        arrays=merged,
        transform=canonical_grid.transform,
        crs=canonical_grid.crs,
        nodata=np.nan,
        metadata={
            "n_tiles_merged": len(bundles),
            "aligned_to": canonical_grid.source_name,
        },
    )
    validate_als_merged_bundle(out, site_id=canonical_grid.site_id)
    return out
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def make_als_height_structure_compute_fn():
    def _compute(arrays: dict[str, np.ndarray]) -> dict[str, np.ndarray]:
        out = {}

        for name, arr in arrays.items():
            out[name] = nan_to_num_copy(arr).astype(np.float32)

        if "als_chm_max" in arrays:
            chm = nan_to_num_copy(arrays["als_chm_max"])
            out["als_chm_gradmag"] = gradient_magnitude(chm)
            out["als_chm_localstd_5"] = local_std(chm, size=5)

        if "als_height_mean" in arrays and "als_chm_max" in arrays:
            out["als_gap_max_minus_mean"] = (
                nan_to_num_copy(arrays["als_chm_max"]) - nan_to_num_copy(arrays["als_height_mean"])
            ).astype(np.float32)

        if "als_point_count" in arrays:
            count = nan_to_num_copy(arrays["als_point_count"])
            out["als_point_density_blur_5"] = get_uniform_blur(count, neighborhood_size=5).astype(np.float32)

        return out

    return _compute


def run_als_chunked_pipeline(
    site_id: str,
    *,
    site_assets: SiteAssetBundle,
    canonical_grid: CanonicalGrid,
    chunk_manifest: ChunkManifest,
    registry: RasterStackRegistry | None = None,
) -> RasterStackRegistry:
    tiles_df = select_intersecting_als_tiles(site_assets, canonical_grid)
    tiles_df = validate_als_tile_inventory(tiles_df, site_id=site_id)

    if tiles_df.empty:
        raise ValueError(f"No ALS tiles intersect the canonical grid for site={site_id}")

    tile_bundles: list[SourceRasterBundle] = []
    failed_tiles: list[str] = []

    for _, row in tiles_df.iterrows():
        tile_name = str(row.get("name") or row.get("filename") or row.name)

        try:
            local_tile = prepare_als_tile_local_copy(site_id, tile_row=row)
            tile_id = Path(local_tile).stem

            bundle = rasterize_als_structural_metrics_from_las(
                local_tile,
                site_id=site_id,
                tile_id=tile_id,
                resolution=fe_cfg.als.structural_raster_resolution_m,
            )
            tile_bundles.append(bundle)

        except Exception as e:
            LOGGER.warning(
                "ALS tile processing failed | site=%s | tile=%s | err=%s",
                site_id,
                tile_name,
                e,
            )
            failed_tiles.append(tile_name)

        finally:
            try:
                if 'local_tile' in locals():
                    maybe_prune_local_raw_als_tile(local_tile)
            except Exception as e:
                LOGGER.warning(
                    "ALS raw tile prune failed | site=%s | tile=%s | err=%s",
                    site_id,
                    tile_name,
                    e,
                )

    if not tile_bundles:
        raise ValueError(f"All ALS tiles failed for site={site_id}; failed_tiles={failed_tiles}")

    LOGGER.info(
        "ALS rasterization complete | site=%s | successful_tiles=%d | failed_tiles=%d",
        site_id,
        len(tile_bundles),
        len(failed_tiles),
    )

    merged_bundle = align_and_merge_als_tile_bundles(
        tile_bundles,
        canonical_grid=canonical_grid,
    )

    registry = run_source_chunked_pipeline(
        site_id=site_id,
        source_name="als",
        raw_bundle=merged_bundle,
        canonical_grid=canonical_grid,
        chunk_manifest=chunk_manifest,
        family_specs=ALS_FAMILY_SPECS,
        family_compute_fns={
            "height_structure": make_als_height_structure_compute_fn(),
        },
        family_cfg_payloads={
            "height_structure": {
                "structural_raster_resolution_m": fe_cfg.als.structural_raster_resolution_m,
                "tall_canopy_threshold_m": fe_cfg.als.tall_canopy_threshold_m,
                "local_relief_window_px": fe_cfg.als.local_relief_window_px,
                "knn_k": fe_cfg.als.knn_k,
            }
        },
        registry=registry,
    )

    return registry
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
TEST_SITE = fe_cfg.sites[0]

site_assets = prepare_site_assets(TEST_SITE, force_refresh=False)
canonical_grid = build_canonical_grid_for_site(TEST_SITE, assets=site_assets, force_refresh=False)

tiles_df = build_als_tile_inventory(site_assets, canonical_grid)
print("Raw ALS inventory rows:", len(tiles_df))
display(tiles_df.head(10))

tiles_valid = validate_als_tile_inventory(tiles_df, site_id=TEST_SITE)
print("Validated ALS rows:", len(tiles_valid))
display(
    tiles_valid[
        [c for c in ["name", "source_file", "url", "href", "download_url", "intersects_canonical_grid"] if c in tiles_valid.columns]
    ].head(10)
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 2026-04-17 11:06:54,887 | INFO     | features.notebook | START | stage=site_assets | site=calaveras-big-trees | source=None | family=None
# 2026-04-17 11:06:54,888 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=site_metadata_manifest | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/site_assets/site_metadata_manifest.json
# 2026-04-17 11:06:54,889 | INFO     | features.notebook | Using site metadata manifest | site=calaveras-big-trees
# 2026-04-17 11:06:54,890 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=source_inventory | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/site_assets/source_inventory.json
# 2026-04-17 11:06:54,890 | INFO     | features.notebook | Using cached source inventory | site=calaveras-big-trees
# 2026-04-17 11:06:54,939 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse (no manifest changes) | site=calaveras-big-trees | keys=['naip', 'als_metadata', '3dep', 'rap', 'source_inventory'] | notes=0
# 2026-04-17 11:06:54,939 | INFO     | features.notebook | END   | stage=site_assets | site=calaveras-big-trees | source=None | family=None | duration=0.05s
# 2026-04-17 11:06:55,027 | INFO     | features.notebook | Using cached canonical grid | site=calaveras-big-trees
# 2026-04-17 11:06:55,030 | INFO     | features.notebook | Built ALS tile inventory | rows=10
# Raw ALS inventory rows: 10
#       count  compressed  major_version  minor_version  dataformat_id  \
# 0  36906926        True              1              4              6
# 1  36370037        True              1              4              6
# 2  39198120        True              1              4              6
# 3  39876902        True              1              4              6
# 4  37664314        True              1              4              6
# 5  32272833        True              1              4              6
# 6  37644869        True              1              4              6
# 7  39200800        True              1              4              6
# 8  32063001        True              1              4              6
# 9  36002705        True              1              4              6
#
#                                                  srs  \
# 0  {'compoundwkt': 'COMPD_CS["NAD83(2011) / UTM z...
# 1  {'compoundwkt': 'COMPD_CS["NAD83(2011) / UTM z...
# 2  {'compoundwkt': 'COMPD_CS["NAD83(2011) / UTM z...
# 3  {'compoundwkt': 'COMPD_CS["NAD83(2011) / UTM z...
# 4  {'compoundwkt': 'COMPD_CS["NAD83(2011) / UTM z...
# 5  {'compoundwkt': 'COMPD_CS["NAD83(2011) / UTM z...
# 6  {'compoundwkt': 'COMPD_CS["NAD83(2011) / UTM z...
# 7  {'compoundwkt': 'COMPD_CS["NAD83(2011) / UTM z...
# 8  {'compoundwkt': 'COMPD_CS["NAD83(2011) / UTM z...
# 9  {'compoundwkt': 'COMPD_CS["NAD83(2011) / UTM z...
#
#                                        native_bounds  \
# 0  {'minx': 739000, 'maxx': 739999.99, 'miny': 42...
# 1  {'minx': 740000, 'maxx': 740999.99, 'miny': 42...
# 2  {'minx': 740000, 'maxx': 740999.99, 'miny': 42...
# 3  {'minx': 741000, 'maxx': 741999.99, 'miny': 42...
# 4  {'minx': 741000, 'maxx': 741999.99, 'miny': 42...
# 5  {'minx': 742000, 'maxx': 742999.99, 'miny': 42...
# 6  {'minx': 742000, 'maxx': 742999.99, 'miny': 42...
# 7  {'minx': 742000, 'maxx': 742999.99, 'miny': 42...
# 8  {'minx': 743000, 'maxx': 743999.99, 'miny': 42...
# 9  {'minx': 743000, 'maxx': 743999.99, 'miny': 42...
#
#                                              srs_wkt  \
# 0  COMPD_CS["NAD83(2011) / UTM zone 10N + NAVD88 ...
# 1  COMPD_CS["NAD83(2011) / UTM zone 10N + NAVD88 ...
# 2  COMPD_CS["NAD83(2011) / UTM zone 10N + NAVD88 ...
# 3  COMPD_CS["NAD83(2011) / UTM zone 10N + NAVD88 ...
# 4  COMPD_CS["NAD83(2011) / UTM zone 10N + NAVD88 ...
# 5  COMPD_CS["NAD83(2011) / UTM zone 10N + NAVD88 ...
# 6  COMPD_CS["NAD83(2011) / UTM zone 10N + NAVD88 ...
# 7  COMPD_CS["NAD83(2011) / UTM zone 10N + NAVD88 ...
# 8  COMPD_CS["NAD83(2011) / UTM zone 10N + NAVD88 ...
# 9  COMPD_CS["NAD83(2011) / UTM zone 10N + NAVD88 ...
#
#                                             srs_json         stats_keys  \
# 0  {'type': 'CompoundCRS', 'name': 'NAD83(2011) /...  [bbox, statistic]
# 1  {'type': 'CompoundCRS', 'name': 'NAD83(2011) /...  [bbox, statistic]
# 2  {'type': 'CompoundCRS', 'name': 'NAD83(2011) /...  [bbox, statistic]
# 3  {'type': 'CompoundCRS', 'name': 'NAD83(2011) /...  [bbox, statistic]
# 4  {'type': 'CompoundCRS', 'name': 'NAD83(2011) /...  [bbox, statistic]
# 5  {'type': 'CompoundCRS', 'name': 'NAD83(2011) /...  [bbox, statistic]
# 6  {'type': 'CompoundCRS', 'name': 'NAD83(2011) /...  [bbox, statistic]
# 7  {'type': 'CompoundCRS', 'name': 'NAD83(2011) /...  [bbox, statistic]
# 8  {'type': 'CompoundCRS', 'name': 'NAD83(2011) /...  [bbox, statistic]
# 9  {'type': 'CompoundCRS', 'name': 'NAD83(2011) /...  [bbox, statistic]
#
#                                        metadata_keys  \
# 0  [comp_spatialreference, compressed, copc, coun...
# 1  [comp_spatialreference, compressed, copc, coun...
# 2  [comp_spatialreference, compressed, copc, coun...
# 3  [comp_spatialreference, compressed, copc, coun...
# 4  [comp_spatialreference, compressed, copc, coun...
# 5  [comp_spatialreference, compressed, copc, coun...
# 6  [comp_spatialreference, compressed, copc, coun...
# 7  [comp_spatialreference, compressed, copc, coun...
# 8  [comp_spatialreference, compressed, copc, coun...
# 9  [comp_spatialreference, compressed, copc, coun...
#
#                                   source_file  href  \
# 0  USGS_LPC_CA_SierraNevada_B22_10SGH3935.laz  None
# 1  USGS_LPC_CA_SierraNevada_B22_10SGH4035.laz  None
# 2  USGS_LPC_CA_SierraNevada_B22_10SGH4036.laz  None
# 3  USGS_LPC_CA_SierraNevada_B22_10SGH4136.laz  None
# 4  USGS_LPC_CA_SierraNevada_B22_10SGH4137.laz  None
# 5  USGS_LPC_CA_SierraNevada_B22_10SGH4236.laz  None
# 6  USGS_LPC_CA_SierraNevada_B22_10SGH4237.laz  None
# 7  USGS_LPC_CA_SierraNevada_B22_10SGH4238.laz  None
# 8  USGS_LPC_CA_SierraNevada_B22_10SGH4337.laz  None
# 9  USGS_LPC_CA_SierraNevada_B22_10SGH4338.laz  None
#
#                                                  url  \
# 0  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 1  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 2  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 3  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 4  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 5  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 6  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 7  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 8  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 9  https://wifire-data.sdsc.edu/nc/public.php/dav...
#
#                                         download_url  \
# 0  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 1  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 2  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 3  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 4  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 5  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 6  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 7  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 8  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 9  https://wifire-data.sdsc.edu/nc/public.php/dav...
#
#                                          name  intersects_canonical_grid
# 0  USGS_LPC_CA_SierraNevada_B22_10SGH3935.laz                       True
# 1  USGS_LPC_CA_SierraNevada_B22_10SGH4035.laz                       True
# 2  USGS_LPC_CA_SierraNevada_B22_10SGH4036.laz                       True
# 3  USGS_LPC_CA_SierraNevada_B22_10SGH4136.laz                       True
# 4  USGS_LPC_CA_SierraNevada_B22_10SGH4137.laz                       True
# 5  USGS_LPC_CA_SierraNevada_B22_10SGH4236.laz                       True
# 6  USGS_LPC_CA_SierraNevada_B22_10SGH4237.laz                       True
# 7  USGS_LPC_CA_SierraNevada_B22_10SGH4238.laz                       True
# 8  USGS_LPC_CA_SierraNevada_B22_10SGH4337.laz                       True
# 9  USGS_LPC_CA_SierraNevada_B22_10SGH4338.laz                       True
# Validated ALS rows: 10
#                                          name  \
# 0  USGS_LPC_CA_SierraNevada_B22_10SGH3935.laz
# 1  USGS_LPC_CA_SierraNevada_B22_10SGH4035.laz
# 2  USGS_LPC_CA_SierraNevada_B22_10SGH4036.laz
# 3  USGS_LPC_CA_SierraNevada_B22_10SGH4136.laz
# 4  USGS_LPC_CA_SierraNevada_B22_10SGH4137.laz
# 5  USGS_LPC_CA_SierraNevada_B22_10SGH4236.laz
# 6  USGS_LPC_CA_SierraNevada_B22_10SGH4237.laz
# 7  USGS_LPC_CA_SierraNevada_B22_10SGH4238.laz
# 8  USGS_LPC_CA_SierraNevada_B22_10SGH4337.laz
# 9  USGS_LPC_CA_SierraNevada_B22_10SGH4338.laz
#
#                                   source_file  \
# 0  USGS_LPC_CA_SierraNevada_B22_10SGH3935.laz
# 1  USGS_LPC_CA_SierraNevada_B22_10SGH4035.laz
# 2  USGS_LPC_CA_SierraNevada_B22_10SGH4036.laz
# 3  USGS_LPC_CA_SierraNevada_B22_10SGH4136.laz
# 4  USGS_LPC_CA_SierraNevada_B22_10SGH4137.laz
# 5  USGS_LPC_CA_SierraNevada_B22_10SGH4236.laz
# 6  USGS_LPC_CA_SierraNevada_B22_10SGH4237.laz
# 7  USGS_LPC_CA_SierraNevada_B22_10SGH4238.laz
# 8  USGS_LPC_CA_SierraNevada_B22_10SGH4337.laz
# 9  USGS_LPC_CA_SierraNevada_B22_10SGH4338.laz
#
#                                                  url  href  \
# 0  https://wifire-data.sdsc.edu/nc/public.php/dav...  None
# 1  https://wifire-data.sdsc.edu/nc/public.php/dav...  None
# 2  https://wifire-data.sdsc.edu/nc/public.php/dav...  None
# 3  https://wifire-data.sdsc.edu/nc/public.php/dav...  None
# 4  https://wifire-data.sdsc.edu/nc/public.php/dav...  None
# 5  https://wifire-data.sdsc.edu/nc/public.php/dav...  None
# 6  https://wifire-data.sdsc.edu/nc/public.php/dav...  None
# 7  https://wifire-data.sdsc.edu/nc/public.php/dav...  None
# 8  https://wifire-data.sdsc.edu/nc/public.php/dav...  None
# 9  https://wifire-data.sdsc.edu/nc/public.php/dav...  None
#
#                                         download_url  \
# 0  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 1  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 2  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 3  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 4  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 5  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 6  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 7  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 8  https://wifire-data.sdsc.edu/nc/public.php/dav...
# 9  https://wifire-data.sdsc.edu/nc/public.php/dav...
#
#    intersects_canonical_grid
# 0                       True
# 1                       True
# 2                       True
# 3                       True
# 4                       True
# 5                       True
# 6                       True
# 7                       True
# 8                       True
# 9                       True

# %%
TEST_SITE = fe_cfg.sites[0]

site_assets = prepare_site_assets(TEST_SITE, force_refresh=False)
canonical_grid = build_canonical_grid_for_site(TEST_SITE, assets=site_assets, force_refresh=False)
chunk_manifest = build_chunk_manifest(canonical_grid, force_refresh=False)

registry_als = run_als_chunked_pipeline(
    TEST_SITE,
    site_assets=site_assets,
    canonical_grid=canonical_grid,
    chunk_manifest=chunk_manifest,
    registry=RasterStackRegistry(
        site_id=TEST_SITE,
        config_signature=fe_config_signature(),
        layers=[],
    ),
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 2026-04-17 11:06:58,535 | INFO     | features.notebook | START | stage=site_assets | site=calaveras-big-trees | source=None | family=None
# 2026-04-17 11:06:58,536 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=site_metadata_manifest | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/site_assets/site_metadata_manifest.json
# 2026-04-17 11:06:58,537 | INFO     | features.notebook | Using site metadata manifest | site=calaveras-big-trees
# 2026-04-17 11:06:58,538 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=source_inventory | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/site_assets/source_inventory.json
# 2026-04-17 11:06:58,538 | INFO     | features.notebook | Using cached source inventory | site=calaveras-big-trees
# 2026-04-17 11:06:58,543 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse (no manifest changes) | site=calaveras-big-trees | keys=['naip', 'als_metadata', '3dep', 'rap', 'source_inventory'] | notes=0
# 2026-04-17 11:06:58,543 | INFO     | features.notebook | END   | stage=site_assets | site=calaveras-big-trees | source=None | family=None | duration=0.01s
# 2026-04-17 11:06:58,544 | INFO     | features.notebook | Using cached canonical grid | site=calaveras-big-trees
# 2026-04-17 11:06:58,545 | INFO     | features.notebook | Using cached chunk manifest | site=calaveras-big-trees | n_chunks=48
# 2026-04-17 11:06:58,548 | INFO     | features.notebook | Built ALS tile inventory | rows=10
# 2026-04-17 11:07:02,738 | INFO     | features.notebook | Downloaded ALS tile | site=calaveras-big-trees | tile=USGS_LPC_CA_SierraNevada_B22_10SGH3935.laz | attempt=1 | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/als_structural_rasters/calaveras-big-trees/raw_tiles/USGS_LPC_CA_SierraNevada_B22_10SGH3935.laz
# 2026-04-17 11:07:20,262 | INFO     | features.notebook | Pruned local raw ALS tile | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/als_structural_rasters/calaveras-big-trees/raw_tiles/USGS_LPC_CA_SierraNevada_B22_10SGH3935.laz
# 2026-04-17 11:07:24,200 | INFO     | features.notebook | Downloaded ALS tile | site=calaveras-big-trees | tile=USGS_LPC_CA_SierraNevada_B22_10SGH4035.laz | attempt=1 | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/als_structural_rasters/calaveras-big-trees/raw_tiles/USGS_LPC_CA_SierraNevada_B22_10SGH4035.laz
# 2026-04-17 11:07:40,164 | INFO     | features.notebook | Pruned local raw ALS tile | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/als_structural_rasters/calaveras-big-trees/raw_tiles/USGS_LPC_CA_SierraNevada_B22_10SGH4035.laz
# 2026-04-17 11:07:45,067 | INFO     | features.notebook | Downloaded ALS tile | site=calaveras-big-trees | tile=USGS_LPC_CA_SierraNevada_B22_10SGH4036.laz | attempt=1 | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/als_structural_rasters/calaveras-big-trees/raw_tiles/USGS_LPC_CA_SierraNevada_B22_10SGH4036.laz
# 2026-04-17 11:08:03,639 | INFO     | features.notebook | Pruned local raw ALS tile | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/als_structural_rasters/calaveras-big-trees/raw_tiles/USGS_LPC_CA_SierraNevada_B22_10SGH4036.laz
# 2026-04-17 11:08:08,010 | INFO     | features.notebook | Downloaded ALS tile | site=calaveras-big-trees | tile=USGS_LPC_CA_SierraNevada_B22_10SGH4136.laz | attempt=1 | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/als_structural_rasters/calaveras-big-trees/raw_tiles/USGS_LPC_CA_SierraNevada_B22_10SGH4136.laz
# 2026-04-17 11:08:26,610 | INFO     | features.notebook | Pruned local raw ALS tile | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/als_structural_rasters/calaveras-big-trees/raw_tiles/USGS_LPC_CA_SierraNevada_B22_10SGH4136.laz
# 2026-04-17 11:08:31,010 | INFO     | features.notebook | Downloaded ALS tile | site=calaveras-big-trees | tile=USGS_LPC_CA_SierraNevada_B22_10SGH4137.laz | attempt=1 | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/als_structural_rasters/calaveras-big-trees/raw_tiles/USGS_LPC_CA_SierraNevada_B22_10SGH4137.laz
# 2026-04-17 11:08:48,207 | INFO     | features.notebook | Pruned local raw ALS tile | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/als_structural_rasters/calaveras-big-trees/raw_tiles/USGS_LPC_CA_SierraNevada_B22_10SGH4137.laz
# 2026-04-17 11:08:52,080 | INFO     | features.notebook | Downloaded ALS tile | site=calaveras-big-trees | tile=USGS_LPC_CA_SierraNevada_B22_10SGH4236.laz | attempt=1 | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/als_structural_rasters/calaveras-big-trees/raw_tiles/USGS_LPC_CA_SierraNevada_B22_10SGH4236.laz
# 2026-04-17 11:09:05,888 | INFO     | features.notebook | Pruned local raw ALS tile | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/als_structural_rasters/calaveras-big-trees/raw_tiles/USGS_LPC_CA_SierraNevada_B22_10SGH4236.laz
# 2026-04-17 11:09:10,906 | INFO     | features.notebook | Downloaded ALS tile | site=calaveras-big-trees | tile=USGS_LPC_CA_SierraNevada_B22_10SGH4237.laz | attempt=1 | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/als_structural_rasters/calaveras-big-trees/raw_tiles/USGS_LPC_CA_SierraNevada_B22_10SGH4237.laz
# 2026-04-17 11:09:28,079 | INFO     | features.notebook | Pruned local raw ALS tile | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/als_structural_rasters/calaveras-big-trees/raw_tiles/USGS_LPC_CA_SierraNevada_B22_10SGH4237.laz
# 2026-04-17 11:09:32,748 | INFO     | features.notebook | Downloaded ALS tile | site=calaveras-big-trees | tile=USGS_LPC_CA_SierraNevada_B22_10SGH4238.laz | attempt=1 | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/als_structural_rasters/calaveras-big-trees/raw_tiles/USGS_LPC_CA_SierraNevada_B22_10SGH4238.laz
# 2026-04-17 11:09:50,408 | INFO     | features.notebook | Pruned local raw ALS tile | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/als_structural_rasters/calaveras-big-trees/raw_tiles/USGS_LPC_CA_SierraNevada_B22_10SGH4238.laz
# 2026-04-17 11:10:06,141 | INFO     | features.notebook | Pruned local raw ALS tile | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/als_structural_rasters/calaveras-big-trees/raw_tiles/USGS_LPC_CA_SierraNevada_B22_10SGH4337.laz
# 2026-04-17 11:10:24,342 | INFO     | features.notebook | Pruned local raw ALS tile | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/als_structural_rasters/calaveras-big-trees/raw_tiles/USGS_LPC_CA_SierraNevada_B22_10SGH4338.laz
# 2026-04-17 11:10:24,343 | INFO     | features.notebook | ALS rasterization complete | site=calaveras-big-trees | successful_tiles=10 | failed_tiles=0
# 2026-04-17 11:11:00,323 | INFO     | features.notebook | Validated ALS merged bundle | site=calaveras-big-trees | layers=6 | shape=(5375, 7398)
# 2026-04-17 11:11:04,369 | INFO     | features.notebook | SOURCE CHUNKED RUN | site=calaveras-big-trees | source=als | families=('height_structure',) | n_chunks=48
# 2026-04-17 11:11:04,369 | INFO     | features.notebook | SOURCE FAMILY START | site=calaveras-big-trees | source=als | family=height_structure
# 2026-04-17 11:11:04,460 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00000
# 2026-04-17 11:11:04,829 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00000.npz
# 2026-04-17 11:11:04,829 | INFO     | oauth2client.client | access_token is expired. Now: 2026-04-17 11:11:04.829716, token_expiry: 2026-04-17 10:59:16
# 2026-04-17 11:11:04,830 | INFO     | oauth2client.client | access_token is expired. Now: 2026-04-17 11:11:04.830100, token_expiry: 2026-04-17 10:59:16
# 2026-04-17 11:11:04,874 | INFO     | oauth2client.client | Refreshing access_token
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00000.npz
# 2026-04-17 11:11:10,864 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00000.npz
# 2026-04-17 11:11:10,910 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00000 | duration=6.45s | sec_per_unit=6.0563
# 2026-04-17 11:11:10,910 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00001 | est_remaining_sec=278.59
# 2026-04-17 11:11:10,999 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00001
# 2026-04-17 11:11:11,277 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00001.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00001.npz
# 2026-04-17 11:11:14,918 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00001.npz
# 2026-04-17 11:11:14,963 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00001 | duration=3.96s | sec_per_unit=3.6931
# 2026-04-17 11:11:14,963 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00002 | est_remaining_sec=219.36
# 2026-04-17 11:11:15,134 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00002
# 2026-04-17 11:11:15,436 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00002.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00002.npz
# 2026-04-17 11:11:19,316 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00002.npz
# 2026-04-17 11:11:19,363 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00002 | duration=4.23s | sec_per_unit=3.9395
# 2026-04-17 11:11:19,363 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00003 | est_remaining_sec=200.77
# 2026-04-17 11:11:19,520 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00003
# 2026-04-17 11:11:19,888 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00003.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00003.npz
# 2026-04-17 11:11:24,259 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00003.npz
# 2026-04-17 11:11:24,303 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00003 | duration=4.78s | sec_per_unit=4.4570
# 2026-04-17 11:11:24,304 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00004 | est_remaining_sec=195.07
# 2026-04-17 11:11:24,396 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00004
# 2026-04-17 11:11:25,954 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00004.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00004.npz
# 2026-04-17 11:11:30,299 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00004.npz
# 2026-04-17 11:11:30,349 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00004 | duration=5.95s | sec_per_unit=5.5463
# 2026-04-17 11:11:30,349 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00005 | est_remaining_sec=199.01
# 2026-04-17 11:11:30,436 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00005
# 2026-04-17 11:11:32,572 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00005.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00005.npz
# 2026-04-17 11:11:37,279 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00005.npz
# 2026-04-17 11:11:37,323 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00005 | duration=6.89s | sec_per_unit=6.4163
# 2026-04-17 11:11:37,323 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00006 | est_remaining_sec=205.74
# 2026-04-17 11:11:37,411 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00006
# 2026-04-17 11:11:39,484 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00006.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00006.npz
# 2026-04-17 11:11:44,575 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00006.npz
# 2026-04-17 11:11:44,619 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00006 | duration=7.21s | sec_per_unit=6.7162
# 2026-04-17 11:11:44,620 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00007 | est_remaining_sec=210.43
# 2026-04-17 11:11:44,708 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00007
# 2026-04-17 11:11:45,368 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00007.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00007.npz
# 2026-04-17 11:11:49,105 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00007.npz
# 2026-04-17 11:11:49,150 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00007 | duration=4.44s | sec_per_unit=18.0854
# 2026-04-17 11:11:49,156 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00008 | est_remaining_sec=267.69
# 2026-04-17 11:11:49,245 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00008
# 2026-04-17 11:11:49,528 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00008.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00008.npz
# 2026-04-17 11:11:52,727 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00008.npz
# 2026-04-17 11:11:52,771 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00008 | duration=3.53s | sec_per_unit=3.2855
# 2026-04-17 11:11:52,772 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00009 | est_remaining_sec=245.71
# 2026-04-17 11:11:52,859 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00009
# 2026-04-17 11:11:53,142 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00009.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00009.npz
# 2026-04-17 11:11:56,493 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00009.npz
# 2026-04-17 11:11:56,540 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00009 | duration=3.68s | sec_per_unit=3.4029
# 2026-04-17 11:11:56,541 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00010 | est_remaining_sec=227.91
# 2026-04-17 11:11:56,637 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00010
# 2026-04-17 11:11:57,390 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00010.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00010.npz
# 2026-04-17 11:12:01,413 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00010.npz
# 2026-04-17 11:12:01,458 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00010 | duration=4.82s | sec_per_unit=4.4573
# 2026-04-17 11:12:01,458 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00011 | est_remaining_sec=216.18
# 2026-04-17 11:12:01,545 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00011
# 2026-04-17 11:12:04,443 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00011.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00011.npz
# 2026-04-17 11:12:08,798 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00011.npz
# 2026-04-17 11:12:08,842 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00011 | duration=7.30s | sec_per_unit=6.7462
# 2026-04-17 11:12:08,843 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00012 | est_remaining_sec=212.34
# 2026-04-17 11:12:08,930 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00012
# 2026-04-17 11:12:11,074 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00012.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00012.npz
# 2026-04-17 11:12:16,570 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00012.npz
# 2026-04-17 11:12:16,615 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00012 | duration=7.69s | sec_per_unit=7.1053
# 2026-04-17 11:12:16,616 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00013 | est_remaining_sec=208.99
# 2026-04-17 11:12:16,703 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00013
# 2026-04-17 11:12:18,977 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00013.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00013.npz
# 2026-04-17 11:12:23,370 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00013.npz
# 2026-04-17 11:12:23,414 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00013 | duration=6.71s | sec_per_unit=6.2047
# 2026-04-17 11:12:23,415 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00014 | est_remaining_sec=202.98
# 2026-04-17 11:12:23,502 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00014
# 2026-04-17 11:12:25,557 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00014.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00014.npz
# 2026-04-17 11:12:30,306 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00014.npz
# 2026-04-17 11:12:30,350 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00014 | duration=6.85s | sec_per_unit=6.3318
# 2026-04-17 11:12:30,351 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00015 | est_remaining_sec=197.21
# 2026-04-17 11:12:30,442 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00015
# 2026-04-17 11:12:31,051 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00015.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00015.npz
# 2026-04-17 11:12:34,890 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00015.npz
# 2026-04-17 11:12:34,938 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00015 | duration=4.50s | sec_per_unit=18.1664
# 2026-04-17 11:12:34,943 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00016 | est_remaining_sec=214.31
# 2026-04-17 11:12:35,039 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00016
# 2026-04-17 11:12:35,448 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00016.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00016.npz
# 2026-04-17 11:12:38,815 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00016.npz
# 2026-04-17 11:12:38,859 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00016 | duration=3.82s | sec_per_unit=3.5599
# 2026-04-17 11:12:38,860 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00017 | est_remaining_sec=201.48
# 2026-04-17 11:12:38,947 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00017
# 2026-04-17 11:12:39,949 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00017.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00017.npz
# 2026-04-17 11:12:44,314 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00017.npz
# 2026-04-17 11:12:44,358 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00017 | duration=5.41s | sec_per_unit=5.0026
# 2026-04-17 11:12:44,359 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00018 | est_remaining_sec=192.00
# 2026-04-17 11:12:44,446 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00018
# 2026-04-17 11:12:45,873 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00018.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00018.npz
# 2026-04-17 11:12:50,393 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00018.npz
# 2026-04-17 11:12:50,437 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00018 | duration=5.99s | sec_per_unit=5.5394
# 2026-04-17 11:12:50,438 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00019 | est_remaining_sec=183.79
# 2026-04-17 11:12:50,525 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00019
# 2026-04-17 11:12:52,688 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00019.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00019.npz
# 2026-04-17 11:12:56,887 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00019.npz
# 2026-04-17 11:12:56,932 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00019 | duration=6.41s | sec_per_unit=5.9231
# 2026-04-17 11:12:56,932 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00020 | est_remaining_sec=176.36
# 2026-04-17 11:12:57,065 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00020
# 2026-04-17 11:12:59,125 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00020.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00020.npz
# 2026-04-17 11:13:03,574 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00020.npz
# 2026-04-17 11:13:03,619 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00020 | duration=6.55s | sec_per_unit=6.0590
# 2026-04-17 11:13:03,619 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00021 | est_remaining_sec=169.24
# 2026-04-17 11:13:03,710 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00021
# 2026-04-17 11:13:06,652 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00021.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00021.npz
# 2026-04-17 11:13:11,550 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00021.npz
# 2026-04-17 11:13:11,595 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00021 | duration=7.89s | sec_per_unit=7.2903
# 2026-04-17 11:13:11,595 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00022 | est_remaining_sec=163.62
# 2026-04-17 11:13:11,683 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00022
# 2026-04-17 11:13:12,992 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00022.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00022.npz
# 2026-04-17 11:13:17,612 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00022.npz
# 2026-04-17 11:13:17,656 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00022 | duration=5.97s | sec_per_unit=5.5223
# 2026-04-17 11:13:17,656 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00023 | est_remaining_sec=156.01
# 2026-04-17 11:13:17,744 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00023
# 2026-04-17 11:13:18,123 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00023.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00023.npz
# 2026-04-17 11:13:23,374 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00023.npz
# 2026-04-17 11:13:23,526 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00023 | duration=5.78s | sec_per_unit=23.3626
# 2026-04-17 11:13:23,531 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00024 | est_remaining_sec=165.67
# 2026-04-17 11:13:23,618 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00024
# 2026-04-17 11:13:23,900 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00024.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00024.npz
# 2026-04-17 11:13:27,388 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00024.npz
# 2026-04-17 11:13:27,432 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00024 | duration=3.81s | sec_per_unit=3.5533
# 2026-04-17 11:13:27,433 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00025 | est_remaining_sec=155.25
# 2026-04-17 11:13:27,520 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00025
# 2026-04-17 11:13:29,591 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00025.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00025.npz
# 2026-04-17 11:13:34,483 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00025.npz
# 2026-04-17 11:13:34,528 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00025 | duration=7.01s | sec_per_unit=6.4796
# 2026-04-17 11:13:34,529 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00026 | est_remaining_sec=147.73
# 2026-04-17 11:13:34,695 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00026
# 2026-04-17 11:13:36,776 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00026.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00026.npz
# 2026-04-17 11:13:41,436 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00026.npz
# 2026-04-17 11:13:41,480 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00026 | duration=6.79s | sec_per_unit=6.2735
# 2026-04-17 11:13:41,481 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00027 | est_remaining_sec=140.13
# 2026-04-17 11:13:41,568 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00027
# 2026-04-17 11:13:43,622 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00027.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00027.npz
# 2026-04-17 11:13:48,250 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00027.npz
# 2026-04-17 11:13:48,295 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00027 | duration=6.73s | sec_per_unit=6.2195
# 2026-04-17 11:13:48,295 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00028 | est_remaining_sec=132.59
# 2026-04-17 11:13:48,382 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00028
# 2026-04-17 11:13:50,744 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00028.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00028.npz
# 2026-04-17 11:13:55,093 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00028.npz
# 2026-04-17 11:13:55,137 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00028 | duration=6.75s | sec_per_unit=6.2453
# 2026-04-17 11:13:55,138 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00029 | est_remaining_sec=125.16
# 2026-04-17 11:13:55,225 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00029
# 2026-04-17 11:13:57,098 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00029.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00029.npz
# 2026-04-17 11:14:01,773 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00029.npz
# 2026-04-17 11:14:01,817 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00029 | duration=6.59s | sec_per_unit=6.0943
# 2026-04-17 11:14:01,818 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00030 | est_remaining_sec=117.72
# 2026-04-17 11:14:01,912 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00030
# 2026-04-17 11:14:02,184 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00030.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00030.npz
# 2026-04-17 11:14:05,453 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00030.npz
# 2026-04-17 11:14:05,497 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00030 | duration=3.58s | sec_per_unit=3.3143
# 2026-04-17 11:14:05,497 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00031 | est_remaining_sec=108.93
# 2026-04-17 11:14:05,587 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00031
# 2026-04-17 11:14:05,681 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00031.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00031.npz
# 2026-04-17 11:14:09,060 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00031.npz
# 2026-04-17 11:14:09,104 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00031 | duration=3.52s | sec_per_unit=14.2079
# 2026-04-17 11:14:09,108 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00032 | est_remaining_sec=105.59
# 2026-04-17 11:14:09,196 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00032
# 2026-04-17 11:14:11,039 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00032.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00032.npz
# 2026-04-17 11:14:15,099 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00032.npz
# 2026-04-17 11:14:15,143 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00032 | duration=5.95s | sec_per_unit=5.5416
# 2026-04-17 11:14:15,144 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00033 | est_remaining_sec=97.91
# 2026-04-17 11:14:15,231 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00033
# 2026-04-17 11:14:17,349 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00033.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00033.npz
# 2026-04-17 11:14:22,000 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00033.npz
# 2026-04-17 11:14:22,044 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00033 | duration=6.81s | sec_per_unit=6.2993
# 2026-04-17 11:14:22,045 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00034 | est_remaining_sec=90.66
# 2026-04-17 11:14:22,133 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00034
# 2026-04-17 11:14:23,547 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00034.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00034.npz
# 2026-04-17 11:14:27,814 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00034.npz
# 2026-04-17 11:14:27,863 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00034 | duration=5.73s | sec_per_unit=5.2976
# 2026-04-17 11:14:27,864 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00035 | est_remaining_sec=83.11
# 2026-04-17 11:14:27,951 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00035
# 2026-04-17 11:14:28,797 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00035.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00035.npz
# 2026-04-17 11:14:33,628 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00035.npz
# 2026-04-17 11:14:33,672 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00035 | duration=5.72s | sec_per_unit=5.2897
# 2026-04-17 11:14:33,673 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00036 | est_remaining_sec=75.68
# 2026-04-17 11:14:33,760 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00036
# 2026-04-17 11:14:34,443 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00036.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00036.npz
# 2026-04-17 11:14:38,633 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00036.npz
# 2026-04-17 11:14:38,678 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00036 | duration=4.92s | sec_per_unit=4.5468
# 2026-04-17 11:14:38,678 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00037 | est_remaining_sec=68.17
# 2026-04-17 11:14:38,766 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00037
# 2026-04-17 11:14:39,351 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00037.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00037.npz
# 2026-04-17 11:14:43,073 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00037.npz
# 2026-04-17 11:14:43,117 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00037 | duration=4.35s | sec_per_unit=4.0228
# 2026-04-17 11:14:43,117 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00038 | est_remaining_sec=60.69
# 2026-04-17 11:14:43,211 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00038
# 2026-04-17 11:14:43,483 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00038.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00038.npz
# 2026-04-17 11:14:46,884 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00038.npz
# 2026-04-17 11:14:46,929 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00038 | duration=3.72s | sec_per_unit=3.4375
# 2026-04-17 11:14:46,929 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00039 | est_remaining_sec=53.27
# 2026-04-17 11:14:47,017 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00039
# 2026-04-17 11:14:47,112 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00039.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00039.npz
# 2026-04-17 11:14:50,320 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00039.npz
# 2026-04-17 11:14:50,366 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00039 | duration=3.35s | sec_per_unit=13.5309
# 2026-04-17 11:14:50,371 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00040 | est_remaining_sec=47.81
# 2026-04-17 11:14:50,458 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00040
# 2026-04-17 11:14:51,126 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00040.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00040.npz
# 2026-04-17 11:14:54,914 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00040.npz
# 2026-04-17 11:14:54,958 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00040 | duration=4.50s | sec_per_unit=16.5783
# 2026-04-17 11:14:54,958 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00041 | est_remaining_sec=42.41
# 2026-04-17 11:14:55,047 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00041
# 2026-04-17 11:14:55,659 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00041.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00041.npz
# 2026-04-17 11:14:59,420 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00041.npz
# 2026-04-17 11:14:59,465 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00041 | duration=4.42s | sec_per_unit=16.1511
# 2026-04-17 11:14:59,467 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00042 | est_remaining_sec=36.42
# 2026-04-17 11:14:59,554 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00042
# 2026-04-17 11:15:00,365 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00042.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00042.npz
# 2026-04-17 11:15:05,573 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00042.npz
# 2026-04-17 11:15:05,618 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00042 | duration=6.06s | sec_per_unit=22.1698
# 2026-04-17 11:15:05,619 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00043 | est_remaining_sec=30.52
# 2026-04-17 11:15:05,706 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00043
# 2026-04-17 11:15:05,805 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00043.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00043.npz
# 2026-04-17 11:15:09,022 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00043.npz
# 2026-04-17 11:15:09,083 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00043 | duration=3.38s | sec_per_unit=12.3471
# 2026-04-17 11:15:09,084 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00044 | est_remaining_sec=23.21
# 2026-04-17 11:15:09,171 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00044
# 2026-04-17 11:15:09,271 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00044.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00044.npz
# 2026-04-17 11:15:12,727 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00044.npz
# 2026-04-17 11:15:12,771 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00044 | duration=3.60s | sec_per_unit=13.1629
# 2026-04-17 11:15:12,772 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00045 | est_remaining_sec=15.72
# 2026-04-17 11:15:12,859 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00045
# 2026-04-17 11:15:12,959 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00045.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00045.npz
# 2026-04-17 11:15:16,798 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00045.npz
# 2026-04-17 11:15:16,845 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00045 | duration=3.99s | sec_per_unit=14.5729
# 2026-04-17 11:15:16,846 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00046 | est_remaining_sec=8.00
# 2026-04-17 11:15:16,933 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00046
# 2026-04-17 11:15:17,032 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00046.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00046.npz
# 2026-04-17 11:15:20,658 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00046.npz
# 2026-04-17 11:15:20,702 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00046 | duration=3.77s | sec_per_unit=13.7805
# 2026-04-17 11:15:20,703 | INFO     | features.notebook | SOURCE ETA | site=calaveras-big-trees | source=als | family=height_structure | chunk=chunk_00047 | est_remaining_sec=0.00
# 2026-04-17 11:15:20,791 | INFO     | features.notebook | START | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00047
# 2026-04-17 11:15:20,848 | INFO     | features.notebook | PUSH ARTIFACT | key=family_chunk_npz | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00047.npz
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00047.npz
# 2026-04-17 11:15:24,518 | INFO     | features.notebook | PRUNED LOCAL ARTIFACT | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/als/height_structure/chunk_00047.npz
# 2026-04-17 11:15:24,564 | INFO     | features.notebook | END   | stage=family_chunk_compute | site=calaveras-big-trees | source=als | family=height_structure:chunk_00047 | duration=3.77s | sec_per_unit=60.2821
# 2026-04-17 11:15:24,564 | INFO     | features.notebook | SOURCE FAMILY DONE | site=calaveras-big-trees | source=als | family=height_structure
# 2026-04-17 11:15:24,749 | INFO     | features.notebook | PUSH ARTIFACT | key=stack_registry | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/stack/stack_registry.json
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/4dfeca633c8d4b58/stack/stack_registry.json
# 2026-04-17 11:15:28,502 | INFO     | features.notebook | SOURCE CHUNKED RUN COMPLETE | site=calaveras-big-trees | source=als | registered_layers=480

# %%
print("ALS layers:", len(registry_als.layers))
display(stack_registry_frame(registry_als).head(30))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ALS layers: 480
#                 site_id source_name       family_name  \
# 0   calaveras-big-trees         als  height_structure
# 1   calaveras-big-trees         als  height_structure
# 2   calaveras-big-trees         als  height_structure
# 3   calaveras-big-trees         als  height_structure
# 4   calaveras-big-trees         als  height_structure
# 5   calaveras-big-trees         als  height_structure
# 6   calaveras-big-trees         als  height_structure
# 7   calaveras-big-trees         als  height_structure
# 8   calaveras-big-trees         als  height_structure
# 9   calaveras-big-trees         als  height_structure
# 10  calaveras-big-trees         als  height_structure
# 11  calaveras-big-trees         als  height_structure
# 12  calaveras-big-trees         als  height_structure
# 13  calaveras-big-trees         als  height_structure
# 14  calaveras-big-trees         als  height_structure
# 15  calaveras-big-trees         als  height_structure
# 16  calaveras-big-trees         als  height_structure
# 17  calaveras-big-trees         als  height_structure
# 18  calaveras-big-trees         als  height_structure
# 19  calaveras-big-trees         als  height_structure
# 20  calaveras-big-trees         als  height_structure
# 21  calaveras-big-trees         als  height_structure
# 22  calaveras-big-trees         als  height_structure
# 23  calaveras-big-trees         als  height_structure
# 24  calaveras-big-trees         als  height_structure
# 25  calaveras-big-trees         als  height_structure
# 26  calaveras-big-trees         als  height_structure
# 27  calaveras-big-trees         als  height_structure
# 28  calaveras-big-trees         als  height_structure
# 29  calaveras-big-trees         als  height_structure
#
#                                   layer_name  \
# 0                   als_chm_max::chunk_00000
# 1   als_distance_to_tall_canopy::chunk_00000
# 2               als_height_mean::chunk_00000
# 3                als_height_std::chunk_00000
# 4              als_local_relief::chunk_00000
# 5               als_point_count::chunk_00000
# 6               als_chm_gradmag::chunk_00000
# 7            als_chm_localstd_5::chunk_00000
# 8        als_gap_max_minus_mean::chunk_00000
# 9      als_point_density_blur_5::chunk_00000
# 10                  als_chm_max::chunk_00001
# 11  als_distance_to_tall_canopy::chunk_00001
# 12              als_height_mean::chunk_00001
# 13               als_height_std::chunk_00001
# 14             als_local_relief::chunk_00001
# 15              als_point_count::chunk_00001
# 16              als_chm_gradmag::chunk_00001
# 17           als_chm_localstd_5::chunk_00001
# 18       als_gap_max_minus_mean::chunk_00001
# 19     als_point_density_blur_5::chunk_00001
# 20                  als_chm_max::chunk_00002
# 21  als_distance_to_tall_canopy::chunk_00002
# 22              als_height_mean::chunk_00002
# 23               als_height_std::chunk_00002
# 24             als_local_relief::chunk_00002
# 25              als_point_count::chunk_00002
# 26              als_chm_gradmag::chunk_00002
# 27           als_chm_localstd_5::chunk_00002
# 28       als_gap_max_minus_mean::chunk_00002
# 29     als_point_density_blur_5::chunk_00002
#
#                                              rel_path  \
# 0   features/calaveras-big-trees/4dfeca633c8d4b58/...
# 1   features/calaveras-big-trees/4dfeca633c8d4b58/...
# 2   features/calaveras-big-trees/4dfeca633c8d4b58/...
# 3   features/calaveras-big-trees/4dfeca633c8d4b58/...
# 4   features/calaveras-big-trees/4dfeca633c8d4b58/...
# 5   features/calaveras-big-trees/4dfeca633c8d4b58/...
# 6   features/calaveras-big-trees/4dfeca633c8d4b58/...
# 7   features/calaveras-big-trees/4dfeca633c8d4b58/...
# 8   features/calaveras-big-trees/4dfeca633c8d4b58/...
# 9   features/calaveras-big-trees/4dfeca633c8d4b58/...
# 10  features/calaveras-big-trees/4dfeca633c8d4b58/...
# 11  features/calaveras-big-trees/4dfeca633c8d4b58/...
# 12  features/calaveras-big-trees/4dfeca633c8d4b58/...
# 13  features/calaveras-big-trees/4dfeca633c8d4b58/...
# 14  features/calaveras-big-trees/4dfeca633c8d4b58/...
# 15  features/calaveras-big-trees/4dfeca633c8d4b58/...
# 16  features/calaveras-big-trees/4dfeca633c8d4b58/...
# 17  features/calaveras-big-trees/4dfeca633c8d4b58/...
# 18  features/calaveras-big-trees/4dfeca633c8d4b58/...
# 19  features/calaveras-big-trees/4dfeca633c8d4b58/...
# 20  features/calaveras-big-trees/4dfeca633c8d4b58/...
# 21  features/calaveras-big-trees/4dfeca633c8d4b58/...
# 22  features/calaveras-big-trees/4dfeca633c8d4b58/...
# 23  features/calaveras-big-trees/4dfeca633c8d4b58/...
# 24  features/calaveras-big-trees/4dfeca633c8d4b58/...
# 25  features/calaveras-big-trees/4dfeca633c8d4b58/...
# 26  features/calaveras-big-trees/4dfeca633c8d4b58/...
# 27  features/calaveras-big-trees/4dfeca633c8d4b58/...
# 28  features/calaveras-big-trees/4dfeca633c8d4b58/...
# 29  features/calaveras-big-trees/4dfeca633c8d4b58/...
#
#                                            local_path  \
# 0   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 1   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 2   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 3   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 4   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 5   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 6   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 7   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 8   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 9   /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 10  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 11  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 12  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 13  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 14  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 15  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 16  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 17  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 18  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 19  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 20  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 21  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 22  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 23  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 24  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 25  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 26  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 27  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 28  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
# 29  /home/jovyan/work/Dry-shRub/shrub/Final/artifa...
#
#                            remote_ref  chunked    dtype         shape  \
# 0   1cpLX0VrvV3XiJ1WP0TwkSNgnm49knVRC     True  float32  (1024, 1024)
# 1   1cpLX0VrvV3XiJ1WP0TwkSNgnm49knVRC     True  float32  (1024, 1024)
# 2   1cpLX0VrvV3XiJ1WP0TwkSNgnm49knVRC     True  float32  (1024, 1024)
# 3   1cpLX0VrvV3XiJ1WP0TwkSNgnm49knVRC     True  float32  (1024, 1024)
# 4   1cpLX0VrvV3XiJ1WP0TwkSNgnm49knVRC     True  float32  (1024, 1024)
# 5   1cpLX0VrvV3XiJ1WP0TwkSNgnm49knVRC     True  float32  (1024, 1024)
# 6   1cpLX0VrvV3XiJ1WP0TwkSNgnm49knVRC     True  float32  (1024, 1024)
# 7   1cpLX0VrvV3XiJ1WP0TwkSNgnm49knVRC     True  float32  (1024, 1024)
# 8   1cpLX0VrvV3XiJ1WP0TwkSNgnm49knVRC     True  float32  (1024, 1024)
# 9   1cpLX0VrvV3XiJ1WP0TwkSNgnm49knVRC     True  float32  (1024, 1024)
# 10  1xsMIo26KOOo5OIA3pi8wK6JHcXGD7BHT     True  float32  (1024, 1024)
# 11  1xsMIo26KOOo5OIA3pi8wK6JHcXGD7BHT     True  float32  (1024, 1024)
# 12  1xsMIo26KOOo5OIA3pi8wK6JHcXGD7BHT     True  float32  (1024, 1024)
# 13  1xsMIo26KOOo5OIA3pi8wK6JHcXGD7BHT     True  float32  (1024, 1024)
# 14  1xsMIo26KOOo5OIA3pi8wK6JHcXGD7BHT     True  float32  (1024, 1024)
# 15  1xsMIo26KOOo5OIA3pi8wK6JHcXGD7BHT     True  float32  (1024, 1024)
# 16  1xsMIo26KOOo5OIA3pi8wK6JHcXGD7BHT     True  float32  (1024, 1024)
# 17  1xsMIo26KOOo5OIA3pi8wK6JHcXGD7BHT     True  float32  (1024, 1024)
# 18  1xsMIo26KOOo5OIA3pi8wK6JHcXGD7BHT     True  float32  (1024, 1024)
# 19  1xsMIo26KOOo5OIA3pi8wK6JHcXGD7BHT     True  float32  (1024, 1024)
# 20  16hGgzegi_SlqNf0Lnp-6BO5h797EvaIS     True  float32  (1024, 1024)
# 21  16hGgzegi_SlqNf0Lnp-6BO5h797EvaIS     True  float32  (1024, 1024)
# 22  16hGgzegi_SlqNf0Lnp-6BO5h797EvaIS     True  float32  (1024, 1024)
# 23  16hGgzegi_SlqNf0Lnp-6BO5h797EvaIS     True  float32  (1024, 1024)
# 24  16hGgzegi_SlqNf0Lnp-6BO5h797EvaIS     True  float32  (1024, 1024)
# 25  16hGgzegi_SlqNf0Lnp-6BO5h797EvaIS     True  float32  (1024, 1024)
# 26  16hGgzegi_SlqNf0Lnp-6BO5h797EvaIS     True  float32  (1024, 1024)
# 27  16hGgzegi_SlqNf0Lnp-6BO5h797EvaIS     True  float32  (1024, 1024)
# 28  16hGgzegi_SlqNf0Lnp-6BO5h797EvaIS     True  float32  (1024, 1024)
# 29  16hGgzegi_SlqNf0Lnp-6BO5h797EvaIS     True  float32  (1024, 1024)
#
#                                                 notes
# 0   [chunk_00000, Local artifact pruned after veri...
# 1   [chunk_00000, Local artifact pruned after veri...
# 2   [chunk_00000, Local artifact pruned after veri...
# 3   [chunk_00000, Local artifact pruned after veri...
# 4   [chunk_00000, Local artifact pruned after veri...
# 5   [chunk_00000, Local artifact pruned after veri...
# 6   [chunk_00000, Local artifact pruned after veri...
# 7   [chunk_00000, Local artifact pruned after veri...
# 8   [chunk_00000, Local artifact pruned after veri...
# 9   [chunk_00000, Local artifact pruned after veri...
# 10  [chunk_00001, Local artifact pruned after veri...
# 11  [chunk_00001, Local artifact pruned after veri...
# 12  [chunk_00001, Local artifact pruned after veri...
# 13  [chunk_00001, Local artifact pruned after veri...
# 14  [chunk_00001, Local artifact pruned after veri...
# 15  [chunk_00001, Local artifact pruned after veri...
# 16  [chunk_00001, Local artifact pruned after veri...
# 17  [chunk_00001, Local artifact pruned after veri...
# 18  [chunk_00001, Local artifact pruned after veri...
# 19  [chunk_00001, Local artifact pruned after veri...
# 20  [chunk_00002, Local artifact pruned after veri...
# 21  [chunk_00002, Local artifact pruned after veri...
# 22  [chunk_00002, Local artifact pruned after veri...
# 23  [chunk_00002, Local artifact pruned after veri...
# 24  [chunk_00002, Local artifact pruned after veri...
# 25  [chunk_00002, Local artifact pruned after veri...
# 26  [chunk_00002, Local artifact pruned after veri...
# 27  [chunk_00002, Local artifact pruned after veri...
# 28  [chunk_00002, Local artifact pruned after veri...
# 29  [chunk_00002, Local artifact pruned after veri...

# %%
def run_als_all_sites(
    *,
    force_refresh_assets: bool = False,
    force_refresh_source: bool = False,
) -> dict[str, Any]:
    out: dict[str, Any] = {}

    for site_id in fe_cfg.sites:
        LOGGER.info("=" * 80)
        LOGGER.info("RUN ALS ALL SITES | site=%s", site_id)

        try:
            site_assets = prepare_site_assets(
                site_id,
                force_refresh=force_refresh_assets,
            )

            if site_assets.source_assets.get("naip") is None:
                raise RuntimeError(f"NAIP unavailable for site={site_id}")

            als_meta = site_assets.source_assets.get("als_metadata", [])
            if not als_meta:
                raise RuntimeError(f"ALS metadata unavailable for site={site_id}")

            canonical_grid = build_canonical_grid_for_site(
                site_id,
                assets=site_assets,
                force_refresh=fe_cfg.force_refresh_features,
            )

            chunk_manifest = build_chunk_manifest(
                canonical_grid,
                force_refresh=fe_cfg.force_rebuild_chunk_manifest,
            )

            # NAIP only needed to anchor canonical space.
            naip_asset = site_assets.source_assets.get("naip")
            if naip_asset is not None:
                maybe_prune_local_site_naip_after_grid_build(site_id, naip_asset)

            registry = run_als_chunked_pipeline(
                site_id,
                site_assets=site_assets,
                canonical_grid=canonical_grid,
                chunk_manifest=chunk_manifest,
                registry=RasterStackRegistry(
                    site_id=site_id,
                    config_signature=fe_config_signature(),
                    layers=[],
                ),
            )

            out[site_id] = {
                "status": "success",
                "registry": registry,
                "notes": list(site_assets.notes),
            }

        except Exception as e:
            LOGGER.warning("RUN ALS ALL SITES FAILED | site=%s | err=%s", site_id, e)
            out[site_id] = {
                "status": "failed",
                "registry": None,
                "notes": [str(e)],
            }

        finally:
            try:
                clear_artifact_staging_dir()
            except Exception as e:
                LOGGER.warning("Failed clearing artifact staging after ALS site run | site=%s | err=%s", site_id, e)

    return out
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
als_runs = run_als_all_sites(
    force_refresh_assets=False,
    force_refresh_source=False,
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 2026-04-17 11:15:28,540 | INFO     | features.notebook | ================================================================================
# 2026-04-17 11:15:28,541 | INFO     | features.notebook | RUN ALS ALL SITES | site=calaveras-big-trees
# 2026-04-17 11:15:28,541 | INFO     | features.notebook | START | stage=site_assets | site=calaveras-big-trees | source=None | family=None
# 2026-04-17 11:15:28,542 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=site_metadata_manifest | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/site_assets/site_metadata_manifest.json
# 2026-04-17 11:15:28,544 | INFO     | features.notebook | Using site metadata manifest | site=calaveras-big-trees
# 2026-04-17 11:15:28,544 | INFO     | features.notebook | LOAD ARTIFACT (local) | key=source_inventory | rel_path=features/calaveras-big-trees/4dfeca633c8d4b58/site_assets/source_inventory.json
# 2026-04-17 11:15:28,545 | INFO     | features.notebook | Using cached source inventory | site=calaveras-big-trees
# 2026-04-17 11:15:28,596 | INFO     | features.notebook | Prepared site assets from enriched manifest reuse (no manifest changes) | site=calaveras-big-trees | keys=['naip', 'als_metadata', '3dep', 'rap', 'source_inventory'] | notes=0
# 2026-04-17 11:15:28,597 | INFO     | features.notebook | END   | stage=site_assets | site=calaveras-big-trees | source=None | family=None | duration=0.06s
# 2026-04-17 11:15:28,688 | INFO     | features.notebook | Using cached canonical grid | site=calaveras-big-trees
# 2026-04-17 11:15:28,689 | INFO     | features.notebook | Using cached chunk manifest | site=calaveras-big-trees | n_chunks=48
# 2026-04-17 11:15:28,733 | INFO     | features.notebook | Pruned local NAIP site asset after canonical grid build | site=calaveras-big-trees | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/site_assets/calaveras-big-trees/naip/calaveras_big_trees.tif
# 2026-04-17 11:15:28,736 | INFO     | features.notebook | Built ALS tile inventory | rows=10
# 2026-04-17 11:15:32,964 | INFO     | features.notebook | Downloaded ALS tile | site=calaveras-big-trees | tile=USGS_LPC_CA_SierraNevada_B22_10SGH3935.laz | attempt=1 | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/notebook_cache/als_structural_rasters/calaveras-big-trees/raw_tiles/USGS_LPC_CA_SierraNevada_B22_10SGH3935.laz

# %%
als_summary_rows = []
for site_id, payload in als_runs.items():
    registry = payload["registry"]
    als_summary_rows.append(
        {
            "site_id": site_id,
            "status": payload["status"],
            "n_layers": 0 if registry is None else len(registry.layers),
            "notes": " | ".join(payload["notes"]),
        }
    )

als_summary_df = pd.DataFrame(als_summary_rows)
display(als_summary_df)

# %% [markdown]
# # Multi-source runner

# %%
def run_multisource_fe_notebook_pipeline(
    site_id: str,
    *,
    include_naip: bool = True,
    include_3dep: bool = False,
    include_rap: bool = False,
    include_als: bool = False,
    rebuild_registry: bool = True,
    force_refresh_assets: bool | None = None,
    force_refresh_features: bool | None = None,
    force_refresh_source: bool = False,
) -> dict[str, Any]:
    force_refresh_assets = fe_cfg.force_refresh_assets if force_refresh_assets is None else force_refresh_assets
    force_refresh_features = fe_cfg.force_refresh_features if force_refresh_features is None else force_refresh_features

    site_assets = prepare_site_assets(site_id, force_refresh=force_refresh_assets)

    canonical_grid = build_canonical_grid_for_site(
        site_id,
        assets=site_assets,
        force_refresh=force_refresh_features,
    )

    chunk_manifest = build_chunk_manifest(
        canonical_grid,
        force_refresh=fe_cfg.force_rebuild_chunk_manifest,
    )

    # Canonical space is now cached; local NAIP can be pruned aggressively.
    naip_asset = site_assets.source_assets.get("naip")
    if naip_asset is not None:
        maybe_prune_local_site_naip_after_grid_build(site_id, naip_asset)

    registry = (
        RasterStackRegistry(
            site_id=site_id,
            config_signature=fe_config_signature(),
            layers=[],
        )
        if rebuild_registry
        else load_or_init_stack_registry(site_id, fe_config_signature())
    )

    source_results: dict[str, dict[str, Any]] = {}
    executed_sources: list[str] = []

    def _run_source(source_name: str, fn):
        nonlocal registry
        LOGGER.info("=" * 80)
        LOGGER.info("RUN MULTISOURCE FE | site=%s | source=%s", site_id, source_name)

        try:
            registry = fn(registry)
            source_results[source_name] = {
                "status": "success",
                "n_layers_after": len(registry.layers),
                "notes": [],
            }
            executed_sources.append(source_name)
        except Exception as e:
            LOGGER.warning(
                "RUN MULTISOURCE FE SOURCE FAILED | site=%s | source=%s | err=%s",
                site_id, source_name, e
            )
            source_results[source_name] = {
                "status": "failed",
                "n_layers_after": len(registry.layers),
                "notes": [str(e)],
            }
        finally:
            try:
                clear_artifact_staging_dir()
            except Exception as e:
                LOGGER.warning(
                    "Failed clearing artifact staging after multisource source run | site=%s | source=%s | err=%s",
                    site_id, source_name, e
                )

    if include_naip:
        _run_source(
            "naip",
            lambda reg: run_naip_chunked_pipeline(
                site_id,
                assets=site_assets,
                grid=canonical_grid,
                chunk_manifest=chunk_manifest,
                rebuild_registry=False,
                registry=reg,
            )
        )

    if include_3dep:
        _run_source(
            "3dep",
            lambda reg: run_3dep_chunked_pipeline(
                site_id,
                site_assets=site_assets,
                canonical_grid=canonical_grid,
                chunk_manifest=chunk_manifest,
                registry=reg,
                force_refresh_source=force_refresh_source,
            )
        )

    if include_rap:
        _run_source(
            "rap",
            lambda reg: run_rap_chunked_pipeline(
                site_id,
                site_assets=site_assets,
                canonical_grid=canonical_grid,
                chunk_manifest=chunk_manifest,
                registry=reg,
                force_refresh_source=force_refresh_source,
            )
        )

    if include_als:
        _run_source(
            "als",
            lambda reg: run_als_chunked_pipeline(
                site_id,
                site_assets=site_assets,
                canonical_grid=canonical_grid,
                chunk_manifest=chunk_manifest,
                registry=reg,
            )
        )

    registry = deduplicate_stack_registry(registry)
    stack_rec = save_stack_registry(registry)

    return {
        "site_id": site_id,
        "executed_sources": executed_sources,
        "source_results": source_results,
        "site_assets": site_assets,
        "canonical_grid": canonical_grid,
        "chunk_manifest": chunk_manifest,
        "stack_registry": registry,
        "stack_registry_artifact": stack_rec,
    }

# %%
TEST_SITE = fe_cfg.sites[0]

multisource_run = run_multisource_fe_notebook_pipeline(
    TEST_SITE,
    include_naip=True,
    include_3dep=True,
    include_rap=True,
    include_als=True,
    rebuild_registry=True,
    force_refresh_assets=False,
    force_refresh_features=False,
    force_refresh_source=False,
)

# %%
print("Executed sources:", multisource_run["executed_sources"])
display(pd.DataFrame(multisource_run["source_results"]).T)
display(stack_registry_frame(multisource_run["stack_registry"]).head(30))
print("Total registered layers:", len(multisource_run["stack_registry"].layers))

# %%
def run_multisource_fe_all_sites(
    *,
    include_naip: bool = True,
    include_3dep: bool = True,
    include_rap: bool = True,
    include_als: bool = True,
    rebuild_registry: bool = True,
    force_refresh_assets: bool | None = None,
    force_refresh_features: bool | None = None,
    force_refresh_source: bool = False,
) -> dict[str, Any]:
    out: dict[str, Any] = {}

    for site_id in fe_cfg.sites:
        LOGGER.info("=" * 100)
        LOGGER.info("RUN MULTISOURCE FE ALL SITES | site=%s", site_id)

        try:
            run_payload = run_multisource_fe_notebook_pipeline(
                site_id,
                include_naip=include_naip,
                include_3dep=include_3dep,
                include_rap=include_rap,
                include_als=include_als,
                rebuild_registry=rebuild_registry,
                force_refresh_assets=force_refresh_assets,
                force_refresh_features=force_refresh_features,
                force_refresh_source=force_refresh_source,
            )
            out[site_id] = {
                "status": "success",
                **run_payload,
            }
        except Exception as e:
            LOGGER.warning("RUN MULTISOURCE FE ALL SITES FAILED | site=%s | err=%s", site_id, e)
            out[site_id] = {
                "status": "failed",
                "site_id": site_id,
                "executed_sources": [],
                "source_results": {},
                "stack_registry": None,
                "notes": [str(e)],
            }
        finally:
            try:
                clear_artifact_staging_dir()
            except Exception:
                pass

    return out

# %%
all_multisource_runs = run_multisource_fe_all_sites(
    include_naip=True,
    include_3dep=True,
    include_rap=True,
    include_als=True,
    rebuild_registry=True,
    force_refresh_assets=False,
    force_refresh_features=False,
    force_refresh_source=False,
)

# %%
multi_summary_rows = []
for site_id, payload in all_multisource_runs.items():
    reg = payload.get("stack_registry")
    multi_summary_rows.append(
        {
            "site_id": site_id,
            "status": payload["status"],
            "executed_sources": ", ".join(payload.get("executed_sources", [])),
            "n_layers": 0 if reg is None else len(reg.layers),
        }
    )

display(pd.DataFrame(multi_summary_rows))

# %% [markdown]
# # Aggregation

# %%
def build_modeling_ready_feature_views(
    registry: RasterStackRegistry,
    *,
    site_id: str,
    canonical_grid: CanonicalGrid,
    chunk_manifest: ChunkManifest,
    objects_df: pd.DataFrame,
    pixel_layer_names: Iterable[str] | None = None,
    object_layer_names: Iterable[str] | None = None,
) -> dict[str, Any]:
    selection = modeling_stack_layer_selection(registry)

    pixel_layer_names = list(pixel_layer_names) if pixel_layer_names is not None else selection["pixel_layers"]
    object_layer_names = list(object_layer_names) if object_layer_names is not None else selection["object_layers"]

    assembled_pixel_layers = assemble_selected_layers(
        registry,
        chunk_manifest,
        canonical_grid,
        base_layer_names=pixel_layer_names,
    )

    object_feature_df = aggregate_selected_registered_layers_to_objects(
        registry,
        site_id=site_id,
        canonical_grid=canonical_grid,
        chunk_manifest=chunk_manifest,
        objects_df=objects_df,
        base_layer_names=object_layer_names,
    )

    return {
        "site_id": site_id,
        "pixel_layer_names": pixel_layer_names,
        "object_layer_names": object_layer_names,
        "assembled_pixel_layers": assembled_pixel_layers,
        "object_feature_df": object_feature_df,
    }

# %%
def persist_modeling_view_manifest(
    *,
    site_id: str,
    pixel_layer_names: list[str],
    object_layer_names: list[str],
    object_feature_shape: tuple[int, int],
) -> PersistedArtifactRecord:
    payload = {
        "site_id": site_id,
        "config_signature": current_fe_config_signature(),
        "pixel_layer_names": pixel_layer_names,
        "object_layer_names": object_layer_names,
        "object_feature_shape": list(object_feature_shape),
    }
    return persist_json_artifact(
        payload,
        artifact_key="runtime_log",  # replace with dedicated spec later if you add one
        site_id=site_id,
    )

# %%
TEST_SITE = fe_cfg.sites[0]

run_payload = run_multisource_fe_notebook_pipeline(
    TEST_SITE,
    include_naip=True,
    include_3dep=True,
    include_rap=True,
    include_als=True,
    rebuild_registry=True,
)

# %%
site_objects = label_objects_for_site(TEST_SITE)

model_views = build_modeling_ready_feature_views(
    run_payload["stack_registry"],
    site_id=TEST_SITE,
    canonical_grid=run_payload["canonical_grid"],
    chunk_manifest=run_payload["chunk_manifest"],
    objects_df=site_objects,
)

# %%
print("Assembled pixel layers:", len(model_views["assembled_pixel_layers"]))
print("Object feature table shape:", model_views["object_feature_df"].shape)

display(pd.Series(sorted(model_views["assembled_pixel_layers"].keys())).to_frame("pixel_layer"))
display(model_views["object_feature_df"].head(10))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 2026-04-16 02:38:58,478 | INFO     | features.notebook | START | stage=stack_assemble | site=calaveras-big-trees | source=assembled_stack | family=naip_idx_ndvi
# 2026-04-16 02:39:00,422 | INFO     | features.notebook | END   | stage=stack_assemble | site=calaveras-big-trees | source=assembled_stack | family=naip_idx_ndvi | duration=1.94s | sec_per_unit=0.0489
# 2026-04-16 02:39:00,455 | INFO     | features.notebook | START | stage=stack_assemble | site=calaveras-big-trees | source=assembled_stack | family=naip_tex_gradmag
# 2026-04-16 02:39:03,759 | INFO     | features.notebook | END   | stage=stack_assemble | site=calaveras-big-trees | source=assembled_stack | family=naip_tex_gradmag | duration=3.30s | sec_per_unit=0.0831
# 2026-04-16 02:39:03,759 | INFO     | features.notebook | START | stage=object_aggregation | site=calaveras-big-trees | source=naip | family=None
# 2026-04-16 02:39:03,767 | INFO     | features.notebook | END   | stage=object_aggregation | site=calaveras-big-trees | source=naip | family=None | duration=0.01s | sec_per_unit=0.0002
# 2026-04-16 02:39:03,767 | INFO     | features.notebook | OBJECT AGG DONE | site=calaveras-big-trees | n_objects=36 | n_rows=36 | n_cols=16
# Object feature preview shape: (36, 16)
#                site_id  object_id                plot_id   row   col  \
# 0  calaveras-big-trees          1  CATCU_0009_20250615_1  1142  6601
# 1  calaveras-big-trees          2  CATCU_0009_20250615_1  1138  6601
# 2  calaveras-big-trees          3  CATCU_0009_20250615_1  1132  6603
# 3  calaveras-big-trees          4  CATCU_0009_20250615_1  1160  6610
# 4  calaveras-big-trees          5  CATCU_0009_20250615_1  1149  6609
#
#    valid_sample  naip_idx_ndvi__centroid  naip_idx_ndvi__mean  \
# 0          True                 0.333333             0.382695
# 1          True                 0.447059             0.420429
# 2          True                 0.482143             0.459324
# 3          True                -0.050505             0.082980
# 4          True                 0.478261             0.513365
#
#    naip_idx_ndvi__std  naip_idx_ndvi__min  naip_idx_ndvi__max  \
# 0            0.066159            0.270588            0.525773
# 1            0.045759            0.302752            0.497717
# 2            0.055235            0.289340            0.573529
# 3            0.191337           -0.126984            0.489796
# 4            0.037535            0.443299            0.602041
#
#    naip_tex_gradmag__centroid  naip_tex_gradmag__mean  naip_tex_gradmag__std  \
# 0                   17.867569               25.453485              10.854493
# 1                   42.361538               23.354887              15.017296
# 2                   10.000000               20.300701              14.768600
# 3                    6.500000               19.293486              10.056414
# 4                   13.038404               17.405663               9.317881
#
#    naip_tex_gradmag__min  naip_tex_gradmag__max
# 0               2.236068              43.176960
# 1               2.236068              58.806889
# 2               3.500000              56.402573
# 3               1.414214              36.173195
# 4               5.000000              35.415394

# %%
site_objects = label_objects_for_site(TEST_SITE)

obj_df, obj_rec = build_and_persist_object_feature_table(
    naip_stack_registry,
    site_id=TEST_SITE,
    canonical_grid=canonical_grid,
    chunk_manifest=chunk_manifest,
    objects_df=site_objects,
    source_name="naip",
    family_names=["veg_idx", "texture"],
    base_layer_names=["naip_idx_ndvi", "naip_tex_gradmag"],
)

print(obj_df.shape)
print(obj_rec)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 2026-04-16 02:38:49,341 | INFO     | features.notebook | label_objects_for_site | requested=calaveras-big-trees | matched_rows=36 | unique_sites=['calaveras-big-trees', 'dl-bliss', 'independence-lake', 'pacific-union-college', 'sedgwick', 'shaver-lake']
# 2026-04-16 02:38:49,389 | INFO     | features.notebook | START | stage=stack_assemble | site=calaveras-big-trees | source=assembled_stack | family=naip_idx_ndvi
# 2026-04-16 02:38:51,368 | INFO     | features.notebook | END   | stage=stack_assemble | site=calaveras-big-trees | source=assembled_stack | family=naip_idx_ndvi | duration=1.98s | sec_per_unit=0.0497
# 2026-04-16 02:38:51,402 | INFO     | features.notebook | START | stage=stack_assemble | site=calaveras-big-trees | source=assembled_stack | family=naip_tex_gradmag
# 2026-04-16 02:38:54,691 | INFO     | features.notebook | END   | stage=stack_assemble | site=calaveras-big-trees | source=assembled_stack | family=naip_tex_gradmag | duration=3.29s | sec_per_unit=0.0827
# 2026-04-16 02:38:54,692 | INFO     | features.notebook | START | stage=object_aggregation | site=calaveras-big-trees | source=naip | family=None
# 2026-04-16 02:38:54,699 | INFO     | features.notebook | END   | stage=object_aggregation | site=calaveras-big-trees | source=naip | family=None | duration=0.01s | sec_per_unit=0.0002
# 2026-04-16 02:38:54,700 | INFO     | features.notebook | OBJECT AGG DONE | site=calaveras-big-trees | n_objects=36 | n_rows=36 | n_cols=16
# 2026-04-16 02:38:54,805 | INFO     | features.notebook | PUSH ARTIFACT | key=object_feature_table | rel_path=features/calaveras-big-trees/91fef1517fca02cc/objects/object_features.csv
# [artifact_store] Creating new Drive artifact for features/calaveras-big-trees/91fef1517fca02cc/objects/object_features.csv
# 2026-04-16 02:38:58,427 | INFO     | features.notebook | Persisted object feature table | site=calaveras-big-trees | path=/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/artifact_store_local/features/calaveras-big-trees/91fef1517fca02cc/objects/object_features.csv
# (36, 16)
# PersistedArtifactRecord(artifact_key='object_feature_table', rel_path='features/calaveras-big-trees/91fef1517fca02cc/objects/object_features.csv', local_path='/home/jovyan/work/Dry-shRub/shrub/Final/artifacts/features/artifact_store_local/features/calaveras-big-trees/91fef1517fca02cc/objects/object_features.csv', remote_ref='1Xz0rVTsowt0nmEvuaho61tIYcMyy-Qz-', storage_tier='local_then_remote', exists_local=True, exists_remote=True, pruned_local=False, notes=[])
