# %% [markdown]
# # Setup

# %%
#!pip install -r requirements.txt

# %%
from pathlib import Path
import tempfile
import pandas as pd
import numpy as np
import sys
import json
import rasterio
from rasterio.windows import Window
from requests import HTTPError

repo_root = Path.cwd().resolve().parents[1]
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from Final.shared_utils import setup_logging, tail_text_file
from Final.config import default_config
from Final.paths import PROJECT_ROOT, FINAL_ROOT, SPRINT3_BASE_ROOT, LABELING_ROOT

from Final.labeling.sprint3_runner import (
    discover_remote_ptx_files_for_site,
    download_ptx_with_cache,
    run_sprint3_for_ptx,
    append_results_manifest,
    sprint3_results_to_frame,
    summarize_ptx_entries_by_site, 
    select_ptx_entries,
    cleanup_stale_ptx_cache,
    cleanup_ptx_file,
)
from Final.labeling.sprint3_standardize import (
    build_local_sprint3_manifest,
    standardize_sprint3_manifest,
    standardize_sprint3_directory,
    summarize_objects,
)
from Final.labeling.object_refinement import refine_shrub_objects
from Final.labeling.transforms import transform_objects_to_als, shrub_csv_to_transform_name
from Final.labeling.alignment import align_objects_to_naip
from Final.labeling.rasterize import (
    rasterize_objects,
    resample_single_band,
    write_single_band_geotiff,
)
from Final.labeling.dedup import deduplicate_artifact_table, extract_plot_key
from Final.labeling.qa import create_overlay_figure
from Final.labeling.export import export_table
from Final.labeling.io import download_file, extract_als_metadata
from Final.labeling.manifests import (
    cleanup_path,
    list_files_with_suffix,
    site_to_remote_base,
    site_to_tif_name,
)

cfg = default_config(repo_root / 'Final' / 'artifacts')
cfg.debug = True

logger = setup_logging(
    name="shrub",
    log_dir=cfg.output.logs_root,
    log_filename="labeling_pipeline.log",
    force=True,
)

logger.info("PROJECT_ROOT = %s", cfg.data.project_root)
logger.info("SPRINT3_BASE_DIR = %s", cfg.data.sprint3_base_dir)
logger.info("LABELING_ROOT = %s", LABELING_ROOT)
# Out:
# 2026-04-09 22:45:57 | INFO     | shrub | PROJECT_ROOT = /home/jovyan/work/Dry-shRub/shrub
# 2026-04-09 22:45:57 | INFO     | shrub | SPRINT3_BASE_DIR = /home/jovyan/work/Dry-shRub/shrub/Sprint 3/Base
# 2026-04-09 22:45:57 | INFO     | shrub | LABELING_ROOT = /home/jovyan/work/Dry-shRub/shrub/Final/labeling

# %% [markdown]
# # Run Sprint 3 (InteLLiMon)
#
# Generate shrub lists and other metrics from TLS scans

# %%
MAX_PTX_PER_SITE = cfg.labeling.max_ptx_per_site
SPRINT3_VARIANTS = tuple(cfg.labeling.sprint3_variants)

SPRINT3_OUTPUT_ROOT = cfg.output.labeling_root
SPRINT3_CACHE_ROOT = cfg.output.labeling_root / "ptx_cache"
SPRINT3_MANIFEST_CSV = cfg.output.labeling_root / "manifests" / cfg.labeling.sprint3_manifest_name

SPRINT3_OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)
SPRINT3_CACHE_ROOT.mkdir(parents=True, exist_ok=True)
SPRINT3_MANIFEST_CSV.parent.mkdir(parents=True, exist_ok=True)

logger.info("Sprint 3 output root: %s", SPRINT3_OUTPUT_ROOT)
logger.info("Sprint 3 PTX cache root: %s", SPRINT3_CACHE_ROOT)
logger.info("Sprint 3 manifest CSV: %s", SPRINT3_MANIFEST_CSV)
logger.info("Sprint 3 variants: %s", SPRINT3_VARIANTS)
logger.info("MAX_PTX_PER_SITE: %s", MAX_PTX_PER_SITE)
# Out:
# 2026-04-09 19:58:24 | INFO     | shrub | Sprint 3 output root: /home/jovyan/work/Dry-shRub/shrub/Final/artifacts/labeling
# 2026-04-09 19:58:24 | INFO     | shrub | Sprint 3 PTX cache root: /home/jovyan/work/Dry-shRub/shrub/Final/artifacts/labeling/ptx_cache
# 2026-04-09 19:58:24 | INFO     | shrub | Sprint 3 manifest CSV: /home/jovyan/work/Dry-shRub/shrub/Final/artifacts/labeling/manifests/sprint3_runs.csv
# 2026-04-09 19:58:24 | INFO     | shrub | Sprint 3 variants: ('original', 'revised')
# 2026-04-09 19:58:24 | INFO     | shrub | MAX_PTX_PER_SITE: 1

# %%
if cfg.labeling.cleanup_stale_ptx_before_run:
    stale_removed_df = cleanup_stale_ptx_cache(
        cache_root=SPRINT3_CACHE_ROOT,
        stale_days=cfg.labeling.stale_ptx_days,
    )
    if not stale_removed_df.empty:
        display(stale_removed_df)

ptx_summary_df = summarize_ptx_entries_by_site(
    cfg=cfg,
    site_ids=cfg.sites,
)

display(ptx_summary_df)
# Out:
# 2026-04-09 18:38:35 | INFO     | shrub.labeling.sprint3_runner | Discovering remote PTX files for site=calaveras-big-trees at https://wifire-data.sdsc.edu/nc/public.php/dav/files/ucca-calaveras-big-trees/original_TLS
# 2026-04-09 18:38:36 | INFO     | shrub.labeling.sprint3_runner | Discovering remote PTX files for site=dl-bliss at https://wifire-data.sdsc.edu/nc/public.php/dav/files/ucca-dl-bliss/original_TLS
# 2026-04-09 18:38:37 | INFO     | shrub.labeling.sprint3_runner | Discovering remote PTX files for site=independence-lake at https://wifire-data.sdsc.edu/nc/public.php/dav/files/ucca-independence-lake/original_TLS
# 2026-04-09 18:38:37 | INFO     | shrub.labeling.sprint3_runner | Discovering remote PTX files for site=pacific-union-college at https://wifire-data.sdsc.edu/nc/public.php/dav/files/ucca-pacific-union-college/original_TLS
# ...

# %%
selected_ptx_df = select_ptx_entries(
    ptx_summary_df,
    max_ptx_per_site=MAX_PTX_PER_SITE,
)

print(f"Selected up to {MAX_PTX_PER_SITE} PTX file(s) per site")
display(selected_ptx_df)
# Out:
# Selected up to 1 PTX file(s) per site
#                  site_id                   ptx_name  \
# 0    calaveras-big-trees  CATCU_0009_20250615_1.ptx
# 1               dl-bliss  CAAEU_0027_20250728_1.ptx
# 2      independence-lake  CATNF_6118_20250820_1.ptx
# 3  pacific-union-college  CALNU_0039_20250810_1.ptx
# 4               sedgwick  CASBC_0087_20250712_1.ptx
# 5            shaver-lake  CAFKU_0096_20240804_1.ptx
#
#                                              ptx_url date_token       date  \
# 0  https://wifire-data.sdsc.edu/nc/public.php/dav...   20250615 2025-06-15
# 1  https://wifire-data.sdsc.edu/nc/public.php/dav...   20250728 2025-07-28
# 2  https://wifire-data.sdsc.edu/nc/public.php/dav...   20250820 2025-08-20
# 3  https://wifire-data.sdsc.edu/nc/public.php/dav...   20250810 2025-08-10
# 4  https://wifire-data.sdsc.edu/nc/public.php/dav...   20250712 2025-07-12
# 5  https://wifire-data.sdsc.edu/nc/public.php/dav...   20240804 2024-08-04
#
# ...

# %%
if not ptx_summary_df.empty:
    site_ptx_summary = (
        ptx_summary_df.assign(has_ptx=ptx_summary_df["ptx_name"].notna())
        .groupby("site_id", dropna=False)
        .agg(
            n_discovered=("has_ptx", "sum"),
            latest_date=("date", "max"),
            earliest_date=("date", "min"),
        )
        .reset_index()
        .sort_values("site_id")
    )
    display(site_ptx_summary)
else:
    print("No PTX discovery results available.")
# Out:
#                  site_id  n_discovered latest_date earliest_date
# 0    calaveras-big-trees           109  2025-06-15    2024-09-23
# 1               dl-bliss            27  2025-07-28    2025-07-21
# 2      independence-lake            57  2025-08-20    2024-07-30
# 3  pacific-union-college            54  2025-08-10    2024-11-07
# 4               sedgwick           119  2025-07-12    2024-09-10
# 5            shaver-lake            25  2024-08-04    2024-07-16

# %%
all_results = []

for _, row in selected_ptx_df.iterrows():
    site = row["site_id"]
    ptx_entry = {
        "name": row["ptx_name"],
        "url": row["ptx_url"],
    }

    local_ptx = None
    all_variants_ok = True

    try:
        local_ptx = download_ptx_with_cache(
            site_id=site,
            ptx_entry=ptx_entry,
            cache_root=SPRINT3_CACHE_ROOT,
        )
    except Exception:
        logger.exception("Failed to download PTX for site=%s entry=%s", site, ptx_entry)
        continue

    for variant in SPRINT3_VARIANTS:
        logger.info(
            "Starting Sprint 3 | site=%s | variant=%s | ptx=%s",
            site,
            variant,
            local_ptx.name,
        )
        try:
            result = run_sprint3_for_ptx(
                site_id=site,
                ptx_path=local_ptx,
                sprint3_base_dir=cfg.data.sprint3_base_dir,
                output_root=SPRINT3_OUTPUT_ROOT,
                variant=variant,
                raise_on_error=True,
                force_rerun=cfg.labeling.sprint3_force_rerun,
                require_success_artifacts=cfg.labeling.sprint3_require_success_artifacts,
            )
            all_results.append(result)
            append_results_manifest(SPRINT3_MANIFEST_CSV, [result])

            logger.info(
                "Completed Sprint 3 | site=%s | variant=%s | ptx=%s | cache=%s",
                site,
                variant,
                local_ptx.name,
                result.used_cache,
            )

        except Exception:
            all_variants_ok = False
            logger.exception(
                "Sprint 3 failed | site=%s | variant=%s | ptx=%s",
                site,
                variant,
                local_ptx.name,
            )

    if (
        local_ptx is not None
        and cfg.labeling.cleanup_ptx_after_all_variants
        and all_variants_ok
    ):
        cleanup_ptx_file(local_ptx)

if len(all_results) > 0:
    sprint3_results_df = sprint3_results_to_frame(all_results)
else:
    sprint3_results_df = (
        pd.read_csv(SPRINT3_MANIFEST_CSV)
        if SPRINT3_MANIFEST_CSV.exists()
        else pd.DataFrame()
    )

display(sprint3_results_df)
# Out:
# 2026-04-09 18:11:55 | INFO     | shrub.labeling.sprint3_runner | Downloading PTX for site=calaveras-big-trees from https://wifire-data.sdsc.edu/nc/public.php/dav/files/ucca-calaveras-big-trees/original_TLS/CATCU_0009_20250615_1.ptx
# 2026-04-09 18:12:07 | INFO     | shrub.labeling.sprint3_runner | Downloaded PTX to /home/jovyan/work/Dry-shRub/shrub/Final/artifacts/labeling/ptx_cache/calaveras-big-trees/CATCU_0009_20250615_1.ptx
# 2026-04-09 18:12:07 | INFO     | shrub | Starting Sprint 3 | site=calaveras-big-trees | variant=original | ptx=CATCU_0009_20250615_1.ptx
# 2026-04-09 18:12:07 | INFO     | shrub.labeling.sprint3_runner | Using cached Sprint 3 outputs for site=calaveras-big-trees variant=original ptx=CATCU_0009_20250615_1.ptx
# ...

# %%
if not sprint3_results_df.empty:
    summary = (
        sprint3_results_df
        .groupby(["site_id", "variant"], dropna=False)
        .agg(
            n_runs=("input_ptx", "count"),
            n_success=("returncode", lambda s: int((s == 0).sum())),
            n_cached=("used_cache", lambda s: int(pd.Series(s).fillna(False).astype(bool).sum())),
        )
        .reset_index()
    )
    display(summary)
else:
    print("No Sprint 3 runs recorded yet.")
# Out:
#                   site_id   variant  n_runs  n_success  n_cached
# 0     calaveras-big-trees  original       1          1         1
# 1     calaveras-big-trees   revised       1          1         1
# 2                dl-bliss  original       1          1         1
# 3                dl-bliss   revised       1          1         1
# 4       independence-lake  original       1          1         1
# 5       independence-lake   revised       1          1         1
# 6   pacific-union-college  original       1          1         1
# 7   pacific-union-college   revised       1          1         1
# 8                sedgwick  original       1          1         1
# 9                sedgwick   revised       1          1         1
# 10            shaver-lake  original       1          1         0
# 11            shaver-lake   revised       1          1         0

# %% [markdown]
# # Standardize Sprint 3 shrub outputs

# %%
runs_df = (
    pd.read_csv(SPRINT3_MANIFEST_CSV)
    if SPRINT3_MANIFEST_CSV.exists()
    else pd.DataFrame()
)

# keep only successful rows
runs_df = runs_df[runs_df["returncode"] == 0].copy()

objects = standardize_sprint3_manifest(
    runs_df,
    source_version_prefix="sprint3",
    label_variant="base",
    keep_only_valid_runs=True,
)

refined_objects = refine_shrub_objects(objects, cfg)

display(objects.head())
display(summarize_objects(refined_objects))
# Out:
# 2026-04-09 19:59:40 | INFO     | shrub.labeling.sprint3_standardize | Loaded 1 shrub object(s) from /home/jovyan/work/Dry-shRub/shrub/Final/artifacts/labeling/calaveras-big-trees/sprint3/revised/CATCU_0001_20240923_1/Shrubs/CATCU_0001_20240923_1.csv
# 2026-04-09 19:59:40 | INFO     | shrub.labeling.sprint3_standardize | Loaded 40 shrub object(s) from /home/jovyan/work/Dry-shRub/shrub/Final/artifacts/labeling/calaveras-big-trees/sprint3/original/CATCU_0008_20250615_1/Shrubs/CATCU_0008_20250615_1.csv
# 2026-04-09 19:59:40 | INFO     | shrub.labeling.sprint3_standardize | Loaded 10 shrub object(s) from /home/jovyan/work/Dry-shRub/shrub/Final/artifacts/labeling/calaveras-big-trees/sprint3/revised/CATCU_0008_20250615_1/Shrubs/CATCU_0008_20250615_1.csv
# ...

# %% [markdown]
# # Run Sprint 4

# %%
SPRINT4_FORCE_RERUN = False
SPRINT4_MANIFEST_CSV = cfg.output.labeling_root / "manifests" / "sprint4_artifacts.csv"
SPRINT4_SITE_CACHE_ROOT = cfg.output.labeling_root / "site_cache"

SPRINT4_MANIFEST_CSV.parent.mkdir(parents=True, exist_ok=True)
SPRINT4_SITE_CACHE_ROOT.mkdir(parents=True, exist_ok=True)

# %%
def build_als_metadata_for_site(site: str, temp_dir: Path) -> list[dict]:
    als_url = f"{site_to_remote_base(cfg, site)}/{cfg.data.als_dir}"
    als_files = list_files_with_suffix(als_url, (".laz", ".las", ".copc.laz"))
    
    if not als_files:
        raise RuntimeError(f"No ALS files found for site '{site}' at {als_url}")

    logger.info("Downloading %d ALS file(s) for site=%s", len(als_files), site)

    records = []
    for entry in als_files:
        local_path = temp_dir / "als" / entry["name"]
        download_file(entry["url"], local_path)
        meta = extract_als_metadata(local_path)
        meta["source_file"] = entry["name"]
        records.append(meta)

    logger.info("Built ALS metadata records for site=%s", site)
    return records

# %%
def _site_cache_root(site: str) -> Path:
    root = SPRINT4_SITE_CACHE_ROOT / site
    root.mkdir(parents=True, exist_ok=True)
    return root


def _site_transform_cache_root(site: str) -> Path:
    root = _site_cache_root(site) / "transforms"
    root.mkdir(parents=True, exist_ok=True)
    return root


def _site_transform_index_path(site: str) -> Path:
    return _site_transform_cache_root(site) / "transform_index.json"


def _site_naip_cache_root(site: str) -> Path:
    root = _site_cache_root(site) / "naip"
    root.mkdir(parents=True, exist_ok=True)
    return root


def _site_als_cache_root(site: str) -> Path:
    root = _site_cache_root(site) / "als_metadata"
    root.mkdir(parents=True, exist_ok=True)
    return root


def validate_cached_naip(naip_path: Path) -> bool:
    """
    Open the cached TIFF and read a tiny window to ensure it is not corrupt.
    """
    try:
        with rasterio.open(naip_path) as src:
            h = max(1, min(16, src.height))
            w = max(1, min(16, src.width))
            src.read([1], window=Window(0, 0, w, h))
        return True
    except Exception as e:
        logger.warning("Cached NAIP validation failed for %s: %s", naip_path, e)
        return False


def artifact_paths_for_plot(site: str, plot_id: str, source_version: str) -> dict:
    sv = str(source_version)

    masks_dir = cfg.output.labeling_root / "masks" / site / sv
    conf_dir = cfg.output.labeling_root / "confidence" / site / sv
    objid_dir = cfg.output.labeling_root / "object_id" / site / sv
    objects_dir = cfg.output.labeling_root / "objects" / site / sv
    qa_dir = cfg.output.labeling_root / "qa" / site / sv

    for d in [masks_dir, conf_dir, objid_dir, objects_dir, qa_dir]:
        d.mkdir(parents=True, exist_ok=True)

    return {
        "binary_path": masks_dir / f"{plot_id}_mask.tif",
        "confidence_path": conf_dir / f"{plot_id}_confidence.tif",
        "object_id_path": objid_dir / f"{plot_id}_object_id.tif",
        "object_table_path": objects_dir / f"{plot_id}_objects.csv",
        "qa_path": qa_dir / f"{plot_id}_overlay.png",
        "masks_dir": masks_dir,
        "conf_dir": conf_dir,
    }


def has_successful_sprint4_outputs(site: str, plot_id: str, source_version: str) -> bool:
    paths = artifact_paths_for_plot(site, plot_id, source_version)

    required = [
        paths["binary_path"],
        paths["confidence_path"],
        paths["object_id_path"],
        paths["object_table_path"],
        paths["qa_path"],
    ]
    if not all(p.exists() for p in required):
        return False

    for res in cfg.raster.create_multires:
        if float(res) == 1.0:
            continue
        multires_binary = paths["masks_dir"] / f"{plot_id}_mask_{res:g}m.tif"
        multires_conf = paths["conf_dir"] / f"{plot_id}_confidence_{res:g}m.tif"
        if not multires_binary.exists() or not multires_conf.exists():
            return False

    return True


def build_artifact_rows_from_disk(
    *,
    site: str,
    plot_id: str,
    source_version: str,
    objects_df: pd.DataFrame,
) -> pd.DataFrame:
    paths = artifact_paths_for_plot(site, plot_id, source_version)

    date_token = objects_df["ptx_date_token"].iloc[0] if "ptx_date_token" in objects_df.columns and len(objects_df) else None
    variant = objects_df["variant"].iloc[0] if "variant" in objects_df.columns and len(objects_df) else None
    plot_key = extract_plot_key(plot_id)

    rows = []
    for res in cfg.raster.create_multires:
        if float(res) == 1.0:
            multires_binary_path = paths["binary_path"]
            multires_conf_path = paths["confidence_path"]
        else:
            multires_binary_path = paths["masks_dir"] / f"{plot_id}_mask_{res:g}m.tif"
            multires_conf_path = paths["conf_dir"] / f"{plot_id}_confidence_{res:g}m.tif"

        rows.append(
            {
                "site_id": site,
                "plot_id": plot_id,
                "plot_key": plot_key,
                "variant": variant,
                "label_variant": "base",
                "resolution_m": float(res),
                "binary_mask_path": str(multires_binary_path),
                "confidence_mask_path": str(multires_conf_path),
                "object_id_raster_path": str(paths["object_id_path"]),
                "object_table_path": str(paths["object_table_path"]),
                "qa_overlay_path": str(paths["qa_path"]),
                "n_objects": int(len(objects_df)),
                "n_valid_objects": int(objects_df["valid_object"].sum()),
                "date_token": date_token,
                "source_version": source_version,
            }
        )

    return pd.DataFrame(rows)


def append_sprint4_artifacts_manifest(manifest_csv: Path, new_artifacts_df: pd.DataFrame) -> pd.DataFrame:
    manifest_csv = Path(manifest_csv)
    manifest_csv.parent.mkdir(parents=True, exist_ok=True)

    if manifest_csv.exists():
        old_df = pd.read_csv(manifest_csv)
        combined = pd.concat([old_df, new_artifacts_df], ignore_index=True)
    else:
        combined = new_artifacts_df.copy()

    dedup_subset = ["site_id", "plot_id", "source_version", "resolution_m", "label_variant"]
    combined = combined.drop_duplicates(subset=dedup_subset, keep="last")
    combined.to_csv(manifest_csv, index=False)
    return combined


def prepare_site_assets(site: str, force_refresh: bool = False):
    """
    Cache:
    - NAIP raster per site, with integrity validation
    - ALS metadata per site

    Bulky ALS downloads are temporary only.
    """
    site_base = site_to_remote_base(cfg, site)

    # ---------- NAIP cache ----------
    naip_name = site_to_tif_name(site)
    naip_local = _site_naip_cache_root(site) / naip_name
    naip_url = f"{site_base}/{cfg.data.naip_3dep_dir}/{naip_name}"

    use_cached_naip = False
    if (not force_refresh) and naip_local.exists():
        if validate_cached_naip(naip_local):
            logger.info("Using cached NAIP for site=%s: %s", site, naip_local)
            use_cached_naip = True
        else:
            logger.warning("Deleting corrupt cached NAIP for site=%s: %s", site, naip_local)
            naip_local.unlink(missing_ok=True)

    if not use_cached_naip:
        logger.info("Downloading NAIP for site=%s to %s", site, naip_local)
        download_file(naip_url, naip_local)
        if not validate_cached_naip(naip_local):
            raise RuntimeError(f"Downloaded NAIP for site={site} is still unreadable: {naip_local}")

    # ---------- ALS metadata cache ----------
    als_cache_dir = _site_als_cache_root(site)
    als_meta_json = als_cache_dir / "als_metadata.json"

    if (not force_refresh) and als_meta_json.exists():
        logger.info("Using cached ALS metadata for site=%s: %s", site, als_meta_json)
        als_meta = json.loads(als_meta_json.read_text(encoding="utf-8"))
    else:
        als_url = f"{site_base}/{cfg.data.als_dir}"
        als_files = list_files_with_suffix(als_url, (".laz", ".las", ".copc.laz"))
        if not als_files:
            raise RuntimeError(f"No ALS files found for site '{site}' at {als_url}")

        logger.info("Downloading %d ALS file(s) for site=%s to extract metadata", len(als_files), site)

        records = []
        scratch_dir = Path(tempfile.mkdtemp(prefix=f"sprint4_als_{site}_"))
        try:
            for entry in als_files:
                local_path = scratch_dir / entry["name"]
                download_file(entry["url"], local_path)
                meta = extract_als_metadata(local_path)
                meta["source_file"] = entry["name"]
                records.append(meta)

                try:
                    local_path.unlink(missing_ok=True)
                    logger.info("Deleted temporary ALS file after metadata extraction: %s", local_path)
                except Exception as e:
                    logger.warning("Failed to delete temporary ALS file %s: %s", local_path, e)
        finally:
            cleanup_path(scratch_dir)

        als_meta_json.write_text(json.dumps(records, indent=2), encoding="utf-8")
        als_meta = records
        logger.info("Cached ALS metadata for site=%s at %s", site, als_meta_json)

    return naip_local, als_meta


def get_site_transform_index(site: str, force_refresh: bool = False) -> dict:
    """
    Cache a listing of available remote transform files for the site.
    """
    index_path = _site_transform_index_path(site)

    if (not force_refresh) and index_path.exists():
        logger.info("Using cached transform index for site=%s: %s", site, index_path)
        return json.loads(index_path.read_text(encoding="utf-8"))

    remote_dir = f"{site_to_remote_base(cfg, site)}/{cfg.data.transformations_dir}"
    entries = list_files_with_suffix(remote_dir, (".txt",))
    index = {entry["name"]: entry["url"] for entry in entries}
    index_path.write_text(json.dumps(index, indent=2), encoding="utf-8")
    logger.info("Cached transform index for site=%s with %d entries", site, len(index))
    return index


def get_transform_local_cached(site: str, plot_id: str, force_refresh: bool = False) -> Path:
    transform_name = shrub_csv_to_transform_name(f"{plot_id}.csv")
    transform_local = _site_transform_cache_root(site) / transform_name

    if (not force_refresh) and transform_local.exists():
        logger.info("Using cached transform for site=%s plot_id=%s", site, plot_id)
        return transform_local

    transform_index = get_site_transform_index(site, force_refresh=force_refresh)

    # exact match first
    if transform_name in transform_index:
        transform_url = transform_index[transform_name]
        logger.info("Downloading exact-match transform for site=%s plot_id=%s from %s", site, plot_id, transform_url)
        download_file(transform_url, transform_local)
        return transform_local

    # fallback: any transform starting with plot_id and ending with toALS.txt
    fallback_names = sorted(
        name for name in transform_index
        if name.startswith(plot_id) and name.endswith("toALS.txt")
    )
    if fallback_names:
        chosen = fallback_names[0]
        transform_url = transform_index[chosen]
        logger.warning(
            "Exact transform missing for site=%s plot_id=%s; using fallback transform %s",
            site, plot_id, chosen
        )
        download_file(transform_url, transform_local)
        return transform_local

    raise FileNotFoundError(
        f"No transform file found for site={site}, plot_id={plot_id}. "
        f"Expected exact name {transform_name} or fallback starting with {plot_id}."
    )


def process_one_object_group_to_labels(
    *,
    site,
    plot_id,
    source_version,
    objects_group,
    naip_path,
    als_meta,
    force_rerun=False,
):
    logger.info(
        "Processing Sprint 4 transfer | site=%s | plot_id=%s | source_version=%s | n_objects=%d",
        site, plot_id, source_version, len(objects_group)
    )

    if (not force_rerun) and has_successful_sprint4_outputs(site, plot_id, source_version):
        logger.info(
            "Using cached Sprint 4 outputs | site=%s | plot_id=%s | source_version=%s",
            site, plot_id, source_version
        )
        paths = artifact_paths_for_plot(site, plot_id, source_version)
        cached_objects = pd.read_csv(paths["object_table_path"])
        cached_artifacts = build_artifact_rows_from_disk(
            site=site,
            plot_id=plot_id,
            source_version=source_version,
            objects_df=cached_objects,
        )
        return cached_objects, cached_artifacts

    transform_local = get_transform_local_cached(site, plot_id, force_refresh=force_rerun)

    objects = objects_group.copy()
    objects, tile = transform_objects_to_als(objects, transform_local, als_meta)

    tile_wkt = tile.get("srs_wkt")
    if not tile_wkt:
        raise ValueError(f"ALS tile {tile.get('source_file')} is missing CRS/WKT metadata.")

    objects, grid = align_objects_to_naip(objects, naip_path, tile_wkt, cfg)
    binary, confidence, object_id = rasterize_objects(objects, grid, cfg)

    paths = artifact_paths_for_plot(site, plot_id, source_version)

    write_single_band_geotiff(paths["binary_path"], binary, grid, dtype="uint8", nodata=cfg.raster.background_value)
    write_single_band_geotiff(paths["confidence_path"], confidence, grid, dtype="float32", nodata=cfg.raster.confidence_background)
    write_single_band_geotiff(paths["object_id_path"], object_id, grid, dtype="int32", nodata=0)
    export_table(objects, paths["object_table_path"])

    # QA overlay is useful but non-essential; don't fail the whole plot because of it
    try:
        create_overlay_figure(naip_path, paths["binary_path"], paths["qa_path"])
    except Exception as e:
        logger.warning(
            "QA overlay failed for site=%s plot_id=%s source_version=%s: %s",
            site, plot_id, source_version, e
        )

    for res in cfg.raster.create_multires:
        if float(res) == 1.0:
            continue

        b_res, b_grid = resample_single_band(binary, grid, res)
        c_res, c_grid = resample_single_band(confidence, grid, res)

        multires_binary_path = paths["masks_dir"] / f"{plot_id}_mask_{res:g}m.tif"
        multires_conf_path = paths["conf_dir"] / f"{plot_id}_confidence_{res:g}m.tif"

        write_single_band_geotiff(multires_binary_path, b_res, b_grid, dtype="uint8", nodata=cfg.raster.background_value)
        write_single_band_geotiff(multires_conf_path, c_res, c_grid, dtype="float32", nodata=cfg.raster.confidence_background)

    artifacts_df = build_artifact_rows_from_disk(
        site=site,
        plot_id=plot_id,
        source_version=source_version,
        objects_df=objects,
    )

    logger.info(
        "Finished Sprint 4 transfer | site=%s | plot_id=%s | source_version=%s",
        site, plot_id, source_version
    )
    return objects, artifacts_df

# %%
def site_has_pending_sprint4_work(site: str, site_objects: pd.DataFrame) -> bool:
    grouped = site_objects.groupby(["plot_id", "source_version"], dropna=False)
    for (plot_id, source_version), _ in grouped:
        if not has_successful_sprint4_outputs(site, plot_id, source_version):
            return True
    return False


all_site_objects = []
all_site_artifacts = []

for site in cfg.sites:
    logger.info("=" * 100)
    logger.info("Processing full Sprint 4 site loop for site=%s", site)

    site_objects = refined_objects[refined_objects["site_id"] == site].copy()
    if site_objects.empty:
        logger.info("No Sprint 4 objects available for site=%s; skipping.", site)
        continue

    if not SPRINT4_FORCE_RERUN and not site_has_pending_sprint4_work(site, site_objects):
        logger.info("All Sprint 4 outputs already cached for site=%s; skipping site asset prep.", site)

        grouped = site_objects.groupby(["site_id", "plot_id", "source_version"], dropna=False)
        for (_, plot_id, source_version), group_df in grouped:
            cached_objects, cached_artifacts = process_one_object_group_to_labels(
                site=site,
                plot_id=plot_id,
                source_version=source_version,
                objects_group=group_df,
                naip_path=None,   # won't be used due to cache hit
                als_meta=None,    # won't be used due to cache hit
                force_rerun=False,
            )
            all_site_objects.append(cached_objects)
            all_site_artifacts.append(cached_artifacts)
            append_sprint4_artifacts_manifest(SPRINT4_MANIFEST_CSV, cached_artifacts)
        continue

    try:
        naip_local, als_meta = prepare_site_assets(site, force_refresh=False)

        grouped = site_objects.groupby(["site_id", "plot_id", "source_version"], dropna=False)
        for (_, plot_id, source_version), group_df in grouped:
            try:
                objects_df, artifacts_df = process_one_object_group_to_labels(
                    site=site,
                    plot_id=plot_id,
                    source_version=source_version,
                    objects_group=group_df,
                    naip_path=naip_local,
                    als_meta=als_meta,
                    force_rerun=SPRINT4_FORCE_RERUN,
                )
                all_site_objects.append(objects_df)
                all_site_artifacts.append(artifacts_df)
                append_sprint4_artifacts_manifest(SPRINT4_MANIFEST_CSV, artifacts_df)
            except Exception:
                logger.exception(
                    "Sprint 4 failed | site=%s | plot_id=%s | source_version=%s",
                    site, plot_id, source_version
                )
                continue
    finally:
        # nothing bulky to clean anymore except optional future temp scratch
        pass

if len(all_site_objects) > 0:
    objects_all = pd.concat(all_site_objects, ignore_index=True)
else:
    objects_all = pd.DataFrame()

if len(all_site_artifacts) > 0:
    artifacts_all = pd.concat(all_site_artifacts, ignore_index=True)
else:
    artifacts_all = pd.DataFrame()

artifacts_all = deduplicate_artifact_table(artifacts_all)

print("All objects:", len(objects_all))
print("All artifact rows:", len(artifacts_all))

summary_dir = cfg.output.labeling_root / "summaries"
summary_dir.mkdir(parents=True, exist_ok=True)

objects_all.to_csv(summary_dir / "objects_all.csv", index=False)
artifacts_all.to_csv(summary_dir / "artifacts_all.csv", index=False)

print("Saved:")
print(summary_dir / "objects_all.csv")
print(summary_dir / "artifacts_all.csv")
print(SPRINT4_MANIFEST_CSV)
# Out:
# 2026-04-09 22:46:53 | INFO     | shrub | ====================================================================================================
# 2026-04-09 22:46:53 | INFO     | shrub | Processing full Sprint 4 site loop for site=calaveras-big-trees
# 2026-04-09 22:46:55 | INFO     | shrub | All Sprint 4 outputs already cached for site=calaveras-big-trees; skipping site asset prep.
# 2026-04-09 22:46:55 | INFO     | shrub | Processing Sprint 4 transfer | site=calaveras-big-trees | plot_id=CATCU_0001_20240923_1 | source_version=sprint3_revised | n_objects=1
# 2026-04-09 22:46:55 | INFO     | shrub | Using cached Sprint 4 outputs | site=calaveras-big-trees | plot_id=CATCU_0001_20240923_1 | source_version=sprint3_revised
# 2026-04-09 22:46:56 | INFO     | shrub | Processing Sprint 4 transfer | site=calaveras-big-trees | plot_id=CATCU_0008_20250615_1 | source_version=sprint3_original | n_objects=40
# ...
